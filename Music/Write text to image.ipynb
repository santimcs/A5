# %%
from PIL import Image, ImageDraw, ImageFont

# Use a TrueType font with a larger size
font = ImageFont.truetype("arial.ttf", 160)

# Load your image
image_path = "Folder.png"  # Change if needed
img = Image.open(image_path)

# Create a drawing context
draw = ImageDraw.Draw(img)

# Define text
song_title  = "Time of Our Lives"
artist_name = "Zho Lei"

# Choose font and color
font = ImageFont.truetype("arial.ttf", 40)
text_color = (255, 255, 255)  # white
# text_color = (0, 0, 0)  # black

# Get image dimensions
width, height = img.size

# Position for middle right
x_position = int(width * 0.40)
y_position = int(height * 0.70)

# Draw shadow for readability
shadow_offset = 2
# draw.text((x_position + shadow_offset, y_position + shadow_offset), song_title, font=font, fill=(0, 0, 0))
draw.text((x_position, y_position), song_title, font=font, fill=text_color)
# draw.text((x_position + shadow_offset, y_position + 20 + shadow_offset), artist_name, font=font, fill=(0, 0, 0))
draw.text((x_position, y_position + 40), artist_name, font=font, fill=text_color)


# Save result
img.save("Folder.jpg")
print("Saved as Folder.jpg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\PIL\JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 38
#      34 draw.text((x_position, y_position + 40), artist_name, font=font, fill=text_color)
#      37 # Save result
# ---> 38 img.save("Folder.jpg")
#      39 print("Saved as Folder.jpg")
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2568, in Image.save(self, fp, format, **params)
#    2565     fp = cast(IO[bytes], fp)
#    2567 try:
# -> 2568     save_handler(self, fp, filename)
#    2569 except Exception:
#    2570     if open_fp:
#
# ...
