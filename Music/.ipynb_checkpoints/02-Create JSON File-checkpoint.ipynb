# %%
import os
import json
import datetime
from pathlib import Path

def scan_mp4_files(folder_path):
    """Scan folder for MP4 files and return sorted list"""
    mp4_files = []
    
    try:
        for file in os.listdir(folder_path):
            if file.lower().endswith('.mp4'):
                mp4_files.append(file)
        
        # Sort alphabetically
        mp4_files.sort()
        
    except Exception as e:
        print(f"Error scanning folder: {e}")
    
    return mp4_files

def generate_songs_json(mp4_files, output_file='songs.json'):
    """Generate JSON file with MP4 file list"""
    
    data = {
        "generated_at": datetime.datetime.now().isoformat(),
        "total_songs": len(mp4_files),
        "songs": mp4_files
    }
    
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2, ensure_ascii=False)
        
        print(f"✅ Successfully generated {output_file}")
        print(f"📊 Total songs: {len(mp4_files)}")
        print(f"🕒 Generated at: {data['generated_at']}")
        
        return True
        
    except Exception as e:
        print(f"❌ Error generating JSON file: {e}")
        return False

def analyze_filenames(mp4_files):
    """Analyze MP4 filenames and extract song/artist information"""
    
    print("\n🎵 Filename Analysis:")
    
    for filename in mp4_files:
        # Remove .mp4 extension
        name_without_ext = filename[:-4]
        
        # Try to split by underscore
        if '_' in name_without_ext:
            parts = name_without_ext.split('_')
            song_title = parts[0].strip()
            artist = ' '.join(parts[1:]).strip()
            print(f"   🎶 '{song_title}' by {artist}")
        else:
            print(f"   📁 {name_without_ext} (no artist)")

def generate_upload_checklist(mp4_files, lyrics_folder):
    """Generate a checklist of files to upload to AWS"""
    
    print("\n📋 Upload Checklist for AWS:")
    print("=" * 50)
    
    # Core app files
    core_files = ['index.html', 'style.css', 'script.js', 'songs.json']
    
    print("\n🚀 Core App Files:")
    for file in core_files:
        if os.path.exists(file):
            print(f"   ✅ {file}")
        else:
            print(f"   ❌ {file} (MISSING)")
    
    print(f"\n🎵 MP4 Files to Upload ({len(mp4_files)} files):")
    for i, mp4_file in enumerate(mp4_files, 1):
        file_path = os.path.join(lyrics_folder, mp4_file)
        if os.path.exists(file_path):
            file_size = os.path.getsize(file_path) / (1024 * 1024)  # Size in MB
            print(f"   ✅ {i:2d}. {mp4_file} ({file_size:.1f} MB)")
        else:
            print(f"   ❌ {i:2d}. {mp4_file} (FILE NOT FOUND)")
    
    print("\n💡 Upload all checked files to your AWS Lyrics folder")

def quick_refresh(lyrics_folder):
    """Quick refresh - scan and update songs.json"""
    print("🔄 Refreshing song list...")
    
    mp4_files = scan_mp4_files(lyrics_folder)
    print(f"📊 Found {len(mp4_files)} MP4 files")
    
    if generate_songs_json(mp4_files):
        print("✅ Refresh complete!")
    else:
        print("❌ Refresh failed!")
    
    return mp4_files

def main():
    """Main function to run the MP4 file scanner"""
    
    # Set your Lyrics folder path - CHANGE THIS TO YOUR MP4 FOLDER
    LYRICS_FOLDER = r"C:\Users\PC1\OneDrive\A5\Data\Videos\AWS"   #chgfld  
    
    print(f"🎵 MP4 File Scanner")
    print(f"📁 Scanning folder: {LYRICS_FOLDER}")
    print("=" * 50)
    
    # Scan for MP4 files
    mp4_files = scan_mp4_files(LYRICS_FOLDER)
    
    if not mp4_files:
        print("❌ No MP4 files found in the specified folder.")
        return
    
    print(f"\n✅ Found {len(mp4_files)} MP4 files:")
    for i, file in enumerate(mp4_files, 1):
        print(f"   {i:2d}. {file}")
    
    # Generate songs.json
    generate_songs_json(mp4_files)
    
    # Analyze filenames
    analyze_filenames(mp4_files)
    
    # Generate upload checklist
    generate_upload_checklist(mp4_files, LYRICS_FOLDER)
    
    print("\n" + "=" * 50)
    print("🎉 Script completed successfully!")

if __name__ == "__main__":
    main()
# Out:
# 🎵 MP4 File Scanner
# 📁 Scanning folder: C:\Users\PC1\OneDrive\A5\Data\Videos\AWS
# ==================================================
#
# ✅ Found 103 MP4 files:
#     1. (Everything I Do) I Do It For You_Bryan Adams.mp4
#     2. A Change Is Gonna Come_Sam Cooke.mp4
#     3. A Day in the Life_Beatles The.mp4
#     4. Against the Wind_Bob Seger.mp4
#     5. All Too Well_Taylor Swift.mp4
#     6. All of Me_John Legend.mp4
#     7. Always Remember Us This Way_Lady Gaga.mp4
#     8. Angel_Sarah McLachlan.mp4
#     9. Bad Guy_Billie Eilish.mp4
#    10. Because You Loved Me_Anonymous Singer.mp4
#    11. Bleeding Love_Leona Lewis.mp4
#    12. Blowin' in the Wind_Bob Dylan.mp4
#    13. Bohemian Rhapsody_Queen .mp4
#    14. Candle in the Wind_Elton John.mp4
#    15. Careless Whisper_George Michael.mp4
#    16. Chan Fu_Ma Jiantao.mp4
#    17. Cold Heart_Elton John.mp4
#    18. Comfortably Numb_Roger Waters.mp4
#    19. Dancing Queen_Abba .mp4
#    20. Desperado_Eagles The.mp4
#    21. Don't Stop Believin'_Journey .mp4
#    22. Dreams_Fleetwood Mac .mp4
#    23. Dust in the Wind_Kansas .mp4
#    24. End Of The Road_Boyz II Men .mp4
#    25. Eternal Flame_The Bangles.mp4
#    26. Every Breath You Take_Police The.mp4
#    27. Faded_Alan Walker.mp4
#    28. Family Affair_Mary J.Blige.mp4
#    29. Fast Car_Tracy Chapman.mp4
#    30. Fire and Rain_James Taylor.mp4
#    31. Flowers_Miley Cyrus.mp4
#    32. Forever Young_UNDRESSD .mp4
#    33. Girl on Fire_Alicia Keys.mp4
#    34. Girls Just Want To Have Fun_Cyndi Lauper.mp4
#    35. Hallelujah_Jeff Buckley.mp4
#    36. Here Comes The Sun_Beatles The.mp4
#    37. Hey Jude_Beatles The.mp4
#    38. Home_Michael Buble.mp4
#    39. Hotel California_Eagles The.mp4
#    40. How Do I Live_LeAnn Rimes.mp4
#    41. I Hate Myself for Loving You_Joan Jett and the Blackhearts .mp4
#    42. I Love You_Vanny Vabiola.mp4
#    43. I Will Always Love You_Whitney Houston.mp4
#    44. I'd Rather Go Blind_Etta James.mp4
#    45. I'll Be Missing You_Puff Daddy & Faith Evans .mp4
#    46. Imagine_John Lennon.mp4
#    47. Just Give Me A Reason_P!nk .mp4
#    48. Knockin’ on Heaven’s Door_Bob Dylan.mp4
#    49. Let Her Go_Passenger .mp4
#    50. Let Her Go_Passenger.mp4
#    51. Life for Rent_Dido .mp4
#    52. Like a Rolling Stone_Bob Dylan.mp4
