# %% [markdown]
# ### portmy database: stocks table
# ### stock database: buy, price tables

# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
conmy = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

pd.set_option('display.float_format','{:,.2f}'.format)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2023, 12, 31)

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(2)
yesterday = today - num_business_days
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-12-31
# yesterday: 2023-12-28 00:00:00

# %%
yesterday = yesterday.date()
week_ago = yesterday -timedelta(days = 8)
print(f'a week ago: {week_ago}')
print(f'yesterday: {yesterday}')
# Out:
# a week ago: 2023-12-20
# yesterday: 2023-12-28

# %% [markdown]
# ### Restart & Run All Cells

# %% [markdown]
# ### This process affects only already in port stocks. To highlight price changes in percent.

# %%
cols = 'name price_w price_d percent perform mrkt '.split()

format_dict = {
    'qty':'{:,}',    
    'price':'{:.2f}','price_d':'{:.2f}','price_w':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'maxp':'{:.2f}','minp':'{:.2f}','opnp':'{:.2f}',    
    'pct':'{:,.2f}%','percent':'{:,.2f}%',
    
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}',
    'daily_volume':'{:,.2f}','beta':'{:,.2f}', 
    'dly_vol':'{:,.2f}', 
}

# %%
sql = """
SELECT name, date, price 
FROM buy 
ORDER BY date DESC 
LIMIT 1
"""
df_buy = pd.read_sql(sql, const)
df_buy.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4efba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4efba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4efba_row0_col0" class="data row0 col0" >TOA</td>
#       <td id="T_4efba_row0_col1" class="data row0 col1" >2023-09-06</td>
#       <td id="T_4efba_row0_col2" class="data row0 col2" >26.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = df_buy['name']
name = names.to_string(index=False)

sql = '''
SELECT * FROM stocks WHERE name = '%s'
'''
sql = sql % name
print(sql)

df_stocks = pd.read_sql(sql, conmy)
df_stocks.style.format(format_dict)
# Out:
# SELECT * FROM stocks WHERE name = 'TOA'
# <style type="text/css">
# </style>
# <table id="T_640c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >market</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >min_price</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >paid_up</th>
#       <th class="col_heading level0 col9" >market_cap</th>
#       <th class="col_heading level0 col10" >daily_volume</th>
#       <th class="col_heading level0 col11" >beta</th>
#       <th class="col_heading level0 col12" >ticker_id</th>
#       <th class="col_heading level0 col13" >created_at</th>
#       <th class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_640c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_640c5_row0_col0" class="data row0 col0" >643</td>
#       <td id="T_640c5_row0_col1" class="data row0 col1" >TOA</td>
#       <td id="T_640c5_row0_col2" class="data row0 col2" >SETTHSI    </td>
#       <td id="T_640c5_row0_col3" class="data row0 col3" >33.50</td>
#       <td id="T_640c5_row0_col4" class="data row0 col4" >36.50</td>
#       <td id="T_640c5_row0_col5" class="data row0 col5" >25.00</td>
#       <td id="T_640c5_row0_col6" class="data row0 col6" >42.37</td>
#       <td id="T_640c5_row0_col7" class="data row0 col7" >5.38</td>
#       <td id="T_640c5_row0_col8" class="data row0 col8" >2,029.00</td>
#       <td id="T_640c5_row0_col9" class="data row0 col9" >67,971.50</td>
#       <td id="T_640c5_row0_col10" class="data row0 col10" >117.78</td>
#       <td id="T_640c5_row0_col11" class="data row0 col11" >0.81</td>
#       <td id="T_640c5_row0_col12" class="data row0 col12" >645</td>
#       <td id="T_640c5_row0_col13" class="data row0 col13" >2017-10-13 05:51:19.667793</td>
#       <td id="T_640c5_row0_col14" class="data row0 col14" >2023-01-31 03:08:01.315353</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = '''
SELECT * FROM price WHERE name = "%s" ORDER BY date DESC LIMIT 5
'''
sql = sql % name
print(sql)

df_price = pd.read_sql(sql, const)
df_price.style.format(format_dict)
# Out:
# SELECT * FROM price WHERE name = "TOA" ORDER BY date DESC LIMIT 5
# <style type="text/css">
# </style>
# <table id="T_23224_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23224_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23224_row0_col0" class="data row0 col0" >TOA</td>
#       <td id="T_23224_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_23224_row0_col2" class="data row0 col2" >22.60</td>
#       <td id="T_23224_row0_col3" class="data row0 col3" >22.70</td>
#       <td id="T_23224_row0_col4" class="data row0 col4" >22.50</td>
#       <td id="T_23224_row0_col5" class="data row0 col5" >726,123</td>
#       <td id="T_23224_row0_col6" class="data row0 col6" >22.60</td>
#     </tr>
#     <tr>
#       <th id="T_23224_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23224_row1_col0" class="data row1 col0" >TOA</td>
#       <td id="T_23224_row1_col1" class="data row1 col1" >2023-12-27</td>
#       <td id="T_23224_row1_col2" class="data row1 col2" >22.60</td>
#       <td id="T_23224_row1_col3" class="data row1 col3" >22.70</td>
#       <td id="T_23224_row1_col4" class="data row1 col4" >22.50</td>
#       <td id="T_23224_row1_col5" class="data row1 col5" >440,505</td>
#       <td id="T_23224_row1_col6" class="data row1 col6" >22.60</td>
#     </tr>
#     <tr>
#       <th id="T_23224_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23224_row2_col0" class="data row2 col0" >TOA</td>
#       <td id="T_23224_row2_col1" class="data row2 col1" >2023-12-26</td>
#       <td id="T_23224_row2_col2" class="data row2 col2" >22.80</td>
#       <td id="T_23224_row2_col3" class="data row2 col3" >22.80</td>
#       <td id="T_23224_row2_col4" class="data row2 col4" >22.60</td>
#       <td id="T_23224_row2_col5" class="data row2 col5" >313,711</td>
#       <td id="T_23224_row2_col6" class="data row2 col6" >22.70</td>
#     </tr>
#     <tr>
#       <th id="T_23224_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23224_row3_col0" class="data row3 col0" >TOA</td>
#       <td id="T_23224_row3_col1" class="data row3 col1" >2023-12-25</td>
#       <td id="T_23224_row3_col2" class="data row3 col2" >22.80</td>
#       <td id="T_23224_row3_col3" class="data row3 col3" >23.00</td>
#       <td id="T_23224_row3_col4" class="data row3 col4" >22.50</td>
#       <td id="T_23224_row3_col5" class="data row3 col5" >474,891</td>
#       <td id="T_23224_row3_col6" class="data row3 col6" >22.90</td>
#     </tr>
#     <tr>
#       <th id="T_23224_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23224_row4_col0" class="data row4 col0" >TOA</td>
#       <td id="T_23224_row4_col1" class="data row4 col1" >2023-12-22</td>
#       <td id="T_23224_row4_col2" class="data row4 col2" >22.70</td>
#       <td id="T_23224_row4_col3" class="data row4 col3" >22.80</td>
#       <td id="T_23224_row4_col4" class="data row4 col4" >22.30</td>
#       <td id="T_23224_row4_col5" class="data row4 col5" >633,156</td>
#       <td id="T_23224_row4_col6" class="data row4 col6" >22.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = '''
SELECT name
FROM buy 
WHERE active = 1
ORDER BY name'''
df_price = pd.read_sql(sql, const)

names = df_price.name.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))

sql = """
SELECT name, price AS price_d 
FROM price 
WHERE date = '%s' AND name IN (%s)
ORDER BY name, date"""
sql = sql % (yesterday, in_p)
print(sql)

df_today = pd.read_sql(sql, const)
df_today.shape[0]
# Out:
# SELECT name, price AS price_d
# FROM price
# WHERE date = '2023-12-28' AND name IN ('AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'TOA', 'WHAIR', 'WHART')
# ORDER BY name, date
# 30

# %%
sql = """
SELECT name, price AS price_w
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (week_ago, in_p)
print(sql)

df_wkago = pd.read_sql(sql, const)
df_wkago.shape[0]
# Out:
# SELECT name, price AS price_w
# FROM price
# WHERE date = '2023-12-20' AND name IN ('AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'TOA', 'WHAIR', 'WHART')
# ORDER BY name
# 30

# %%
trend = pd.merge(df_today, df_wkago, on='name',how='inner')
trend.shape
# Out:
# (30, 3)

# %%
def performance(vals):
    price_d, price_w = vals
    if (price_d > price_w):
        return 'Better'
    elif (price_d < price_w):
        return 'Worse'
    else:
        return 'No Change'

# %%
trend['percent'] = (trend.price_d-trend.price_w)/trend.price_w * 100

# %%
trend
# Out:
#        name  price_d  price_w  percent
# 0        AH    28.00    27.00     3.70
# 1    AIMIRT    10.40    10.40     0.00
# 2       ASK    19.90    19.70     1.02
# 3       ASP     2.84     2.80     1.43
# 4       AWC     3.56     3.56     0.00
# 5       BCH    22.40    21.70     3.23
# 6   CPNREIT    11.30    11.10     1.80
# 7       DIF     7.75     7.40     4.73
# 8    GVREIT     5.70     5.60     1.79
# 9       IVL    27.25    27.75    -1.80
# 10    JASIF     6.25     5.85     6.84
# 11    JMART    17.30    17.80    -2.81
# 12      JMT    25.50    26.25    -2.86
# 13      KCE    55.00    55.25    -0.45
# 14      MCS     6.50     6.45     0.78
# 15      NER     4.96     4.64     6.90
# 16      ORI     8.45     8.30     1.81
# 17      PTG     8.75     8.60     1.74
# 18    PTTGC    38.50    40.50    -4.94
# 19      RCL    24.20    22.50     7.56
# 20      SCC   306.00   297.00     3.03
# 21     SENA     2.36     2.34     0.85
# 22   SINGER    11.60    12.00    -3.33
# 23      STA    16.10    14.90     8.05
# 24    SYNEX    10.40     9.90     5.05
# 25    TFFIF     6.55     6.45     1.55
# 26      TMT     6.10     6.15    -0.81
# 27      TOA    22.60    22.50     0.44
# 28    WHAIR     5.50     5.40     1.85
# 29    WHART    10.30     9.70     6.19

# %%
trend["perform"] = trend[["price_d","price_w"]].apply(performance, axis=1)

# %%
trend.sort_values(by=['percent'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba8b8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_d</th>
#       <th class="col_heading level0 col2" >price_w</th>
#       <th class="col_heading level0 col3" >percent</th>
#       <th class="col_heading level0 col4" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba8b8_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_ba8b8_row0_col0" class="data row0 col0" >PTTGC</td>
#       <td id="T_ba8b8_row0_col1" class="data row0 col1" >38.50</td>
#       <td id="T_ba8b8_row0_col2" class="data row0 col2" >40.50</td>
#       <td id="T_ba8b8_row0_col3" class="data row0 col3" >-4.94%</td>
#       <td id="T_ba8b8_row0_col4" class="data row0 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_ba8b8_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_ba8b8_row1_col1" class="data row1 col1" >11.60</td>
#       <td id="T_ba8b8_row1_col2" class="data row1 col2" >12.00</td>
#       <td id="T_ba8b8_row1_col3" class="data row1 col3" >-3.33%</td>
#       <td id="T_ba8b8_row1_col4" class="data row1 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_ba8b8_row2_col0" class="data row2 col0" >JMT</td>
#       <td id="T_ba8b8_row2_col1" class="data row2 col1" >25.50</td>
#       <td id="T_ba8b8_row2_col2" class="data row2 col2" >26.25</td>
#       <td id="T_ba8b8_row2_col3" class="data row2 col3" >-2.86%</td>
#       <td id="T_ba8b8_row2_col4" class="data row2 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_ba8b8_row3_col0" class="data row3 col0" >JMART</td>
#       <td id="T_ba8b8_row3_col1" class="data row3 col1" >17.30</td>
#       <td id="T_ba8b8_row3_col2" class="data row3 col2" >17.80</td>
#       <td id="T_ba8b8_row3_col3" class="data row3 col3" >-2.81%</td>
#       <td id="T_ba8b8_row3_col4" class="data row3 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_ba8b8_row4_col0" class="data row4 col0" >IVL</td>
#       <td id="T_ba8b8_row4_col1" class="data row4 col1" >27.25</td>
#       <td id="T_ba8b8_row4_col2" class="data row4 col2" >27.75</td>
#       <td id="T_ba8b8_row4_col3" class="data row4 col3" >-1.80%</td>
#       <td id="T_ba8b8_row4_col4" class="data row4 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_ba8b8_row5_col0" class="data row5 col0" >TMT</td>
#       <td id="T_ba8b8_row5_col1" class="data row5 col1" >6.10</td>
#       <td id="T_ba8b8_row5_col2" class="data row5 col2" >6.15</td>
#       <td id="T_ba8b8_row5_col3" class="data row5 col3" >-0.81%</td>
#       <td id="T_ba8b8_row5_col4" class="data row5 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row6" class="row_heading level0 row6" >13</th>
#       <td id="T_ba8b8_row6_col0" class="data row6 col0" >KCE</td>
#       <td id="T_ba8b8_row6_col1" class="data row6 col1" >55.00</td>
#       <td id="T_ba8b8_row6_col2" class="data row6 col2" >55.25</td>
#       <td id="T_ba8b8_row6_col3" class="data row6 col3" >-0.45%</td>
#       <td id="T_ba8b8_row6_col4" class="data row6 col4" >Worse</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_ba8b8_row7_col0" class="data row7 col0" >AIMIRT</td>
#       <td id="T_ba8b8_row7_col1" class="data row7 col1" >10.40</td>
#       <td id="T_ba8b8_row7_col2" class="data row7 col2" >10.40</td>
#       <td id="T_ba8b8_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_ba8b8_row7_col4" class="data row7 col4" >No Change</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_ba8b8_row8_col0" class="data row8 col0" >AWC</td>
#       <td id="T_ba8b8_row8_col1" class="data row8 col1" >3.56</td>
#       <td id="T_ba8b8_row8_col2" class="data row8 col2" >3.56</td>
#       <td id="T_ba8b8_row8_col3" class="data row8 col3" >0.00%</td>
#       <td id="T_ba8b8_row8_col4" class="data row8 col4" >No Change</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_ba8b8_row9_col0" class="data row9 col0" >TOA</td>
#       <td id="T_ba8b8_row9_col1" class="data row9 col1" >22.60</td>
#       <td id="T_ba8b8_row9_col2" class="data row9 col2" >22.50</td>
#       <td id="T_ba8b8_row9_col3" class="data row9 col3" >0.44%</td>
#       <td id="T_ba8b8_row9_col4" class="data row9 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row10" class="row_heading level0 row10" >14</th>
#       <td id="T_ba8b8_row10_col0" class="data row10 col0" >MCS</td>
#       <td id="T_ba8b8_row10_col1" class="data row10 col1" >6.50</td>
#       <td id="T_ba8b8_row10_col2" class="data row10 col2" >6.45</td>
#       <td id="T_ba8b8_row10_col3" class="data row10 col3" >0.78%</td>
#       <td id="T_ba8b8_row10_col4" class="data row10 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row11" class="row_heading level0 row11" >21</th>
#       <td id="T_ba8b8_row11_col0" class="data row11 col0" >SENA</td>
#       <td id="T_ba8b8_row11_col1" class="data row11 col1" >2.36</td>
#       <td id="T_ba8b8_row11_col2" class="data row11 col2" >2.34</td>
#       <td id="T_ba8b8_row11_col3" class="data row11 col3" >0.85%</td>
#       <td id="T_ba8b8_row11_col4" class="data row11 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row12" class="row_heading level0 row12" >2</th>
#       <td id="T_ba8b8_row12_col0" class="data row12 col0" >ASK</td>
#       <td id="T_ba8b8_row12_col1" class="data row12 col1" >19.90</td>
#       <td id="T_ba8b8_row12_col2" class="data row12 col2" >19.70</td>
#       <td id="T_ba8b8_row12_col3" class="data row12 col3" >1.02%</td>
#       <td id="T_ba8b8_row12_col4" class="data row12 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row13" class="row_heading level0 row13" >3</th>
#       <td id="T_ba8b8_row13_col0" class="data row13 col0" >ASP</td>
#       <td id="T_ba8b8_row13_col1" class="data row13 col1" >2.84</td>
#       <td id="T_ba8b8_row13_col2" class="data row13 col2" >2.80</td>
#       <td id="T_ba8b8_row13_col3" class="data row13 col3" >1.43%</td>
#       <td id="T_ba8b8_row13_col4" class="data row13 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row14" class="row_heading level0 row14" >25</th>
#       <td id="T_ba8b8_row14_col0" class="data row14 col0" >TFFIF</td>
#       <td id="T_ba8b8_row14_col1" class="data row14 col1" >6.55</td>
#       <td id="T_ba8b8_row14_col2" class="data row14 col2" >6.45</td>
#       <td id="T_ba8b8_row14_col3" class="data row14 col3" >1.55%</td>
#       <td id="T_ba8b8_row14_col4" class="data row14 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row15" class="row_heading level0 row15" >17</th>
#       <td id="T_ba8b8_row15_col0" class="data row15 col0" >PTG</td>
#       <td id="T_ba8b8_row15_col1" class="data row15 col1" >8.75</td>
#       <td id="T_ba8b8_row15_col2" class="data row15 col2" >8.60</td>
#       <td id="T_ba8b8_row15_col3" class="data row15 col3" >1.74%</td>
#       <td id="T_ba8b8_row15_col4" class="data row15 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row16" class="row_heading level0 row16" >8</th>
#       <td id="T_ba8b8_row16_col0" class="data row16 col0" >GVREIT</td>
#       <td id="T_ba8b8_row16_col1" class="data row16 col1" >5.70</td>
#       <td id="T_ba8b8_row16_col2" class="data row16 col2" >5.60</td>
#       <td id="T_ba8b8_row16_col3" class="data row16 col3" >1.79%</td>
#       <td id="T_ba8b8_row16_col4" class="data row16 col4" >Better</td>
#     </tr>
#     <tr>
#       <th id="T_ba8b8_level0_row17" class="row_heading level0 row17" >6</th>
#       <td id="T_ba8b8_row1

# %%
file_name = 'trend.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
osd_file = osd_path + file_name

trend.sort_values(['percent'],ascending=[True]).to_csv(output_file, index=False)
trend.sort_values(['percent'],ascending=[True]).to_csv(data_file, index=False)
trend.sort_values(['percent'],ascending=[True]).to_csv(osd_file, index=False)

# %% [markdown]
# ### Filter only performance = "Worse"

# %%
mask = trend.perform == 'Worse'
trend[mask]
# Out:
#       name  price_d  price_w  percent perform
# 0       AH    27.00    27.50    -1.82   Worse
# 1   AIMIRT    10.30    10.40    -0.96   Worse
# 7      DIF     7.50     8.10    -7.41   Worse
# 10   JASIF     5.95     6.00    -0.83   Worse
# 11   JMART    18.00    18.20    -1.10   Worse
# 12     JMT    26.25    26.50    -0.94   Worse
# 14     MCS     6.45     6.50    -0.77   Worse
# 17     PTG     8.30     9.00    -7.78   Worse
# 18   PTTGC    38.50    38.75    -0.65   Worse
# 25   TFFIF     6.50     6.55    -0.76   Worse

# %%
trend.perform.value_counts(normalize=True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ae4c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ae4c_level0_row0" class="row_heading level0 row0" >Better</th>
#       <td id="T_6ae4c_row0_col0" class="data row0 col0" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6ae4c_level0_row1" class="row_heading level0 row1" >Worse</th>
#       <td id="T_6ae4c_row1_col0" class="data row1 col0" >33.33%</td>
#     </tr>
#     <tr>
#       <th id="T_6ae4c_level0_row2" class="row_heading level0 row2" >No Change</th>
#       <td id="T_6ae4c_row2_col0" class="data row2 col0" >16.67%</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = '''
SELECT name, max_price AS max, min_price AS min, pe, pbv, daily_volume AS volume, beta, market
FROM stocks
'''
my_stocks = pd.read_sql(sql, conmy)
my_stocks.shape
# Out:
# (248, 8)

# %%
filters = [
   (my_stocks.market.str.contains('SET50')),
   (my_stocks.market.str.contains('SET100')),
   (my_stocks.market.str.contains('mai'))]
values = ['SET50','SET100','mai']
my_stocks["mrkt"] = np.select(filters, values, default='SET999')

# %%
trend2 = pd.merge(trend, my_stocks, on='name', how='inner')
trend2.sort_values(['percent'],ascending=[True]).shape
# Out:
# (30, 13)

# %%
set50 = trend2.mrkt.str.contains('SET50') 
flt_set50 = trend2[set50]
flt_set50[cols].sort_values(by=['percent','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_63a65_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_w</th>
#       <th class="col_heading level0 col2" >price_d</th>
#       <th class="col_heading level0 col3" >percent</th>
#       <th class="col_heading level0 col4" >perform</th>
#       <th class="col_heading level0 col5" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63a65_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_63a65_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_63a65_row0_col1" class="data row0 col1" >18.20</td>
#       <td id="T_63a65_row0_col2" class="data row0 col2" >18.00</td>
#       <td id="T_63a65_row0_col3" class="data row0 col3" >-1.10%</td>
#       <td id="T_63a65_row0_col4" class="data row0 col4" >Worse</td>
#       <td id="T_63a65_row0_col5" class="data row0 col5" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_63a65_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_63a65_row1_col0" class="data row1 col0" >JMT</td>
#       <td id="T_63a65_row1_col1" class="data row1 col1" >26.50</td>
#       <td id="T_63a65_row1_col2" class="data row1 col2" >26.25</td>
#       <td id="T_63a65_row1_col3" class="data row1 col3" >-0.94%</td>
#       <td id="T_63a65_row1_col4" class="data row1 col4" >Worse</td>
#       <td id="T_63a65_row1_col5" class="data row1 col5" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_63a65_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_63a65_row2_col0" class="data row2 col0" >PTTGC</td>
#       <td id="T_63a65_row2_col1" class="data row2 col1" >38.75</td>
#       <td id="T_63a65_row2_col2" class="data row2 col2" >38.50</td>
#       <td id="T_63a65_row2_col3" class="data row2 col3" >-0.65%</td>
#       <td id="T_63a65_row2_col4" class="data row2 col4" >Worse</td>
#       <td id="T_63a65_row2_col5" class="data row2 col5" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_63a65_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_63a65_row3_col0" class="data row3 col0" >AWC</td>
#       <td id="T_63a65_row3_col1" class="data row3 col1" >3.48</td>
#       <td id="T_63a65_row3_col2" class="data row3 col2" >3.48</td>
#       <td id="T_63a65_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_63a65_row3_col4" class="data row3 col4" >No Change</td>
#       <td id="T_63a65_row3_col5" class="data row3 col5" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_63a65_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_63a65_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_63a65_row4_col1" class="data row4 col1" >292.00</td>
#       <td id="T_63a65_row4_col2" class="data row4 col2" >296.00</td>
#       <td id="T_63a65_row4_col3" class="data row4 col3" >1.37%</td>
#       <td id="T_63a65_row4_col4" class="data row4 col4" >Better</td>
#       <td id="T_63a65_row4_col5" class="data row4 col5" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_63a65_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_63a65_row5_col0" class="data row5 col0" >IVL</td>
#       <td id="T_63a65_row5_col1" class="data row5 col1" >25.00</td>
#       <td id="T_63a65_row5_col2" class="data row5 col2" >27.25</td>
#       <td id="T_63a65_row5_col3" class="data row5 col3" >9.00%</td>
#       <td id="T_63a65_row5_col4" class="data row5 col4" >Better</td>
#       <td id="T_63a65_row5_col5" class="data row5 col5" >SET50</td>
#     </tr>
#   </tbody>
# </table>

# %%
flt_set50.perform.value_counts(normalize=True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_93935_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93935_level0_row0" class="row_heading level0 row0" >Worse</th>
#       <td id="T_93935_row0_col0" class="data row0 col0" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_93935_level0_row1" class="row_heading level0 row1" >Better</th>
#       <td id="T_93935_row1_col0" class="data row1 col0" >33.33%</td>
#     </tr>
#     <tr>
#       <th id="T_93935_level0_row2" class="row_heading level0 row2" >No Change</th>
#       <td id="T_93935_row2_col0" class="data row2 col0" >16.67%</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100 = trend2.mrkt.str.contains('SET100')
flt_set100 = trend2[set100]
flt_set100[cols].sort_values(by=['percent','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f95f5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_w</th>
#       <th class="col_heading level0 col2" >price_d</th>
#       <th class="col_heading level0 col3" >percent</th>
#       <th class="col_heading level0 col4" >perform</th>
#       <th class="col_heading level0 col5" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f95f5_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_f95f5_row0_col0" class="data row0 col0" >PTG</td>
#       <td id="T_f95f5_row0_col1" class="data row0 col1" >9.00</td>
#       <td id="T_f95f5_row0_col2" class="data row0 col2" >8.30</td>
#       <td id="T_f95f5_row0_col3" class="data row0 col3" >-7.78%</td>
#       <td id="T_f95f5_row0_col4" class="data row0 col4" >Worse</td>
#       <td id="T_f95f5_row0_col5" class="data row0 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_f95f5_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_f95f5_row1_col1" class="data row1 col1" >11.90</td>
#       <td id="T_f95f5_row1_col2" class="data row1 col2" >12.00</td>
#       <td id="T_f95f5_row1_col3" class="data row1 col3" >0.84%</td>
#       <td id="T_f95f5_row1_col4" class="data row1 col4" >Better</td>
#       <td id="T_f95f5_row1_col5" class="data row1 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_f95f5_row2_col0" class="data row2 col0" >KCE</td>
#       <td id="T_f95f5_row2_col1" class="data row2 col1" >55.50</td>
#       <td id="T_f95f5_row2_col2" class="data row2 col2" >56.25</td>
#       <td id="T_f95f5_row2_col3" class="data row2 col3" >1.35%</td>
#       <td id="T_f95f5_row2_col4" class="data row2 col4" >Better</td>
#       <td id="T_f95f5_row2_col5" class="data row2 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_f95f5_row3_col0" class="data row3 col0" >BCH</td>
#       <td id="T_f95f5_row3_col1" class="data row3 col1" >21.20</td>
#       <td id="T_f95f5_row3_col2" class="data row3 col2" >21.70</td>
#       <td id="T_f95f5_row3_col3" class="data row3 col3" >2.36%</td>
#       <td id="T_f95f5_row3_col4" class="data row3 col4" >Better</td>
#       <td id="T_f95f5_row3_col5" class="data row3 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row4" class="row_heading level0 row4" >23</th>
#       <td id="T_f95f5_row4_col0" class="data row4 col0" >STA</td>
#       <td id="T_f95f5_row4_col1" class="data row4 col1" >14.50</td>
#       <td id="T_f95f5_row4_col2" class="data row4 col2" >15.00</td>
#       <td id="T_f95f5_row4_col3" class="data row4 col3" >3.45%</td>
#       <td id="T_f95f5_row4_col4" class="data row4 col4" >Better</td>
#       <td id="T_f95f5_row4_col5" class="data row4 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_f95f5_row5_col0" class="data row5 col0" >ORI</td>
#       <td id="T_f95f5_row5_col1" class="data row5 col1" >8.15</td>
#       <td id="T_f95f5_row5_col2" class="data row5 col2" >8.45</td>
#       <td id="T_f95f5_row5_col3" class="data row5 col3" >3.68%</td>
#       <td id="T_f95f5_row5_col4" class="data row5 col4" >Better</td>
#       <td id="T_f95f5_row5_col5" class="data row5 col5" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_f95f5_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_f95f5_row6_col0" class="data row6 col0" >RCL</td>
#       <td id="T_f95f5_row6_col1" class="data row6 col1" >20.00</td>
#       <td id="T_f95f5_row6_col2" class="data row6 col2" >24.40</td>
#       <td id="T_f95f5_row6_col3" class="data row6 col3" >22.00%</td>
#       <td id="T_f95f5_row6_col4" class="data row6 col4" >Better</td>
#       <td id="T_f95f5_row6_col5" class="data row6 col5" >SET100</td>
#     </tr>
#   </tbody>
# </table>

# %%
flt_set100[cols].perform.value_counts(normalize=True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f7dca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7dca_level0_row0" class="row_heading level0 row0" >Better</th>
#       <td id="T_f7dca_row0_col0" class="data row0 col0" >85.71%</td>
#     </tr>
#     <tr>
#       <th id="T_f7dca_level0_row1" class="row_heading level0 row1" >Worse</th>
#       <td id="T_f7dca_row1_col0" class="data row1 col0" >14.29%</td>
#     </tr>
#   </tbody>
# </table>

# %%
set999 = trend2.mrkt.str.contains('SET999')
flt_set999 = trend2[set999]
flt_set999[cols].sort_values(by=['percent','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cb22_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_w</th>
#       <th class="col_heading level0 col2" >price_d</th>
#       <th class="col_heading level0 col3" >percent</th>
#       <th class="col_heading level0 col4" >perform</th>
#       <th class="col_heading level0 col5" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cb22_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_1cb22_row0_col0" class="data row0 col0" >DIF</td>
#       <td id="T_1cb22_row0_col1" class="data row0 col1" >8.10</td>
#       <td id="T_1cb22_row0_col2" class="data row0 col2" >7.50</td>
#       <td id="T_1cb22_row0_col3" class="data row0 col3" >-7.41%</td>
#       <td id="T_1cb22_row0_col4" class="data row0 col4" >Worse</td>
#       <td id="T_1cb22_row0_col5" class="data row0 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_1cb22_row1_col0" class="data row1 col0" >AH</td>
#       <td id="T_1cb22_row1_col1" class="data row1 col1" >27.50</td>
#       <td id="T_1cb22_row1_col2" class="data row1 col2" >27.00</td>
#       <td id="T_1cb22_row1_col3" class="data row1 col3" >-1.82%</td>
#       <td id="T_1cb22_row1_col4" class="data row1 col4" >Worse</td>
#       <td id="T_1cb22_row1_col5" class="data row1 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_1cb22_row2_col0" class="data row2 col0" >AIMIRT</td>
#       <td id="T_1cb22_row2_col1" class="data row2 col1" >10.40</td>
#       <td id="T_1cb22_row2_col2" class="data row2 col2" >10.30</td>
#       <td id="T_1cb22_row2_col3" class="data row2 col3" >-0.96%</td>
#       <td id="T_1cb22_row2_col4" class="data row2 col4" >Worse</td>
#       <td id="T_1cb22_row2_col5" class="data row2 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_1cb22_row3_col0" class="data row3 col0" >JASIF</td>
#       <td id="T_1cb22_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_1cb22_row3_col2" class="data row3 col2" >5.95</td>
#       <td id="T_1cb22_row3_col3" class="data row3 col3" >-0.83%</td>
#       <td id="T_1cb22_row3_col4" class="data row3 col4" >Worse</td>
#       <td id="T_1cb22_row3_col5" class="data row3 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row4" class="row_heading level0 row4" >14</th>
#       <td id="T_1cb22_row4_col0" class="data row4 col0" >MCS</td>
#       <td id="T_1cb22_row4_col1" class="data row4 col1" >6.50</td>
#       <td id="T_1cb22_row4_col2" class="data row4 col2" >6.45</td>
#       <td id="T_1cb22_row4_col3" class="data row4 col3" >-0.77%</td>
#       <td id="T_1cb22_row4_col4" class="data row4 col4" >Worse</td>
#       <td id="T_1cb22_row4_col5" class="data row4 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row5" class="row_heading level0 row5" >25</th>
#       <td id="T_1cb22_row5_col0" class="data row5 col0" >TFFIF</td>
#       <td id="T_1cb22_row5_col1" class="data row5 col1" >6.55</td>
#       <td id="T_1cb22_row5_col2" class="data row5 col2" >6.50</td>
#       <td id="T_1cb22_row5_col3" class="data row5 col3" >-0.76%</td>
#       <td id="T_1cb22_row5_col4" class="data row5 col4" >Worse</td>
#       <td id="T_1cb22_row5_col5" class="data row5 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1cb22_row6_col0" class="data row6 col0" >CPNREIT</td>
#       <td id="T_1cb22_row6_col1" class="data row6 col1" >11.00</td>
#       <td id="T_1cb22_row6_col2" class="data row6 col2" >11.00</td>
#       <td id="T_1cb22_row6_col3" class="data row6 col3" >0.00%</td>
#       <td id="T_1cb22_row6_col4" class="data row6 col4" >No Change</td>
#       <td id="T_1cb22_row6_col5" class="data row6 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_1cb22_row7_col0" class="data row7 col0" >SENA</td>
#       <td id="T_1cb22_row7_col1" class="data row7 col1" >2.32</td>
#       <td id="T_1cb22_row7_col2" class="data row7 col2" >2.32</td>
#       <td id="T_1cb22_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_1cb22_row7_col4" class="data row7 col4" >No Change</td>
#       <td id="T_1cb22_row7_col5" class="data row7 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row8" class="row_heading level0 row8" >26</th>
#       <td id="T_1cb22_row8_col0" class="data row8 col0" >TMT</td>
#       <td id="T_1cb22_row8_col1" class="data row8 col1" >6.20</td>
#       <td id="T_1cb22_row8_col2" class="data row8 col2" >6.20</td>
#       <td id="T_1cb22_row8_col3" class="data row8 col3" >0.00%</td>
#       <td id="T_1cb22_row8_col4" class="data row8 col4" >No Change</td>
#       <td id="T_1cb22_row8_col5" class="data row8 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row9" class="row_heading level0 row9" >28</th>
#       <td id="T_1cb22_row9_col0" class="data row9 col0" >WHAIR</td>
#       <td id="T_1cb22_row9_col1" class="data row9 col1" >5.45</td>
#       <td id="T_1cb22_row9_col2" class="data row9 col2" >5.45</td>
#       <td id="T_1cb22_row9_col3" class="data row9 col3" >0.00%</td>
#       <td id="T_1cb22_row9_col4" class="data row9 col4" >No Change</td>
#       <td id="T_1cb22_row9_col5" class="data row9 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row10" class="row_heading level0 row10" >3</th>
#       <td id="T_1cb22_row10_col0" class="data row10 col0" >ASP</td>
#       <td id="T_1cb22_row10_col1" class="data row10 col1" >2.78</td>
#       <td id="T_1cb22_row10_col2" class="data row10 col2" >2.80</td>
#       <td id="T_1cb22_row10_col3" class="data row10 col3" >0.72%</td>
#       <td id="T_1cb22_row10_col4" class="data row10 col4" >Better</td>
#       <td id="T_1cb22_row10_col5" class="data row10 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_1cb22_row11_col0" class="data row11 col0" >GVREIT</td>
#       <td id="T_1cb22_row11_col1" class="data row11 col1" >5.60</td>
#       <td id="T_1cb22_row11_col2" class="data row11 col2" >5.65</td>
#       <td id="T_1cb22_row11_col3" class="data row11 col3" >0.89%</td>
#       <td id="T_1cb22_row11_col4" class="data row11 col4" >Better</td>
#       <td id="T_1cb22_row11_col5" class="data row11 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row12" class="row_heading level0 row12" >2</th>
#       <td id="T_1cb22_row12_col0" class="data row12 col0" >ASK</td>
#       <td id="T_1cb22_row12_col1" class="data row12 col1" >19.70</td>
#       <td id="T_1cb22_row12_col2" class="data row12 col2" >19.90</td>
#       <td id="T_1cb22_row12_col3" class="data row12 col3" >1.02%</td>
#       <td id="T_1cb22_row12_col4" class="data row12 col4" >Better</td>
#       <td id="T_1cb22_row12_col5" class="data row12 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row13" class="row_heading level0 row13" >29</th>
#       <td id="T_1cb22_row13_col0" class="data row13 col0" >WHART</td>
#       <td id="T_1cb22_row13_col1" class="data row13 col1" >9.75</td>
#       <td id="T_1cb22_row13_col2" class="data row13 col2" >9.90</td>
#       <td id="T_1cb22_row13_col3" class="data row13 col3" >1.54%</td>
#       <td id="T_1cb22_row13_col4" class="data row13 col4" >Better</td>
#       <td id="T_1cb22_row13_col5" class="data row13 col5" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_1cb22_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_1cb22_row14_col0" class="data row14 col0" >NER</td>
#       <td id="T_1cb22_row14_col1" class="data row14 col1" >4.58</td>
#       <td id="T_1cb22_row14_col2" class="data row14 col2" >4.68</td>
#       <td id="T_1cb22_row14_col3" class="data row14 col3" >2.18%</td>
#       <td id="T_1cb22_row14_col4" class="data row14 col4"

# %%
flt_set999[cols].perform.value_counts(normalize=True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9c18_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9c18_level0_row0" class="row_heading level0 row0" >Better</th>
#       <td id="T_c9c18_row0_col0" class="data row0 col0" >41.18%</td>
#     </tr>
#     <tr>
#       <th id="T_c9c18_level0_row1" class="row_heading level0 row1" >Worse</th>
#       <td id="T_c9c18_row1_col0" class="data row1 col0" >35.29%</td>
#     </tr>
#     <tr>
#       <th id="T_c9c18_level0_row2" class="row_heading level0 row2" >No Change</th>
#       <td id="T_c9c18_row2_col0" class="data row2 col0" >23.53%</td>
#     </tr>
#   </tbody>
# </table>

# %%
setmai = trend2.mrkt.str.contains('mai')
flt_setmai = trend2[setmai]
flt_setmai[cols].sort_values(by=['percent','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c552b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_w</th>
#       <th class="col_heading level0 col2" >price_d</th>
#       <th class="col_heading level0 col3" >percent</th>
#       <th class="col_heading level0 col4" >perform</th>
#       <th class="col_heading level0 col5" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
flt_setmai[cols].perform.value_counts(normalize=True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b89e4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >perform</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
