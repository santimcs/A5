# %%
import calendar
import os
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

pd.set_option('display.max_row',None)

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2023, 12, 31), datetime.date(2023, 12, 30))

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(2)
yesterday = today - num_business_days
#yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-12-31
# yesterday: 2023-12-28 00:00:00

# %%
yesterday = yesterday.date()
a_year_ago = yesterday - timedelta(days=365)
yesterday, a_year_ago
# Out:
# (datetime.date(2023, 12, 28), datetime.date(2022, 12, 28))

# %% [markdown]
# ### Restart and Run All Cells

# %% [markdown]
# ### Weekly process or when stataus changes.

# %%
pd.read_sql_query('SELECT COUNT(*) AS records FROM sales', conlite)
# Out:
#    records
# 0        0

# %%
sqlDel = """DELETE FROM sales"""
rp = conlite.execute(sqlDel)
rp.rowcount
# Out:
# 0

# %%
sql = """
SELECT name
FROM orders 
ORDER BY name
"""
df = pd.read_sql(sql, conlite)

names = df['name'].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BBL', 'BCH', 'BEM', 'BH', 'CK', 'CPN', 'CPNREIT', 'DIF', 'GVREIT', 'HANA', 'ICHI', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'KTB', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'TOA', 'WHAIR', 'WHART'"

# %%
len(in_p.split(','))
# Out:
# 38

# %% [markdown]
# ### Get past one year data

# %%
sql = """
SELECT name, date, price, qty, maxp, minp 
FROM price 
WHERE date >= '%s' AND name IN (%s) 
ORDER BY name, date"""
sql = sql % (a_year_ago, in_p)
print(sql)
# Out:
# SELECT name, date, price, qty, maxp, minp
# FROM price
# WHERE date >= '2022-12-28' AND name IN ('AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BBL', 'BCH', 'BEM', 'BH', 'CK', 'CPN', 'CPNREIT', 'DIF', 'GVREIT', 'HANA', 'ICHI', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'KTB', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'TOA', 'WHAIR', 'WHART')
# ORDER BY name, date

# %%
# 163      BEM  2023-12-08    8.10    8.15    8.00   20542323    8.00
# 164   BEAUTY  2023-12-08    0.45    0.46    0.44    3300103    0.45
# 165     BDMS  2023-12-08   25.75   26.00   25.50   26016786   25.75
# 166     BCPG  2023-12-08    8.70    8.85    8.70    1804225    8.80
# 167      BCP  2023-12-08   42.50   43.25   42.25    2814734   42.75
# 168      BCH  2023-12-08   21.40   21.50   21.20    8073273   21.30
# 169      BBL  2023-12-08  149.50  150.50  149.00    4184305  149.50
# 170    BANPU  2023-12-08    6.75    7.10    6.75  174281649    7.05
# 171      BAM  2023-12-08    8.20    8.40    8.15    5606409    8.35
# 172       BA  2023-12-08   14.60   14.80   14.40    1105060   14.70
# 173      AWC  2023-12-08    3.72    3.76    3.68   27105562    3.74
# 174      ASW  2023-12-08    8.20    8.25    8.15      30535    8.25
# 175      ASP  2023-12-08    2.80    2.80    2.76     370134    2.78
# 176      ASK  2023-12-08   20.00   20.20   20.00     226611   20.00
# 177    ASIAN  2023-12-08    6.85    7.00    6.80     984463    6.95
# 178       AP  2023-12-08   10.70   10.80   10.60    6231939   10.60
# 179      AOT  2023-12-08   60.00   60.25   59.75   20027578   60.00
# 180     ANAN  2023-12-08    0.77    0.79    0.76   12008313    0.76
# 181    AMATA  2023-12-08   25.75   26.75   25.50    3070105   26.50
# 182       AJ  2023-12-08    7.00    7.05    6.75     320550    6.85
# 183      AIT  2023-12-08    3.90    3.98    3.90    2389012    3.94
# 184   AIMIRT  2023-12-08   10.20   10.30   10.10     593108   10.30
# 185       AH  2023-12-08   26.50   27.50   26.50    2297292   27.50
# 186   AEONTS  2023-12-08  149.50  152.00  148.00     199906  150.50
# 187   ADVANC  2023-12-08  220.00  220.00  218.00    2055619  220.00
# 188      ACE  2023-12-08    1.48    1.50    1.46    2544715    1.47

# %%
df.query("date == '2023-12-08'")
# Out:
# Empty DataFrame
# Columns: [name, date, price, qty, maxp, minp]
# Index: []

# %%
	# Set a variable  
	req_date = '2023-12-08'  
	  
	# Use the variable in the query function  
	df_filtered = df.query('date == @req_date')  
	  
	# View the filtered DataFrame  
	print(df_filtered)
# Out:
# Empty DataFrame
# Columns: [name, date, price, qty, maxp, minp]
# Index: []

# %%
data_path = "../data/"
file_name = "Yearly-Price-by-Name.csv"
output_file = data_path + file_name

df.set_index("name", inplace=True)
df.to_csv(output_file, header=None)

# %% [markdown]
# ### Create monitors from orders

# %%
sql = """
SELECT name,trade 
FROM orders 
WHERE name IN (%s)
ORDER BY name
"""
sql = sql % in_p
orders = pd.read_sql(sql, conlite)
orders.set_index(['name'],inplace=True)
orders
# Out:
#         trade
# name
# AH          B
# AIMIRT      S
# ASK         B
# ASP         S
# AWC         S
# BBL         B
# BCH         S
# BEM         B
# BH          B
# CK          B
# CPN         B
# CPNREIT     B
# DIF         B
# GVREIT      B
# HANA        B
# ICHI        B
# IVL         S
# JASIF       B
# JMART       S
# JMT         B
# KCE         S
# KTB         B
# MCS         S
# NER         B
# ORI         B
# PTG         B
# PTTGC       B
# RCL         S
# SCC         S
# SENA        B
# SINGER      B
# STA         S
# SYNEX       B
# TFFIF       B
# TMT         B
# TOA         S
# WHAIR       B
# WHART       B

# %%
file_name = "monitors.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name

orders.to_csv(data_file, header=None)
orders.to_csv(output_file)
orders.to_csv(box_file)

# %%
sql = """
SELECT trade, COUNT(*) AS items 
FROM orders
GROUP BY trade
ORDER BY trade
"""
grp = pd.read_sql(sql, conlite)
grp
# Out:
#   trade  items
# 0     B     26
# 1     S     12

# %% [markdown]
# ### For new orders that never have XXX.html & XXX.CSV

# %%
file_name = 'price-uploads.csv'
url = data_path + file_name
url
# Out:
# '../data/price-uploads.csv'

# %%
uploads = pd.read_csv(url)
uploads.sort_values(['name'],ascending=[True]).shape
# Out:
# (152, 1)

# %%
df_merge = pd.merge(orders, uploads, on='name', how='outer', indicator=True)
df_merge.sort_values(['name'],ascending=[True]).shape
# Out:
# (157, 3)

# %%
new_prices = df_merge['_merge'] == 'left_only'
df_merge[new_prices]
# Out:
#    name trade     _merge
# 0    AH     B  left_only
# 4   AWC     S  left_only
# 7   BEM     B  left_only
# 10  CPN     B  left_only
# 35  TOA     S  left_only

# %%
new_prices = df_merge['_merge'] == 'right_only'
df_merge[new_prices].shape
# Out:
# (119, 3)

# %%
sql = """
SELECT name, status, market
FROM stocks 
ORDER BY status, name
"""
stocks = pd.read_sql(sql, conlite)
stocks.set_index(["name"], inplace=True)
stocks.shape
# Out:
# (38, 2)

# %%
file_name = "stocks-all.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

stocks.to_csv(data_file, header=None)
stocks.to_csv(output_file)
stocks.to_csv(box_file)
stocks.to_csv(one_file)

# %%
sql = """
SELECT name, status 
FROM stocks 
WHERE status IN ("B","O")
ORDER BY name
"""
buy_candidates = pd.read_sql(sql, conlite)
buy_candidates.set_index(["name"], inplace=True)
buy_candidates
# Out:
#         status
# name
# AH           B
# ASK          B
# BBL          O
# BEM          O
# BH           O
# CK           O
# CPN          O
# CPNREIT      B
# DIF          B
# GVREIT       B
# HANA         O
# ICHI         O
# JASIF        B
# JMT          B
# KTB          O
# NER          B
# ORI          B
# PTG          B
# PTTGC        B
# SENA         B
# SINGER       B
# SYNEX        B
# TFFIF        B
# TMT          B
# WHAIR        B
# WHART        B

# %%
buy_candidates.shape[0]
# Out:
# 26

# %%
sql = """
SELECT name, status 
FROM stocks 
WHERE status IN ("I","S")
ORDER BY name
"""

sell_candidates = pd.read_sql(sql, conlite)
sell_candidates.set_index(["name"], inplace=True)
sell_candidates
# Out:
#        status
# name
# AIMIRT      I
# ASP         I
# AWC         I
# BCH         I
# IVL         I
# JMART       I
# KCE         I
# MCS         I
# RCL         I
# SCC         I
# STA         I
# TOA         I

# %%
sell_candidates.shape[0]
# Out:
# 12
