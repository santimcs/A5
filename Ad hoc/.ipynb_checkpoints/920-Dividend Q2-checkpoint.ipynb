# %%
import pandas as pd
from sqlalchemy import create_engine, text
from datetime import date, timedelta
from pandas.tseries.offsets import BDay
import calendar

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

data_path = "../excel/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

year = 2024
quarter = 2
today = date.today()
today
# Out:
# datetime.date(2024, 9, 17)

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
today, yesterday
# Out:
# (datetime.date(2024, 9, 17), datetime.date(2024, 9, 16))

# %%
format_dict = {    
    'shares':'{:,}',    
    'q4':'{:.4f}','q3':'{:.4f}','q2':'{:.4f}','q1':'{:.4f}','dividend':'{:.4f}','qtrly':'{:.4f}',
    'price':'{:.2f}',    
    'amount':'{:,.2f}','net':'{:,.2f}','cost_amt':'{:,.2f}',
    'yield':'{:,.2f}%','pct':'{:,.2f}%',
    'xdate':'{:%Y-%m-%d}','paiddate':'{:%Y-%m-%d}',
              }

# %% [markdown]
# ### New dividend stock

# %%
name = 'ICHI'
sql = """
SELECT * 
FROM DIVIDEND
WHERE name = '%s'
"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6cc8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sqlIns = """
INSERT INTO dividend
VALUES('ICHI',.60,0,0,0,.60,0,0,00,'2023-05-09','2023-05-24','',2)
"""
rp = const.execute(sqlIns)
rp.rowcount
# Out:
# 1

# %%
sql = """
SELECT * 
FROM DIVIDEND
WHERE name = '%s'
"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a0516_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0516_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0516_row0_col0" class="data row0 col0" >ICHI</td>
#       <td id="T_a0516_row0_col1" class="data row0 col1" >0.6000</td>
#       <td id="T_a0516_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_a0516_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_a0516_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_a0516_row0_col5" class="data row0 col5" >0.6000</td>
#       <td id="T_a0516_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_a0516_row0_col7" class="data row0 col7" >2023-05-09</td>
#       <td id="T_a0516_row0_col8" class="data row0 col8" >2023-05-24</td>
#       <td id="T_a0516_row0_col9" class="data row0 col9" ></td>
#       <td id="T_a0516_row0_col10" class="data row0 col10" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Start of Update dividend

# %%
def update_dividend1(q2,XDATE,PAIDDATE,actual,name):
    sql = "UPDATE dividend SET q2 = %s, dividend = q1+q2+q3+q4, XDATE = '%s', PAIDDATE = '%s', actual = %s WHERE name = '%s'"
    sql = sql % (q2,XDATE, PAIDDATE, actual,name)
    rp = const.execute(sql)
    return "Records updated = " + str(rp.rowcount)

# %%
def update_dividend1(q2, XDATE, PAIDDATE, actual, name):
    # Use parameterized query to avoid SQL injection
    sql = text("""
        UPDATE dividend 
        SET q2 = :q2, 
            dividend = q1 + q2 + q3 + q4, 
            XDATE = :XDATE, 
            PAIDDATE = :PAIDDATE, 
            actual = :actual 
        WHERE name = :name
    """)
    
    # Execute the query with parameters
    rp = const.execute(sql, {
        'q2': q2,
        'XDATE': XDATE,
        'PAIDDATE': PAIDDATE,
        'actual': actual,
        'name': name
    })
    
    return f"Records updated = {rp.rowcount}"

# %%
name = 'JMART'
sql = """
SELECT * FROM DIVIDEND WHERE name = '%s'"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_aeea1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeea1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeea1_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_aeea1_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_aeea1_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_aeea1_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_aeea1_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_aeea1_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_aeea1_row0_col6" class="data row0 col6" >6,800</td>
#       <td id="T_aeea1_row0_col7" class="data row0 col7" >2024-04-11</td>
#       <td id="T_aeea1_row0_col8" class="data row0 col8" >2024-05-03</td>
#       <td id="T_aeea1_row0_col9" class="data row0 col9" ></td>
#       <td id="T_aeea1_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
q2 = 0.24
XDATE = '2024-09-30'
PAIDDATE = '2024-10-11'
actual = 1

update_dividend1(q2,XDATE,PAIDDATE,actual,name)
# Out:
# 'Records updated = 1'

# %%
sql = """
SELECT * FROM DIVIDEND WHERE name = '%s'"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f6c3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f6c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f6c3_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_5f6c3_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_5f6c3_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_5f6c3_row0_col3" class="data row0 col3" >0.2400</td>
#       <td id="T_5f6c3_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_5f6c3_row0_col5" class="data row0 col5" >0.2400</td>
#       <td id="T_5f6c3_row0_col6" class="data row0 col6" >6,800</td>
#       <td id="T_5f6c3_row0_col7" class="data row0 col7" >2024-09-30</td>
#       <td id="T_5f6c3_row0_col8" class="data row0 col8" >2024-10-11</td>
#       <td id="T_5f6c3_row0_col9" class="data row0 col9" ></td>
#       <td id="T_5f6c3_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * FROM price WHERE name = '%s'
ORDER BY date DESC"""
sql = sql % name
price= pd.read_sql(sql, const)
price
# Out:
#      name        date  price   maxp   minp       qty   opnp
# 0     RCL  2024-08-09  22.80  23.80  22.70  10938786  23.60
# 1     RCL  2024-08-08  23.40  23.60  22.60   5763256  22.60
# 2     RCL  2024-08-07  22.70  22.80  22.00   7031034  22.20
# 3     RCL  2024-08-06  21.90  22.60  21.50   9344114  22.20
# 4     RCL  2024-08-05  21.40  23.30  21.40  13701876  22.80
# ...   ...         ...    ...    ...    ...       ...    ...
# 1303  RCL  2019-03-12   4.66   4.72   4.64     99200   4.68
# 1304  RCL  2019-03-11   4.68   4.72   4.66    111200   4.72
# 1305  RCL  2019-03-08   4.72   4.74   4.66    285900   4.70
# 1306  RCL  2019-03-07   4.70   4.70   4.62    159700   4.62
# 1307  RCL  2019-03-06   4.66   4.70   4.64    186601   4.70
#
# [1308 rows x 7 columns]

# %%
def update_dividend2(shares, q2, actual, name):
    # Use parameterized query to avoid SQL injection
    sql = text("""
        UPDATE dividend 
        SET q2 = :q2, 
            dividend = q1 + q2 + q3 + q4, 
            shares = :shares, 
            actual = :actual 
        WHERE name = :name
    """)
    
    # Execute the query with parameters
    rp = const.execute(sql, {
        'q2': q2,
        'shares': shares,
        'actual': actual,
        'name': name
    })
    
    return f"Records updated = {rp.rowcount}"

# %%
name = 'AH'
sql = """
SELECT * 
FROM DIVIDEND
WHERE name = '%s'
"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_535df_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_535df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_535df_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_535df_row0_col1" class="data row0 col1" >0.9600</td>
#       <td id="T_535df_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_535df_row0_col3" class="data row0 col3" >0.7000</td>
#       <td id="T_535df_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_535df_row0_col5" class="data row0 col5" >1.6600</td>
#       <td id="T_535df_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_535df_row0_col7" class="data row0 col7" >2023-08-29</td>
#       <td id="T_535df_row0_col8" class="data row0 col8" >2023-09-13</td>
#       <td id="T_535df_row0_col9" class="data row0 col9" ></td>
#       <td id="T_535df_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
shares = 1200
q2 = 0.70
actual = 1

# %%
update_dividend2(shares,q2,actual,name)
# Out:
# 'Records updated = 1'

# %%
sql = """
SELECT * 
FROM DIVIDEND
WHERE name = '%s'
"""
sql = sql % name
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5568a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5568a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5568a_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_5568a_row0_col1" class="data row0 col1" >0.9600</td>
#       <td id="T_5568a_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_5568a_row0_col3" class="data row0 col3" >0.7000</td>
#       <td id="T_5568a_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_5568a_row0_col5" class="data row0 col5" >1.6600</td>
#       <td id="T_5568a_row0_col6" class="data row0 col6" >1,200</td>
#       <td id="T_5568a_row0_col7" class="data row0 col7" >2023-08-29</td>
#       <td id="T_5568a_row0_col8" class="data row0 col8" >2023-09-13</td>
#       <td id="T_5568a_row0_col9" class="data row0 col9" ></td>
#       <td id="T_5568a_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
def update_dividend3(actual,name):
    sql = "UPDATE dividend SET xdate = DATE_ADD(xdate, INTERVAL 3 MONTH), \
    paiddate = DATE_ADD(paiddate, INTERVAL 3 MONTH),dividend=q1+q2+q3+q4, actual = %s \
    WHERE name = '%s'"
    sql = sql % (2, name)
    rp = const.execute(sql)
    return "Records updated = " + str(rp.rowcount)

# %%
actual = 2
name = 'RCL'
update_dividend3(actual,name)
# Out:
# 'Records updated = 1'

# %% [markdown]
# ### Toggle actual status

# %%
name = 'PTT'
actual = 0
sqlUpd = "UPDATE dividend SET actual = %s WHERE name = '%s'"
sqlUpd = sqlUpd % (actual, name)
rp = const.execute(sqlUpd)
rp.rowcount
# Out:
# 1

# %% [markdown]
# ### Delete dividend record

# %%
sqlDel = '''
DELETE FROM dividend
WHERE name IN ("MC")
'''
rp = const.execute(sqlDel)
rp.rowcount
# Out:
# 1

# %% [markdown]
# ### Start of output to cloud

# %%
sql = """
SELECT Y.NAME AS name,  Q2 AS qtrly, SHARES, XDATE, PAIDDATE, 
P.price AS price, Y.DIVIDEND, ACTUAL, B.price * B.volbuy AS cost_amt
FROM dividend AS Y, price AS P, buy AS B
WHERE Y.name = P.name 
AND Y.name = B.name 
AND Q2 > 0 
AND P.date = '%s'
ORDER BY XDATE
"""
sql = sql % today 
print(sql)
# Out:
# SELECT Y.NAME AS name,  Q2 AS qtrly, SHARES, XDATE, PAIDDATE,
# P.price AS price, Y.DIVIDEND, ACTUAL, B.price * B.volbuy AS cost_amt
# FROM dividend AS Y, price AS P, buy AS B
# WHERE Y.name = P.name
# AND Y.name = B.name
# AND Q2 > 0
# AND P.date = '2024-08-23'
# ORDER BY XDATE

# %%
cols = 'name qtrly shares amount net xdate paiddate cost_amt pct actual'.split()

# %%
dividend = pd.read_sql(sql, const)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend['amount'] = round(dividend['shares'] * dividend['qtrly'], 2)
dividend['net'] = round(dividend['amount'] * 0.9, 2)
dividend['pct'] = round(dividend['net'] / dividend['cost_amt'] * 100, 2)
dividend[cols].sort_values('xdate',ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_44588_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qtrly</th>
#       <th class="col_heading level0 col2" >shares</th>
#       <th class="col_heading level0 col3" >amount</th>
#       <th class="col_heading level0 col4" >net</th>
#       <th class="col_heading level0 col5" >xdate</th>
#       <th class="col_heading level0 col6" >paiddate</th>
#       <th class="col_heading level0 col7" >cost_amt</th>
#       <th class="col_heading level0 col8" >pct</th>
#       <th class="col_heading level0 col9" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44588_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44588_row0_col0" class="data row0 col0" >ORI</td>
#       <td id="T_44588_row0_col1" class="data row0 col1" >0.1600</td>
#       <td id="T_44588_row0_col2" class="data row0 col2" >48,000</td>
#       <td id="T_44588_row0_col3" class="data row0 col3" >7,680.00</td>
#       <td id="T_44588_row0_col4" class="data row0 col4" >6,912.00</td>
#       <td id="T_44588_row0_col5" class="data row0 col5" >2024-05-08</td>
#       <td id="T_44588_row0_col6" class="data row0 col6" >2024-05-23</td>
#       <td id="T_44588_row0_col7" class="data row0 col7" >508,800.00</td>
#       <td id="T_44588_row0_col8" class="data row0 col8" >1.36%</td>
#       <td id="T_44588_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_44588_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44588_row1_col0" class="data row1 col0" >SCC</td>
#       <td id="T_44588_row1_col1" class="data row1 col1" >2.5000</td>
#       <td id="T_44588_row1_col2" class="data row1 col2" >600</td>
#       <td id="T_44588_row1_col3" class="data row1 col3" >1,500.00</td>
#       <td id="T_44588_row1_col4" class="data row1 col4" >1,350.00</td>
#       <td id="T_44588_row1_col5" class="data row1 col5" >2024-08-07</td>
#       <td id="T_44588_row1_col6" class="data row1 col6" >2024-08-23</td>
#       <td id="T_44588_row1_col7" class="data row1 col7" >243,000.00</td>
#       <td id="T_44588_row1_col8" class="data row1 col8" >0.56%</td>
#       <td id="T_44588_row1_col9" class="data row1 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44588_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44588_row2_col0" class="data row2 col0" >DIF</td>
#       <td id="T_44588_row2_col1" class="data row2 col1" >0.2222</td>
#       <td id="T_44588_row2_col2" class="data row2 col2" >30,000</td>
#       <td id="T_44588_row2_col3" class="data row2 col3" >6,666.00</td>
#       <td id="T_44588_row2_col4" class="data row2 col4" >5,999.40</td>
#       <td id="T_44588_row2_col5" class="data row2 col5" >2024-08-13</td>
#       <td id="T_44588_row2_col6" class="data row2 col6" >2024-09-05</td>
#       <td id="T_44588_row2_col7" class="data row2 col7" >441,000.00</td>
#       <td id="T_44588_row2_col8" class="data row2 col8" >1.36%</td>
#       <td id="T_44588_row2_col9" class="data row2 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44588_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T
level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_44588_row7_col0" class="data row7 col0" >MCS</td>
#       <td id="T_44588_row7_col1" class="data row7 col1" >0.2000</td>
#       <td id="T_44588_row7_col2" class="data row7 col2" >78,000</td>
#       <td id="T_44588_row7_col3" class="data row7 col3" >15,600.00</td>
#       <td id="T_44588_row7_col4" class="data row7 col4" >14,040.00</td>
#       <td id="T_44588_row7_col5" class="data row7 col5" >2024-08-23</td>
#       <td id="T_44588_row7_col6" class="data row7 col6" >2024-09-10</td>
#       <td id="T_44588_row7_col7" class="data row7 col7" >1,177,800.00</td>
#       <td id="T_44588_row7_col8" class="data row7 col8" >1.19%</td>
#       <td id="T_44588_row7_col9" class="data row7 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44588_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_44588_row8_col0" class="data row8 col0" >NER</td>
#       <td id="T_44588_row8_col1" class="data row8 col1" >0.0500</td>
#       <td id="T_44588_row8_col2" class="data row8 col2" >27,000</td>
#       <td id="T_44588_row8_col3" class="data row8 col3" >1,350.00</td>
#       <td id="T_44588_row8_col4" class="data row8 col4" >1,215.00</td>
#       <td id="T_44588_row8_col5" class="data row8 col5" >2024-08-23</td>
#       <td id="T_44588_row8_col6" class="data row8 col6" >2024-09-06</td>
#       <td id="T_44588_row8_col7" class="data row8 col7" >201,150.00</td>
#       <td id="T_44588_row8_col8" class="data row8 col8" >0.60%</td>
#       <td id="T_44588_row8_col9" class="data row8 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_44588_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_44588_row9_col0" class="data row9 col0" >WHAIR</td>
#       <td id="T_44588_row9_col

# %%
dividend.net.sum()
# Out:
# 82063.84000000001

# %%
file_name = '17-div-24q2.xlsx'
data_file = data_path + file_name
output_file = csv_path + file_name
osd_file = osd_path + file_name
one_file = one_path + file_name

dividend[cols].sort_values(['name'],ascending=[True]).to_excel(output_file, index=False)
dividend[cols].sort_values(['name'],ascending=[True]).to_excel(data_file, index=False)
dividend[cols].sort_values(['name'],ascending=[True]).to_excel(osd_file, index=False)
dividend[cols].sort_values(['name'],ascending=[True]).to_excel(one_file, index=False)

# %%
sql = 'SELECT name, q_eps, aq_eps, publish_date FROM epss WHERE year = %s-1 AND quarter = %s ORDER BY name'
sql = sql % (year, quarter)
print(sql)
eps = pd.read_sql(sql, conlt)
eps.dtypes
# Out:
# SELECT name, q_eps, aq_eps, publish_date FROM epss WHERE year = 2024-1 AND quarter = 2 ORDER BY name
# name             object
# q_eps           float64
# aq_eps          float64
# publish_date     object
# dtype: object

# %%
df_merge = pd.merge(dividend, eps, on='name', how='inner')
df_merge.sort_values('name',ascending=True)
# Out:
#       name   qtrly  shares      xdate   paiddate   price  dividend  actual  \
# 15      AH  0.3000    1200 2024-08-27 2024-09-11   19.80    1.2500       1
# 10  AIMIRT  0.1433   12500 2024-08-26 2024-09-12   10.60    0.8680       1
# 13     ASP  0.0700   30000 2024-08-27 2024-09-12    2.48    0.1700       1
# 19     BCH  0.1200    4000 2024-08-29 2024-09-12   16.10    0.3700       1
# 2      DIF  0.2222   30000 2024-08-13 2024-09-05    7.85    0.8972       1
# 18  GVREIT  0.1963   66000 2024-08-28 2024-09-12    5.50    0.7833       1
# 12     IVL  0.1750    8000 2024-08-27 2024-09-12   18.80    0.7750       1
# 17   TFFIF  0.1102   20000   2204.00   1983.60   2023-05-11 2024-08-28
# 18  GVREIT  0.1963   66000  12955.80  11660.22   2023-05-15 2024-08-28
# 1      SCC  2.5000     600   1500.00   1350.00   2023-07-26 2024-08-07
# 7    WHAIR  0.1372   50000   6860.00   6174.00   2023-08-08 2024-08-23
# 11     KCE  0.6000   10000   6000.00   5400.00   2023-08-08 2024-08-26
# 3    WHART  0.1930   25000   4825.00   4342.50   2023-08-09 2024-08-20
# 5      JMT  0.3800    6000   2280.00   2052.00   2023-08-10 2024-08-22
# 9      NER  0.0500   27000   1350.00   1215.00   2023-08-11 2024-08-23
# 2      DIF  0.2222   30000   6666.00   5999.40   2023-08-11 2024-08-13
# 4      RCL  0.5000   27000  13500.00  12150.00   2023-08-11 2024-08-22
# 6      TMT  0.0500   36000   1800.00   1620.00   2023-08-11 2024-08-22
# 12     IVL  0.1750    8000   1400.00   1260.00   2023-08-11 2024-08-27
# 15      AH  0.3000    1200    360.00    324.00   2023-08-11 2024-08-27
# 14   SYNEX  0.1000   15000   1500.00   1350.00   2023-08-11 2024-08-27
# 10  AIMIRT  0.1433   12500   1791.25   1612.12   2023-08-13 2024-08-26
# 0      ORI  0.1600   48000   7680.00   6912.00   2023-08-15 2024-05-08
# 8      MCS  0.2000   78000  15600.00  14040.00   2023-08-15 2024-08-23
# 13     ASP  0.0700   30000   2100.00   1890.00   2023-08-15 2024-08-27
# 19     BCH  0.1200    4000    480.00    432.00   2023-08-15 2024-08-29
# 16     TOA  0.3300    1000    330.00    297.00   2023-08-16 2024-08-28
#
#      paiddate   q_eps   aq_eps
# 17 2024-09-13  0.0000   0.0000
# 18 2024-09-12  0.0000   0.0000
# 1  2024-08-23  6.7400  20.5100
# 7  2024-09-24  0.0000   0.0000
# 11 2024-09-11  0.3200   0.6100
# 3  2024-09-06  0.0000   0.0000
# 5  2024-09-05  0.3800   0.6900
# 9  2024-09-06  0.2470   0.4180
# 2  2024-09-05  0.0000   0.0000
# 4  2024-09-06  0.6950   1.7960
# 6  2024-09-06  0.0400   0.2800
# 12 2024-09-12  0.0400   0.1900
# 15 2024-09-11  1.1600   2.7400
# 14 2024-09-10  0.1000   0.2600
# 10 2024-09-12  0.0000   0.0000
# 0  2024-05-23  0.3558   0.6809
# 8  2024-09-10  0.0200  -0.0100
# 13 2024-09-12  0.0500   0.1100
# 19 2024-09-12  0.1100   0.2200
# 16 2024-09-13  0.3700   0.6800

# %%
file_name = '17-div-24q2.xlsx'
data_file = data_path + file_name
output_file = csv_path + file_name
osd_file = osd_path + file_name
one_file = one_path + file_name

df_merge[colt].sort_values(['name'],ascending=[True]).to_excel(output_file, index=False)
df_merge[colt].sort_values(['name'],ascending=[True]).to_excel(data_file, index=False)
df_merge[colt].sort_values(['name'],ascending=[True]).to_excel(one_file, index=False)

# %% [markdown]
# ### End of output to cloud

# %%
const.commit()
const.close()
