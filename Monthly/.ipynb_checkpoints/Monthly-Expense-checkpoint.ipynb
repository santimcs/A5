# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from itables import show
pd.options.display.max_rows = 31

engine = create_engine("sqlite:///c:\\ruby\\expense\\db\\development.sqlite3")
conn = engine.connect()
today = date.today()
today
# Out:
# datetime.date(2023, 12, 31)

# %%
sql = "SELECT C.id, C.name AS item, G.name AS kind, G.id FROM categories C \
       JOIN groups G ON group_id = G.id"
df_c = pd.read_sql(sql, conn)
df_c.head()
# Out:
#    id              item            kind  id
# 0   1  Books & Software     Edutainment   3
# 1   2               CCF          Luxury   5
# 2   3         Cigarette          Luxury   5
# 3   4              Food            Food   4
# 4   5              Fuel  Transportation  10

# %%
# create a date object
date = pd.to_datetime('2023-12-31')

# find the beginning of the month for the given date
bom = date.to_period('M').start_time
eom = date.to_period('M').end_time
bom = bom.date()
eom = eom.date()
print(f'Month start: {bom}')
print(f'Month end: {eom}')
# Out:
# Month start: 2023-12-01
# Month end: 2023-12-31

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY amount DESC
"""
sql = sql % eom
print(sql)

df = pd.read_sql(sql, conn)
df
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-12-31"
# ORDER BY amount DESC
#          date  amount            item           kind
# 0  2023-12-31   10000          Parent         Parent
# 1  2023-12-31    1310            Pets           Pets
# 2  2023-12-31     750         ChatGPT    Edutainment
# 3  2023-12-31     640   Internet Home  Communication
# 4  2023-12-31     420         Netflix    Edutainment
# 5  2023-12-31     320  Telephone Dtac  Communication
# 6  2023-12-31     210           Apple    Edutainment
# 7  2023-12-31     170          Google    Edutainment
# 8  2023-12-31     150           Apple    Edutainment
# 9  2023-12-31      40           Apple    Edutainment

# %%
formatted_amt = '{:,.2f}'.format(df.amount.sum())
print(formatted_amt)
# Out:
# 14,010.00

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY amount DESC
"""
sql = sql % (eom)
print(sql)

df_eom = pd.read_sql(sql, conn)
df_eom
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-12-31"
# ORDER BY amount DESC
#          date  amount            item           kind
# 0  2023-12-31   10000          Parent         Parent
# 1  2023-12-31    1310            Pets           Pets
# 2  2023-12-31     750         ChatGPT    Edutainment
# 3  2023-12-31     640   Internet Home  Communication
# 4  2023-12-31     420         Netflix    Edutainment
# 5  2023-12-31     320  Telephone Dtac  Communication
# 6  2023-12-31     210           Apple    Edutainment
# 7  2023-12-31     170          Google    Edutainment
# 8  2023-12-31     150           Apple    Edutainment
# 9  2023-12-31      40           Apple    Edutainment

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date BETWEEN "%s" AND "%s" 
ORDER BY date
"""
sql = sql % (bom, eom)
print(sql)

df_t = pd.read_sql(sql, conn)
df_t.tail()
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date BETWEEN "2023-12-01" AND "2023-12-31"
# ORDER BY date
#           date  amount     item         kind
# 27  2023-12-31     170   Google  Edutainment
# 28  2023-12-31     210    Apple  Edutainment
# 29  2023-12-31     150    Apple  Edutainment
# 30  2023-12-31      40    Apple  Edutainment
# 31  2023-12-31     750  ChatGPT  Edutainment

# %%
grouped = df_t.groupby("item")
grouped['amount'].sum()
# Out:
# item
# Apple               400
# ChatGPT             750
# Food               4290
# Fuel               1100
# Google              170
# Internet Home       640
# Merit Making       2000
# Netflix             420
# Parent            10000
# Pets              30840
# Telephone Dtac      320
# Transportation      250
# Name: amount, dtype: int64

# %%
grouped = df_t.groupby("kind")
grouped['amount'].sum()
# Out:
# kind
# Communication       960
# Edutainment        1740
# Food               4290
# Others             2000
# Parent            10000
# Pets              30840
# Transportation     1350
# Name: amount, dtype: int64

# %%
expense = grouped.amount.sum()
formatted_amt = '{:,.2f}'.format(sum(expense))
print(formatted_amt)
# Out:
# 51,180.00

# %%
fig_path = "../fig/Expense-2312.png"
with plt.style.context("my_custom_style"):
    plt.figure(figsize=(12, 12))
    ax = expense.plot.pie(
        colors=["green", "red", "orange", "cyan", "yellow", "blue", "gold"],
        startangle=90,
        autopct="%1.1f%%",
    )
    plt.savefig(fig_path)

# %%
expense.to_csv("../data/expense-2312.csv")

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY date
"""
sql = sql % (eom)
print(sql)
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-11-30"
# ORDER BY date

# %%
df_tmp = pd.read_sql(sql, conn)
show(df_tmp[['date','amount','item','kind']])
# Out:
# <div><table id="78943500-73dd-4794-872b-6daae33ec5a3" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>date</th>
#       <th>amount</th>
#       <th>item</th>
#       <th>kind</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         var dt_args = {"columnDefs": [{"width": "70px", "targets": "_all"}], "paging": false, "data": [["2023-11-30", 10000, "Parent", "Parent"], ["2023-11-30", 640, "Internet Home", "Communication"], ["2023-11-30", 420, "Netflix", "Edutainment"], ["2023-11-30", 320, "Telephone Dtac", "Communication"], ["2023-11-30", 170, "Google", "Edutainment"], ["2023-11-30", 150, "Apple", "Edutainment"], ["2023-11-30", 40, "Apple", "Edutainment"], ["2023-11-30", 710, "ChatGPT", "Edutainment"]]};
#         dt_args = eval_functions(dt_args);
#         table = $('#78943500-73dd-4794-872b-6daae33ec5a3').DataTable(dt_args);
#     });
# })
# </script>
# </div>

# %%
df_tmp.to_csv("../data/expense-eom.csv")

# %%
sql = "SELECT * FROM groups"
groups = pd.read_sql(sql, conn)
groups.dtypes
# Out:
# id             int64
# name          object
# created_at    object
# updated_at    object
# factor4       object
# dtype: object

# %%
groups
# Out:
#     id            name                  created_at  \
# 0    1         Apparel  2016-01-01 13:38:53.119230
# 1    2   Communication  2016-01-01 13:38:53.199234
# 2    3     Edutainment  2016-01-01 13:38:53.289240
# 3    4            Food  2016-01-01 13:38:53.356243
# 4    5          Luxury  2016-01-01 13:38:53.422247
# 5    6        Medicine  2016-01-01 13:38:53.498252
# 6    7          Others  2016-01-01 13:38:53.564255
# 7    8          Parent  2016-01-01 13:38:53.622259
# 8    9         Shelter  2016-01-01 13:38:53.689263
# 9   10  Transportation  2016-01-01 13:38:53.764267
# 10  11            Pets         2020-01-02 16:09:09
# 11  12          Mother         2023-08-02 15:34:55
#
#                     updated_at factor4
# 0   2016-01-01 13:38:53.119230       2
# 1   2016-01-01 13:38:53.199234       5
# 2   2016-01-01 13:38:53.289240       6
# 3   2016-01-01 13:38:53.356243       1
# 4   2016-01-01 13:38:53.422247       6
# 5   2016-01-01 13:38:53.498252       4
# 6   2016-01-01 13:38:53.564255       6
# 7   2016-01-01 13:38:53.622259       7
# 8   2016-01-01 13:38:53.689263       3
# 9   2016-01-01 13:38:53.764267       5
# 10         2020-01-02 16:09:09       8
# 11         2023-08-02 15:34:55       9

# %%
sql = "SELECT * FROM categories"
categories = pd.read_sql(sql, conn)
categories.dtypes
# Out:
# id             int64
# sequence       int64
# name          object
# default        int64
# group_id       int64
# created_at    object
# updated_at    object
# dtype: object

# %%
categories
# Out:
#     id  sequence              name  default  group_id  \
# 0    1         4  Books & Software        0         3
# 1    2        19               CCF      600         5
# 2    3         2         Cigarette        0         5
# 3    4         1              Food        0         4
# 4    5         3              Fuel        0        10
# ..  ..       ...               ...      ...       ...
# 38  39        76           Netflix      420         3
# 39  40        77           ChatGPT      690         3
# 40  41        78        MidJourney      350         3
# 41  42        79     Yearly Norton     1990         3
# 42  43        80     Microsoft 365     2900         3
#
#                     created_at                  updated_at
# 0   2016-01-01 14:34:11.909054  2016-01-01 14:34:11.909054
# 1   2016-01-01 14:34:11.976058  2016-01-01 14:34:11.976058
# 2   2016-01-01 14:34:12.067063  2016-01-01 14:34:12.067063
# 3   2016-01-01 14:34:12.148068  2016-01-01 14:34:12.148068
# 4   2016-01-01 14:34:12.209071  2016-01-01 14:34:12.209071
# ..                         ...                         ...
# 38         2022-06-30 15:12:52         2022-06-30 15:12:52
# 39         2023-03-31 16:02:59         2023-03-31 16:02:59
# 40         2023-03-31 16:03:46         2023-03-31 16:03:46
# 41         2023-09-03 08:17:21         2023-09-03 08:17:21
# 42         2023-11-06 14:36:46         2023-11-06 14:36:46
#
# [43 rows x 7 columns]

# %%
sql = "SELECT * FROM transactions"
transactions = pd.read_sql(sql, conn)
transactions.dtypes
# Out:
# id              int64
# date           object
# category_id     int64
# amount          int64
# created_at     object
# updated_at     object
# dtype: object

# %%
transactions.tail()
# Out:
#         id        date  category_id  amount                  created_at  \
# 2673  2706  2023-11-30           30     150  2023-11-30 14:44:57.258151
# 2674  2707  2023-11-30           30      40  2023-11-30 14:45:05.709194
# 2675  2708  2023-11-30           40     710  2023-11-30 14:45:29.874863
# 2676  2709  2023-10-09           30     210  2023-11-30 14:50:07.171560
# 2677  2710  2023-09-02           41    3460  2023-11-30 14:57:35.366899
#
#                       updated_at
# 2673  2023-11-30 14:50:55.973626
# 2674  2023-11-30 14:45:05.709194
# 2675  2023-11-30 14:45:29.874863
# 2676  2023-11-30 14:50:07.171560
# 2677  2023-11-30 14:57:35.366899
