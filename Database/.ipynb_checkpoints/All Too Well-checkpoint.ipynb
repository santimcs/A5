# %%
from moviepy.editor import *
from sqlalchemy import create_engine
from datetime import datetime
import pandas as pd
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Your database connection
engine = create_engine('mysql+pymysql://root@localhost:3306/music_development')
data_path = '../data/'

# Get song data
sql = '''
SELECT S.id, rank, name, artist_id, A.first_name, A.last_name , youtube_code 
FROM songs S
JOIN artists A
ON S.artist_id = A.id
WHERE name LIKE "Because You Loved Me"
'''
songs = pd.read_sql(sql, engine)
songs
# Out:
#     id  rank                  name  artist_id first_name last_name  \
# 0  294   563  Because You Loved Me        174     Celine      Dion
# 1  489  1001  Because You Loved Me        263  Anonymous    Singer
#
#   youtube_code
# 0  9CkKuA86Mis
# 1  c5OebIpqKec

# %%
songId = songs['id'].iloc[1]
artist_name = songs['first_name'].iloc[1] + ' ' + songs['last_name'].iloc[1]
artist_name
# Out:
# 'Anonymous Singer'

# %%
# Get lyrics
sql = f"""
SELECT id, song_id, content 
FROM lyrics 
WHERE song_id = {songId}
"""
lyrics = pd.read_sql(sql, engine)
lyrics
# Out:
#     id  song_id                                            content
# 0  408      489  21|I was walking in the shadows.\r\n25|Couldn'...

# %%
# Get the lyrics content
lyrics_content = lyrics.content.iloc[0]

# Print with proper line breaks (replace \r\n with actual newlines)
print("Full lyrics content:")
print("-" * 50)
print(lyrics_content.replace('\r\n', '\n'))
print("=" * 50)
# Out:
# Full lyrics content:
# --------------------------------------------------
# 21|I was walking in the shadows.
# 25|Couldn't see the light of day.
# 30|Every dream I try to follow,
# 34|somehow it just slipped away.
# 39|But then you came and found me.
# 43|Pulled me from the cold.
#
# 47|You gave me hope and meaning.
# 51|You gave me a hand to hold.
# 56|Because you love me,
# 60|I learn how to stand tall.
# 65|Because you love me,
# 68|I can rise after the fall.
#
# 74|Through the heartache
# 76|and the sorrow,
# 78|through the nights I thought I drowned
# 82|because you love me.
# 86|I turn my life around.
#
# 103|The blues were heavy on my shoulders.
# 108|The night kept calling my name.
# 112|Whiskey glass on the table.
# 116|But nothing ever eased the pain.
# 121|THen your arms became my shelter.
# 125|Your voice my sweetest song.
# 130|Because you love me, baby.
# 134|I knew where I belong.
# 139|Because you love me,
# 142|I found the strength inside.
# 147|Because you love me,
# 151|I no longer have to hide.
# 156|throudh the silence, through the
# 159|thunder,
# 161|through the tears I couldn't fight
# 165|because you love me.
# 168|I see the morning light.
#
# 176|When the world turned its back on me,
# 180|you stayed right by my side
# 184|Every broken piece you mened, every
# 187|storm you held me tight.
#
# 193|Show me what it means
# 196|to be truly free.
# 201|Yes, darling.
# 203|I'm the man I am
# 210|because you believe in me.
#
# 239|Huh? Huh?
#
# 247|Now I'm singing on this stage,
# 251|but it ain't about the fame.
# 255|It's a song of gratitude
# 259|and it carries your sweet name.
# 264|So let the whole world listen.
# 268|Let the truth be known.
#
# 273|Every step
# 275|that I've taken, I never walked alone.
# 282|Because you love me,
# 285|I learn how to stand tall.
# 290|Because you love me,
# 294|I can rise after the fall.
# 299|Through the dark and stormy weather,
# 304|through the nights I thought I drowned
# 308|because you love me.
# 311|I turn my life around.
# 321|Baby, because you love me.
#
# 328|Yeah.
# 330|Because you love me,
#
# 337|I'm alive
#
# 343|because you love me.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ==================================================

# %%
# begin of modified function
def parse_timestamp_lyrics(lyrics_text):
    """Parse lyrics with timestamp format from YouTube transcripts using pipe separator"""
    lines = [line.strip() for line in lyrics_text.split('\n') if line.strip()]
    
    lyrics_with_timing = []
    
    for line in lines:
        # Split by the first pipe to separate timestamp from text
        if '|' in line:
            timestamp_str, text = line.split('|', 1)
            try:
                # Convert timestamp to float (seconds)
                timestamp = float(timestamp_str.strip())
                lyrics_with_timing.append({
                    'timestamp': timestamp,
                    'text': text.strip(),  # MODIFIED: Convert to uppercase
                    'start_time': timestamp,
                    'end_time': None,  # Will be calculated later
                    'duration_seconds': None,  # NEW: Will be calculated later
                    'word_count': None,  # NEW: Will be calculated
                    'spaces_count': None,  # NEW: Will be calculated
                    'char_count': None  # NEW: Will be calculated
                })
            except ValueError:
                # Skip lines that don't have valid timestamps
                print(f"⚠️ Skipping line with invalid timestamp: {line}")
                continue
        else:
            print(f"⚠️ Skipping line without Pipe separator: {line}")
    
    # Sort by timestamp
    lyrics_with_timing.sort(key=lambda x: x['timestamp'])
    
    # Calculate end times and additional metrics
    for i in range(len(lyrics_with_timing)):
        if i < len(lyrics_with_timing) - 1:
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i + 1]['timestamp']
        else:
            # For the last line, we'll set a default duration
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i]['timestamp'] + 5  # 5 seconds default
        
        # NEW: Calculate duration in seconds
        lyrics_with_timing[i]['duration_seconds'] = lyrics_with_timing[i]['end_time'] - lyrics_with_timing[i]['start_time']
        
        # NEW: Calculate word count (split by spaces and filter out empty strings)
        words = [word for word in lyrics_with_timing[i]['text'].split() if word]
        lyrics_with_timing[i]['word_count'] = len(words)
        
        # NEW: Calculate spaces between words (word_count - 1, minimum 0)
        lyrics_with_timing[i]['spaces_count'] = max(0, lyrics_with_timing[i]['word_count'] - 1)
        
        # NEW: Calculate total characters including spaces
        lyrics_with_timing[i]['char_count'] = len(lyrics_with_timing[i]['text'])
    
    return lyrics_with_timing
# end of modified function
    
def get_current_lyric(current_time, lyrics_with_timing):
    """Find which lyric should be displayed at current time"""
    for lyric in lyrics_with_timing:
        if lyric['start_time'] <= current_time < lyric['end_time']:
            return lyric['text']
    return None

def create_timestamp_synced_video(song_id=songId, max_duration=None):
    """Create video using timestamp-based lyrics from YouTube transcripts"""
    
    try:
        # Get song data
        query = f"""
        SELECT s.name as song_name, s.location as audio_file,
               l.content as lyrics, a.first_name, a.last_name
        FROM songs s 
        JOIN lyrics l ON s.id = l.song_id 
        JOIN artists a ON s.artist_id = a.id 
        WHERE s.id = {song_id}
        """
        
        df = pd.read_sql(query, engine)
        song_data = df.iloc[0]
        
        print(f"🎵 Creating TIMESTAMP-SYNCED video for: {song_data['song_name']}")
        
        # Construct file paths
        audio_dir = os.path.join(r"C:\ruby\music\public\uploads\song\location", str(song_id))
        audio_path = os.path.join(audio_dir, song_data['audio_file'])
        background_image_path = os.path.join(audio_dir, "Folder.jpg")
        
        print(f"🔊 Audio: {os.path.basename(audio_path)}")
        print(f"🖼️ Background: {os.path.basename(background_image_path)}")
        
        if not os.path.exists(audio_path):
            print("❌ Audio file not found")
            return None
        
        # Load audio clip to get duration
        audio_clip = AudioFileClip(audio_path)
        full_duration = audio_clip.duration
        
        # Apply duration limit
        if max_duration:
            duration = min(max_duration, full_duration)
            print(f"⏱️ Using LIMITED duration: {duration:.1f}s (max_duration={max_duration}s)")
        else:
            duration = full_duration
            print(f"⏱️ Using FULL duration: {duration:.1f}s")
        
        # Trim audio if needed
        if max_duration and full_duration > max_duration:
            audio_clip = audio_clip.subclip(0, duration)
        
        # Parse timestamp-based lyrics
        lyrics_with_timing = parse_timestamp_lyrics(song_data['lyrics'])
        
        if not lyrics_with_timing:
            print("❌ Could not parse timestamp lyrics")
            return None
        
        print(f"📝 Parsed {len(lyrics_with_timing)} timestamped lyrics lines")
        
        # Filter lyrics to only include those within the limited duration
        if max_duration:
            lyrics_with_timing = [lyric for lyric in lyrics_with_timing if lyric['start_time'] < duration]
            # Adjust the end time of the last lyric to match the limited duration
            if lyrics_with_timing and lyrics_with_timing[-1]['end_time'] > duration:
                lyrics_with_timing[-1]['end_time'] = duration
        
        print(f"📝 Final timing: {len(lyrics_with_timing)} lyrics lines")
        print(f"⏱️ Video duration: {duration:.1f}s ({duration/60:.1f} minutes)")
        
        # Display parsed timing with new columns
        # print("\n📋 Parsed Lyrics Timing:")
        # print("-" * 80)
        # for i, lyric in enumerate(lyrics_with_timing):
        #     print(f"{i+1:2d}. {lyric['start_time']:5.1f}s - {lyric['end_time']:5.1f}s:"
        #           f"{lyric['text'][:40]}{'...' if len(lyric['text']) > 40 else ''}|"
        #           f"{lyric['duration_seconds']:4.1f}s|"
        #           f"{lyric['word_count']:2d}|"
        #           f"{lyric['spaces_count']:2d}|"
        #           f"{lyric['char_count']:3d}")
        # print("=" * 80)
        # print("🎵" * 3)
        # end of Display parsed timing with new columns

        # Display parsed timing with new columns
        print("\n📋 Parsed Lyrics Timing:")
        print("-" * 80)
        for i, lyric in enumerate(lyrics_with_timing):
            display_text = lyric['text'][:40] + ('...' if len(lyric['text']) > 40 else '')
    
            print(f"{i+1:2d}. {lyric['start_time']:5.1f}s - {lyric['end_time']:5.1f}s: "
                  f"{display_text:<43} | "  # <-- This ensures fixed width of 43 characters
                  f"{lyric['duration_seconds']:4.1f}s | "
                  f"{lyric['word_count']:2d} | "
                  f"{lyric['spaces_count']:2d} | "
                  f"{lyric['char_count']:3d}")
        # end of Display parsed timing with new columns

        # Video settings
        fps = 24
        width, height = 640, 480
        
        def make_synced_frame(t):
            try:
                # Load background
                if os.path.exists(background_image_path):
                    bg_image = Image.open(background_image_path)
                    bg_image = bg_image.resize((width, height), Image.Resampling.LANCZOS)
                    frame = np.array(bg_image)
                else:
                    frame = np.full((height, width, 3), [40, 40, 80], dtype=np.uint8)
                
                # Convert to PIL for text drawing
                pil_img = Image.fromarray(frame)
                draw = ImageDraw.Draw(pil_img)
                
                # Load font
                try:
                    font = ImageFont.truetype("arial.ttf", 32)
                except:
                    try:
                        font = ImageFont.truetype("C:/Windows/Fonts/arial.ttf", 32)
                    except:
                        font = ImageFont.load_default()
                
                # Get current lyric based on timestamp timing
                current_line = get_current_lyric(t, lyrics_with_timing)
                
                if current_line:
                    # Calculate text position
                    try:
                        bbox = draw.textbbox((0, 0), current_line, font=font)
                    except AttributeError:
                        bbox = draw.textsize(current_line, font=font)
                        bbox = (0, 0, bbox[0], bbox[1])
                    
                    text_width = bbox[2] - bbox[0]
                    text_height = bbox[3] - bbox[1]
                    x = (width - text_width) // 2
                    # y = (height - text_height) // 2
                    y = height - 100  # Position near bottom - the lesser the lower
                    
                    # Semi-transparent background for text
                    padding = 10
                    draw.rectangle([
                        x - padding, y - padding,
                        x + text_width + padding, y + text_height + padding
                    ], fill=(0, 0, 0, 180))
                    
                    # Text with shadow for readability
                    shadow_color = (0, 0, 0)
                    text_color = (255, 255, 255)
                    
                    # Shadow
                    draw.text((x+2, y+2), current_line, font=font, fill=shadow_color)
                    # Main text
                    draw.text((x, y), current_line, font=font, fill=text_color)
                
                return np.array(pil_img)
                
            except Exception as e:
                print(f"❌ Frame error at {t:.1f}s: {e}")
                return np.zeros((height, width, 3), dtype=np.uint8)
        
        # Create video
        print("🎬 Creating timestamp-synced video frames...")
        video = VideoClip(make_synced_frame, duration=duration)
        video = video.set_audio(audio_clip)
        
        # Export
        output_dir = '../data/videos'
        os.makedirs(output_dir, exist_ok=True)
        
        # Include duration in filename
        duration_suffix = f"_{max_duration}s" if max_duration else "_full"
        
        output_file = os.path.join(output_dir, f"{song_data['song_name']}_{artist_name}.mp4")
        
        print("📹 Exporting video...")
        video.write_videofile(
            output_file, 
            fps=fps, 
            codec='libx264',
            audio_codec='aac',
            verbose=False,
            logger=None
        )
        
        print(f"✅ TIMESTAMP-SYNCED VIDEO CREATED: {output_file}")
        print(f"📊 File size: {os.path.getsize(output_file) / (1024*1024):.1f} MB")
        
        # Clean up
        video.close()
        audio_clip.close()
        
        return output_file
        
    except Exception as e:
        print(f"❌ Video creation error: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the timestamp-synced version
if __name__ == "__main__":
    print("=" * 70)
    print("🎬 CREATING TIMESTAMP-SYNCED VIDEO")
    print("=" * 70)
    
    result = create_timestamp_synced_video(song_id=songId, max_duration=None)
    
    if result:
        print(f"\n🎉 SUCCESS! Timestamp-synced video created: {result}")
        print("\n✨ Features:")
        print("   ✅ YouTube transcript timestamp parsing")
        print("   ✅ Pipe separator for timestamps")
        print("   ✅ No complex audio analysis needed")
        print("   ✅ Perfect synchronization with original timestamps")
    else:
        print("\n❌ Timestamp-synced video creation failed")
# Out:
# ======================================================================
# 🎬 CREATING TIMESTAMP-SYNCED VIDEO
# ======================================================================
# 🎵 Creating TIMESTAMP-SYNCED video for: Because You Loved Me
# 🔊 Audio: Because_You_Loved_Me_-_Anonymous.mp3
# 🖼️ Background: Folder.jpg
# ⏱️ Using FULL duration: 355.0s
# 📝 Parsed 65 timestamped lyrics lines
# 📝 Final timing: 65 lyrics lines
# ⏱️ Video duration: 355.0s (5.9 minutes)
#
# 📋 Parsed Lyrics Timing:
# --------------------------------------------------------------------------------
#  1.  21.0s -  25.0s: I was walking in the shadows.               |  4.0s |  6 |  5 |  29
#  2.  25.0s -  30.0s: Couldn't see the light of day.              |  5.0s |  6 |  5 |  30
#  3.  30.0s -  34.0s: Every dream I try to follow,                |  4.0s |  6 |  5 |  28
#  4.  34.0s -  39.0s: somehow it just slipped away.               |  5.0s |  5 |  4 |  29
#  5.  39.0s -  43.0s: But then you came and found me.             |  4.0s |  7 |  6 |  31
#  6.  43.0s -  47.0s: Pulled me from the cold.                    |  4.0s |  5 |  4 |  24
#  7.  47.0s -  51.0s: You gave me hope and meaning.               |  4.0s |  6 |  5 |  29
#  8.  51.0s -  56.0s: You gave me a hand to hold.                 |  5.0s |  7 |  6 |  27
#  9.  56.0s -  60.0s: Because you love me,                        |  4.0s |  4 |  3 |  20
# 10.  60.0s -  65.0s: I learn how to stand tall.                  |  5.0s |  6 |  5 |  26
# 11.  65.0s -  68.0s: Because you love me,                        |  3.0s |  4 |  3 |  20
# 12.  68.0s -  74.0s: I can rise after the fall.                  |  6.0s |  6 |  5 |  26
# 13.  74.0s -  76.0s: Through the heartache                       |  2.0s |  3 |  2 |  21
# 14.  76.0s -  78.0s: and the sorrow,                             |  2.0s |  3 |  2 |  15
# 15.  78.0s -  82.0s: through the nights I thought I drowned      |  4.0s |  7 |  6 |  38
# 16.  82.0s -  86.0s: because you love me.                        |  4.0s |  4 |  3 |  20
# 17.  86.0s - 103.0s: I turn my life around.                      | 17.0s |  5 |  4 |  22
# 18. 103.0s - 108.0s: The blues were heavy on my shoulders.       |  5.0s |  7 |  6 |  37
# 19. 108.0s - 112.0s: The night kept calling my name.             |  4.0s |  6 |  5 |  31
# 20. 112.0s - 116.0s: Whiskey glass on the table.                 |  4.0s |  5 |  4 |  27
# 21. 116.0s - 121.0s: But nothing ever eased the pain.            |  5.0s |  6 |  5 |  32
# 22. 121.0s - 125.0s: THen your arms became my shelter.           |  4.0s |  6 |  5 |  33
# 23. 125.0s - 130.0s: Your voice my sweetest song.                |  5.0s |  5 |  4 |  28
# 24. 130.0s - 134.0s: Because you love me, baby.                  |  4.0s |  5 |  4 |  26
# 25. 134.0s - 139.0s: I knew where I belong.                      |  5.0s |  5 |  4 |  22
# 26. 139.0s - 142.0s: Because you love me,                        |  3.0s |  4 |  3 |  20
# 27. 142.0s - 147.0s: I found the strength inside.                |  5.0s |  5 |  4 |  28
# 28. 147.0s - 151.0s: Because you love me,                        |  4.0s |  4 |  3 |  20
# 29. 151.0s - 156.0s: I no longer have to hide.                   |  5.0s |  6 |  5 |  25
# 30. 156.0s - 159.0s: throudh the silence, through the            |  3.0s |  5 |  4 |  32
# 31. 159.0s - 161.0s: thunder,                                    |  2.0s |  1 |  0 |   8
# 32. 161.0s - 165.0s: through the tears I couldn't fight          |  4.0s |  6 |  5 |  34
# 33. 165.0s - 168.0s: because you love me.                        |  3.0s |  4 |  3 |  20
# 34. 168.0s - 176.0s: I see the morning light.                    |  8.0s |  5 |  4 |  24
# 35. 176.0s - 180.0s: When the world turned its back on me,       |  4.0s |  8 |  7 |  37
# 36. 180.0s - 184.0s: you stayed right by my side                 |  4.0s |  6 |  5 |  27
# 37. 184.0s - 187.0s: Every broken piece you mened, every         |  3.0s |  6 |  5 |  35
# 38. 187.0s - 193.0s: storm you held me tight.                    |  6.0s |  5 |  4 |  24
# 39. 193.0s - 196.0s: Show me what it means                       |  3.0s |  5 |  4 |  21
# 40. 196.0s - 201.0s: to be truly free.                           |  5.0s |  4 |  3 |  17
# 41. 201.0s - 203.0s: Yes, darling.                               |  2.0s |  2 |  1 |  13
# 42. 203.0s - 210.0s: I'm the man I am                            |  7.0s |  5 |  4 |  16
# 43. 210.0s - 239.0s: because you believe in me.                  | 29.0s |  5 |  4 |  26
# 44. 239.0s - 247.0s: Huh? Huh?                                   |  8.0s |  2 |  1 |   9
# 45. 247.0s - 251.0s: Now I'm singing on this stage,              |  4.0s |  6 |  5 |  30
# 46. 251.0s - 255.0s: but it ain't about the fame.                |  4.0s |  6 |  5 |  28
# 47. 255.0s - 259.0s: It's a song of gratitude                    |  4.0s |  5 |  4 |  24
# 48. 259.0s - 264.0s: and it carries your sweet name.             |  5.0s |  6 |  5 |  31
# 49. 264.0s - 268.0s: So let the whole world listen.              |  4.0s |  6 |  5 |  30
# 50. 268.0s - 273.0s: Let the truth be known.                     |  5.0s |  5 |  4 |  23
# 51. 273.0s - 275.0s: Every step                                  |  2.0s |  2 |  1 |  10
# 52. 275.0s - 282.0s: that I've taken, I never walked alone.      |  7.0s |  7 |  6 |  38
# 53. 282.0s - 285.0s: Because you love me,                        |  3.0s |  4 |  3 |  20
# 54. 285.0s - 290.0s: I learn how to stand tall.                  |  5.0s |  6 |  5 |  26
# 55. 290.0s - 294.0s: Because you love me,                        |  4.0s |  4 |  3 |  20
# 56. 294.0s - 299.0s: I can rise after the fall.                  |  5.0s |  6 |  5 |  26
# 57. 299.0s - 304.0s: Through the dark and stormy weather,        |  5.0s |  6 |  5 |  36
# 58. 304.0s - 308.0s: through the nights I thought I drowned      |  4.0s |  7 |  6 |  38
# 59. 308.0s - 311.0s: because you love me.                        |  3.0s |  4 |  3 |  20
# 60. 311.0s - 321.0s: I turn my life around.                      | 10.0s |  5 |  4 |  22
# 61. 321.0s - 328.0s: Baby, because you love me.                  |  7.0s |  5 |  4 |  26
# 62. 328.0s - 330.0s: Yeah.                                       |  2.0s |  1 |  0 |   5
# 63. 330.0s - 337.0s: Because you love me,                        |  7.0s |  4 |  3 |  20
# 64. 337.0s - 343.0s: I'm alive                                   |  6.0s |  2 |  1 |   9
# 65. 343.0s - 348.0s: because you love me.                        |  5.0s |  4 |  3 |  20
# 🎬 Creating timestamp-synced video frames...
# 📹 Exporting video...
# ✅ TIMESTAMP-SYNCED VIDEO CREATED: ../data/videos\Because You Loved Me_Anonymous Singer.mp4
# 📊 File size: 7.7 MB
#
# 🎉 SUCCESS! Timestamp-synced video created: ../data/videos\Because You Loved Me_Anonymous Singer.mp4
#
# ✨ Features:
#    ✅ YouTube transcript timestamp parsing
#    ✅ Pipe separator for timestamps
#    ✅ No complex audio analysis needed
#    ✅ Perfect synchronization with original timestamps
