# %%
from moviepy.editor import *
from sqlalchemy import create_engine
from datetime import datetime
import pandas as pd
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# Your database connection
engine = create_engine('mysql+pymysql://root@localhost:3306/music_development')
data_path = '../data/'

# Get song data
sql = '''
SELECT * FROM songs
WHERE name LIKE "someone you loved"
'''
songs = pd.read_sql(sql, engine)
songId = songs['id'].iloc[0]

# Get lyrics
sql = f"""
SELECT id, song_id, content 
FROM lyrics 
WHERE song_id = {songId}
"""
lyrics = pd.read_sql(sql, engine)
# Get the lyrics content
lyrics_content = lyrics.content.iloc[0]

# Print with proper line breaks (replace \r\n with actual newlines)
print("Full lyrics content:")
print("=" * 50)
print(lyrics_content.replace('\r\n', '\n'))

def parse_timestamp_lyrics(lyrics_text):
    """Parse lyrics with timestamp format from YouTube transcripts using pipe separator"""
    lines = [line.strip() for line in lyrics_text.split('\n') if line.strip()]
    
    lyrics_with_timing = []
    
    for line in lines:
        # Split by the first pipe to separate timestamp from text
        if '|' in line:
            timestamp_str, text = line.split('|', 1)
            try:
                # Convert timestamp to float (seconds)
                timestamp = float(timestamp_str.strip())
                lyrics_with_timing.append({
                    'timestamp': timestamp,
                    'text': text.strip().upper(),  # MODIFIED: Convert to uppercase
                    'start_time': timestamp,
                    'end_time': None  # Will be calculated later
                })
            except ValueError:
                # Skip lines that don't have valid timestamps
                print(f"⚠️ Skipping line with invalid timestamp: {line}")
                continue
        else:
            print(f"⚠️ Skipping line without Pipe separator: {line}")
    
    # Sort by timestamp
    lyrics_with_timing.sort(key=lambda x: x['timestamp'])
    
    # Calculate end times (next line's start time, or song duration for last line)
    for i in range(len(lyrics_with_timing)):
        if i < len(lyrics_with_timing) - 1:
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i + 1]['timestamp']
        else:
            # For the last line, we'll set a default duration
            lyrics_with_timing[i]['end_time'] = lyrics_with_timing[i]['timestamp'] + 5  # 5 seconds default
    
    return lyrics_with_timing
    

    


def get_current_lyric(current_time, lyrics_with_timing):
    """Find which lyric should be displayed at current time"""
    for lyric in lyrics_with_timing:
        if lyric['start_time'] <= current_time < lyric['end_time']:
            return lyric['text']
    return None

def create_timestamp_synced_video(song_id=songId, max_duration=None):
    """Create video using timestamp-based lyrics from YouTube transcripts"""
    
    try:
        # Get song data
        query = f"""
        SELECT s.name as song_name, s.location as audio_file,
               l.content as lyrics, a.first_name, a.last_name
        FROM songs s 
        JOIN lyrics l ON s.id = l.song_id 
        JOIN artists a ON s.artist_id = a.id 
        WHERE s.id = {song_id}
        """
        
        df = pd.read_sql(query, engine)
        song_data = df.iloc[0]
        
        print(f"🎵 Creating TIMESTAMP-SYNCED video for: {song_data['song_name']}")
        
        # Construct file paths
        audio_dir = os.path.join(r"C:\ruby\music\public\uploads\song\location", str(song_id))
        audio_path = os.path.join(audio_dir, song_data['audio_file'])
        background_image_path = os.path.join(audio_dir, "Folder.jpg")
        
        print(f"🔊 Audio: {os.path.basename(audio_path)}")
        print(f"🖼️ Background: {os.path.basename(background_image_path)}")
        
        if not os.path.exists(audio_path):
            print("❌ Audio file not found")
            return None
        
        # Load audio clip to get duration
        audio_clip = AudioFileClip(audio_path)
        full_duration = audio_clip.duration
        
        # Apply duration limit
        if max_duration:
            duration = min(max_duration, full_duration)
            print(f"⏱️ Using LIMITED duration: {duration:.1f}s (max_duration={max_duration}s)")
        else:
            duration = full_duration
            print(f"⏱️ Using FULL duration: {duration:.1f}s")
        
        # Trim audio if needed
        if max_duration and full_duration > max_duration:
            audio_clip = audio_clip.subclip(0, duration)
        
        # Parse timestamp-based lyrics
        lyrics_with_timing = parse_timestamp_lyrics(song_data['lyrics'])
        
        if not lyrics_with_timing:
            print("❌ Could not parse timestamp lyrics")
            return None
        
        print(f"📝 Parsed {len(lyrics_with_timing)} timestamped lyrics lines")
        
        # Filter lyrics to only include those within the limited duration
        if max_duration:
            lyrics_with_timing = [lyric for lyric in lyrics_with_timing if lyric['start_time'] < duration]
            # Adjust the end time of the last lyric to match the limited duration
            if lyrics_with_timing and lyrics_with_timing[-1]['end_time'] > duration:
                lyrics_with_timing[-1]['end_time'] = duration
        
        print(f"📝 Final timing: {len(lyrics_with_timing)} lyrics lines")
        print(f"⏱️ Video duration: {duration:.1f}s ({duration/60:.1f} minutes)")
        
        # Display parsed timing
        print("\n📋 Parsed Lyrics Timing:")
        print("-" * 50)
        for i, lyric in enumerate(lyrics_with_timing):
            print(f"{i+1:2d}. {lyric['start_time']:5.1f}s - {lyric['end_time']:5.1f}s: {lyric['text'][:40]}{'...' if len(lyric['text']) > 40 else ''}")
        
        # Video settings
        fps = 24
        width, height = 640, 480
        
        def make_synced_frame(t):
            try:
                # Load background
                if os.path.exists(background_image_path):
                    bg_image = Image.open(background_image_path)
                    bg_image = bg_image.resize((width, height), Image.Resampling.LANCZOS)
                    frame = np.array(bg_image)
                else:
                    frame = np.full((height, width, 3), [40, 40, 80], dtype=np.uint8)
                
                # Convert to PIL for text drawing
                pil_img = Image.fromarray(frame)
                draw = ImageDraw.Draw(pil_img)
                
                # Load font
                try:
                    font = ImageFont.truetype("arial.ttf", 32)
                except:
                    try:
                        font = ImageFont.truetype("C:/Windows/Fonts/arial.ttf", 32)
                    except:
                        font = ImageFont.load_default()
                
                # Get current lyric based on timestamp timing
                current_line = get_current_lyric(t, lyrics_with_timing)
                
                if current_line:
                    # Calculate text position
                    try:
                        bbox = draw.textbbox((0, 0), current_line, font=font)
                    except AttributeError:
                        bbox = draw.textsize(current_line, font=font)
                        bbox = (0, 0, bbox[0], bbox[1])
                    
                    text_width = bbox[2] - bbox[0]
                    text_height = bbox[3] - bbox[1]
                    x = (width - text_width) // 2
                    # y = (height - text_height) // 2
                    y = height - 200  # Position near bottom - ADJUST THIS VALUE AS NEEDED
                    
                    # Semi-transparent background for text
                    padding = 10
                    draw.rectangle([
                        x - padding, y - padding,
                        x + text_width + padding, y + text_height + padding
                    ], fill=(0, 0, 0, 180))
                    
                    # Text with shadow for readability
                    shadow_color = (0, 0, 0)
                    text_color = (255, 255, 255)
                    
                    # Shadow
                    draw.text((x+2, y+2), current_line, font=font, fill=shadow_color)
                    # Main text
                    draw.text((x, y), current_line, font=font, fill=text_color)
                
                return np.array(pil_img)
                
            except Exception as e:
                print(f"❌ Frame error at {t:.1f}s: {e}")
                return np.zeros((height, width, 3), dtype=np.uint8)
        
        # Create video
        print("🎬 Creating timestamp-synced video frames...")
        video = VideoClip(make_synced_frame, duration=duration)
        video = video.set_audio(audio_clip)
        
        # Export
        output_dir = '../data/videos'
        os.makedirs(output_dir, exist_ok=True)
        
        # Include duration in filename
        duration_suffix = f"_{max_duration}s" if max_duration else "_full"
        
        output_file = os.path.join(output_dir, f"{song_data['song_name']}_Lewis_Capaldi.mp4")
        
        print("📹 Exporting video...")
        video.write_videofile(
            output_file, 
            fps=fps, 
            codec='libx264',
            audio_codec='aac',
            verbose=False,
            logger=None
        )
        
        print(f"✅ TIMESTAMP-SYNCED VIDEO CREATED: {output_file}")
        print(f"📊 File size: {os.path.getsize(output_file) / (1024*1024):.1f} MB")
        
        # Clean up
        video.close()
        audio_clip.close()
        
        return output_file
        
    except Exception as e:
        print(f"❌ Video creation error: {e}")
        import traceback
        traceback.print_exc()
        return None

# Run the timestamp-synced version
if __name__ == "__main__":
    print("=" * 70)
    print("🎬 CREATING TIMESTAMP-SYNCED VIDEO")
    print("=" * 70)
    
    result = create_timestamp_synced_video(song_id=songId, max_duration=None)
    
    if result:
        print(f"\n🎉 SUCCESS! Timestamp-synced video created: {result}")
        print("\n✨ Features:")
        print("   ✅ YouTube transcript timestamp parsing")
        print("   ✅ Pipe separator for timestamps")
        print("   ✅ No complex audio analysis needed")
        print("   ✅ Perfect synchronization with original timestamps")
    else:
        print("\n❌ Timestamp-synced video creation failed")
# Out:
# Full lyrics content:
# ==================================================
# 9|I'm going under and this time
# 12|I fear there's no one to save me
# 18|This all or nothing really
# 21|got a way of driving me crazy
# 25|I need somebody to heal
# 27|Somebody to know
# 29|Somebody to have
# 31|Somebody to hold
# 33|It's easy to say
# 35|But it's never the same
# 38|I guess I kinda liked the
# 40|way you numbed all the pain
#
# 42|Now the day bleeds
# 44|Into nightfall
# 47|And you're not here
# 49|To get me through it all
# 51|I let my guard down
# 53|And then you pulled the rug
# 55|I was getting kinda used to
# 57|being someone you loved
#
# 61|I'm going under and this time
# 64|I fear there's no one to turn to
# 70|This all or nothing way of loving
# 73|got me sleeping without you
# 77|Now, I need somebody to know
# 80|Somebody to heal
# 82|Somebody to have
# 84|Just to know how it feels
# 86|It's easy to say
# 88|but it's never the same
# 91|I guess I kinda liked
# 93|the way you helped me escape
#
# 95|Now the day bleeds
# 97|Into nightfall
# 98|And you're not here
# 100|To get me through it all
# 103|I let my guard down
# 105|And then you pulled the rug
# 107|I was getting kinda used to
# 110|being someone you loved
#
# 113|And I tend to close
# 116|my eyes when it hurts sometimes
# 119|I fall into your arms
# 122|I'll be safe in your
# 125|sound till I come back around
# 129|For now the day bleeds
# 131|Into nightfall
# 133|And you're not here
# 135|To get me through it all
# 138|I let my guard down
# 140|And then you pulled the rug
# 142|I was getting kinda used to
# 144|being someone you loved
#
# 147|But now the day bleeds
# 149|Into nightfall
# 151|And you're not here
# 153|To get me through it all
# 155|I let my guard down
# 157|And then you pulled the rug
# 160|I was getting kinda used to
# 162|being someone you loved
# 165|I let my guard down
# 167|And then you pulled the rug
# 169|I was getting kinda used to
# 171|being someone you loved
#
#
# ======================================================================
# 🎬 CREATING TIMESTAMP-SYNCED VIDEO
# ======================================================================
# 🎵 Creating TIMESTAMP-SYNCED video for: Someone You Loved
# 🔊 Audio: Lewis_Capaldi_-_Someone_You_Loved__Lyrics_.mp3
# 🖼️ Background: Folder.jpg
# ⏱️ Using FULL duration: 182.3s
# 📝 Parsed 65 timestamped lyrics lines
# 📝 Final timing: 65 lyrics lines
# ⏱️ Video duration: 182.3s (3.0 minutes)
#
# 📋 Parsed Lyrics Timing:
# --------------------------------------------------
#  1.   9.0s -  12.0s: I'M GOING UNDER AND THIS TIME
#  2.  12.0s -  18.0s: I FEAR THERE'S NO ONE TO SAVE ME
#  3.  18.0s -  21.0s: THIS ALL OR NOTHING REALLY
#  4.  21.0s -  25.0s: GOT A WAY OF DRIVING ME CRAZY
#  5.  25.0s -  27.0s: I NEED SOMEBODY TO HEAL
#  6.  27.0s -  29.0s: SOMEBODY TO KNOW
#  7.  29.0s -  31.0s: SOMEBODY TO HAVE
#  8.  31.0s -  33.0s: SOMEBODY TO HOLD
#  9.  33.0s -  35.0s: IT'S EASY TO SAY
# 10.  35.0s -  38.0s: BUT IT'S NEVER THE SAME
# 11.  38.0s -  40.0s: I GUESS I KINDA LIKED THE
# 12.  40.0s -  42.0s: WAY YOU NUMBED ALL THE PAIN
# 13.  42.0s -  44.0s: NOW THE DAY BLEEDS
# 14.  44.0s -  47.0s: INTO NIGHTFALL
# 15.  47.0s -  49.0s: AND YOU'RE NOT HERE
# 16.  49.0s -  51.0s: TO GET ME THROUGH IT ALL
# 17.  51.0s -  53.0s: I LET MY GUARD DOWN
# 18.  53.0s -  55.0s: AND THEN YOU PULLED THE RUG
# 19.  55.0s -  57.0s: I WAS GETTING KINDA USED TO
# 20.  57.0s -  61.0s: BEING SOMEONE YOU LOVED
# 21.  61.0s -  64.0s: I'M GOING UNDER AND THIS TIME
# 22.  64.0s -  70.0s: I FEAR THERE'S NO ONE TO TURN TO
# 23.  70.0s -  73.0s: THIS ALL OR NOTHING WAY OF LOVING
# 24.  73.0s -  77.0s: GOT ME SLEEPING WITHOUT YOU
# 25.  77.0s -  80.0s: NOW, I NEED SOMEBODY TO KNOW
# 26.  80.0s -  82.0s: SOMEBODY TO HEAL
# 27.  82.0s -  84.0s: SOMEBODY TO HAVE
# 28.  84.0s -  86.0s: JUST TO KNOW HOW IT FEELS
# 29.  86.0s -  88.0s: IT'S EASY TO SAY
# 30.  88.0s -  91.0s: BUT IT'S NEVER THE SAME
# 31.  91.0s -  93.0s: I GUESS I KINDA LIKED
# 32.  93.0s -  95.0s: THE WAY YOU HELPED ME ESCAPE
# 33.  95.0s -  97.0s: NOW THE DAY BLEEDS
# 34.  97.0s -  98.0s: INTO NIGHTFALL
# 35.  98.0s - 100.0s: AND YOU'RE NOT HERE
# 36. 100.0s - 103.0s: TO GET ME THROUGH IT ALL
# 37. 103.0s - 105.0s: I LET MY GUARD DOWN
# 38. 105.0s - 107.0s: AND THEN YOU PULLED THE RUG
# 39. 107.0s - 110.0s: I WAS GETTING KINDA USED TO
# 40. 110.0s - 113.0s: BEING SOMEONE YOU LOVED
# 41. 113.0s - 116.0s: AND I TEND TO CLOSE
# 42. 116.0s - 119.0s: MY EYES WHEN IT HURTS SOMETIMES
# 43. 119.0s - 122.0s: I FALL INTO YOUR ARMS
# 44. 122.0s - 125.0s: I'LL BE SAFE IN YOUR
# 45. 125.0s - 129.0s: SOUND TILL I COME BACK AROUND
# 46. 129.0s - 131.0s: FOR NOW THE DAY BLEEDS
# 47. 131.0s - 133.0s: INTO NIGHTFALL
# 48. 133.0s - 135.0s: AND YOU'RE NOT HERE
# 49. 135.0s - 138.0s: TO GET ME THROUGH IT ALL
# 50. 138.0s - 140.0s: I LET MY GUARD DOWN
# 51. 140.0s - 142.0s: AND THEN YOU PULLED THE RUG
# 52. 142.0s - 144.0s: I WAS GETTING KINDA USED TO
# 53. 144.0s - 147.0s: BEING SOMEONE YOU LOVED
# 54. 147.0s - 149.0s: BUT NOW THE DAY BLEEDS
# 55. 149.0s - 151.0s: INTO NIGHTFALL
# 56. 151.0s - 153.0s: AND YOU'RE NOT HERE
# 57. 153.0s - 155.0s: TO GET ME THROUGH IT ALL
# 58. 155.0s - 157.0s: I LET MY GUARD DOWN
# 59. 157.0s - 160.0s: AND THEN YOU PULLED THE RUG
# 60. 160.0s - 162.0s: I WAS GETTING KINDA USED TO
# 61. 162.0s - 165.0s: BEING SOMEONE YOU LOVED
# 62. 165.0s - 167.0s: I LET MY GUARD DOWN
# 63. 167.0s - 169.0s: AND THEN YOU PULLED THE RUG
# 64. 169.0s - 171.0s: I WAS GETTING KINDA USED TO
# 65. 171.0s - 176.0s: BEING SOMEONE YOU LOVED
# 🎬 Creating timestamp-synced video frames...
# 📹 Exporting video...
# ✅ TIMESTAMP-SYNCED VIDEO CREATED: ../data/videos\Someone You Loved_timestamp_synced_full.mp4
# 📊 File size: 3.7 MB
#
# 🎉 SUCCESS! Timestamp-synced video created: ../data/videos\Someone You Loved_timestamp_synced_full.mp4
#
# ✨ Features:
#    ✅ YouTube transcript timestamp parsing
#    ✅ Pipe separator for timestamps
#    ✅ No complex audio analysis needed
#    ✅ Perfect synchronization with original timestamps
