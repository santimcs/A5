# %% [markdown]
# ### Restart and Run All

# %%
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

year = 2025
quarter = 2
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2025-08-02 16:33:37

# %%
cols = 'name year quarter q_amt_c q_amt_p inc_profit percent'.split()

format_dict = {
                'q_amt':'{:,}','q_amt_c':'{:,}','q_amt_p':'{:,}','inc_profit':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',   
                'latest_amt':'{:,}','previous_amt':'{:,}','inc_amt':'{:,}',
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'percent':'{:.2f}%','inc_pct':'{:.2f}%'
              }

# %%
sql = '''
SELECT name,year,quarter,q_amt 
FROM epss 
WHERE (year = %s AND quarter <= %s)
OR (year = %s-1 AND quarter >= %s+1) 
ORDER BY year DESC, quarter DESC'''
sql = sql % (year, quarter, year, quarter)
dfc = pd.read_sql(sql, conlt)
dfc['Counter'] = 1
dfc_grp = dfc.groupby(['name'], as_index=False).sum()
dfc_grp = dfc_grp[dfc_grp['Counter'] == 4]
dfc_grp
# Out:
#        name  year  quarter     q_amt  Counter
# 11      AOT  8098       10  19232337        4
# 21      BAY  8098       10  29777061        4
# 22      BBL  8098       10  47338316        4
# 34       BH  8098       10   7449565        4
# 58    DELTA  8098       10  18183229        4
# 69      FPT  8098       10   1511634        4
# 74   GLOBAL  8098       10   2029459        4
# 79   GVREIT  8098       10    484476        4
# 81      HFT  8098       10    213634        4
# 82    HMPRO  8098       10   6274941        4
# 96    KBANK  8098       10  48739130        4
# 100     KKP  8098       10   5181278        4
# 101     KTB  8098       10  44417766        4
# 102     KTC  8098       10   7563281        4
# 107    LHFG  8098       10   2403169        4
# 115      MC  8098       10    738268        4
# 118    MINT  8098       10   7283297        4
# 119     MST  8098       10    377878        4
# 135     PSL  8098       10    345736        4
# 139   PTTEP  8098       10  66239984        4
# 154     SCB  8098       10  47935817        4
# 155     SCC  8098       10  18644986        4
# 157    SCGP  8098       10   2430430        4
# 167     SNC  8098       10    359279        4
# 183   TFFIF  8098       10   -355288        4
# 190   TISCO  8098       10   6702132        4
# 206     TTB  8098       10  20442050        4

# %%
dfc = pd.read_sql(sql, conlt)
dfc["Counter"] = 1
dfc_grp = dfc.groupby(["name"], as_index=False).sum()
dfc_grp = dfc_grp[dfc_grp["Counter"] == 4]
dfc_grp.shape
# Out:
# (27, 5)

# %%
sql = """
SELECT name,year,quarter,q_amt 
FROM epss 
WHERE (year = %s AND quarter <= %s-1) 
OR (year = %s-1 AND quarter >= %s) 
ORDER BY year DESC, quarter DESC"""
sql = sql % (year, quarter, year, quarter)
print(sql)
# Out:
# SELECT name,year,quarter,q_amt
# FROM epss
# WHERE (year = 2025 AND quarter <= 2-1)
# OR (year = 2025-1 AND quarter >= 2)
# ORDER BY year DESC, quarter DESC

# %%
dfp = pd.read_sql(sql, conlt)
dfp['Counter'] = 1
dfp_grp = dfp.groupby(['name'], as_index=False).sum()
dfp_grp = dfp_grp[dfp_grp['Counter'] == 4]
dfp_grp.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac294">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac294_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ac294_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_ac294_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_ac294_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_ac294_level0_col4" class="col_heading level0 col4" >Counter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac294_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac294_row0_col0" class="data row0 col0" >3BBIF</td>
#       <td id="T_ac294_row0_col1" class="data row0 col1" >8097</td>
#       <td id="T_ac294_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_ac294_row0_col3" class="data row0 col3" >5,497,047</td>
#       <td id="T_ac294_row0_col4" class="data row0 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ac294_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac294_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_ac294_row1_col1" class="data row1 col1" >8097</td>
#       <td id="T_ac294_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_ac294_row1_col3" class="data row1 col3" >809,620</td>
#       <td id="T_ac294_row1_col4" class="data row1 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ac294_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac294_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_ac294_row2_col1" class="data row2 col1" >8097</td>
#       <td id="T_ac294_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_ac294_row2_col3" class="data row2 col3" >37,207,829</td>
#       <td id="T_ac294_row2_col4" class="data row2 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ac294_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac294_row3_col0" class="data row3 col0" >AEONTS</td>
#       <td id="T_ac294_row3_col1" class="data row3 col1" >8097</td>
#       <td id="T_ac294_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_ac294_row3_col3" class="data row3 col3" >3,107,917</td>
#       <td id="T_ac294_row3_col4" class="data row3 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ac294_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac294_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_ac294_row4_col1" class="data row4 col1" >8097</td>
#       <td id="T_ac294_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_ac294_row4_col3" class="data row4 col3" >733,651</td>
#       <td id="T_ac294_row4_col4" class="data row4 col4" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfp.name.unique().shape
# Out:
# (224,)

# %%
dfm = pd.merge(dfc_grp, dfp_grp, on="name", suffixes=(["_c", "_p"]), how="inner")
dfm["inc_profit"] = dfm["q_amt_c"] - dfm["q_amt_p"]
dfm["percent"] = round(dfm["inc_profit"] / abs(dfm["q_amt_p"]) * 100, 2)
dfm["year"] = year
dfm["quarter"] = "Q" + str(quarter)
df_percent = dfm[cols]
df_percent.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_08e6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08e6a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_08e6a_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_08e6a_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_08e6a_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_08e6a_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_08e6a_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_08e6a_level0_col6" class="col_heading level0 col6" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08e6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08e6a_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_08e6a_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_08e6a_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_08e6a_row0_col3" class="data row0 col3" >19,232,337</td>
#       <td id="T_08e6a_row0_col4" class="data row0 col4" >19,963,660</td>
#       <td id="T_08e6a_row0_col5" class="data row0 col5" >-731,323</td>
#       <td id="T_08e6a_row0_col6" class="data row0 col6" >-3.66%</td>
#     </tr>
#     <tr>
#       <th id="T_08e6a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08e6a_row1_col0" class="data row1 col0" >BAY</td>
#       <td id="T_08e6a_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_08e6a_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_08e6a_row1_col3" class="data row1 col3" >29,777,061</td>
#       <td id="T_08e6a_row1_col4" class="data row1 col4" >29,690,620</td>
#       <td id="T_08e6a_row1_col5" class="data row1 col5" >86,441</td>
#       <td id="T_08e6a_row1_col6" class="data row1 col6" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_08e6a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08e6a_row2_col0" class="data row2 col0" >BBL</td>
#       <td id="T_08e6a_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_08e6a_row2_col2" class="data row2 col2" >Q2</td>
#       <td id="T_08e6a_row2_col3" class="data row2 col3" >47,338,316</td>
#       <td id="T_08e6a_row2_col4" class="data row2 col4" >47,305,278</td>
#       <td id="T_08e6a_row2_col5" class="data row2 col5" >33,038</td>
#       <td id="T_08e6a_row2_col6" class="data row2 col6" >0.07%</td>
#     </tr>
#     <tr>
#       <th id="T_08e6a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08e6a_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_08e6a_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_08e6a_row3_col2" class="data row3 col2" >Q2</td>
#       <td id="T_08e6a_row3_col3" class="data row3 col3" >7,449,565</td>
#       <td id="T_08e6a_row3_col4" class="data row3 col4" >7,523,720</td>
#       <td id="T_08e6a_row3_col5" class="data row3 col5" >-74,155</td>
#       <td id="T_08e6a_row3_col6" class="data row3 col6" >-0.99%</td>
#     </tr>
#     <tr>
#       <th id="T_08e6a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08e6a_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_08e6a_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_08e6a_row4_col2" class="data row4 col2" >Q2</td>
#       <td id="T_08e6a_row4_col3" class="data row4 col3" >18,183,229</td>
#       <td id="T_08e6a_row4_col4" class="data row4 col4" >20,119,197</td>
#       <td id="T_08e6a_row4_col5" class="data row4 col5" >-1,935,968</td>
#       <td id="T_08e6a_row4_col6" class="data row4 col6" >-9.62%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create the SQL query with parameter binding
sql = text("DELETE FROM qt_profits WHERE year = :year AND quarter = :quarter")

# Execute the query with parameters
params = {'year': year, 'quarter': f'Q{quarter}'}
rp = conlt.execute(sql, params)

# Print the number of rows affected
print("Rows deleted:", rp.rowcount)
# Out:
# Rows deleted: 17

# %%
sql = 'SELECT name, id FROM tickers'
tickers = pd.read_sql(sql, conlt)
tickers.shape
# Out:
# (394, 2)

# %%
df_ins = pd.merge(df_percent, tickers, on="name", how="inner")
df_ins.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5079_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_a5079_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_a5079_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_a5079_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_a5079_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_a5079_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_a5079_level0_col6" class="col_heading level0 col6" >percent</th>
#       <th id="T_a5079_level0_col7" class="col_heading level0 col7" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5079_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_a5079_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_a5079_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_a5079_row0_col3" class="data row0 col3" >19,232,337</td>
#       <td id="T_a5079_row0_col4" class="data row0 col4" >19,963,660</td>
#       <td id="T_a5079_row0_col5" class="data row0 col5" >-731,323</td>
#       <td id="T_a5079_row0_col6" class="data row0 col6" >-3.66%</td>
#       <td id="T_a5079_row0_col7" class="data row0 col7" >24</td>
#     </tr>
#     <tr>
#       <th id="T_a5079_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5079_row1_col0" class="data row1 col0" >BAY</td>
#       <td id="T_a5079_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_a5079_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_a5079_row1_col3" class="data row1 col3" >29,777,061</td>
#       <td id="T_a5079_row1_col4" class="data row1 col4" >29,690,620</td>
#       <td id="T_a5079_row1_col5" class="data row1 col5" >86,441</td>
#       <td id="T_a5079_row1_col6" class="data row1 col6" >0.29%</td>
#       <td id="T_a5079_row1_col7" class="data row1 col7" >49</td>
#     </tr>
#     <tr>
#       <th id="T_a5079_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5079_row2_col0" class="data row2 col0" >BBL</td>
#       <td id="T_a5079_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_a5079_row2_col2" class="data row2 col2" >Q2</td>
#       <td id="T_a5079_row2_col3" class="data row2 col3" >47,338,316</td>
#       <td id="T_a5079_row2_col4" class="data row2 col4" >47,305,278</td>
#       <td id="T_a5079_row2_col5" class="data row2 col5" >33,038</td>
#       <td id="T_a5079_row2_col6" class="data row2 col6" >0.07%</td>
#       <td id="T_a5079_row2_col7" class="data row2 col7" >50</td>
#     </tr>
#     <tr>
#       <th id="T_a5079_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5079_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_a5079_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_a5079_row3_col2" class="data row3 col2" >Q2</td>
#       <td id="T_a5079_row3_col3" class="data row3 col3" >7,449,565</td>
#       <td id="T_a5079_row3_col4" class="data row3 col4" >7,523,720</td>
#       <td id="T_a5079_row3_col5" class="data row3 col5" >-74,155</td>
#       <td id="T_a5079_row3_col6" class="data row3 col6" >-0.99%</td>
#       <td id="T_a5079_row3_col7" class="data row3 col7" >61</td>
#     </tr>
#     <tr>
#       <th id="T_a5079_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5079_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_a5079_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_a5079_row4_col2" class="data row4 col2" >Q2</td>
#       <td id="T_a5079_row4_col3" class="data row4 col3" >18,183,229</td>
#       <td id="T_a5079_row4_col4" class="data row4 col4" >20,119,197</td>
#       <td id="T_a5079_row4_col5" class="data row4 col5" >-1,935,968</td>
#       <td id="T_a5079_row4_col6" class="data row4 col6" >-9.62%</td>
#       <td id="T_a5079_row4_col7" class="data row4 col7" >138</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert DataFrame to list of records
rcds = df_ins.values.tolist()

# Define column names in the same order as values
columns = ['name', 'year', 'quarter', 'latest_amt', 'previous_amt', 'inc_amt', 'inc_pct', 'ticker_id']

# SQL insert statement with named parameters
sql = text("""
    INSERT INTO qt_profits 
    (name, year, quarter, latest_amt, previous_amt, inc_amt, inc_pct, ticker_id)
    VALUES (:name, :year, :quarter, :latest_amt, :previous_amt, :inc_amt, :inc_pct, :ticker_id)
""")

try:
    # Execute inserts
    for rcd in rcds:
        # Convert list to dictionary
        params = dict(zip(columns, rcd))
        conlt.execute(sql, params)
except Exception as e:
    raise e

# %% [markdown]
# ### End of loop

# %%
criteria_1 = df_ins.q_amt_c > 440_000
df_ins.loc[criteria_1, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_36753">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36753_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_36753_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_36753_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_36753_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_36753_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_36753_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_36753_level0_col6" class="col_heading level0 col6" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36753_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36753_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_36753_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_36753_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_36753_row0_col3" class="data row0 col3" >19,232,337</td>
#       <td id="T_36753_row0_col4" class="data row0 col4" >19,963,660</td>
#       <td id="T_36753_row0_col5" class="data row0 col5" >-731,323</td>
#       <td id="T_36753_row0_col6" class="data row0 col6" >-3.66%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36753_row1_col0" class="data row1 col0" >BAY</td>
#       <td id="T_36753_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_36753_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_36753_row1_col3" class="data row1 col3" >29,777,061</td>
#       <td id="T_36753_row1_col4" class="data row1 col4" >29,690,620</td>
#       <td id="T_36753_row1_col5" class="data row1 col5" >86,441</td>
#       <td id="T_36753_row1_col6" class="data row1 col6" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_36753_row2_col0" class="data row2 col0" >BBL</td>
#       <td id="T_36753_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_36753_row2_col2" class="data row2 col2" >Q2</td>
#       <td id="T_36753_row2_col3" class="data row2 col3" >47,338,316</td>
#       <td id="T_36753_row2_col4" class="data row2 col4" >47,305,278</td>
#       <td id="T_36753_row2_col5" class="data row2 col5" >33,038</td>
#       <td id="T_36753_row2_col6" class="data row2 col6" >0.07%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_36753_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_36753_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_36753_row3_col2" class="data row3 col2" >Q2</td>
#       <td id="T_36753_row3_col3" class="data row3 col3" >7,449,565</td>
#       <td id="T_36753_row3_col4" class="data row3 col4" >7,523,720</td>
#       <td id="T_36753_row3_col5" class="data row3 col5" >-74,155</td>
#       <td id="T_36753_row3_col6" class="data row3 col6" >-0.99%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_36753_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_36753_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_36753_row4_col2" class="data row4 col2" >Q2</td>
#       <td id="T_36753_row4_col3" class="data row4 col3" >18,183,229</td>
#       <td id="T_36753_row4_col4" class="data row4 col4" >20,119,197</td>
#       <td id="T_36753_row4_col5" class="data row4 col5" >-1,935,968</td>
#       <td id="T_36753_row4_col6" class="data row4 col6" >-9.62%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_36753_row5_col0" class="data row5 col0" >FPT</td>
#       <td id="T_36753_row5_col1" class="data row5 col1" >2025</td>
#       <td id="T_36753_row5_col2" class="data row5 col2" >Q2</td>
#       <td id="T_36753_row5_col3" class="data row5 col3" >1,511,634</td>
#       <td id="T_36753_row5_col4" class="data row5 col4" >1,447,950</td>
#       <td id="T_36753_row5_col5" class="data row5 col5" >63,684</td>
#       <td id="T_36753_row5_col6" class="data row5 col6" >4.40%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_36753_row6_col0" class="data row6 col0" >GLOBAL</td>
#       <td id="T_36753_row6_col1" class="data row6 col1" >2025</td>
#       <td id="T_36753_row6_col2" class="data row6 col2" >Q2</td>
#       <td id="T_36753_row6_col3" class="data row6 col3" >2,029,459</td>
#       <td id="T_36753_row6_col4" class="data row6 col4" >2,273,624</td>
#       <td id="T_36753_row6_col5" class="data row6 col5" >-244,165</td>
#       <td id="T_36753_row6_col6" class="data row6 col6" >-10.74%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_36753_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_36753_row7_col1" class="data row7 col1" >2025</td>
#       <td id="T_36753_row7_col2" class="data row7 col2" >Q2</td>
#       <td id="T_36753_row7_col3" class="data row7 col3" >484,476</td>
#       <td id="T_36753_row7_col4" class="data row7 col4" >463,216</td>
#       <td id="T_36753_row7_col5" class="data row7 col5" >21,260</td>
#       <td id="T_36753_row7_col6" class="data row7 col6" >4.59%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_36753_row8_col0" class="data row8 col0" >HMPRO</td>
#       <td id="T_36753_row8_col1" class="data row8 col1" >2025</td>
#       <td id="T_36753_row8_col2" class="data row8 col2" >Q2</td>
#       <td id="T_36753_row8_col3" class="data row8 col3" >6,274,941</td>
#       <td id="T_36753_row8_col4" class="data row8 col4" >6,498,086</td>
#       <td id="T_36753_row8_col5" class="data row8 col5" >-223,145</td>
#       <td id="T_36753_row8_col6" class="data row8 col6" >-3.43%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_36753_row9_col0" class="data row9 col0" >KBANK</td>
#       <td id="T_36753_row9_col1" class="data row9 col1" >2025</td>
#       <td id="T_36753_row9_col2" class="data row9 col2" >Q2</td>
#       <td id="T_36753_row9_col3" class="data row9 col3" >48,739,130</td>
#       <td id="T_36753_row9_col4" class="data row9 col4" >48,903,853</td>
#       <td id="T_36753_row9_col5" class="data row9 col5" >-164,723</td>
#       <td id="T_36753_row9_col6" class="data row9 col6" >-0.34%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_36753_row10_col0" class="data row10 col0" >KKP</td>
#       <td id="T_36753_row10_col1" class="data row10 col1" >2025</td>
#       <td id="T_36753_row10_col2" class="data row10 col2" >Q2</td>
#       <td id="T_36753_row10_col3" class="data row10 col3" >5,181,278</td>
#       <td id="T_36753_row10_col4" class="data row10 col4" >4,540,664</td>
#       <td id="T_36753_row10_col5" class="data row10 col5" >640,614</td>
#       <td id="T_36753_row10_col6" class="data row10 col6" >14.11%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_36753_row11_col0" class="data row11 col0" >KTB</td>
#       <td id="T_36753_row11_col1" class="data row11 col1" >2025</td>
#       <td id="T_36753_row11_col2" class="data row11 col2" >Q2</td>
#       <td id="T_36753_row11_col3" class="data row11 col3" >44,417,766</td>
#       <td id="T_36753_row11_col4" class="data row11 col4" >44,490,908</td>
#       <td id="T_36753_row11_col5" class="data row11 col5" >-73,142</td>
#       <td id="T_36753_row11_col6" class="data row11 col6" >-0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_36753_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_36753_row12_col0" class="data row12 col0" >KTC</td>
#       <td id="T_36753_row12_col1" class="data row12 col1" >2025</td>
#       <td id="T_36753_row12_col2" class="data row12 col2" >Q2</td>
#       <td id="T_36753_row12_col3" class="da

# %%
criteria_2 = df_ins.q_amt_p > 400_000
df_ins.loc[criteria_2, cols].head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f720">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f720_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9f720_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_9f720_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_9f720_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_9f720_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_9f720_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_9f720_level0_col6" class="col_heading level0 col6" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f720_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_9f720_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_9f720_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_9f720_row0_col3" class="data row0 col3" >19,232,337</td>
#       <td id="T_9f720_row0_col4" class="data row0 col4" >19,963,660</td>
#       <td id="T_9f720_row0_col5" class="data row0 col5" >-731,323</td>
#       <td id="T_9f720_row0_col6" class="data row0 col6" >-3.66%</td>
#     </tr>
#     <tr>
#       <th id="T_9f720_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f720_row1_col0" class="data row1 col0" >BAY</td>
#       <td id="T_9f720_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_9f720_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_9f720_row1_col3" class="data row1 col3" >29,777,061</td>
#       <td id="T_9f720_row1_col4" class="data row1 col4" >29,690,620</td>
#       <td id="T_9f720_row1_col5" class="data row1 col5" >86,441</td>
#       <td id="T_9f720_row1_col6" class="data row1 col6" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_9f720_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f720_row2_col0" class="data row2 col0" >BBL</td>
#       <td id="T_9f720_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_9f720_row2_col2" class="data row2 col2" >Q2</td>
#       <td id="T_9f720_row2_col3" class="data row2 col3" >47,338,316</td>
#       <td id="T_9f720_row2_col4" class="data row2 col4" >47,305,278</td>
#       <td id="T_9f720_row2_col5" class="data row2 col5" >33,038</td>
#       <td id="T_9f720_row2_col6" class="data row2 col6" >0.07%</td>
#     </tr>
#     <tr>
#       <th id="T_9f720_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f720_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_9f720_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_9f720_row3_col2" class="data row3 col2" >Q2</td>
#       <td id="T_9f720_row3_col3" class="data row3 col3" >7,449,565</td>
#       <td id="T_9f720_row3_col4" class="data row3 col4" >7,523,720</td>
#       <td id="T_9f720_row3_col5" class="data row3 col5" >-74,155</td>
#       <td id="T_9f720_row3_col6" class="data row3 col6" >-0.99%</td>
#     </tr>
#     <tr>
#       <th id="T_9f720_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f720_row4_col0" class="data row4 col0" >DELTA</td>
#       <td id="T_9f720_row4_col1" class="data row4 col1" >2025</td>
#       <td id="T_9f720_row4_col2" class="data row4 col2" >Q2</td>
#       <td id="T_9f720_row4_col3" class="data row4 col3" >18,183,229</td>
#       <td id="T_9f720_row4_col4" class="data row4 col4" >20,119,197</td>
#       <td id="T_9f720_row4_col5" class="data row4 col5" >-1,935,968</td>
#       <td id="T_9f720_row4_col6" class="data row4 col6" >-9.62%</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria_3 = df_ins.percent > 10.00
df_ins.loc[criteria_3, cols].head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3b21d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b21d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3b21d_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_3b21d_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_3b21d_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_3b21d_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_3b21d_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_3b21d_level0_col6" class="col_heading level0 col6" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b21d_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_3b21d_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_3b21d_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_3b21d_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_3b21d_row0_col3" class="data row0 col3" >5,181,278</td>
#       <td id="T_3b21d_row0_col4" class="data row0 col4" >4,540,664</td>
#       <td id="T_3b21d_row0_col5" class="data row0 col5" >640,614</td>
#       <td id="T_3b21d_row0_col6" class="data row0 col6" >14.11%</td>
#     </tr>
#     <tr>
#       <th id="T_3b21d_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_3b21d_row1_col0" class="data row1 col0" >SCC</td>
#       <td id="T_3b21d_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_3b21d_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_3b21d_row1_col3" class="data row1 col3" >18,644,986</td>
#       <td id="T_3b21d_row1_col4" class="data row1 col4" >5,015,628</td>
#       <td id="T_3b21d_row1_col5" class="data row1 col5" >13,629,358</td>
#       <td id="T_3b21d_row1_col6" class="data row1 col6" >271.74%</td>
#     </tr>
#     <tr>
#       <th id="T_3b21d_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_3b21d_row2_col0" class="data row2 col0" >SNC</td>
#       <td id="T_3b21d_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_3b21d_row2_col2" class="data row2 col2" >Q2</td>
#       <td id="T_3b21d_row2_col3" class="data row2 col3" >359,279</td>
#       <td id="T_3b21d_row2_col4" class="data row2 col4" >314,857</td>
#       <td id="T_3b21d_row2_col5" class="data row2 col5" >44,422</td>
#       <td id="T_3b21d_row2_col6" class="data row2 col6" >14.11%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ins_criteria = criteria_1 & criteria_2 & criteria_3
df_ins.loc[df_ins_criteria, cols].head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_342cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_342cb_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_342cb_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_342cb_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_342cb_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_342cb_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_342cb_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_342cb_level0_col6" class="col_heading level0 col6" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_342cb_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_342cb_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_342cb_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_342cb_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_342cb_row0_col3" class="data row0 col3" >5,181,278</td>
#       <td id="T_342cb_row0_col4" class="data row0 col4" >4,540,664</td>
#       <td id="T_342cb_row0_col5" class="data row0 col5" >640,614</td>
#       <td id="T_342cb_row0_col6" class="data row0 col6" >14.11%</td>
#     </tr>
#     <tr>
#       <th id="T_342cb_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_342cb_row1_col0" class="data row1 col0" >SCC</td>
#       <td id="T_342cb_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_342cb_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_342cb_row1_col3" class="data row1 col3" >18,644,986</td>
#       <td id="T_342cb_row1_col4" class="data row1 col4" >5,015,628</td>
#       <td id="T_342cb_row1_col5" class="data row1 col5" >13,629,358</td>
#       <td id="T_342cb_row1_col6" class="data row1 col6" >271.74%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ins[df_ins_criteria].sort_values(by=["percent"], ascending=[False]).head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c612">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c612_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3c612_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_3c612_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_3c612_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_3c612_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_3c612_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_3c612_level0_col6" class="col_heading level0 col6" >percent</th>
#       <th id="T_3c612_level0_col7" class="col_heading level0 col7" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c612_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_3c612_row0_col0" class="data row0 col0" >SCC</td>
#       <td id="T_3c612_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_3c612_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_3c612_row0_col3" class="data row0 col3" >18,644,986</td>
#       <td id="T_3c612_row0_col4" class="data row0 col4" >5,015,628</td>
#       <td id="T_3c612_row0_col5" class="data row0 col5" >13,629,358</td>
#       <td id="T_3c612_row0_col6" class="data row0 col6" >271.74%</td>
#       <td id="T_3c612_row0_col7" class="data row0 col7" >427</td>
#     </tr>
#     <tr>
#       <th id="T_3c612_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_3c612_row1_col0" class="data row1 col0" >KKP</td>
#       <td id="T_3c612_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_3c612_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_3c612_row1_col3" class="data row1 col3" >5,181,278</td>
#       <td id="T_3c612_row1_col4" class="data row1 col4" >4,540,664</td>
#       <td id="T_3c612_row1_col5" class="data row1 col5" >640,614</td>
#       <td id="T_3c612_row1_col6" class="data row1 col6" >14.11%</td>
#       <td id="T_3c612_row1_col7" class="data row1 col7" >255</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ins[df_ins_criteria].sort_values(by=["name"], ascending=[True]).head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ef76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ef76_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_8ef76_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_8ef76_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_8ef76_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_8ef76_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_8ef76_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_8ef76_level0_col6" class="col_heading level0 col6" >percent</th>
#       <th id="T_8ef76_level0_col7" class="col_heading level0 col7" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ef76_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_8ef76_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_8ef76_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_8ef76_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_8ef76_row0_col3" class="data row0 col3" >5,181,278</td>
#       <td id="T_8ef76_row0_col4" class="data row0 col4" >4,540,664</td>
#       <td id="T_8ef76_row0_col5" class="data row0 col5" >640,614</td>
#       <td id="T_8ef76_row0_col6" class="data row0 col6" >14.11%</td>
#       <td id="T_8ef76_row0_col7" class="data row0 col7" >255</td>
#     </tr>
#     <tr>
#       <th id="T_8ef76_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_8ef76_row1_col0" class="data row1 col0" >SCC</td>
#       <td id="T_8ef76_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_8ef76_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_8ef76_row1_col3" class="data row1 col3" >18,644,986</td>
#       <td id="T_8ef76_row1_col4" class="data row1 col4" >5,015,628</td>
#       <td id="T_8ef76_row1_col5" class="data row1 col5" >13,629,358</td>
#       <td id="T_8ef76_row1_col6" class="data row1 col6" >271.74%</td>
#       <td id="T_8ef76_row1_col7" class="data row1 col7" >427</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_ins[df_ins_criteria].sort_values(by=["name"], ascending=[True]).head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40b66_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_40b66_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_40b66_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_40b66_level0_col3" class="col_heading level0 col3" >q_amt_c</th>
#       <th id="T_40b66_level0_col4" class="col_heading level0 col4" >q_amt_p</th>
#       <th id="T_40b66_level0_col5" class="col_heading level0 col5" >inc_profit</th>
#       <th id="T_40b66_level0_col6" class="col_heading level0 col6" >percent</th>
#       <th id="T_40b66_level0_col7" class="col_heading level0 col7" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b66_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_40b66_row0_col0" class="data row0 col0" >KKP</td>
#       <td id="T_40b66_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_40b66_row0_col2" class="data row0 col2" >Q2</td>
#       <td id="T_40b66_row0_col3" class="data row0 col3" >5,181,278</td>
#       <td id="T_40b66_row0_col4" class="data row0 col4" >4,540,664</td>
#       <td id="T_40b66_row0_col5" class="data row0 col5" >640,614</td>
#       <td id="T_40b66_row0_col6" class="data row0 col6" >14.11%</td>
#       <td id="T_40b66_row0_col7" class="data row0 col7" >255</td>
#     </tr>
#     <tr>
#       <th id="T_40b66_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_40b66_row1_col0" class="data row1 col0" >SCC</td>
#       <td id="T_40b66_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_40b66_row1_col2" class="data row1 col2" >Q2</td>
#       <td id="T_40b66_row1_col3" class="data row1 col3" >18,644,986</td>
#       <td id="T_40b66_row1_col4" class="data row1 col4" >5,015,628</td>
#       <td id="T_40b66_row1_col5" class="data row1 col5" >13,629,358</td>
#       <td id="T_40b66_row1_col6" class="data row1 col6" >271.74%</td>
#       <td id="T_40b66_row1_col7" class="data row1 col7" >427</td>
#     </tr>
#   </tbody>
# </table>

# %%
conlt.commit()
conlt.close()

# %%
current_time = datetime.now()
formatted_time = current_time.strftime("%Y:%m:%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025:08:02 16:33:37
