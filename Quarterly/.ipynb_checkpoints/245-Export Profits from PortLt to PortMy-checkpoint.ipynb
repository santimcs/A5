# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine, text

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

year = 2025
quarter = 2
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time )
# Out:
# 2025-08-13 17:09:27

# %% [markdown]
# ### Insert Profits from PortLt to PortMy

# %%
sql = """
SELECT * 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

lt_profits = pd.read_sql(sql, conlt)
lt_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 2
#      id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0  2802    CBG  2025        2     1       3084688         2288670     796018
# 1  2803    CKP  2025        2     1       2412207         1105431    1306776
# 2  2804   GPSC  2025        2     1       4929121         3440570    1488551
# 3  2805   GULF  2025        2     1      95184877        14506279   80678598
# 4  2806    MTC  2025        2     1       6251924         5225764    1026160
# 5  2807    SCC  2025        2     1      18644986        11814106    6830880
# 6  2808   SMPC  2025        2     1        598966          477538     121428
# 7  2809    TVO  2025        2     1       2425616          909838    1515778
# 8  2810  SYNEX  2025        2     1        694197          529751     164446
#
#    inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  inc_pct_py  \
# 0      34.78       3084688  ...    800495   690737      109758   15.889984
# 1     118.21       2412207  ...    610152    73920      536232  725.422078
# 2      43.26       4929121  ...   2019251  1428522      590729   41.352461
# 3     556.16      95184877  ...  63871479        0    63871479  999.990000
# 4      19.64       6251924  ...   1647011  1444235      202776   14.040374
# 5      57.82      18644986  ...  17337286  3707928    13629358  367.573426
# 6      25.43        598966  ...    207612   197354       10258    5.197766
# 7     166.60       2425616  ...    647618   550247       97371   17.695871
# 8      31.04        694197  ...    190158   159905       30253   18.919358
#
#     q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id    mean_pct     std_pct
# 0    760482       40013     5.261532         87   14.905379   14.315010
# 1     70465      539687   765.893706        107  409.526446  390.202145
# 2   1140036      879215    77.121687        197   43.838537   25.996432
# 3  21382850    42488629   198.704237        653  999.990000         NaN
# 4   1571215       75796     4.824037        315   10.463603    7.733210
# 5   1098848    16238438  1477.769264        427  543.725673  636.015611
# 6    145446       62166    42.741636        455   18.777351   19.089449
# 7    533615      114003    21.364279        585   52.460038   76.451262
# 8    188217        1941     1.031256        495   13.887654   13.805954
#
# [9 rows x 23 columns]

# %%
lt_profits = lt_profits.drop(columns=['id'])
lt_profits.shape
# Out:
# (9, 22)

# %%
sql = """
SELECT * 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

my_profits = pd.read_sql(sql, conmy)
my_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 2
#     id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0  173    CBG  2025        2     1       3084688         2288670     796018
# 1  174    CKP  2025        2     1       2412207         1105431    1306776
# 2  175   GPSC  2025        2     1       4929121         3440570    1488551
# 3  176   GULF  2025        2     1      95184877        14506279   80678598
# 4  177    MTC  2025        2     1       6251924         5225764    1026160
# 5  178    SCC  2025        2     1      18644986        11814106    6830880
# 6  179   SMPC  2025        2     1        598966          477538     121428
# 7  180    TVO  2025        2     1       2425616          909838    1515778
# 8  181  SYNEX  2025        2     1        694197          529751     164446
#
#    inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  inc_pct_py  \
# 0      34.78       3084688  ...    800495   690737      109758   15.889984
# 1     118.21       2412207  ...    610152    73920      536232  725.422078
# 2      43.26       4929121  ...   2019251  1428522      590729   41.352461
# 3     556.16      95184877  ...  63871479        0    63871479  999.990000
# 4      19.64       6251924  ...   1647011  1444235      202776   14.040374
# 5      57.82      18644986  ...  17337286  3707928    13629358  367.573426
# 6      25.43        598966  ...    207612   197354       10258    5.197766
# 7     166.60       2425616  ...    647618   550247       97371   17.695871
# 8      31.04        694197  ...    190158   159905       30253   18.919358
#
#     q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id    mean_pct     std_pct
# 0    760482       40013     5.261532         87   14.905379   14.315010
# 1     70465      539687   765.893706        107  409.526446  390.202145
# 2   1140036      879215    77.121687        197   43.838537   25.996432
# 3  21382850    42488629   198.704237        653  999.990000         NaN
# 4   1571215       75796     4.824037        315   10.463603    7.733210
# 5   1098848    16238438  1477.769264        427  543.725673  636.015611
# 6    145446       62166    42.741636        455   18.777351   19.089449
# 7    533615      114003    21.364279        585   52.460038   76.451262
# 8    188217        1941     1.031256        495   13.887654   13.805954
#
# [9 rows x 23 columns]

# %%
conmy.commit()

# %%
quarter
# Out:
# 2

# %%
sqlDel = text("DELETE FROM profits WHERE year = :year AND quarter = :quarter")
print(sqlDel)  # Shows the uncompiled SQL with placeholders

# Execute and get the result
result = conmy.execute(sqlDel, {"year": year, "quarter": quarter})
rows_deleted = result.rowcount  # Get the number of rows deleted
#conmy.commit()  # Commit the transaction

print(f"Number of rows deleted: {rows_deleted}")
# Out:
# DELETE FROM profits WHERE year = :year AND quarter = :quarter
# Number of rows deleted: 9

# %%
# Define SQL statement using named placeholders
sqlInsMy = text("""
INSERT INTO profits (name, year, quarter, kind,
latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
q_amt_c, y_amt, inc_amt_py, inc_pct_py,
q_amt_p, inc_amt_pq, inc_pct_pq,
ticker_id, mean_pct, std_pct)
VALUES (:name, :year, :quarter, :kind,
:latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
:latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
:q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
:q_amt_p, :inc_amt_pq, :inc_pct_pq,
:ticker_id, :mean_pct, :std_pct)
""")
print(sqlInsMy)
# Out:
# INSERT INTO profits (name, year, quarter, kind,
# latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
# latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
# q_amt_c, y_amt, inc_amt_py, inc_pct_py,
# q_amt_p, inc_amt_pq, inc_pct_pq,
# ticker_id, mean_pct, std_pct)
# VALUES (:name, :year, :quarter, :kind,
# :latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
# :latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
# :q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
# :q_amt_p, :inc_amt_pq, :inc_pct_pq,
# :ticker_id, :mean_pct, :std_pct)

# %%
rcds = lt_profits.values.tolist()
print(f"Number of rows to insert: {len(rcds)}")
# Out:
# Number of rows to insert: 9

# %%
# Convert list data to dictionaries for named parameters
columns = [
    "name", "year", "quarter", "kind",
    "latest_amt_y", "previous_amt_y", "inc_amt_y", "inc_pct_y",
    "latest_amt_q", "previous_amt_q", "inc_amt_q", "inc_pct_q",
    "q_amt_c", "y_amt", "inc_amt_py", "inc_pct_py",
    "q_amt_p", "inc_amt_pq", "inc_pct_pq",
    "ticker_id", "mean_pct", "std_pct"
]

records_dicts = [dict(zip(columns, rcd)) for rcd in rcds]
#print(records_dicts)

# Insert data using transactions
try:
    result = conmy.execute(sqlInsMy, records_dicts)  # Bulk insert using named parameters
    rows_insert = result.rowcount
    print(f"{rows_insert} rows inserted successfully!")
except Exception as e:
    print("Error inserting data:", e)
finally:
    conmy.commit()
# Out:
# 9 rows inserted successfully!

# %% [markdown]
# ### PortPg Process

# %%
sql = """
SELECT * 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

pg_profits = pd.read_sql(sql, conmy)
pg_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 2
#     id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0  182    CBG  2025        2     1       3084688         2288670     796018
# 1  183    CKP  2025        2     1       2412207         1105431    1306776
# 2  184   GPSC  2025        2     1       4929121         3440570    1488551
# 3  185   GULF  2025        2     1      95184877        14506279   80678598
# 4  186    MTC  2025        2     1       6251924         5225764    1026160
# 5  187    SCC  2025        2     1      18644986        11814106    6830880
# 6  188   SMPC  2025        2     1        598966          477538     121428
# 7  189    TVO  2025        2     1       2425616          909838    1515778
# 8  190  SYNEX  2025        2     1        694197          529751     164446
#
#    inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  inc_pct_py  \
# 0      34.78       3084688  ...    800495   690737      109758   15.889984
# 1     118.21       2412207  ...    610152    73920      536232  725.422078
# 2      43.26       4929121  ...   2019251  1428522      590729   41.352461
# 3     556.16      95184877  ...  63871479        0    63871479  999.990000
# 4      19.64       6251924  ...   1647011  1444235      202776   14.040374
# 5      57.82      18644986  ...  17337286  3707928    13629358  367.573426
# 6      25.43        598966  ...    207612   197354       10258    5.197766
# 7     166.60       2425616  ...    647618   550247       97371   17.695871
# 8      31.04        694197  ...    190158   159905       30253   18.919358
#
#     q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id    mean_pct     std_pct
# 0    760482       40013     5.261532         87   14.905379   14.315010
# 1     70465      539687   765.893706        107  409.526446  390.202145
# 2   1140036      879215    77.121687        197   43.838537   25.996432
# 3  21382850    42488629   198.704237        653  999.990000         NaN
# 4   1571215       75796     4.824037        315   10.463603    7.733210
# 5   1098848    16238438  1477.769264        427  543.725673  636.015611
# 6    145446       62166    42.741636        455   18.777351   19.089449
# 7    533615      114003    21.364279        585   52.460038   76.451262
# 8    188217        1941     1.031256        495   13.887654   13.805954
#
# [9 rows x 23 columns]

# %%
sqlDel = text("DELETE FROM profits WHERE year = :year AND quarter = :quarter")
print(sqlDel)  # Shows the uncompiled SQL with placeholders

# Execute and get the result
result = conpg.execute(sqlDel, {"year": year, "quarter": quarter})
rows_deleted = result.rowcount  # Get the number of rows deleted

print(f"Number of rows deleted: {rows_deleted}")
# Out:
# DELETE FROM profits WHERE year = :year AND quarter = :quarter
# Number of rows deleted: 9

# %%
sql = 'SELECT name, id FROM tickers'
pg_tickers = pd.read_sql(sql, conpg)
pg_tickers.shape
# Out:
# (396, 2)

# %%
pg_tickers.query('name == "GULF"')
# Out:
#      name   id
# 129  GULF  207

# %%
df_merge = pd.merge(my_profits, pg_tickers, on="name", how="inner")
df_merge.rename(columns={"id": "ticker_id"}, inplace=True)

# %%
df_merge.shape
# Out:
# (9, 24)

# %%
df_merge.dtypes
# Out:
# id_x                int64
# name               object
# year                int64
# quarter             int64
# kind                int64
# latest_amt_y        int64
# previous_amt_y      int64
# inc_amt_y           int64
# inc_pct_y         float64
# latest_amt_q        int64
# previous_amt_q      int64
# inc_amt_q           int64
# inc_pct_q         float64
# q_amt_c             int64
# y_amt               int64
# inc_amt_py          int64
# inc_pct_py        float64
# q_amt_p             int64
# inc_amt_pq          int64
# inc_pct_pq        float64
# ticker_id           int64
# mean_pct          float64
# std_pct           float64
# id_y                int64
# dtype: object

# %%
colv = 'name year quarter kind latest_amt_y previous_amt_y inc_amt_y inc_pct_y \
        latest_amt_q previous_amt_q inc_amt_q inc_pct_q q_amt_c y_amt \
        inc_amt_py inc_pct_py q_amt_p inc_amt_pq inc_pct_pq \
        ticker_id mean_pct std_pct'.split()
format_dict = {
    'q_amt': '{:,}',
    'y_amt': '{:,}',
    'yoy_gain': '{:,}',
    'q_amt_c': '{:,}',
    'q_amt_p': '{:,}',
    'aq_amt': '{:,}',
    'ay_amt': '{:,}',
    'acc_gain': '{:,}',
    'latest_amt': '{:,}',
    'previous_amt': '{:,}',
    'inc_amt': '{:,}',
    'inc_amt_pq': '{:,}',
    'inc_amt_py': '{:,}',    
    'latest_amt_q': '{:,}',
    'previous_amt_q': '{:,}',
    'inc_amt_q': '{:,}',
    'latest_amt_y': '{:,}',
    'previous_amt_y': '{:,}',
    'inc_amt_y': '{:,}',
    'kind_x': '{:,}',
    'inc_pct': '{:.2f}%',
    'inc_pct_q': '{:.2f}%',
    'inc_pct_y': '{:.2f}%',
    'inc_pct_pq': '{:.2f}%',
    'inc_pct_py': '{:.2f}%',   
    'mean_pct': '{:.2f}%',
    'std_pct': '{:.2f}%',      
}

# %%
final = df_merge[colv].copy()
final.sort_values(by=['ticker_id'],ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_94420">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94420_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_94420_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_94420_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_94420_level0_col3" class="col_heading level0 col3" >kind</th>
#       <th id="T_94420_level0_col4" class="col_heading level0 col4" >latest_amt_y</th>
#       <th id="T_94420_level0_col5" class="col_heading level0 col5" >previous_amt_y</th>
#       <th id="T_94420_level0_col6" class="col_heading level0 col6" >inc_amt_y</th>
#       <th id="T_94420_level0_col7" class="col_heading level0 col7" >inc_pct_y</th>
#       <th id="T_94420_level0_col8" class="col_heading level0 col8" >latest_amt_q</th>
#       <th id="T_94420_level0_col9" class="col_heading level0 col9" >previous_amt_q</th>
#       <th id="T_94420_level0_col10" class="col_heading level0 col10" >inc_amt_q</th>
#       <th id="T_94420_level0_col11" class="col_heading level0 col11" >inc_pct_q</th>
#       <th id="T_94420_level0_col12" class="col_heading level0 col12" >q_amt_c</th>
#       <th id="T_94420_level0_col13" class="col_heading level0 col13" >y_amt</th>
#       <th id="T_94420_level0_col14" class="col_heading level0 col14" >inc_amt_py</th>
#       <th id="T_94420_level0_col15" class="col_heading level0 col15" >inc_pct_py</th>
#       <th id="T_94420_level0_col16" class="col_heading level0 col16" >q_amt_p</th>
#       <th id="T_94420_level0_col17" class="col_heading level0 col17" >inc_amt_pq</th>
#       <th id="T_94420_level0_col18" class="col_heading level0 col18" >inc_pct_pq</th>
#       <th id="T_94420_level0_col19" class="col_heading level0 col19" >ticker_id</th>
#       <th id="T_94420_level0_col20" class="col_heading level0 col20" >mean_pct</th>
#       <th id="T_94420_level0_col21" class="col_heading level0 col21" >std_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94420_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94420_row0_col0" class="data row0 col0" >CBG</td>
#       <td id="T_94420_row0_col1" class="data row0 col1" >2025</td>
#       <td id="T_94420_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_94420_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_94420_row0_col4" class="data row0 col4" >3,084,688</td>
#       <td id="T_94420_row0_col5" class="data row0 col5" >2,288,670</td>
#       <td id="T_94420_row0_col6" class="data row0 col6" >796,018</td>
#       <td id="T_94420_row0_col7" class="data row0 col7" >34.78%</td>
#       <td id="T_94420_row0_col8" class="data row0 col8" >3,084,688</td>
#       <td id="T_94420_row0_col9" class="data row0 col9" >2,974,930</td>
#       <td id="T_94420_row0_col10" class="data row0 col10" >109,758</td>
#       <td id="T_94420_row0_col11" class="data row0 col11" >3.69%</td>
#       <td id="T_94420_row0_col12" class="data row0 col12" >800,495</td>
#       <td id="T_94420_row0_col13" class="data row0 col13" >690,737</td>
#       <td id="T_94420_row0_col14" class="data row0 col14" >109,758</td>
#       <td id="T_94420_row0_col15" class="data row0 col15" >15.89%</td>
#       <td id="T_94420_row0_col16" class="data row0 col16" >760,482</td>
#       <td id="T_94420_row0_col17" class="data row0 col17" >40,013</td>
#       <td id="T_94420_row0_col18" class="data row0 col18" >5.26%</td>
#       <td id="T_94420_row0_col19" class="data row0 col19" >87</td>
#       <td id="T_94420_row0_col20" class="data row0 col20" >14.91%</td>
#       <td id="T_94420_row0_col21" class="data row0 col21" >14.32%</td>
#     </tr>
#     <tr>
#       <th id="T_94420_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94420_row1_col0" class="data row1 col0" >CKP</td>
#       <td id="T_94420_row1_col1" class="data row1 col1" >2025</td>
#       <td id="T_94420_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_94420_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_94420_row1_col4" class="data row1 col4" >2,412,207</td>
#       <td id="T_94420_row1_col5" class="data row1 col5" >1,105,431</td>
#       <td id="T_94420_row1_col6" class="data row1 col6" >1,306,776</td>
#       <td id="T_94420_row1_col7" class="data row1 col7" >118.21%</td>
#       <td id="T_94420_row1_col8" class="data row1 col8" >2,412,207</td>
#       <td id="T_94420_row1_col9" class="data row1 col9" >1,875,975</td>
#       <td id="T_94420_row1_col10" class="data row1 col10" >536,232</td>
#       <td id="T_94420_row1_col11" class="data row1 col11" >28.58%</td>
#       <td id="T_94420_row1_col12" class="data row1 col12" >610,152</td>
#       <td id="T_94420_row1_col13" class="data row1 col13" >73,920</td>
#       <td id="T_94420_row1_col14" class="data row1 col14" >536,232</td>
#       <td id="T_94420_row1_col15" class="data row1 col15" >725.42%</td>
#       <td id="T_94420_row1_col16" class="data row1 col16" >70,465</td>
#       <td id="T_94420_row1_col17" class="data row1 col17" >539,687</td>
#       <td id="T_94420_row1_col18" class="data row1 col18" >765.89%</td>
#       <td id="T_94420_row1_col19" class="data row1 col19" >107</td>
#       <td id="T_94420_row1_col20" class="data row1 col20" >409.53%</td>
#       <td id="T_94420_row1_col21" class="data row1 col21" >390.20%</td>
#     </tr>
#     <tr>
#       <th id="T_94420_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94420_row2_col0" class="data row2 col0" >GPSC</td>
#       <td id="T_94420_row2_col1" class="data row2 col1" >2025</td>
#       <td id="T_94420_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_94420_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_94420_row2_col4" class="data row2 col4" >4,929,121</td>
#       <td id="T_94420_row2_col5" class="data row2 col5" >3,440,570</td>
#       <td id="T_94420_row2_col6" class="data row2 col6" >1,488,551</td>
#       <td id="T_94420_row2_col7" class="data row2 col7" >43.26%</td>
#       <td id="T_94420_row2_col8" class="data row2 col8" >4,929,121</td>
#       <td id="T_94420_row2_col9" class="data row2 col9" >4,338,392</td>
#       <td id="T_94420_row2_col10" class="data row2 col10" >590,729</td>
#       <td id="T_94420_row2_col11" class="data row2 col11" >13.62%</td>
#       <td id="T_94420_row2_col12" class="data row2 col12" >2,019,251</td>
#       <td id="T_94420_row2_col13" class="data row2 col13" >1,428,522</td>
#       <td id="T_94420_row2_col14" class="data row2 col14" >590,729</td>
#       <td id="T_94420_row2_col15" class="data row2 col15" >41.35%</td>
#       <td id="T_94420_row2_col16" class="data row2 col16" >1,140,036</td>
#       <td id="T_94420_row2_col17" class="data row2 col17" >879,215</td>
#       <td id="T_94420_row2_col18" class="data row2 col18" >77.12%</td>
#       <td id="T_94420_row2_col19" class="data row2 col19" >197</td>
#       <td id="T_94420_row2_col20" class="data row2 col20" >43.84%</td>
#       <td id="T_94420_row2_col21" class="data row2 col21" >26.00%</td>
#     </tr>
#     <tr>
#       <th id="T_94420_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_94420_row3_col0" class="data row3 col0" >MTC</td>
#       <td id="T_94420_row3_col1" class="data row3 col1" >2025</td>
#       <td id="T_94420_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_94420_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_94420_row3_col4" class="data row3 col4" >6,251,924</td>
#       <td id="T_94420_row3_col5" class="data row3 col5" >5,225,764</td>
#       <td id="T_94420_row3_col6" class="data row3 col6" >1,026,160</td>
#       <td id="T_94420_row3_col7" class="data row3 col7" >19.64%</td>
#       <td id="T_94420_row3_col8" class="data row3 col8" >6,251,924</td>
#       <td id="T_94420_row3_col9" class="data row3 col9" >6,049,148</td>
#       <td id="T_94420_row3_col10" class="data row3 col10" >202,776</td>
#       <td id="T_94420_row3_col11" class="data row3 col11" >3.35%</td>
#       <td id="T_94420_row3_col12" class="data row3 col12" >1,647,011</td>
#       <td id="T_94420_row3_col13" class="data row3 col13" >1,444,235</td>
#       <td id="T_94420_row

# %%
#final = final[final['name'] != 'GULF']
#final

# %%
final.loc[final['name'] == 'MTC', 'ticker_id'] = 323
final.loc[final['name'] == 'GULF', 'ticker_id'] = 207
final
# Out:
#     name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0    CBG  2025        2     1       3084688         2288670     796018
# 1    CKP  2025        2     1       2412207         1105431    1306776
# 2   GPSC  2025        2     1       4929121         3440570    1488551
# 3   GULF  2025        2     1      95184877        14506279   80678598
# 4    MTC  2025        2     1       6251924         5225764    1026160
# 5    SCC  2025        2     1      18644986        11814106    6830880
# 6   SMPC  2025        2     1        598966          477538     121428
# 7    TVO  2025        2     1       2425616          909838    1515778
# 8  SYNEX  2025        2     1        694197          529751     164446
#
#    inc_pct_y  latest_amt_q  previous_amt_q  ...   q_amt_c    y_amt  \
# 0      34.78       3084688         2974930  ...    800495   690737
# 1     118.21       2412207         1875975  ...    610152    73920
# 2      43.26       4929121         4338392  ...   2019251  1428522
# 3     556.16      95184877        36054658  ...  63871479        0
# 4      19.64       6251924         6049148  ...   1647011  1444235
# 5      57.82      18644986         5015628  ...  17337286  3707928
# 6      25.43        598966          588708  ...    207612   197354
# 7     166.60       2425616         2328245  ...    647618   550247
# 8      31.04        694197          663944  ...    190158   159905
#
#    inc_amt_py  inc_pct_py   q_amt_p  inc_amt_pq   inc_pct_pq  ticker_id  \
# 0      109758   15.889984    760482       40013     5.261532         87
# 1      536232  725.422078     70465      539687   765.893706        107
# 2      590729   41.352461   1140036      879215    77.121687        197
# 3    63871479  999.990000  21382850    42488629   198.704237        207
# 4      202776   14.040374   1571215       75796     4.824037        323
# 5    13629358  367.573426   1098848    16238438  1477.769264        427
# 6       10258    5.197766    145446       62166    42.741636        455
# 7       97371   17.695871    533615      114003    21.364279        585
# 8       30253   18.919358    188217        1941     1.031256        495
#
#      mean_pct     std_pct
# 0   14.905379   14.315010
# 1  409.526446  390.202145
# 2   43.838537   25.996432
# 3  999.990000         NaN
# 4   10.463603    7.733210
# 5  543.725673  636.015611
# 6   18.777351   19.089449
# 7   52.460038   76.451262
# 8   13.887654   13.805954
#
# [9 rows x 22 columns]

# %%
# Define SQL statement using named placeholders
sqlInsPg = text("""
INSERT INTO profits (name, year, quarter, kind,
latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
q_amt_c, y_amt, inc_amt_py, inc_pct_py,
q_amt_p, inc_amt_pq, inc_pct_pq,
ticker_id, mean_pct, std_pct)
VALUES (:name, :year, :quarter, :kind,
:latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
:latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
:q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
:q_amt_p, :inc_amt_pq, :inc_pct_pq,
:ticker_id, :mean_pct, :std_pct)
""")

# Convert list data to dictionaries for named parameters
columns = [
    "name", "year", "quarter", "kind",
    "latest_amt_y", "previous_amt_y", "inc_amt_y", "inc_pct_y",
    "latest_amt_q", "previous_amt_q", "inc_amt_q", "inc_pct_q",
    "q_amt_c", "y_amt", "inc_amt_py", "inc_pct_py",
    "q_amt_p", "inc_amt_pq", "inc_pct_pq",
    "ticker_id", "mean_pct", "std_pct"
]
print(sqlInsPg)
# Out:
# INSERT INTO profits (name, year, quarter, kind,
# latest_amt_y, previous_amt_y, inc_amt_y, inc_pct_y,
# latest_amt_q, previous_amt_q, inc_amt_q, inc_pct_q,
# q_amt_c, y_amt, inc_amt_py, inc_pct_py,
# q_amt_p, inc_amt_pq, inc_pct_pq,
# ticker_id, mean_pct, std_pct)
# VALUES (:name, :year, :quarter, :kind,
# :latest_amt_y, :previous_amt_y, :inc_amt_y, :inc_pct_y,
# :latest_amt_q, :previous_amt_q, :inc_amt_q, :inc_pct_q,
# :q_amt_c, :y_amt, :inc_amt_py, :inc_pct_py,
# :q_amt_p, :inc_amt_pq, :inc_pct_pq,
# :ticker_id, :mean_pct, :std_pct)

# %%
rcds = final.values.tolist()
print(f"Number of rows to insert: {len(rcds)}")
# Out:
# Number of rows to insert: 9

# %%
records_dicts = [dict(zip(columns, rcd)) for rcd in rcds]
#print(records_dicts)

# Check for empty records before attempting insertion
if not rcds:
    print("No records to insert - skipping database operation")
    # In notebook/script context, just proceed to next cell instead of 'return'
try:
    result = conpg.execute(sqlInsPg, records_dicts)  # Bulk insert using named parameters
    rows_insert = result.rowcount
    print(f"{rows_insert} rows inserted successfully!")
except Exception as e:
    print("Error inserting data:", e)
finally:
    conpg.commit()
# Out:
# 9 rows inserted successfully!

# %%
sql = """
SELECT * 
FROM profits 
WHERE  year = %s AND quarter = %s"""
sql = sql % (year, quarter)
print(sql)

pg_profits = pd.read_sql(sql, conpg)
pg_profits
# Out:
# SELECT *
# FROM profits
# WHERE  year = 2025 AND quarter = 2
#       id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0  67741    CBG  2025        2     1       3084688         2288670     796018
# 1  67742    CKP  2025        2     1       2412207         1105431    1306776
# 2  67743   GPSC  2025        2     1       4929121         3440570    1488551
# 3  67744   GULF  2025        2     1      95184877        14506279   80678598
# 4  67745    MTC  2025        2     1       6251924         5225764    1026160
# 5  67746    SCC  2025        2     1      18644986        11814106    6830880
# 6  67747   SMPC  2025        2     1        598966          477538     121428
# 7  67748    TVO  2025        2     1       2425616          909838    1515778
# 8  67749  SYNEX  2025        2     1        694197          529751     164446
#
#    inc_pct_y  latest_amt_q  ...    y_amt  inc_amt_py  inc_pct_py   q_amt_p  \
# 0      34.78       3084688  ...   690737      109758   15.889984    760482
# 1     118.21       2412207  ...    73920      536232  725.422078     70465
# 2      43.26       4929121  ...  1428522      590729   41.352461   1140036
# 3     556.16      95184877  ...        0    63871479  999.990000  21382850
# 4      19.64       6251924  ...  1444235      202776   14.040374   1571215
# 5      57.82      18644986  ...  3707928    13629358  367.573426   1098848
# 6      25.43        598966  ...   197354       10258    5.197766    145446
# 7     166.60       2425616  ...   550247       97371   17.695871    533615
# 8      31.04        694197  ...   159905       30253   18.919358    188217
#
#    inc_amt_pq   inc_pct_pq    mean_pct     std_pct  publish_date  ticker_id
# 0       40013     5.261532   14.905379   14.315010          None         87
# 1      539687   765.893706  409.526446  390.202145          None        107
# 2      879215    77.121687   43.838537   25.996432          None        197
# 3    42488629   198.704237  999.990000         NaN          None        207
# 4       75796     4.824037   10.463603    7.733210          None        323
# 5    16238438  1477.769264  543.725673  636.015611          None        427
# 6       62166    42.741636   18.777351   19.089449          None        455
# 7      114003    21.364279   52.460038   76.451262          None        585
# 8        1941     1.031256   13.887654   13.805954          None        495
#
# [9 rows x 24 columns]
