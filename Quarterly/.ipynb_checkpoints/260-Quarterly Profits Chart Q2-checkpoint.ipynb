# %%
ticker = 'TVO'
year = 2024
quarter = 2
strqtr = 'Q' + str(quarter)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3')
conlt = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

format_dict = {'latest_amt':'{:,}','previous_amt':'{:,}','q_amt':'{:,}','y_amt':'{:,}','diff':'{:,}',
               'inc_amt':'{:,}','inc_pct':'{:.2f}'}

# %%
sql = '''
SELECT * 
FROM epss
WHERE name = '%s'
AND ((year = %s-2 AND quarter >= %s+1) OR (year >= %s-1))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year)
print(sql)
# Out:
# SELECT *
# FROM epss
# WHERE name = 'TVO'
# AND ((year = 2024-2 AND quarter >= 2+1) OR (year >= 2024-1))
# ORDER BY year, quarter

# %%
rp = conlt.execute(sql)
profit = pd.DataFrame(rp.fetchall())
profit.columns = rp.keys()

with plt.style.context('my_custom_style'):
    fig_name = ticker+'-qtr'+'.png'
    fig_path = '../FIG/profits/'+fig_name    

    ax = profit.plot.bar(x='quarter', y=['q_amt'])
    ax.set_title(ticker)
    ax.set_ylabel("Profit Amount")
    plt.savefig(fig_path)
    plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9176\2177461461.py:1: RemovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   rp = conlt.execute(sql)

# %% [markdown]
# ### Create previous year data

# %%
sql = '''
SELECT q_amt
FROM epss
WHERE name = '%s'
AND ((year = %s-2 AND quarter >= %s+1) OR (year = %s-1 AND quarter <= %s))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year,quarter)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'TVO'
# AND ((year = 2024-2 AND quarter >= 2+1) OR (year = 2024-1 AND quarter <= 2))
# ORDER BY year, quarter

# %%
data_last_year = pd.read_sql(sql, conlt)
data_last_year.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea900_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >q_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea900_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea900_row0_col0" class="data row0 col0" >592,753</td>
#     </tr>
#     <tr>
#       <th id="T_ea900_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea900_row1_col0" class="data row1 col0" >-603,226</td>
#     </tr>
#     <tr>
#       <th id="T_ea900_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea900_row2_col0" class="data row2 col0" >128,193</td>
#     </tr>
#     <tr>
#       <th id="T_ea900_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea900_row3_col0" class="data row3 col0" >35,204</td>
#     </tr>
#   </tbody>
# </table>

# %%
profit_last_year = data_last_year.values
profit_last_year
# Out:
# array([[ 592753],
#        [-603226],
#        [ 128193],
#        [  35204]], dtype=int64)

# %% [markdown]
# ### Create current year data

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND ((year = %s-1 AND quarter >= %s+1) OR (year = %s))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'TVO'
# AND ((year = 2024-1 AND quarter >= 2+1) OR (year = 2024))
# ORDER BY year, quarter

# %%
data_this_year = pd.read_sql(sql, conlt)
data_this_year.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_de813_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >q_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de813_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de813_row0_col0" class="data row0 col0" >250,424</td>
#     </tr>
#     <tr>
#       <th id="T_de813_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de813_row1_col0" class="data row1 col0" >315,735</td>
#     </tr>
#     <tr>
#       <th id="T_de813_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_de813_row2_col0" class="data row2 col0" >308,475</td>
#     </tr>
#     <tr>
#       <th id="T_de813_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_de813_row3_col0" class="data row3 col0" >550,247</td>
#     </tr>
#   </tbody>
# </table>

# %%
profit_this_year = data_this_year.values
profit_this_year
# Out:
# array([[250424],
#        [315735],
#        [308475],
#        [550247]], dtype=int64)

# %%
# from python data analytics
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Q'+'.png'
    fig_path = '../FIG/profits/'+fig_name    
    
    index = np.arange(4)
    bw = 0.4
    
    plt.title(ticker, fontsize=40)
    plt.ylabel("Profit Amount", fontsize=20)   
    
    plt.bar(index + 0.0, profit_last_year.reshape(profit_last_year.shape[0]), bw, color='y')
    plt.bar(index + bw,   profit_this_year.reshape(profit_this_year.shape[0]), bw, color='g')   

    plt.xticks(index+1*bw, ['2023-Q3','2023-Q4','2024-Q1','2024-Q2'])

    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name = '%s' AND quarter = 'Q%s'
'''
sql = sql % (ticker,quarter)
print(sql)
# Out:
# SELECT *
# FROM yr_profits
# WHERE name = 'TVO' AND quarter = 'Q2'

# %%
yr_profits = pd.read_sql(sql, conlt)
yr_profits.sort_values(['year'],ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ad634_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >quarter</th>
#       <th class="col_heading level0 col4" >latest_amt</th>
#       <th class="col_heading level0 col5" >previous_amt</th>
#       <th class="col_heading level0 col6" >inc_amt</th>
#       <th class="col_heading level0 col7" >inc_pct</th>
#       <th class="col_heading level0 col8" >ticker_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad634_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_ad634_row0_col0" class="data row0 col0" >101380</td>
#       <td id="T_ad634_row0_col1" class="data row0 col1" >TVO</td>
#       <td id="T_ad634_row0_col2" class="data row0 col2" >2024</td>
#       <td id="T_ad634_row0_col3" class="data row0 col3" >Q2</td>
#       <td id="T_ad634_row0_col4" class="data row0 col4" >1,424,881</td>
#       <td id="T_ad634_row0_col5" class="data row0 col5" >152,924</td>
#       <td id="T_ad634_row0_col6" class="data row0 col6" >1,271,957</td>
#       <td id="T_ad634_row0_col7" class="data row0 col7" >831.76</td>
#       <td id="T_ad634_row0_col8" class="data row0 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_ad634_row1_col0" class="data row1 col0" >97453</td>
#       <td id="T_ad634_row1_col1" class="data row1 col1" >TVO</td>
#       <td id="T_ad634_row1_col2" class="data row1 col2" >2023</td>
#       <td id="T_ad634_row1_col3" class="data row1 col3" >Q2</td>
#       <td id="T_ad634_row1_col4" class="data row1 col4" >152,924</td>
#       <td id="T_ad634_row1_col5" class="data row1 col5" >2,073,619</td>
#       <td id="T_ad634_row1_col6" class="data row1 col6" >-1,920,695</td>
#       <td id="T_ad634_row1_col7" class="data row1 col7" >-92.63</td>
#       <td id="T_ad634_row1_col8" class="data row1 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_ad634_row2_col0" class="data row2 col0" >95341</td>
#       <td id="T_ad634_row2_col1" class="data row2 col1" >TVO</td>
#       <td id="T_ad634_row2_col2" class="data row2 col2" >2022</td>
#       <td id="T_ad634_row2_col3" class="data row2 col3" >Q2</td>
#       <td id="T_ad634_row2_col4" class="data row2 col4" >2,073,619</td>
#       <td id="T_ad634_row2_col5" class="data row2 col5" >2,430,160</td>
#       <td id="T_ad634_row2_col6" class="data row2 col6" >-356,541</td>
#       <td id="T_ad634_row2_col7" class="data row2 col7" >-14.67</td>
#       <td id="T_ad634_row2_col8" class="data row2 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_ad634_row3_col0" class="data row3 col0" >79170</td>
#       <td id="T_ad634_row3_col1" class="data row3 col1" >TVO</td>
#       <td id="T_ad634_row3_col2" class="data row3 col2" >2021</td>
#       <td id="T_ad634_row3_col3" class="data row3 col3" >Q2</td>
#       <td id="T_ad634_row3_col4" class="data row3 col4" >2,430,160</td>
#       <td id="T_ad634_row3_col5" class="data row3 col5" >1,606,817</td>
#       <td id="T_ad634_row3_col6" class="data row3 col6" >823,343</td>
#       <td id="T_ad634_row3_col7" class="data row3 col7" >51.24</td>
#       <td id="T_ad634_row3_col8" class="data row3 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_ad634_row4_col0" class="data row4 col0" >60109</td>
#       <td id="T_ad634_row4_col1" class="data row4 col1" >TVO</td>
#       <td id="T_ad634_row4_col2" class="data row4 col2" >2020</td>
#       <td id="T_ad634_row4_col3" class="data row4 col3" >Q2</td>
#       <td id="T_ad634_row4_col4" class="data row4 col4" >1,606,817</td>
#       <td id="T_ad634_row4_col5" class="data row4 col5" >1,365,483</td>
#       <td id="T_ad634_row4_col6" class="data row4 col6" >241,334</td>
#       <td id="T_ad634_row4_col7" class="data row4 col7" >17.67</td>
#       <td id="T_ad634_row4_col8" class="data row4 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ad634_row5_col0" class="data row5 col0" >42045</td>
#       <td id="T_ad634_row5_col1" class="data row5 col1" >TVO</td>
#       <td id="T_ad634_row5_col2" class="data row5 col2" >2019</td>
#       <td id="T_ad634_row5_col3" class="data row5 col3" >Q2</td>
#       <td id="T_ad634_row5_col4" class="data row5 col4" >1,365,483</td>
#       <td id="T_ad634_row5_col5" class="data row5 col5" >1,995,577</td>
#       <td id="T_ad634_row5_col6" class="data row5 col6" >-630,094</td>
#       <td id="T_ad634_row5_col7" class="data row5 col7" >-31.57</td>
#       <td id="T_ad634_row5_col8" class="data row5 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_ad634_row6_col0" class="data row6 col0" >27537</td>
#       <td id="T_ad634_row6_col1" class="data row6 col1" >TVO</td>
#       <td id="T_ad634_row6_col2" class="data row6 col2" >2018</td>
#       <td id="T_ad634_row6_col3" class="data row6 col3" >Q2</td>
#       <td id="T_ad634_row6_col4" class="data row6 col4" >1,995,577</td>
#       <td id="T_ad634_row6_col5" class="data row6 col5" >1,957,248</td>
#       <td id="T_ad634_row6_col6" class="data row6 col6" >38,329</td>
#       <td id="T_ad634_row6_col7" class="data row6 col7" >1.96</td>
#       <td id="T_ad634_row6_col8" class="data row6 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_ad634_row7_col0" class="data row7 col0" >4257</td>
#       <td id="T_ad634_row7_col1" class="data row7 col1" >TVO</td>
#       <td id="T_ad634_row7_col2" class="data row7 col2" >2017</td>
#       <td id="T_ad634_row7_col3" class="data row7 col3" >Q2</td>
#       <td id="T_ad634_row7_col4" class="data row7 col4" >1,957,248</td>
#       <td id="T_ad634_row7_col5" class="data row7 col5" >2,124,044</td>
#       <td id="T_ad634_row7_col6" class="data row7 col6" >-166,796</td>
#       <td id="T_ad634_row7_col7" class="data row7 col7" >-7.85</td>
#       <td id="T_ad634_row7_col8" class="data row7 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_ad634_row8_col0" class="data row8 col0" >1843</td>
#       <td id="T_ad634_row8_col1" class="data row8 col1" >TVO</td>
#       <td id="T_ad634_row8_col2" class="data row8 col2" >2016</td>
#       <td id="T_ad634_row8_col3" class="data row8 col3" >Q2</td>
#       <td id="T_ad634_row8_col4" class="data row8 col4" >2,124,044</td>
#       <td id="T_ad634_row8_col5" class="data row8 col5" >1,717,113</td>
#       <td id="T_ad634_row8_col6" class="data row8 col6" >406,931</td>
#       <td id="T_ad634_row8_col7" class="data row8 col7" >23.70</td>
#       <td id="T_ad634_row8_col8" class="data row8 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_ad634_row9_col0" class="data row9 col0" >1978</td>
#       <td id="T_ad634_row9_col1" class="data row9 col1" >TVO</td>
#       <td id="T_ad634_row9_col2" class="data row9 col2" >2015</td>
#       <td id="T_ad634_row9_col3" class="data row9 col3" >Q2</td>
#       <td id="T_ad634_row9_col4" class="data row9 col4" >1,717,113</td>
#       <td id="T_ad634_row9_col5" class="data row9 col5" >1,674,837</td>
#       <td id="T_ad634_row9_col6" class="data row9 col6" >42,276</td>
#       <td id="T_ad634_row9_col7" class="data row9 col7" >2.52</td>
#       <td id="T_ad634_row9_col8" class="data row9 col8" >585</td>
#     </tr>
#     <tr>
#       <th id="T_ad634_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_ad634_row10_col0" class="data row10 col0" >2101</td>
#       <td id="T_ad634_row10_col1" class="data row10 col1" >TVO</td>
#       <td id="T_ad634_row10_col2" class="

# %%
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Y'+'.png'
    fig_path = '../fig/profits/'+fig_name
    ax = yr_profits.plot.bar(x='year', y=['previous_amt','latest_amt','inc_amt'])
    ax.set_title(ticker,fontsize=40)
    ax.set_ylabel("Profit Amount",fontsize=20)
    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT * 
FROM tickers
WHERE name = '%s'
'''
sql = sql % ticker
df_tmp = pd.read_sql(sql, conpg)
df_tmp
# Out:
#     id name                                  full_name                sector  \
# 0  594  TVO  THAI VEGETABLE OIL PUBLIC COMPANY LIMITED  Agro & Food Industry
#
#          subsector                 market          website  \
# 0  Food & Beverage  SET / SETTHSI / SETWB  www.tvothai.com
#
#                   created_at                 updated_at
# 0 2018-04-22 04:29:39.677962 2019-11-19 07:13:54.470342

# %%
sql = '''
SELECT T.* 
FROM tickers T
JOIN epss E
ON T.name = E.name WHERE year = %s AND quarter = %s
ORDER BY T.name
'''
sql = sql % (year, quarter)
print(sql)
df_tmp = pd.read_sql(sql, conpg)
df_tmp.query
# Out:
# SELECT T.*
# FROM tickers T
# JOIN epss E
# ON T.name = E.name WHERE year = 2024 AND quarter = 2
# ORDER BY T.name
# <bound method DataFrame.query of       id    name                                          full_name  \
# 0    241   3BBIF     JASMINE BROADBAND INTERNET INFRASTRUCTURE FUND
# 1    667     ACE       ABSOLUTE CLEAN ENERGY PUBLIC COMPANY LIMITED
# 2      8  ADVANC       ADVANCED INFO SERVICE PUBLIC COMPANY LIMITED
# 3      9  AEONTS  AEON THANA SINSAP (THAILAND) PUBLIC COMPANY LI...
# 4     11      AH               AAPICO HITECH PUBLIC COMPANY LIMITED
# ..   ...     ...                                                ...
# 206  217   WHAIR     HEMARAJ LEASEHOLD REAL ESTATE INVESTMENT TRUST
# 207  630   WHART  WHA PREMIUM GROWTH FREEHOLD AND LEASEHOLD REAL...
# 208  631   WHAUP     WHA UTILITIES AND POWER PUBLIC COMPANY LIMITED
# 209  632    WICE              WICE LOGISTICS PUBLIC COMPANY LIMITED
# 210  636    WORK     WORKPOINT ENTERTAINMENT PUBLIC COMPANY LIMITED
#
#                       sector                               subsector  \
# 0                 Technology  Information & Communication Technology
# 1                  Resources                      Energy & Utilities
# 2                 Technology  Information & Communication Technology
# 3                 Financials                    Finance & Securities
# 4                Industrials                              Automotive
# ..                       ...                                     ...
# 206  Property & Construction                   Property Fund & REITs
# 207  Property & Construction                   Property Fund & REITs
# 208                Resources                      Energy & Utilities
# 209                 Services              Transportation & Logistics
# 210                 Services                      Media & Publishing
#
#                       market               website                 created_at  \
# 0                        SET        www.jas-if.com 2018-04-22 04:29:37.600684
# 1                     SET100  www.ace-energy.co.th 2019-11-19 07:13:52.123345
# 2    SET50 / SETHD / SETTHSI    investor.ais.co.th 2018-04-22 04:29:36.118727
# 3                     SET100        www.aeon.co.th 2018-04-22 04:29:36.124123
# 4             sSET / SETTHSI        www.aapico.com 2018-04-22 04:29:36.134601
# ..                       ...                   ...                        ...
# 206                      SET   www.hemarajreit.com 2018-04-22 04:29:37.460955
# 207                      SET       www.whareit.com 2018-04-22 04:29:39.879467
# 208           sSET / SETTHSI        www.wha-up.com 2018-04-22 04:29:39.884477
# 209                     sSET        www.wice.co.th 2018-04-22 04:29:39.912473
# 210                      SET   www.workpoint.co.th 2018-04-22 04:29:39.935932
#
#                     updated_at
# 0   2019-03-03 03:45:01.621634
# 1   2020-07-06 13:23:58.374272
# 2   2021-07-07 03:33:38.798595
# 3   2019-03-03 03:45:00.149450
# 4   2021-07-07 03:33:38.806441
# ..                         ...
# 206 2018-04-22 04:29:37.460955
# 207 2018-04-22 04:29:39.879467
# 208 2021-07-07 03:33:39.291393
# 209 2021-01-26 15:42:35.646871
# 210 2022-01-15 03:54:48.607070
#
# [211 rows x 9 columns]>

# %%
sql = '''
SELECT * 
FROM buy
ORDER BY name
'''
df_buy = pd.read_sql(sql, const)
df_buy
# Out:
#        name        date    volbuy   price  volsell  volbal  active  dividend  \
# 0     3BBIF  2018-05-17  120000.0   10.10      0.0     0.0       1    0.1600
# 1        AH  2023-06-08    1200.0   37.00      0.0     0.0       1    1.2500
# 2    AIMIRT  2023-08-17   12500.0   10.90      0.0     0.0       1    0.8680
# 3       ASK  2023-02-16    6000.0   26.25      0.0     0.0       1    1.1600
# 4       ASP  2022-03-07   30000.0    3.80      0.0     0.0       1    0.1700
# 5       AWC  2023-06-15    9000.0    4.96      0.0     0.0       1    0.0500
# 6       BCH  2021-09-07    4000.0   21.70      0.0     0.0       1    0.3700
# 7   CPNREIT  2022-08-16   55000.0   18.00      0.0     0.0       1    0.8758
# 8       DIF  2020-08-01   30000.0   14.70      0.0     0.0       1    0.8930
# 9    GVREIT  2022-08-24   60000.0    7.90      0.0     0.0       1    0.7833
# 10      IVL  2022-08-29    7200.0   40.00      0.0     0.0       1    0.7750
# 11    JMART  2023-01-20    6800.0   33.00      0.0     0.0       1    0.4800
# 12      JMT  2023-01-26    4200.0   55.50      0.0     0.0       1    0.8700
# 13      KCE  2021-10-07   10000.0   77.25      0.0     0.0       1    1.3000
# 14      MCS  2016-09-20   75000.0   15.40      0.0     0.0       1    0.5200
# 15      NER  2021-09-01   27000.0    7.45      0.0     0.0       1    0.3400
# 16      ORI  2022-04-07   50000.0   10.40      0.0     0.0       1    0.3000
# 17      PTG  2023-07-12    3600.0   11.40      0.0     0.0       1    0.3500
# 18    PTTGC  2021-03-17    6000.0   64.75      0.0     0.0       1    0.7500
# 19      RCL  2021-11-08   27000.0   38.75      0.0     0.0       1    1.0000
# 20      SCC  2021-09-20     600.0  405.00      0.0     0.0       1    6.0000
# 21     SENA  2022-03-29  105000.0    4.48      0.0     0.0       1    0.2342
# 22   SINGER  2023-01-19    6000.0   24.80      0.0     0.0       1    0.0000
# 23      STA  2021-06-15    7500.0   33.80      0.0     0.0       1    1.0000
# 24    SYNEX  2022-01-07   15000.0   28.70      0.0     0.0       1    0.3600
# 25    TFFIF  2023-07-06   20000.0    7.50      0.0     0.0       1    0.4297
# 26      TMT  2021-08-16   36000.0   10.20      0.0     0.0       1    0.2000
# 27      TOA  2023-09-06    1000.0   26.00      0.0     0.0       1    0.6800
# 28    WHAIR  2021-10-11   50000.0    8.70      0.0     0.0       1    0.5482
# 29    WHART  2022-01-05   20000.0   12.30      0.0     0.0       1    0.7735
#
#    period grade
# 0       4    C2
# 1       3    C3
# 2       2    B2
# 3       4    C3
# 4       4    B4
# 5       4    B1
# 6       4    C2
# 7       2    B3
# 8       2    B3
# 9       2    C1
# 10      1    C1
# 11      3    A2
# 12      4    B4
# 13      3    A2
# 14      2    A4
# 15      2    B2
# 16      1    C3
# 17      4    A4
# 18      3    A4
# 19      1    C2
# 20      1    C2
# 21      2    C4
# 22      3    A2
# 23      1    C2
# 24      3    B2
# 25      2    A4
# 26      3    A1
# 27      4    A1
# 28      2    C1
# 29      2    C1

# %%
df_merge = pd.merge(df_buy, df_tmp, on='name', how='inner')
colu = 'period name id'.split()
df_merge[colu]
# Out:
#    period     name   id
# 0       4    3BBIF  241
# 1       3       AH   11
# 2       2   AIMIRT   13
# 3       4      ASK   42
# 4       4      ASP   44
# 5       4      AWC  668
# 6       4      BCH   55
# 7       2  CPNREIT  127
# 8       2      DIF  146
# 9       2   GVREIT  209
# 10      1      IVL  238
# 11      3    JMART  244
# 12      4      JMT  245
# 13      3      KCE  256
# 14      2      MCS  301
# 15      2      NER  649
# 16      1      ORI  347
# 17      4      PTG  387
# 18      3    PTTGC  391
# 19      1      RCL  401
# 20      1      SCC  433
# 21      2     SENA  443
# 22      3   SINGER  452
# 23      1      STA  489
# 24      3    SYNEX  504
# 25      2    TFFIF  655
# 26      3      TMT  553
# 27      4      TOA  562
# 28      2    WHAIR  217
# 29      2    WHART  630

# %%
sql = """
SELECT *
FROM epss
WHERE year = 2023 AND quarter = 2"""
df_epss = pd.read_sql(sql, conlt)
df_epss.columns
# Out:
# Index(['id', 'name', 'year', 'quarter', 'q_amt', 'y_amt', 'aq_amt', 'ay_amt',
#        'q_eps', 'y_eps', 'aq_eps', 'ay_eps', 'ticker_id', 'publish_date'],
#       dtype='object')

# %%
df_merge2 = pd.merge(df_merge, df_epss, on='name', how='inner')
df_merge2['diff'] = df_merge2['q_amt'] - df_merge2['y_amt']
colu = 'period name id_x publish_date q_amt y_amt diff'.split()
df_merge2[colu].sort_values(['diff','name'],ascending=[True,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c3136_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >period</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >id_x</th>
#       <th class="col_heading level0 col3" >publish_date</th>
#       <th class="col_heading level0 col4" >q_amt</th>
#       <th class="col_heading level0 col5" >y_amt</th>
#       <th class="col_heading level0 col6" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3136_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_c3136_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c3136_row0_col1" class="data row0 col1" >IVL</td>
#       <td id="T_c3136_row0_col2" class="data row0 col2" >238</td>
#       <td id="T_c3136_row0_col3" class="data row0 col3" >2023-08-11</td>
#       <td id="T_c3136_row0_col4" class="data row0 col4" >411,131</td>
#       <td id="T_c3136_row0_col5" class="data row0 col5" >20,277,879</td>
#       <td id="T_c3136_row0_col6" class="data row0 col6" >-19,866,748</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_c3136_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_c3136_row1_col1" class="data row1 col1" >PTTGC</td>
#       <td id="T_c3136_row1_col2" class="data row1 col2" >391</td>
#       <td id="T_c3136_row1_col3" class="data row1 col3" >2023-08-09</td>
#       <td id="T_c3136_row1_col4" class="data row1 col4" >-5,591,399</td>
#       <td id="T_c3136_row1_col5" class="data row1 col5" >1,377,911</td>
#       <td id="T_c3136_row1_col6" class="data row1 col6" >-6,969,310</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_c3136_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_c3136_row2_col1" class="data row2 col1" >RCL</td>
#       <td id="T_c3136_row2_col2" class="data row2 col2" >401</td>
#       <td id="T_c3136_row2_col3" class="data row2 col3" >2023-08-11</td>
#       <td id="T_c3136_row2_col4" class="data row2 col4" >575,806</td>
#       <td id="T_c3136_row2_col5" class="data row2 col5" >7,358,155</td>
#       <td id="T_c3136_row2_col6" class="data row2 col6" >-6,782,349</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_c3136_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c3136_row3_col1" class="data row3 col1" >SINGER</td>
#       <td id="T_c3136_row3_col2" class="data row3 col2" >452</td>
#       <td id="T_c3136_row3_col3" class="data row3 col3" >2023-08-10</td>
#       <td id="T_c3136_row3_col4" class="data row3 col4" >-2,395,977</td>
#       <td id="T_c3136_row3_col5" class="data row3 col5" >265,417</td>
#       <td id="T_c3136_row3_col6" class="data row3 col6" >-2,661,394</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row4" class="row_heading level0 row4" >20</th>
#       <td id="T_c3136_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_c3136_row4_col1" class="data row4 col1" >SCC</td>
#       <td id="T_c3136_row4_col2" class="data row4 col2" >433</td>
#       <td id="T_c3136_row4_col3" class="data row4 col3" >2023-07-26</td>
#       <td id="T_c3136_row4_col4" class="data row4 col4" >8,082,241</td>
#       <td id="T_c3136_row4_col5" class="data row4 col5" >9,937,631</td>
#       <td id="T_c3136_row4_col6" class="data row4 col6" >-1,855,390</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_c3136_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_c3136_row5_col1" class="data row5 col1" >3BBIF</td>
#       <td id="T_c3136_row5_col2" class="data row5 col2" >241</td>
#       <td id="T_c3136_row5_col3" class="data row5 col3" >2023-08-09</td>
#       <td id="T_c3136_row5_col4" class="data row5 col4" >66,645</td>
#       <td id="T_c3136_row5_col5" class="data row5 col5" >1,411,836</td>
#       <td id="T_c3136_row5_col6" class="data row5 col6" >-1,345,191</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row6" class="row_heading level0 row6" >23</th>
#       <td id="T_c3136_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_c3136_row6_col1" class="data row6 col1" >STA</td>
#       <td id="T_c3136_row6_col2" class="data row6 col2" >489</td>
#       <td id="T_c3136_row6_col3" class="data row6 col3" >2023-08-10</td>
#       <td id="T_c3136_row6_col4" class="data row6 col4" >110,004</td>
#       <td id="T_c3136_row6_col5" class="data row6 col5" >1,142,125</td>
#       <td id="T_c3136_row6_col6" class="data row6 col6" >-1,032,121</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_c3136_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_c3136_row7_col1" class="data row7 col1" >JMART</td>
#       <td id="T_c3136_row7_col2" class="data row7 col2" >244</td>
#       <td id="T_c3136_row7_col3" class="data row7 col3" >2023-08-10</td>
#       <td id="T_c3136_row7_col4" class="data row7 col4" >-611,222</td>
#       <td id="T_c3136_row7_col5" class="data row7 col5" >389,411</td>
#       <td id="T_c3136_row7_col6" class="data row7 col6" >-1,000,633</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_c3136_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_c3136_row8_col1" class="data row8 col1" >BCH</td>
#       <td id="T_c3136_row8_col2" class="data row8 col2" >55</td>
#       <td id="T_c3136_row8_col3" class="data row8 col3" >2023-08-15</td>
#       <td id="T_c3136_row8_col4" class="data row8 col4" >284,324</td>
#       <td id="T_c3136_row8_col5" class="data row8 col5" >1,143,963</td>
#       <td id="T_c3136_row8_col6" class="data row8 col6" >-859,639</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row9" class="row_heading level0 row9" >17</th>
#       <td id="T_c3136_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_c3136_row9_col1" class="data row9 col1" >PTG</td>
#       <td id="T_c3136_row9_col2" class="data row9 col2" >387</td>
#       <td id="T_c3136_row9_col3" class="data row9 col3" >2023-08-10</td>
#       <td id="T_c3136_row9_col4" class="data row9 col4" >111,227</td>
#       <td id="T_c3136_row9_col5" class="data row9 col5" >600,666</td>
#       <td id="T_c3136_row9_col6" class="data row9 col6" >-489,439</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row10" class="row_heading level0 row10" >16</th>
#       <td id="T_c3136_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_c3136_row10_col1" class="data row10 col1" >ORI</td>
#       <td id="T_c3136_row10_col2" class="data row10 col2" >347</td>
#       <td id="T_c3136_row10_col3" class="data row10 col3" >2023-08-15</td>
#       <td id="T_c3136_row10_col4" class="data row10 col4" >873,074</td>
#       <td id="T_c3136_row10_col5" class="data row10 col5" >1,155,286</td>
#       <td id="T_c3136_row10_col6" class="data row10 col6" >-282,212</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row11" class="row_heading level0 row11" >13</th>
#       <td id="T_c3136_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_c3136_row11_col1" class="data row11 col1" >KCE</td>
#       <td id="T_c3136_row11_col2" class="data row11 col2" >256</td>
#       <td id="T_c3136_row11_col3" class="data row11 col3" >2023-08-08</td>
#       <td id="T_c3136_row11_col4" class="data row11 col4" >376,179</td>
#       <td id="T_c3136_row11_col5" class="data row11 col5" >571,905</td>
#       <td id="T_c3136_row11_col6" class="data row11 col6" >-195,726</td>
#     </tr>
#     <tr>
#       <th id="T_c3136_level0_row12" class="row_heading level0 row12" >21</th>
#       <td id="T_c3136_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_c3136_row12_col1" class="data row12 col1" >SENA</td>
#       <td id="T_c3136_row12_col2" class="data row12 col2" >443</td>
#       <td id="T_c3136_row12_col3" class="data row12 col3" >2023-08-15</td>
#       <td id="T_c3136_row12_col4" class="data row12 col4" >127,024</td>
#       <td id="T_c3136_row12_col5" class="data row12

# %%
df_merge2[colu].sort_values(['publish_date','name'],ascending=[False,True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_48995_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >period</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >id_x</th>
#       <th class="col_heading level0 col3" >publish_date</th>
#       <th class="col_heading level0 col4" >q_amt</th>
#       <th class="col_heading level0 col5" >y_amt</th>
#       <th class="col_heading level0 col6" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48995_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_48995_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_48995_row0_col1" class="data row0 col1" >TOA</td>
#       <td id="T_48995_row0_col2" class="data row0 col2" >562</td>
#       <td id="T_48995_row0_col3" class="data row0 col3" >2023-08-16</td>
#       <td id="T_48995_row0_col4" class="data row0 col4" >741,367</td>
#       <td id="T_48995_row0_col5" class="data row0 col5" >365,203</td>
#       <td id="T_48995_row0_col6" class="data row0 col6" >376,164</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_48995_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_48995_row1_col1" class="data row1 col1" >ASP</td>
#       <td id="T_48995_row1_col2" class="data row1 col2" >44</td>
#       <td id="T_48995_row1_col3" class="data row1 col3" >2023-08-15</td>
#       <td id="T_48995_row1_col4" class="data row1 col4" >110,916</td>
#       <td id="T_48995_row1_col5" class="data row1 col5" >35,116</td>
#       <td id="T_48995_row1_col6" class="data row1 col6" >75,800</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_48995_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_48995_row2_col1" class="data row2 col1" >BCH</td>
#       <td id="T_48995_row2_col2" class="data row2 col2" >55</td>
#       <td id="T_48995_row2_col3" class="data row2 col3" >2023-08-15</td>
#       <td id="T_48995_row2_col4" class="data row2 col4" >284,324</td>
#       <td id="T_48995_row2_col5" class="data row2 col5" >1,143,963</td>
#       <td id="T_48995_row2_col6" class="data row2 col6" >-859,639</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_48995_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_48995_row3_col1" class="data row3 col1" >MCS</td>
#       <td id="T_48995_row3_col2" class="data row3 col2" >301</td>
#       <td id="T_48995_row3_col3" class="data row3 col3" >2023-08-15</td>
#       <td id="T_48995_row3_col4" class="data row3 col4" >10,302</td>
#       <td id="T_48995_row3_col5" class="data row3 col5" >-69,469</td>
#       <td id="T_48995_row3_col6" class="data row3 col6" >79,771</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_48995_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_48995_row4_col1" class="data row4 col1" >ORI</td>
#       <td id="T_48995_row4_col2" class="data row4 col2" >347</td>
#       <td id="T_48995_row4_col3" class="data row4 col3" >2023-08-15</td>
#       <td id="T_48995_row4_col4" class="data row4 col4" >873,074</td>
#       <td id="T_48995_row4_col5" class="data row4 col5" >1,155,286</td>
#       <td id="T_48995_row4_col6" class="data row4 col6" >-282,212</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_48995_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_48995_row5_col1" class="data row5 col1" >SENA</td>
#       <td id="T_48995_row5_col2" class="data row5 col2" >443</td>
#       <td id="T_48995_row5_col3" class="data row5 col3" >2023-08-15</td>
#       <td id="T_48995_row5_col4" class="data row5 col4" >127,024</td>
#       <td id="T_48995_row5_col5" class="data row5 col5" >303,135</td>
#       <td id="T_48995_row5_col6" class="data row5 col6" >-176,111</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_48995_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_48995_row6_col1" class="data row6 col1" >AIMIRT</td>
#       <td id="T_48995_row6_col2" class="data row6 col2" >13</td>
#       <td id="T_48995_row6_col3" class="data row6 col3" >2023-08-13</td>
#       <td id="T_48995_row6_col4" class="data row6 col4" >152,374</td>
#       <td id="T_48995_row6_col5" class="data row6 col5" >141,732</td>
#       <td id="T_48995_row6_col6" class="data row6 col6" >10,642</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_48995_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_48995_row7_col1" class="data row7 col1" >AH</td>
#       <td id="T_48995_row7_col2" class="data row7 col2" >11</td>
#       <td id="T_48995_row7_col3" class="data row7 col3" >2023-08-11</td>
#       <td id="T_48995_row7_col4" class="data row7 col4" >409,986</td>
#       <td id="T_48995_row7_col5" class="data row7 col5" >409,796</td>
#       <td id="T_48995_row7_col6" class="data row7 col6" >190</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_48995_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_48995_row8_col1" class="data row8 col1" >CPNREIT</td>
#       <td id="T_48995_row8_col2" class="data row8 col2" >127</td>
#       <td id="T_48995_row8_col3" class="data row8 col3" >2023-08-11</td>
#       <td id="T_48995_row8_col4" class="data row8 col4" >757,225</td>
#       <td id="T_48995_row8_col5" class="data row8 col5" >856,120</td>
#       <td id="T_48995_row8_col6" class="data row8 col6" >-98,895</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_48995_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_48995_row9_col1" class="data row9 col1" >DIF</td>
#       <td id="T_48995_row9_col2" class="data row9 col2" >146</td>
#       <td id="T_48995_row9_col3" class="data row9 col3" >2023-08-11</td>
#       <td id="T_48995_row9_col4" class="data row9 col4" >2,772,676</td>
#       <td id="T_48995_row9_col5" class="data row9 col5" >2,877,156</td>
#       <td id="T_48995_row9_col6" class="data row9 col6" >-104,480</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_48995_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_48995_row10_col1" class="data row10 col1" >IVL</td>
#       <td id="T_48995_row10_col2" class="data row10 col2" >238</td>
#       <td id="T_48995_row10_col3" class="data row10 col3" >2023-08-11</td>
#       <td id="T_48995_row10_col4" class="data row10 col4" >411,131</td>
#       <td id="T_48995_row10_col5" class="data row10 col5" >20,277,879</td>
#       <td id="T_48995_row10_col6" class="data row10 col6" >-19,866,748</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row11" class="row_heading level0 row11" >15</th>
#       <td id="T_48995_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_48995_row11_col1" class="data row11 col1" >NER</td>
#       <td id="T_48995_row11_col2" class="data row11 col2" >649</td>
#       <td id="T_48995_row11_col3" class="data row11 col3" >2023-08-11</td>
#       <td id="T_48995_row11_col4" class="data row11 col4" >457,212</td>
#       <td id="T_48995_row11_col5" class="data row11 col5" >382,203</td>
#       <td id="T_48995_row11_col6" class="data row11 col6" >75,009</td>
#     </tr>
#     <tr>
#       <th id="T_48995_level0_row12" class="row_heading level0 row12" >19</th>
#       <td id="T_48995_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_48995_row12_col1" class="data row12 col1" >RCL</td>
#       <td id="T_48995_row12_col2" class="data row12 col2" >401</td>
#       <td id="T_48995_row12_col3" class="data row12 col3" >2023-08-11</td>
#       <td id="T_48995_row12_col4" class="data row12 col4" >575,806</td>
#       <td id="T_48995_row12_col5" class="data row12 col5" >7,358,155</td>
#       <td id="T_48995_row12_col6
