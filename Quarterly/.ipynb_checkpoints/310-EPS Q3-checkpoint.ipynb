# %%
import pandas as pd
import os
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = os.path.join(os.path.expanduser("~"), "iCloudDrive")
one_path = os.path.join(os.path.expanduser("~"), "OneDrive","Documents","Data")
osd_path = os.path.join(os.path.expanduser("~"),"OneDrive","Documents","obsidian-git-sync","Data")
dts_path = os.path.join(os.path.expanduser("~"),"Downloads","Datasets")


year = "2024"
quarter = "3"
today = date.today()
today_str = today.strftime("%Y-%m-%d")
today_str
# Out:
# '2025-01-01'

# %%
today = date(2024, 11, 27)
select_date = today.strftime("%Y-%m-%d")
select_date
# Out:
# '2024-11-27'

# %% [markdown]
# ### Tables in the process

# %%
cols = 'name year quarter q_amt y_amt yoy_gain yoy_pct'.split()
colt = 'name year quarter q_amt y_amt yoy_gain yoy_pct aq_amt ay_amt acc_gain acc_pct'.split()

format_dict = {
                'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}',
                'yoy_gain':'{:,}','acc_gain':'{:,}',    
                'q_eps':'{:.4f}','y_eps':'{:.4f}','aq_eps':'{:.4f}','ay_eps':'{:.4f}',
                'yoy_pct':'{:,.2f}%','acc_pct':'{:,.2f}%'
              }

# %%
pd.read_sql_query('SELECT * FROM EPSS ORDER BY id DESC LIMIT 5', conlt).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_570e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_570e8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_570e8_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_570e8_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_570e8_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_570e8_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_570e8_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_570e8_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_570e8_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_570e8_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_570e8_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_570e8_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_570e8_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_570e8_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_570e8_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_570e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_570e8_row0_col0" class="data row0 col0" >23986</td>
#       <td id="T_570e8_row0_col1" class="data row0 col1" >TFFIF</td>
#       <td id="T_570e8_row0_col2" class="data row0 col2" >2024</td>
#       <td id="T_570e8_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_570e8_row0_col4" class="data row0 col4" >-1,939,993</td>
#       <td id="T_570e8_row0_col5" class="data row0 col5" >8,053,194</td>
#       <td id="T_570e8_row0_col6" class="data row0 col6" >-458,370</td>
#       <td id="T_570e8_row0_col7" class="data row0 col7" >9,458,559</td>
#       <td id="T_570e8_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_570e8_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_570e8_row0_col10" class="data row0 col10" >0.0000</td>
#       <td id="T_570e8_row0_col11" class="data row0 col11" >0.0000</td>
#       <td id="T_570e8_row0_col12" class="data row0 col12" >686</td>
#       <td id="T_570e8_row0_col13" class="data row0 col13" >2024-11-27</td>
#     </tr>
#     <tr>
#       <th id="T_570e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_570e8_row1_col0" class="data row1 col0" >23984</td>
#       <td id="T_570e8_row1_col1" class="data row1 col1" >GVREIT</td>
#       <td id="T_570e8_row1_col2" class="data row1 col2" >2024</td>
#       <td id="T_570e8_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_570e8_row1_col4" class="data row1 col4" >-87,267</td>
#       <td id="T_570e8_row1_col5" class="data row1 col5" >-21,830</td>
#       <td id="T_570e8_row1_col6" class="data row1 col6" >457,671</td>
#       <td id="T_570e8_row1_col7" class="data row1 col7" >565,723</td>
#       <td id="T_570e8_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_570e8_row1_col9" class="data row1 col9" >0.0000</td>
#       <td id="T_570e8_row1_col10" class="data row1 col10" >0.0000</td>
#       <td id="T_570e8_row1_col11" class="data row1 col11" >0.0000</td>
#       <td id="T_570e8_row1_col12" class="data row1 col12" >654</td>
#       <td id="T_570e8_row1_col13" class="data row1 col13" >2024-11-27</td>
#     </tr>
#     <tr>
#       <th id="T_570e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_570e8_row2_col0" class="data row2 col0" >23983</td>
#       <td id="T_570e8_row2_col1" class="data row2 col1" >KGI</td>
#       <td id="T_570e8_row2_col2" class="data row2 col2" >2024</td>
#       <td id="T_570e8_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_570e8_row2_col4" class="data row2 col4" >112,341</td>
#       <td id="T_570e8_row2_col5" class="data row2 col5" >266,385</td>
#       <td id="T_570e8_row2_col6" class="data row2 col6" >378,700</td>
#       <td id="T_570e8_row2_col7" class="data row2 col7" >449,882</td>
#       <td id="T_570e8_row2_col8" class="data row2 col8" >0.0600</td>
#       <td id="T_570e8_row2_col9" class="data row2 col9" >0.1300</td>
#       <td id="T_570e8_row2_col10" class="data row2 col10" >0.1900</td>
#       <td id="T_570e8_row2_col11" class="data row2 col11" >0.2300</td>
#       <td id="T_570e8_row2_col12" class="data row2 col12" >252</td>
#       <td id="T_570e8_row2_col13" class="data row2 col13" >2024-11-14</td>
#     </tr>
#     <tr>
#       <th id="T_570e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_570e8_row3_col0" class="data row3 col0" >23982</td>
#       <td id="T_570e8_row3_col1" class="data row3 col1" >SCB</td>
#       <td id="T_570e8_row3_col2" class="data row3 col2" >2024</td>
#       <td id="T_570e8_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_570e8_row3_col4" class="data row3 col4" >10,940,949</td>
#       <td id="T_570e8_row3_col5" class="data row3 col5" >9,663,100</td>
#       <td id="T_570e8_row3_col6" class="data row3 col6" >32,236,305</td>
#       <td id="T_570e8_row3_col7" class="data row3 col7" >32,526,603</td>
#       <td id="T_570e8_row3_col8" class="data row3 col8" >3.2500</td>
#       <td id="T_570e8_row3_col9" class="data row3 col9" >2.8700</td>
#       <td id="T_570e8_row3_col10" class="data row3 col10" >9.5700</td>
#       <td id="T_570e8_row3_col11" class="data row3 col11" >9.6600</td>
#       <td id="T_570e8_row3_col12" class="data row3 col12" >426</td>
#       <td id="T_570e8_row3_col13" class="data row3 col13" >2024-11-14</td>
#     </tr>
#     <tr>
#       <th id="T_570e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_570e8_row4_col0" class="data row4 col0" >23981</td>
#       <td id="T_570e8_row4_col1" class="data row4 col1" >SAT</td>
#       <td id="T_570e8_row4_col2" class="data row4 col2" >2024</td>
#       <td id="T_570e8_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_570e8_row4_col4" class="data row4 col4" >158,729</td>
#       <td id="T_570e8_row4_col5" class="data row4 col5" >263,419</td>
#       <td id="T_570e8_row4_col6" class="data row4 col6" >486,009</td>
#       <td id="T_570e8_row4_col7" class="data row4 col7" >761,043</td>
#       <td id="T_570e8_row4_col8" class="data row4 col8" >0.3700</td>
#       <td id="T_570e8_row4_col9" class="data row4 col9" >0.6200</td>
#       <td id="T_570e8_row4_col10" class="data row4 col10" >1.1400</td>
#       <td id="T_570e8_row4_col11" class="data row4 col11" >1.7900</td>
#       <td id="T_570e8_row4_col12" class="data row4 col12" >421</td>
#       <td id="T_570e8_row4_col13" class="data row4 col13" >2024-11-14</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM epss 
WHERE year = %s AND quarter = %s
AND publish_date >= '%s'
ORDER BY name
"""
sql = sql % (year, quarter, select_date)
print(sql)

epss = pd.read_sql(sql, conlt)
epss.tail().style.format(format_dict)
# Out:
# SELECT *
# FROM epss
# WHERE year = 2024 AND quarter = 3
# AND publish_date >= '2024-11-27'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_0013d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0013d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_0013d_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_0013d_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_0013d_level0_col3" class="col_heading level0 col3" >quarter</th>
#       <th id="T_0013d_level0_col4" class="col_heading level0 col4" >q_amt</th>
#       <th id="T_0013d_level0_col5" class="col_heading level0 col5" >y_amt</th>
#       <th id="T_0013d_level0_col6" class="col_heading level0 col6" >aq_amt</th>
#       <th id="T_0013d_level0_col7" class="col_heading level0 col7" >ay_amt</th>
#       <th id="T_0013d_level0_col8" class="col_heading level0 col8" >q_eps</th>
#       <th id="T_0013d_level0_col9" class="col_heading level0 col9" >y_eps</th>
#       <th id="T_0013d_level0_col10" class="col_heading level0 col10" >aq_eps</th>
#       <th id="T_0013d_level0_col11" class="col_heading level0 col11" >ay_eps</th>
#       <th id="T_0013d_level0_col12" class="col_heading level0 col12" >ticker_id</th>
#       <th id="T_0013d_level0_col13" class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
epss["yoy_gain"] = epss["q_amt"] - epss["y_amt"]
epss["yoy_pct"] = round(epss["yoy_gain"] / abs(epss["y_amt"]) * 100, 2)
epss["acc_gain"] = epss["aq_amt"] - epss["ay_amt"]
epss["acc_pct"] = round(epss["acc_gain"] / abs(epss["ay_amt"]) * 100,2)

df_pct = epss[colt]
df_pct.tail().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c3e12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e12_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c3e12_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_c3e12_level0_col2" class="col_heading level0 col2" >quarter</th>
#       <th id="T_c3e12_level0_col3" class="col_heading level0 col3" >q_amt</th>
#       <th id="T_c3e12_level0_col4" class="col_heading level0 col4" >y_amt</th>
#       <th id="T_c3e12_level0_col5" class="col_heading level0 col5" >yoy_gain</th>
#       <th id="T_c3e12_level0_col6" class="col_heading level0 col6" >yoy_pct</th>
#       <th id="T_c3e12_level0_col7" class="col_heading level0 col7" >aq_amt</th>
#       <th id="T_c3e12_level0_col8" class="col_heading level0 col8" >ay_amt</th>
#       <th id="T_c3e12_level0_col9" class="col_heading level0 col9" >acc_gain</th>
#       <th id="T_c3e12_level0_col10" class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
criteria_1 = df_pct.q_amt > 110_000
df_pct.loc[criteria_1,cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2837_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2837_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2837_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_f2837_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_f2837_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_f2837_row0_col3" class="data row0 col3" >110,520</td>
#       <td id="T_f2837_row0_col4" class="data row0 col4" >316,815</td>
#       <td id="T_f2837_row0_col5" class="data row0 col5" >-206,295</td>
#       <td id="T_f2837_row0_col6" class="data row0 col6" >-65.12%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f2837_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_f2837_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_f2837_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_f2837_row1_col3" class="data row1 col3" >149,501</td>
#       <td id="T_f2837_row1_col4" class="data row1 col4" >121,512</td>
#       <td id="T_f2837_row1_col5" class="data row1 col5" >27,989</td>
#       <td id="T_f2837_row1_col6" class="data row1 col6" >23.03%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_f2837_row2_col0" class="data row2 col0" >AMATA</td>
#       <td id="T_f2837_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_f2837_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_f2837_row2_col3" class="data row2 col3" >765,130</td>
#       <td id="T_f2837_row2_col4" class="data row2 col4" >396,398</td>
#       <td id="T_f2837_row2_col5" class="data row2 col5" >368,732</td>
#       <td id="T_f2837_row2_col6" class="data row2 col6" >93.02%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_f2837_row3_col0" class="data row3 col0" >BAM</td>
#       <td id="T_f2837_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_f2837_row8_col3" class="data row8 col3" >417,407</td>
#       <td id="T_f2837_row8_col4" class="data row8 col4" >325,763</td>
#       <td id="T_f2837_row8_col5" class="data row8 col5" >91,644</td>
#       <td id="T_f2837_row8_col6" class="data row8 col6" >28.13%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row9" class="row_heading level0 row9" >14</th>
#       <td id="T_f2837_row9_col0" class="data row9 col0" >CK</td>
#       <td id="T_f2837_row9_col1" class="data row9 col1" >2024</td>
#       <td id="T_f2837_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_f2837_row9_col3" class="data row9 col3" >1,007,708</td>
#       <td id="T_f2837_row9_col4" class="data row9 col4" >641,042</td>
#       <td id="T_f2837_row9_col5" class="data row9 col5" >366,666</td>
#       <td id="T_f2837_row9_col6" class="data row9 col6" >57.20%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row10" class="row_heading level0 row10" >15</th>
#       <td id="T_f2837_row10_col0" class="data row10 col0" >CPF</td>
#       <td id="T_f2837_row10_col1" class="data row10 col1" >2024</td>
#       <td id="T_f2837_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_f2837_row10_col3" class="data row10 col3" >7,308,983</td>
#       <td id="T_f2837_row10_col4" class="data row10 col4" >-1,810,903</td>
#       <td id="T_f2837_row10_col5" class="data row10 col5" >9,119,886</td>
#       <td id="T_f2837_row10_col6" class="data row10 col6" >503.61%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row11" class="row_heading level0 row11" >16</th>
#       <td id="T_f2837_row11_col0" class="data row11 col0" >CPN</td>
#       <td id="T_f2837_row11_col1" class="data row11 col1" >2024</td>
#       <td id="T_f2837_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_f2837_row11_col3" class="data row11 col3" >4,125,675</td>
#       <td id="T_f2837_row11_col4" class="data row11 col4" >4,161,641</td>
#       <td id="T_f2837_row11_col5" class="data row11 col5" >-35,966</td>
#       <td id="T_f2837_row11_col6" class="data row11 col6" >-0.86%</td>
#     </tr>
#     <tr>
#       <th id="T_f2837_level0_row12" class="row_heading level0 row12" >17</th>
#       <td id="T_f2837_row12_col0" class="data row12 col0" >CPNREIT</td>
#       <td id="T_f2837_row12_col1" class="data row12 col1" >2024</td>
#       <td id="T_f2837_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_f2837_row12_col3" class="data row12 col3" >801,278</td>
#       <td id="T_f2837_row12_col4" class="data row12 col4" >1,271,308</td>
#       <td id="T_f2837_row12_col5" class="data row12 col5" >-470,030</td>
#       <td id="T_f2837_row12_col6" class="data row12 co

# %%
criteria_2 = df_pct.y_amt > 100_000
df_pct.loc[criteria_2, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_77162_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77162_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77162_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_77162_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_77162_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_77162_row0_col3" class="data row0 col3" >110,520</td>
#       <td id="T_77162_row0_col4" class="data row0 col4" >316,815</td>
#       <td id="T_77162_row0_col5" class="data row0 col5" >-206,295</td>
#       <td id="T_77162_row0_col6" class="data row0 col6" >-65.12%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_77162_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_77162_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_77162_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_77162_row1_col3" class="data row1 col3" >149,501</td>
#       <td id="T_77162_row1_col4" class="data row1 col4" >121,512</td>
#       <td id="T_77162_row1_col5" class="data row1 col5" >27,989</td>
#       <td id="T_77162_row1_col6" class="data row1 col6" >23.03%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_77162_row2_col0" class="data row2 col0" >AMATA</td>
#       <td id="T_77162_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_77162_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_77162_row2_col3" class="data row2 col3" >765,130</td>
#       <td id="T_77162_row2_col4" class="data row2 col4" >396,398</td>
#       <td id="T_77162_row2_col5" class="data row2 col5" >368,732</td>
#       <td id="T_77162_row2_col6" class="data row2 col6" >93.02%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_77162_row3_col0" class="data row3 col0" >ASP</td>
#       <td id="T_77162_row3_col1" class="data row3 col1" >2024</td>
#       <td id="T_77162_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_77162_row3_col3" class="data row3 col3" >68,478</td>
#       <td id="T_77162_row3_col4" class="data row3 col4" >102,983</td>
#       <td id="T_77162_row3_col5" class="data row3 col5" >-34,505</td>
#       <td id="T_77162_row3_col6" class="data row3 col6" >-33.51%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_77162_row4_col0" class="data row4 col0" >BAM</td>
#       <td id="T_77162_row4_col1" class="data row4 col1" >2024</td>
#       <td id="T_77162_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_77162_row4_col3" class="data row4 col3" >199,331</td>
#       <td id="T_77162_row4_col4" class="data row4 col4" >382,824</td>
#       <td id="T_77162_row4_col5" class="data row4 col5" >-183,493</td>
#       <td id="T_77162_row4_col6" class="data row4 col6" >-47.93%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_77162_row5_col0" class="data row5 col0" >BJC</td>
#       <td id="T_77162_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_77162_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_77162_row5_col3" class="data row5 col3" >701,363</td>
#       <td id="T_77162_row5_col4" class="data row5 col4" >693,269</td>
#       <td id="T_77162_row5_col5" class="data row5 col5" >8,094</td>
#       <td id="T_77162_row5_col6" class="data row5 col6" >1.17%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_77162_row6_col0" class="data row6 col0" >BKIH</td>
#       <td id="T_77162_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_77162_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_77162_row6_col3" class="data row6 col3" >736,370</td>
#       <td id="T_77162_row6_col4" class="data row6 col4" >856,002</td>
#       <td id="T_77162_row6_col5" class="data row6 col5" >-119,632</td>
#       <td id="T_77162_row6_col6" class="data row6 col6" >-13.98%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_77162_row7_col0" class="data row7 col0" >BLA</td>
#       <td id="T_77162_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_77162_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_77162_row7_col3" class="data row7 col3" >614,248</td>
#       <td id="T_77162_row7_col4" class="data row7 col4" >644,910</td>
#       <td id="T_77162_row7_col5" class="data row7 col5" >-30,662</td>
#       <td id="T_77162_row7_col6" class="data row7 col6" >-4.75%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_77162_row8_col0" class="data row8 col0" >CHG</td>
#       <td id="T_77162_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_77162_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_77162_row8_col3" class="data row8 col3" >417,407</td>
#       <td id="T_77162_row8_col4" class="data row8 col4" >325,763</td>
#       <td id="T_77162_row8_col5" class="data row8 col5" >91,644</td>
#       <td id="T_77162_row8_col6" class="data row8 col6" >28.13%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row9" class="row_heading level0 row9" >14</th>
#       <td id="T_77162_row9_col0" class="data row9 col0" >CK</td>
#       <td id="T_77162_row9_col1" class="data row9 col1" >2024</td>
#       <td id="T_77162_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_77162_row9_col3" class="data row9 col3" >1,007,708</td>
#       <td id="T_77162_row9_col4" class="data row9 col4" >641,042</td>
#       <td id="T_77162_row9_col5" class="data row9 col5" >366,666</td>
#       <td id="T_77162_row9_col6" class="data row9 col6" >57.20%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row10" class="row_heading level0 row10" >16</th>
#       <td id="T_77162_row10_col0" class="data row10 col0" >CPN</td>
#       <td id="T_77162_row10_col1" class="data row10 col1" >2024</td>
#       <td id="T_77162_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_77162_row10_col3" class="data row10 col3" >4,125,675</td>
#       <td id="T_77162_row10_col4" class="data row10 col4" >4,161,641</td>
#       <td id="T_77162_row10_col5" class="data row10 col5" >-35,966</td>
#       <td id="T_77162_row10_col6" class="data row10 col6" >-0.86%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row11" class="row_heading level0 row11" >17</th>
#       <td id="T_77162_row11_col0" class="data row11 col0" >CPNREIT</td>
#       <td id="T_77162_row11_col1" class="data row11 col1" >2024</td>
#       <td id="T_77162_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_77162_row11_col3" class="data row11 col3" >801,278</td>
#       <td id="T_77162_row11_col4" class="data row11 col4" >1,271,308</td>
#       <td id="T_77162_row11_col5" class="data row11 col5" >-470,030</td>
#       <td id="T_77162_row11_col6" class="data row11 col6" >-36.97%</td>
#     </tr>
#     <tr>
#       <th id="T_77162_level0_row12" class="row_heading level0 row12" >18</th>
#       <td id="T_77162_row12_col0" class="data row12 col0" >CPTGF</td>
#       <td id="T_77162_row12_col1" class="data row12 col1" >2024</td>
#       <td id="T_77162_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_77162_row12_col3" class="data row12 col3" >152,987</td>
#       <td id="T_77162_row12_col4" class="data row12 col4" >137,368</td>
#       <td id="T_77162_row12_col5" class="data row12 col5" >15,619</td>
#       <td id="T_77162_row12_col6" class="data row12 col6" >11.3

# %%
criteria_3 = df_pct.yoy_pct > 10.00
df_pct.loc[criteria_3, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f58d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f58d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9f58d_row0_col0" class="data row0 col0" >AIE</td>
#       <td id="T_9f58d_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_9f58d_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_9f58d_row0_col3" class="data row0 col3" >31,171</td>
#       <td id="T_9f58d_row0_col4" class="data row0 col4" >-4,968</td>
#       <td id="T_9f58d_row0_col5" class="data row0 col5" >36,139</td>
#       <td id="T_9f58d_row0_col6" class="data row0 col6" >727.44%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9f58d_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_9f58d_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_9f58d_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_9f58d_row1_col3" class="data row1 col3" >149,501</td>
#       <td id="T_9f58d_row1_col4" class="data row1 col4" >121,512</td>
#       <td id="T_9f58d_row1_col5" class="data row1 col5" >27,989</td>
#       <td id="T_9f58d_row1_col6" class="data row1 col6" >23.03%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_9f58d_row2_col0" class="data row2 col0" >AMATA</td>
#       <td id="T_9f58d_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_9f58d_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_9f58d_row2_col3" class="data row2 col3" >765,130</td>
#       <td id="T_9f58d_row2_col4" class="data row2 col4" >396,398</td>
#       <td id="T_9f58d_row2_col5" class="data row2 col5" >368,732</td>
#       <td id="T_9f58d_row2_col6" class="data row2 col6" >93.02%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T
#       <td id="T_9f58d_row8_col4" class="data row8 col4" >-1,810,903</td>
#       <td id="T_9f58d_row8_col5" class="data row8 col5" >9,119,886</td>
#       <td id="T_9f58d_row8_col6" class="data row8 col6" >503.61%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row9" class="row_heading level0 row9" >18</th>
#       <td id="T_9f58d_row9_col0" class="data row9 col0" >CPTGF</td>
#       <td id="T_9f58d_row9_col1" class="data row9 col1" >2024</td>
#       <td id="T_9f58d_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_9f58d_row9_col3" class="data row9 col3" >152,987</td>
#       <td id="T_9f58d_row9_col4" class="data row9 col4" >137,368</td>
#       <td id="T_9f58d_row9_col5" class="data row9 col5" >15,619</td>
#       <td id="T_9f58d_row9_col6" class="data row9 col6" >11.37%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row10" class="row_heading level0 row10" >23</th>
#       <td id="T_9f58d_row10_col0" class="data row10 col0" >GGC</td>
#       <td id="T_9f58d_row10_col1" class="data row10 col1" >2024</td>
#       <td id="T_9f58d_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_9f58d_row10_col3" class="data row10 col3" >-182,599</td>
#       <td id="T_9f58d_row10_col4" class="data row10 col4" >-262,392</td>
#       <td id="T_9f58d_row10_col5" class="data row10 col5" >79,793</td>
#       <td id="T_9f58d_row10_col6" class="data row10 col6" >30.41%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row11" class="row_heading level0 row11" >24</th>
#       <td id="T_9f58d_row11_col0" class="data row11 col0" >GULF</td>
#       <td id="T_9f58d_row11_col1" class="data row11 col1" >2024</td>
#       <td id="T_9f58d_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_9f58d_row11_col3" class="data row11 col3" >6,029,749</td>
#       <td id="T_9f58d_row11_col4" class="data row11 col4" >3,360,304</td>
#       <td id="T_9f58d_row11_col5" class="data row11 col5" >2,669,445</td>
#       <td id="T_9f58d_row11_col6" class="data row11 col6" >79.44%</td>
#     </tr>
#     <tr>
#       <th id="T_9f58d_level0_row12" class="row_heading level0 row12" >32</th>
#       <td id="T_9f58d_row12_col0" class="data row12 col0" >LPH</td>
#       <td id="T_9f58d_row12_col1" class="data row12 col1" >2024</td>
#       <td id="T_9f58d_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_9f58d_row12_col3" class="data row12 col3" >40,270</td>
#       <td id="T_9f58d_row12_col4" class="data row12 col4" >34,263</td>
#       <td id="T_9f58d_row12_col5" class="data row12 col5" >6,007</td>
#       <td id="T_9f58d_row12_col6" class="data row12 col6" >17.53%</t

# %%
df_pct_criteria = criteria_1 & criteria_2 & criteria_3
#df_pct_criteria = criteria_1 & criteria_3 
df_pct.loc[df_pct_criteria, cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0142e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0142e_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0142e_row0_col0" class="data row0 col0" >AIMIRT</td>
#       <td id="T_0142e_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_0142e_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_0142e_row0_col3" class="data row0 col3" >149,501</td>
#       <td id="T_0142e_row0_col4" class="data row0 col4" >121,512</td>
#       <td id="T_0142e_row0_col5" class="data row0 col5" >27,989</td>
#       <td id="T_0142e_row0_col6" class="data row0 col6" >23.03%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_0142e_row1_col0" class="data row1 col0" >AMATA</td>
#       <td id="T_0142e_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_0142e_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_0142e_row1_col3" class="data row1 col3" >765,130</td>
#       <td id="T_0142e_row1_col4" class="data row1 col4" >396,398</td>
#       <td id="T_0142e_row1_col5" class="data row1 col5" >368,732</td>
#       <td id="T_0142e_row1_col6" class="data row1 col6" >93.02%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_0142e_row2_col0" class="data row2 col0" >CHG</td>
#       <td id="T_0142e_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_0142e_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_0142e_row2_col3" class="data row2 col3" >417,407</td>
#       <td id="T_0142e_row2_col4" class="data row2 col4" >325,763</td>
#       <td id="T_0142e_row2_col5" class="data row2 col5" >91,644</td>
#       <td id="T_0142e_row2_col6" class="data row2 col6" >28.13%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row3" class="row_heading level0 row3" >14</th>
#       <td id="T_0142e_row3_col0" class="data row3 col0" >CK</td>
#       <td id="T_0142e_row3_col1" class="data row3 col1" >2024</td>
#       <td id="T_0142e_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_0142e_row3_col3" class="data row3 col3" >1,007,708</td>
#       <td id="T_0142e_row3_col4" class="data row3 col4" >641,042</td>
#       <td id="T_0142e_row3_col5" class="data row3 col5" >366,666</td>
#       <td id="T_0142e_row3_col6" class="data row3 col6" >57.20%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_0142e_row4_col0" class="data row4 col0" >CPTGF</td>
#       <td id="T_0142e_row4_col1" class="data row4 col1" >2024</td>
#       <td id="T_0142e_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_0142e_row4_col3" class="data row4 col3" >152,987</td>
#       <td id="T_0142e_row4_col4" class="data row4 col4" >137,368</td>
#       <td id="T_0142e_row4_col5" class="data row4 col5" >15,619</td>
#       <td id="T_0142e_row4_col6" class="data row4 col6" >11.37%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_0142e_row5_col0" class="data row5 col0" >GULF</td>
#       <td id="T_0142e_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_0142e_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_0142e_row5_col3" class="data row5 col3" >6,029,749</td>
#       <td id="T_0142e_row5_col4" class="data row5 col4" >3,360,304</td>
#       <td id="T_0142e_row5_col5" class="data row5 col5" >2,669,445</td>
#       <td id="T_0142e_row5_col6" class="data row5 col6" >79.44%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row6" class="row_heading level0 row6" >37</th>
#       <td id="T_0142e_row6_col0" class="data row6 col0" >PRM</td>
#       <td id="T_0142e_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_0142e_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_0142e_row6_col3" class="data row6 col3" >449,775</td>
#       <td id="T_0142e_row6_col4" class="data row6 col4" >328,490</td>
#       <td id="T_0142e_row6_col5" class="data row6 col5" >121,285</td>
#       <td id="T_0142e_row6_col6" class="data row6 col6" >36.92%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_0142e_row7_col0" class="data row7 col0" >RATCH</td>
#       <td id="T_0142e_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_0142e_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_0142e_row7_col3" class="data row7 col3" >1,658,122</td>
#       <td id="T_0142e_row7_col4" class="data row7 col4" >1,182,175</td>
#       <td id="T_0142e_row7_col5" class="data row7 col5" >475,947</td>
#       <td id="T_0142e_row7_col6" class="data row7 col6" >40.26%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row8" class="row_heading level0 row8" >41</th>
#       <td id="T_0142e_row8_col0" class="data row8 col0" >ROJNA</td>
#       <td id="T_0142e_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_0142e_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_0142e_row8_col3" class="data row8 col3" >2,262,762</td>
#       <td id="T_0142e_row8_col4" class="data row8 col4" >267,680</td>
#       <td id="T_0142e_row8_col5" class="data row8 col5" >1,995,082</td>
#       <td id="T_0142e_row8_col6" class="data row8 col6" >745.32%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row9" class="row_heading level0 row9" >46</th>
#       <td id="T_0142e_row9_col0" class="data row9 col0" >SCB</td>
#       <td id="T_0142e_row9_col1" class="data row9 col1" >2024</td>
#       <td id="T_0142e_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_0142e_row9_col3" class="data row9 col3" >10,940,949</td>
#       <td id="T_0142e_row9_col4" class="data row9 col4" >9,663,100</td>
#       <td id="T_0142e_row9_col5" class="data row9 col5" >1,277,849</td>
#       <td id="T_0142e_row9_col6" class="data row9 col6" >13.22%</td>
#     </tr>
#     <tr>
#       <th id="T_0142e_level0_row10" class="row_heading level0 row10" >60</th>
#       <td id="T_0142e_row10_col0" class="data row10 col0" >VIBHA</td>
#       <td id="T_0142e_row10_col1" class="data row10 col1" >2024</td>
#       <td id="T_0142e_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_0142e_row10_col3" class="data row10 col3" >361,431</td>
#       <td id="T_0142e_row10_col4" class="data row10 col4" >291,720</td>
#       <td id="T_0142e_row10_col5" class="data row10 col5" >69,711</td>
#       <td id="T_0142e_row10_col6" class="data row10 col6" >23.90%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_pct[df_pct_criteria].sort_values(by=["yoy_pct"], ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_73713_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#       <th class="col_heading level0 col7" >aq_amt</th>
#       <th class="col_heading level0 col8" >ay_amt</th>
#       <th class="col_heading level0 col9" >acc_gain</th>
#       <th class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73713_level0_row0" class="row_heading level0 row0" >41</th>
#       <td id="T_73713_row0_col0" class="data row0 col0" >ROJNA</td>
#       <td id="T_73713_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_73713_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_73713_row0_col3" class="data row0 col3" >2,262,762</td>
#       <td id="T_73713_row0_col4" class="data row0 col4" >267,680</td>
#       <td id="T_73713_row0_col5" class="data row0 col5" >1,995,082</td>
#       <td id="T_73713_row0_col6" class="data row0 col6" >745.32%</td>
#       <td id="T_73713_row0_col7" class="data row0 col7" >3,083,748</td>
#       <td id="T_73713_row0_col8" class="data row0 col8" >315,825</td>
#       <td id="T_73713_row0_col9" class="data row0 col9" >2,767,923</td>
#       <td id="T_73713_row0_col10" class="data row0 col10" >876.41%</td>
#     </tr>
#     <tr>
#       <th id="T_73713_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_73713_row1_col0" class="data row1 col0" >AMATA</td>
#       <td id="T_73713_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_73713_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_73713_row1_col3" class="data row1 col3" >765,130</td>
#       <td id="T_73713_row1_col4" class="data row1 col4" >396,398</td>
#       <td id="T_73713_row1_col5" class="data row1 col5" >368,732</td>
#       <td id="T_73713_row1_col6" class="data row1 col6" >93.02%</td>
#       <td id="T_73713_row1_col7" class="data row1 col7" >1,459,877</td>
#       <td id="T_73713_row1_col8" class="data row1 col8" >1,201,687</td>
#       <td id="T_73713_row1_col9" class="data row1 col9" >258,190</td>
#       <td id="T_73713_row1_col10" class="data row1 col10" >21.49%</td>
#     </tr>
#     <tr>
#       <th id="T_73713_level0_row2" class="row_heading level0 row2" >24</th>
#       <td id="T_73713_row2_col0" class="data row2 col0" >GULF</td>
#       <td id="T_73713_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_73713_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_73713_row2_col3" class="data row2 col3" >6,029,749</td>
#       <td id="T_73713_row2_col4" class="data row2 col4" >3,360,304</td>
#       <td id="T_73713_row2_col5" class="data row2 col5" >2,669,445</td>
#       <td id="T_73713_row2_col6" class="data row2 col6" >79.44%</td>
#       <td id="T_73713_row2_col7" class="data row2 col7" >14,269,535</td>
#       <td id="T_73713_row2_col8" class="data row2 col8" >10,095,217</td>
#       <td id="T_73713_row2_col9" class="data row2 col9" >4,174,318</td>
#       <td id="T_73713_row2_col10" class="data row2 col10" >41.35%</td>
#     </tr>
#     <tr>
#       <td id="T_73713_row6_col6" class="data row6 col6" >28.13%</td>
#       <td id="T_73713_row6_col7" class="data row6 col7" >873,629</td>
#       <td id="T_73713_row6_col8" class="data row6 col8" >772,204</td>
#       <td id="T_73713_row6_col9" class="data row6 col9" >101,425</td>
#       <td id="T_73713_row6_col10" class="data row6 col10" >13.13%</td>
#     </tr>
#     <tr>
#       <th id="T_73713_level0_row7" class="row_heading level0 row7" >60</th>
#       <td id="T_73713_row7_col0" class="data row7 col0" >VIBHA</td>
#       <td id="T_73713_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_73713_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_73713_row7_col3" class="data row7 col3" >361,431</td>
#       <td id="T_73713_row7_col4" class="data row7 col4" >291,720</td>
#       <td id="T_73713_row7_col5" class="data row7 col5" >69,711</td>
#       <td id="T_73713_row7_col6" class="data row7 col6" >23.90%</td>
#       <td id="T_73713_row7_col7" class="data row7 col7" >778,306</td>
#       <td id="T_73713_row7_col8" class="data row7 col8" >619,875</td>
#       <td id="T_73713_row7_col9" class="data row7 col9" >158,431</td>
#       <td id="T_73713_row7_col10" class="data row7 col10" >25.56%</td>
#     </tr>
#     <tr>
#       <th id="T_73713_level0_row8" class="row_heading level0 row8" >2</th>
#       <td id="T_73713_row8_col0" class="data row8 col0" >AIMIRT</td>
#       <td id="T_73713_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_73713_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_73713_row8_col3" class="data row8 col3" >149,501</td>
#       <td id="T_73713_r

# %%
df_pct[df_pct_criteria].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21660_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >yoy_gain</th>
#       <th class="col_heading level0 col6" >yoy_pct</th>
#       <th class="col_heading level0 col7" >aq_amt</th>
#       <th class="col_heading level0 col8" >ay_amt</th>
#       <th class="col_heading level0 col9" >acc_gain</th>
#       <th class="col_heading level0 col10" >acc_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21660_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_21660_row0_col0" class="data row0 col0" >AIMIRT</td>
#       <td id="T_21660_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_21660_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_21660_row0_col3" class="data row0 col3" >149,501</td>
#       <td id="T_21660_row0_col4" class="data row0 col4" >121,512</td>
#       <td id="T_21660_row0_col5" class="data row0 col5" >27,989</td>
#       <td id="T_21660_row0_col6" class="data row0 col6" >23.03%</td>
#       <td id="T_21660_row0_col7" class="data row0 col7" >606,443</td>
#       <td id="T_21660_row0_col8" class="data row0 col8" >410,220</td>
#       <td id="T_21660_row0_col9" class="data row0 col9" >196,223</td>
#       <td id="T_21660_row0_col10" class="data row0 col10" >47.83%</td>
#     </tr>
#     <tr>
#       <th id="T_21660_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_21660_row1_col0" class="data row1 col0" >AMATA</td>
#       <td id="T_21660_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_21660_row1_col2" class="data row1 col2" >3</td>
#       <td id="T
#       <th id="T_21660_level0_row5" class="row_heading level0 row5" >24</th>
#       <td id="T_21660_row5_col0" class="data row5 col0" >GULF</td>
#       <td id="T_21660_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_21660_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_21660_row5_col3" class="data row5 col3" >6,029,749</td>
#       <td id="T_21660_row5_col4" class="data row5 col4" >3,360,304</td>
#       <td id="T_21660_row5_col5" class="data row5 col5" >2,669,445</td>
#       <td id="T_21660_row5_col6" class="data row5 col6" >79.44%</td>
#       <td id="T_21660_row5_col7" class="data row5 col7" >14,269,535</td>
#       <td id="T_21660_row5_col8" class="data row5 col8" >10,095,217</td>
#       <td id="T_21660_row5_col9" class="data row5 col9" >4,174,318</td>
#       <td id="T_21660_row5_col10" class="data row5 col10" >41.35%</td>
#     </tr>
#     <tr>
#       <th id="T_21660_level0_row6" class="row_heading level0 row6" >37</th>
#       <td id="T_21660_row6_col0" class="data row6 col0" >PRM</td>
#       <td id="T_21660_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_21660_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_21660_row6_col3" class="data row6 col3" >449,775</td>
#       <td id="T_21660_row6_col4" class="data row6 col4" >328,490</td>
#       <td id="T_21660_row6_col5" class="data row6 col5" >121,285</td>
#       <td id="T_21660_row6_col6" class="data row6 col6" >36.92%</td>
#       <td id="T_21660_row6_col7" class="data row6 col7" >1,652,286</td>
#       <td id="T_21660_row6_col8" class="data row6 col8" >1,377,028</td>
#       <td id="T_21660_row6_col9" class="data row6 col9" >275,258</td>
#       <td id="T_21660_row6_col10" class="data row6 col10" >19.99%</td>
#     </tr>
#     <tr>
#       <th id="T_21660_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_21660_row7_col0" class="data row7 col0" >RATCH</td>
#       <td id="T_21660_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_21660_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_21660_row7_col3" class="data row7 col3" >1,658,122</td>
#       <td id="T_21660_row7_col4" class="data row7 col4" >1,182,175</td>
#       <td id="T_21660_row7_col5" class="data row7 col5" >475,947</td>
#       <td id="T_21660_row7_col6" class="data row7 col6" >40.26%</td>
#       <td id="T_21660_row7_col7" class="data row7 col7" >5,485,203</td>
#       <td id="T_21660_row7_col8" class="data row7 col8" >4,754,694</td>
#       <td id="T_21660_row7_col9" class="data row7 col9" >730,509</td>
#       <td id="T_21660_row7_col10" class="data row7 col10" >15.36%</td>
#     </tr>
#     <tr>
#       <th id="T_21660_level0_row8" class="row_heading level0 row8" >41</th>
#       <td id="T_21660_row8_col0" class="data row8 col0" >ROJNA</td>
#       <td id="T_21660_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_21660_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_21660_row8_col3" class="data row8 col3" >2,262,762</td>
#       <td id="T_21660_row8_col4

# %%
names = epss['name']
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'ACE', 'AIE', 'AIMIRT', 'AJ', 'AMATA', 'ANAN', 'ASP', 'BAM', 'BEC', 'BJC', 'BKIH', 'BLA', 'CENTEL', 'CHG', 'CK', 'CPF', 'CPN', 'CPNREIT', 'CPTGF', 'EA', 'ECL', 'FORTH', 'GC', 'GGC', 'GULF', 'HTC', 'IP', 'KBANK', 'KGI', 'KTB', 'LALIN', 'LH', 'LPH', 'NOBLE', 'ONEE', 'ORI', 'PCSGH', 'PRM', 'PSH', 'RATCH', 'RBF', 'ROJNA', 'RS', 'SABUY', 'SAPPE', 'SAT', 'SCB', 'SENA', 'SKN', 'SKR', 'SPCG', 'SPRC', 'SSP', 'SUPER', 'TIPCO', 'TKS', 'TOA', 'TQM', 'TSE', 'TTW', 'VIBHA', 'WICE'"

# %% [markdown]
# ### If new records pass filter criteria then proceed to create quarterly profits process.

# %%
#name = "TSTH"
sql = """
SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
FROM epss E JOIN stocks S ON E.name = S.name 
WHERE E.name IN (%s)
ORDER BY E.name, year DESC, quarter DESC 
LIMIT 12
"""
sql = sql % (in_p)
print(sql)

epss = pd.read_sql(sql, conlt)
epss.style.format(format_dict)
# Out:
# SELECT E.name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, q_eps, y_eps, aq_eps, ay_eps
# FROM epss E JOIN stocks S ON E.name = S.name
# WHERE E.name IN ('ACE', 'AIE', 'AIMIRT', 'AJ', 'AMATA', 'ANAN', 'ASP', 'BAM', 'BEC', 'BJC', 'BKIH', 'BLA', 'CENTEL', 'CHG', 'CK', 'CPF', 'CPN', 'CPNREIT', 'CPTGF', 'EA', 'ECL', 'FORTH', 'GC', 'GGC', 'GULF', 'HTC', 'IP', 'KBANK', 'KGI', 'KTB', 'LALIN', 'LH', 'LPH', 'NOBLE', 'ONEE', 'ORI', 'PCSGH', 'PRM', 'PSH', 'RATCH', 'RBF', 'ROJNA', 'RS', 'SABUY', 'SAPPE', 'SAT', 'SCB', 'SENA', 'SKN', 'SKR', 'SPCG', 'SPRC', 'SSP', 'SUPER', 'TIPCO', 'TKS', 'TOA', 'TQM', 'TSE', 'TTW', 'VIBHA', 'WICE')
# ORDER BY E.name, year DESC, quarter DESC
# LIMIT 12
# <style type="text/css">
# </style>
# <table id="T_85228_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >aq_amt</th>
#       <th class="col_heading level0 col6" >ay_amt</th>
#       <th class="col_heading level0 col7" >q_eps</th>
#       <th class="col_heading level0 col8" >y_eps</th>
#       <th class="col_heading level0 col9" >aq_eps</th>
#       <th class="col_heading level0 col10" >ay_eps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85228_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85228_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_85228_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_85228_row0_col2" class="data row0 col2" >3</td>
#       <td id="T
level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85228_row4_col0" class="data row4 col0" >ACE</td>
#       <td id="T_85228_row4_col1" class="data row4 col1" >2023</td>
#       <td id="T_85228_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_85228_row4_col3" class="data row4 col3" >316,815</td>
#       <td id="T_85228_row4_col4" class="data row4 col4" >381,493</td>
#       <td id="T_85228_row4_col5" class="data row4 col5" >907,646</td>
#       <td id="T_85228_row4_col6" class="data row4 col6" >1,087,953</td>
#       <td id="T_85228_row4_col7" class="data row4 col7" >0.0300</td>
#       <td id="T_85228_row4_col8" class="data row4 col8" >0.0400</td>
#       <td id="T_85228_row4_col9" class="data row4 col9" >0.0900</td>
#       <td id="T_85228_row4_col10" class="data row4 col10" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_85228_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85228_row5_col0" class="data row5 col0" >ACE</td>
#       <td id="T_85228_row5_col1" class="data row5 col1" >2023</td>
#       <td id="T_85228_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_85228_row5_col3" class="data row5 col3" >315,806</td>
#       <td id="T_85228_row5_col4" class="data row5 col4" >383,748</td>
#       <td id="T_85228_row5_col5" class="data row5 col5" >590,831</td>
#       <td id="T_85228_row5_col6" class="data row5 col6" >706,459</td>
#       <td id="T_85228_row5_col7" class="data row5 col7" >0.0300</td>
#       <td id="T_85228_row5_col8" class="data row5 col8" >0.0400</td>
#       <td id="T_85228_row5_col9" class="data row5 col9" >0.0600</td>
#       <td id="T_85228_row5_col10" class="data row5 col10" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_85228_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85228_row6_col0" class="data row6 col0" >ACE</td>
#       <td id="T_85228_row6_col1" class="data row6 col1" >2023</td>
#       <td id="T_85228_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_85228_row6_col3" class="data row6 col3" >275,025</td>
#       <td id="T_85228_row6_col4" class="data row6 col4" >322,711</td>
#       <td id="T_85228_row6_col5" class="data row6 col5" >275,025</td>
#       <td id="T_85228_row6_col6" class="data row6 col6" >322,711</td>
#       <td id="T_85228_row6_col7" class="data row6 col7" >0.0300</td>
#       <td id="T_85228_row6_col8" class="data row6 col8" >0.0300</td>
#       <td id="T_85228_row6_col9" class="data row6 col9" >0.0300</td>
#       <td id="T_85228_row6_col10" class="data row6 col10" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_85228_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85228_row7_col0" class="data row7 col0" >ACE</td>
#       <td id="T_85228_row7_col1" class="data row7 col1" >2022</td>
#       <td id="T_85228_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_85228_row7_col3" class="data row7 col3" >194,027</td>
#       <td id="T_85228_row7_col4" class="data row7 col4" >367,649</td>
#       <td id="T_85228_row7_col5" class="data row7 col5" >1,281,980</td>
#       <td id="T_85228_row7_col6" class="data row7 col6" >1,505,681</td>
#       <td id="T_85228_row7_col7" class="data row7 col7" >0.0200</td>
#       <td id="T_85228_row7_col8" class="data row7 col8" >0.0400</td>
#       <td id="T_85228_row7_col9" class="data row7 col9" >0.1300</td>
#       <td id="T_85228_row7_col10" class="data row7 col10" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_85228_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85228_row8_col0" class="data row8 col0" >ACE</td>
#       <td id="T_85228_row8_col1" class="data row8 col1" >2022</td>
#       <td id="T_85228_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_85228_row8_col3" class="data row8 col3" >381,493</td>
#       <td id="T_85228_row8_col4" class="data row8 col4" >411,246</td>
#       <td id="T_85228_row8_co

# %% [markdown]
# ### Delete from profits of older profit stocks

# %%
#in_p = "'KTC'"
in_p
# Out:
# "'ACE', 'AIE', 'AIMIRT', 'AJ', 'AMATA', 'ANAN', 'ASP', 'BAM', 'BEC', 'BJC', 'BKIH', 'BLA', 'CENTEL', 'CHG', 'CK', 'CPF', 'CPN', 'CPNREIT', 'CPTGF', 'EA', 'ECL', 'FORTH', 'GC', 'GGC', 'GULF', 'HTC', 'IP', 'KBANK', 'KGI', 'KTB', 'LALIN', 'LH', 'LPH', 'NOBLE', 'ONEE', 'ORI', 'PCSGH', 'PRM', 'PSH', 'RATCH', 'RBF', 'ROJNA', 'RS', 'SABUY', 'SAPPE', 'SAT', 'SCB', 'SENA', 'SKN', 'SKR', 'SPCG', 'SPRC', 'SSP', 'SUPER', 'TIPCO', 'TKS', 'TOA', 'TQM', 'TSE', 'TTW', 'VIBHA', 'WICE'"

# %%
sql = """
SELECT * FROM profits
WHERE name IN (%s)
AND quarter < %s
"""
sql = sql % (in_p, quarter)
df_temp = pd.read_sql(sql, conlt)
df_temp
# Out:
#      id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0  2725    CPF  2024        2     1       6386787         3401879    2984908
# 1  2730    CPN  2024        2     1      16847868        12601908    4245960
# 2  2713   GULF  2024        2     1      16362607        13227185    3135422
# 3  2719  NOBLE  2024        2     1        929044          660067     268977
# 4  2739  PCSGH  2024        1     1        743898          610402     133496
# 5  2726  ROJNA  2024        2     1       1652478          954903     697575
# 6  2740  SAPPE  2024        1     1       1151756          774553     377203
# 7  2733  SAPPE  2024        2     1       1250242          919543     330699
#
#    inc_pct_y  latest_amt_q  ...  q_amt_c    y_amt  inc_amt_py  inc_pct_py  \
# 0      87.74       6386787  ...  6924590  -792252     7716842  974.038816
# 1      33.69      16847868  ...  4555797  3677832      877965   23.871808
# 2      23.70      16362607  ...  4741260  2884932     1856328   64.345641
# 3      40.75        929044  ...   124344   111860       12484   11.160379
# 4      21.87        743898  ...   167771   157205       10566    6.721160
# 5      73.05       1652478  ...   628511  -146912      775423  527.814610
# 6      48.70       1151756  ...   352347   274790       77557   28.224098
# 7      35.96       1250242  ...   410758   312272       98486   31.538531
#
#    q_amt_p  inc_amt_pq  inc_pct_pq  ticker_id    mean_pct     std_pct
# 0  1152032     5772558  501.076185        117  535.761250  363.312186
# 1  4154167      401630    9.668124        121   18.182483   12.989627
# 2  3498526     1242734   35.521645        653   34.091822   22.201123
# 3    78678       45666   58.041638        328   27.828004   26.192916
# 4   106623       61148   57.349728        346   21.845222   25.203709
# 5    91963      536548  583.438992        404  318.178400  275.192037
# 6   168018      184329  109.707888        420   48.462997   44.202529
# 7   352347       58411   16.577692        420   23.156556   12.790864
#
# [8 rows x 23 columns]

# %%
sqlDel = """
DELETE FROM profits
WHERE name IN (%s)
AND quarter < %s
"""
sqlDel = sqlDel % (in_p, quarter)
print(sqlDel)
# Out:
# DELETE FROM profits
# WHERE name IN ('ACE', 'AIE', 'AIMIRT', 'AJ', 'AMATA', 'ANAN', 'ASP', 'BAM', 'BEC', 'BJC', 'BKIH', 'BLA', 'CENTEL', 'CHG', 'CK', 'CPF', 'CPN', 'CPNREIT', 'CPTGF', 'EA', 'ECL', 'FORTH', 'GC', 'GGC', 'GULF', 'HTC', 'IP', 'KBANK', 'KGI', 'KTB', 'LALIN', 'LH', 'LPH', 'NOBLE', 'ONEE', 'ORI', 'PCSGH', 'PRM', 'PSH', 'RATCH', 'RBF', 'ROJNA', 'RS', 'SABUY', 'SAPPE', 'SAT', 'SCB', 'SENA', 'SKN', 'SKR', 'SPCG', 'SPRC', 'SSP', 'SUPER', 'TIPCO', 'TKS', 'TOA', 'TQM', 'TSE', 'TTW', 'VIBHA', 'WICE')
# AND quarter < 3

# %%
rp = conlt.execute(sqlDel)
rp.rowcount
# Out:
# 8

# %%
rp = conmy.execute(sqlDel)
rp.rowcount
# Out:
# 4

# %%
rp = conpg.execute(sqlDel)
rp.rowcount
# Out:
# 7

# %%
sql = """
SELECT name, year, quarter 
FROM profits
ORDER BY name
"""
lt_profits = pd.read_sql(sql, conlt)
lt_profits.set_index("name", inplace=True)
lt_profits.index
# Out:
# Index(['2S', 'ADVANC', 'ADVANC', 'ADVANC', 'AIT', 'AYUD', 'BBL', 'BCH', 'BDMS',
#        'BDMS', 'BEM', 'BH', 'CBG', 'CIMBT', 'CKP', 'CPALL', 'CPAXT', 'CRC',
#        'EGATIF', 'FPT', 'GPSC', 'GVREIT', 'ILM', 'IMPACT', 'INTUCH', 'INTUCH',
#        'INTUCH', 'KSL', 'KSL', 'KTB', 'LHFG', 'M', 'MTC', 'MTI', 'OISHI',
#        'PLANB', 'PLANB', 'PTT', 'RCL', 'SAUCE', 'SCB', 'SCCC', 'SJWD', 'SPC',
#        'SPI', 'STARK', 'SYNEX', 'TFFIF', 'TFG', 'TIPH', 'TTB', 'TTB', 'VNT'],
#       dtype='object', name='name')

# %%
my_profits = pd.read_sql(sql, conmy)
my_profits.set_index("name", inplace=True)
my_profits.index
# Out:
# Index(['ADVANC', 'ADVANC', 'ADVANC', 'BCH', 'BDMS', 'BEM', 'BH', 'CBG', 'CKP',
#        'CRC', 'INTUCH', 'MTC', 'PLANB', 'RCL', 'SYNEX', 'TFG'],
#       dtype='object', name='name')

# %%
pg_profits = pd.read_sql(sql, conpg)
pg_profits.set_index("name", inplace=True)
pg_profits.index
# Out:
# Index(['ADVANC', 'AIT', 'BBL', 'BCH', 'BDMS', 'BEM', 'BH', 'CBG', 'CKP',
#        'CPALL', 'CPAXT', 'CRC', 'EGATIF', 'FPT', 'GPSC', 'GVREIT', 'ILM',
#        'IMPACT', 'INTUCH', 'KSL', 'KTB', 'LHFG', 'M', 'MTC', 'PLANB', 'PTT',
#        'RCL', 'SCB', 'SCCC', 'SJWD', 'SPC', 'SYNEX', 'TFFIF', 'TFG', 'TIPH',
#        'TTB'],
#       dtype='object', name='name')

# %% [markdown]
# ### Portfolio that publish today

# %%
sql = """
SELECT * 
FROM tickers
WHERE name IN (%s)
ORDER BY name"""
sql = sql % in_p
print(sql)
# Out:
# SELECT *
# FROM tickers
# WHERE name IN ('ACE', 'AIE', 'AIMIRT', 'AJ', 'AMATA', 'ANAN', 'ASP', 'BAM', 'BEC', 'BJC', 'BKIH', 'BLA', 'CENTEL', 'CHG', 'CK', 'CPF', 'CPN', 'CPNREIT', 'CPTGF', 'EA', 'ECL', 'FORTH', 'GC', 'GGC', 'GULF', 'HTC', 'IP', 'KBANK', 'KGI', 'KTB', 'LALIN', 'LH', 'LPH', 'NOBLE', 'ONEE', 'ORI', 'PCSGH', 'PRM', 'PSH', 'RATCH', 'RBF', 'ROJNA', 'RS', 'SABUY', 'SAPPE', 'SAT', 'SCB', 'SENA', 'SKN', 'SKR', 'SPCG', 'SPRC', 'SSP', 'SUPER', 'TIPCO', 'TKS', 'TOA', 'TQM', 'TSE', 'TTW', 'VIBHA', 'WICE')
# ORDER BY name

# %%
tickers = pd.read_sql(sql, conpg)
tickers[['name','id']].sort_values(by=[ "name"], ascending=[True])
# Out:
#       name   id
# 0      ACE  667
# 1      AIE  691
# 2   AIMIRT   13
# 3       AJ   15
# 4    AMATA   24
# ..     ...  ...
# 57     TQM  657
# 58     TSE  582
# 59     TTW  590
# 60   VIBHA  619
# 61    WICE  632
#
# [62 rows x 2 columns]

# %%
sql = """
SELECT name 
FROM buy
"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (31, 1)

# %%
df_merge = pd.merge(tickers, buys, on='name', how='inner')
df_merge
# Out:
#     id     name                                          full_name  \
# 0   13   AIMIRT  AIM INDUSTRIAL GROWTH FREEHOLD AND LEASEHOLD R...
# 1   44      ASP    ASIA PLUS GROUP HOLDINGS PUBLIC COMPANY LIMITED
# 2  127  CPNREIT                   CPN RETAIL GROWTH LEASEHOLD REIT
# 3  347      ORI             ORIGIN PROPERTY PUBLIC COMPANY LIMITED
# 4  443     SENA             SENADEVELOPMENT PUBLIC COMPANY LIMITED
# 5  562      TOA        TOA PAINT (THAILAND) PUBLIC COMPANY LIMITED
#
#                     sector               subsector                    market  \
# 0  Property & Construction   Property Fund & REITs                       SET
# 1               Financials    Finance & Securities                      sSET
# 2  Property & Construction   Property Fund & REITs                       SET
# 3  Property & Construction    Property Development  SET100 / SETHD / SETTHSI
# 4  Property & Construction    Property Development                      sSET
# 5  Property & Construction  Construction Materials                   SETTHSI
#
#                    website                 created_at  \
# 0          www.aimreit.com 2018-04-22 04:29:36.146073
# 1  www.asiaplusgroup.co.th 2018-04-22 04:29:36.379149
# 2          www.cpnreit.com 2018-04-22 04:29:36.900508
# 3         www.origin.co.th 2018-04-22 04:29:38.228072
# 4           www.sena.co.th 2018-04-22 04:29:38.825191
# 5         www.toagroup.com 2018-04-22 04:29:39.494571
#
#                   updated_at
# 0 2018-04-22 04:29:36.146073
# 1 2018-04-22 04:29:36.379149
# 2 2018-04-22 04:29:36.900508
# 3 2022-01-15 03:54:48.440923
# 4 2018-04-22 04:29:38.825191
# 5 2021-07-07 03:33:39.241053

# %%
file_name = 'pub_stock.xlsx'
xsl_file = xsl_path + file_name
df_merge[['id','name','sector','market']].to_excel(xsl_file, index=False)

# %% [markdown]
# ### Portfolio that already published

# %%
sql = """
SELECT * 
FROM buy"""
buys = pd.read_sql(sql, const)
buys.shape
# Out:
# (31, 10)

# %%
	names = buys["name"].values.tolist()
	in_p = ", ".join(map(lambda name: "'%s'" % name, names))
	in_p
# Out:
# "'STA', 'SINGER', 'PTG', 'KCE', 'MCS', 'DIF', 'TMT', 'JMT', 'WHART', 'BCH', 'SENA', 'TFFIF', '3BBIF', 'ASP', 'IVL', 'PTTGC', 'WHAIR', 'ORI', 'AH', 'ASK', 'GVREIT', 'NER', 'AIMIRT', 'TOA', 'AWC', 'SYNEX', 'SCC', 'RCL', 'JMART', 'CPNREIT', 'TVO'"

# %%
sql = """
SELECT *
FROM epss
WHERE publish_date >= '2024-10-01'
AND name IN (%s)
ORDER BY publish_date, name"""
sql = sql % in_p
df_tmp = pd.read_sql(sql, conlt)
df_tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9fdd1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >quarter</th>
#       <th class="col_heading level0 col4" >q_amt</th>
#       <th class="col_heading level0 col5" >y_amt</th>
#       <th class="col_heading level0 col6" >aq_amt</th>
#       <th class="col_heading level0 col7" >ay_amt</th>
#       <th class="col_heading level0 col8" >q_eps</th>
#       <th class="col_heading level0 col9" >y_eps</th>
#       <th class="col_heading level0 col10" >aq_eps</th>
#       <th class="col_heading level0 col11" >ay_eps</th>
#       <th class="col_heading level0 col12" >ticker_id</th>
#       <th class="col_heading level0 col13" >publish_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fdd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fdd1_row0_col0" class="data row0 col0" >23780</td>
#       <td id="T_9fdd1_row0_col1" class="data row0 col1" >3BBIF</td>
#       <td id="T_9fdd1_row0_col2" class="data row0 col2" >2024</td>
#       <td id="T_9fdd1_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_9fdd1_row0_col4" class="data row0 col4" >1,174,003</td>
#       <td id="T_9fdd1_row0_col5" class="data row0 col5" >-10,261,328</td>
#       <td id="T_9fdd1_row0_col6" class="data row0 col6" >1,958,170</td>
#       <td id="T_9fdd1_row0_col7" class="data row0 col7" >-11,624,684</td>
#       <td id="T_9fdd1_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_9fdd1_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_9fdd1_row0_col10" class="data row0 col10" >0.0000</td>
#       <td id="T_9fdd1_row0_col11" class="data row0 col11" >0.0000</td>
#       <td id="T_9fdd1_row0_col12" class="data row0 col12" >234</td>
#       <td id="T_9fdd1_row0_col13" class="data row0 col13" >2024-10-29</td>
#     </tr>
#     <tr>
#       <th id="T_9fdd1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
#       <td id="T_9fdd1_row6_col7" class="data row6 col7" >-613,008</td>
#       <td id="T_9fdd1_row6_co

# %%
df_tmp.shape
# Out:
# (29, 14)

# %% [markdown]
# ### Not yet published

# %%
sql = """
SELECT name
FROM epss
WHERE publish_date >= '2024-10-01'
"""
epss = pd.read_sql(sql, conlt)
epss.shape
# Out:
# (221, 1)

# %%
	names = epss["name"].values.tolist()
	in_p = ", ".join(map(lambda name: "'%s'" % name, names))
	in_p
# Out:
# "'AEONTS', 'LPF', 'BBL', 'LHFG', 'TTB', 'KTC', 'BAY', 'KKP', 'TISCO', 'TRUE', 'DELTA', 'STANLY', 'PTTEP', 'MST', 'HMPRO', 'GLOBAL', 'SCGP', '3BBIF', 'ADVANC', 'SCC', 'MCS', 'NER', 'WHAIR', 'RCL', 'JMART', 'ASK', 'JMT', 'TMT', 'SINGER', 'STA', 'KEX', 'TCAP', 'STGT', 'CBG', 'SIS', 'SPRIME', 'WORK', 'WHAUP', 'WHA', 'KYE', 'INOX', 'TOP', 'THANI', 'INTUCH', 'BE8', 'ASW', 'S11', 'CPAXT', 'TPIPP', 'SMPC', 'SC', 'GPSC', 'AIT', 'OR', 'TIPH', 'PAP', 'BCP', 'LPN', 'BH', 'SGP', 'QH', 'BCPG', 'PDG', 'HFT', 'TU', 'III', 'DOHOME', 'SCCC', 'IRPC', 'DCC', 'PSL', 'PTTGC', 'AWC', 'IVL', 'MBAX', 'TPIPL', 'ILM', 'VGI', 'EGATIF', 'LIT', 'TTLPF', 'PTL', 'CKP', 'MAJOR', 'LANNA', 'RJH', 'TYCN', 'ICHI', 'BGC', 'BA', 'ASIAN', 'DRT', 'PTG', 'AH', 'KCE', 'SYNEX', 'DCON', 'BANPU', 'PLANB', 'TIDLOR', 'SNC', 'TK', 'BPP', 'MTC', 'COM7', 'EASTW', 'SPALI', 'BDMS', 'EPG', 'TASCO', 'MEGA', 'M', 'SUPEREIF', 'MINT', 'GFPT', 'AP', 'BEAUTY', 'BGRIM', 'VNG', 'WHART', 'DIF', 'TVO', 'BCH', 'GRAMMY', 'SAWAD', 'EGCO', 'TKN', 'PREB', 'TTA', 'FSMART', 'THG', 'SPC', 'BEM', 'OSP', 'TFG', 'BTSGIF', 'CRC', 'PTT', 'CPALL', 'CPNCG', 'HANA', 'GUNKUL', 'POPF', 'SVI', 'SIRI', 'UTP', 'IMH', 'SJWD', 'AIMIRT', 'ASP', 'SENA', 'TOA', 'ORI', 'CPNREIT', 'KBANK', 'KTB', 'VIBHA', 'RS', 'SABUY', 'CHG', 'FORTH', 'NOBLE', 'TQM', 'BTS', 'AJ', 'CK', 'PSH', 'EA', 'AMATA', 'CENTEL', 'SSP', 'TKS', 'PRM', 'ANAN', 'ROJNA', 'RBF', 'PCSGH', 'SPCG', 'LPH', 'LH', 'IMPACT', 'CPF', 'RATCH', 'HTC', 'BAM', 'AIE', 'SAPPE', 'ACE', 'BJC', 'BKIH', 'BLA', 'CPTGF', 'ECL', 'GC', 'KGI', 'LALIN', 'ONEE', 'SKN', 'SKR', 'SPRC', 'SUPER', 'TIPCO', 'TSE', 'TTW', 'WICE', 'FPT', 'BCT', 'BLAND', 'EPG', 'LHK', 'TMW', 'TR', 'TSTH', 'BEC', 'CPN', 'GGC', 'GULF', 'IP', 'SAT', 'SCB', 'KGI'"

# %%
sql = """
SELECT *
FROM buy
WHERE name NOT IN (%s)
ORDER BY name
"""
sql = sql % in_p
df_tmp = pd.read_sql(sql, const)
df_tmp
# Out:
#      name        date   volbuy  price  volsell  volbal  active  dividend  \
# 0  GVREIT  2022-08-24  60000.0    7.9      0.0     0.0       1    0.7833
# 1   TFFIF  2023-07-06  20000.0    7.5      0.0     0.0       1    0.4297
#
#   period grade
# 0      2    C1
# 1      2    A4

# %% [markdown]
# ### Comparison check between EPS and Buy

# %%
sql = """
SELECT name FROM buy WHERE active = 1 ORDER BY name"""
buy = pd.read_sql(sql, const)
buy.shape
# Out:
# (31, 1)

# %%
sql = '''
SELECT * 
FROM epss 
WHERE publish_date >= '%s' 
AND quarter = %s
'''
sql = sql % (select_date, quarter)
print(sql)
tdy_df = pd.read_sql(sql, conlt)
tdy_df.shape
# Out:
# SELECT *
# FROM epss
# WHERE publish_date >= '2024-11-14'
# AND quarter = 3
# (62, 14)

# %%
tdy_buy_df = tdy_df.merge(buy, on='name', how='inner')
tdy_buy_df.sort_values(by='name')
# Out:
#       id     name  year  quarter   q_amt    y_amt   aq_amt   ay_amt   q_eps  \
# 0  23911   AIMIRT  2024        3  149501   121512   606443   410220  0.0000
# 1  23912      ASP  2024        3   68478   102983   293432   341480  0.0300
# 5  23916  CPNREIT  2024        3  801278  1271308  1338631  2662722  0.0000
# 4  23915      ORI  2024        3  402143   724659  1317935  2395583  0.1638
# 2  23913     SENA  2024        3  116254    61827   301801   275131  0.0806
# 3  23914      TOA  2024        3  187898   651159  1468921  2024499  0.0900
#
#     y_eps  aq_eps  ay_eps  ticker_id publish_date
# 0  0.0000  0.0000  0.0000        669   2024-11-14
# 1  0.0500  0.1400  0.1600         40   2024-11-14
# 5  0.0000  0.0000  0.0000        647   2024-11-14
# 4  0.2952  0.5370  0.9761        339   2024-11-14
# 2  0.0429  0.2093  0.1908        437   2024-11-14
# 3  0.3200  0.7300  1.0000        645   2024-11-14

# %%
tdy_buy_df.shape
# Out:
# (6, 14)

# %%
sql = """
SELECT * 
FROM tickers
ORDER BY name"""
print(sql)
tickers = pd.read_sql(sql, conpg)
tickers[['name','id','market']].shape
# Out:
# SELECT *
# FROM tickers
# ORDER BY name
# (396, 3)

# %%
tmp_df = tdy_buy_df.merge(tickers, on='name', how='inner')
tmp_df.shape
# Out:
# (6, 22)

# %%
tmp_df[['name','id_y','market']].sort_values(by='name')
# Out:
#       name  id_y                    market
# 0   AIMIRT    13                       SET
# 1      ASP    44                      sSET
# 5  CPNREIT   127                       SET
# 4      ORI   347  SET100 / SETHD / SETTHSI
# 2     SENA   443                      sSET
# 3      TOA   562                   SETTHSI
