# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from glob import glob

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

pd.set_option('max_rows',None)

data_path = "../data/"

# %%
year = 2024
quarter = 2
year, quarter
# Out:
# (2024, 2)

# %%
sql = """
SELECT name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id
FROM epss
WHERE year = %s AND quarter = %s
ORDER BY name
"""
sql = sql % (year, quarter)
print(sql)
epss_df = pd.read_sql(sql, conlt)
epss_df.shape
# Out:
# SELECT name, year, quarter, q_amt, y_amt, aq_amt, ay_amt, ticker_id
# FROM epss
# WHERE year = 2024 AND quarter = 2
# ORDER BY name
# (208, 8)

# %%
epss_df.columns
# Out:
# Index(['name', 'year', 'quarter', 'q_amt', 'y_amt', 'aq_amt', 'ay_amt',
#        'ticker_id'],
#       dtype='object')

# %%
epss_df['grade'] = 0
epss_df.columns
# Out:
# Index(['name', 'year', 'quarter', 'q_amt', 'y_amt', 'aq_amt', 'ay_amt',
#        'ticker_id', 'grade'],
#       dtype='object')

# %%
def grade(vals):
    qc, qp, aqc, aqp = vals
    if aqc >= aqp:
        if qc >= qp:
            return 1
        else:
            return 2
    else:
        if qc < qp:
            return 4
        else:
            return 3

# %%
epss_df["grade"] = epss_df[["q_amt", "y_amt","aq_amt", "ay_amt"]].apply(grade, axis=1)
epss_df.shape
# Out:
# (208, 9)

# %%
mask1 = epss_df["grade"] == 1
epss_df[mask1].shape
# Out:
# (93, 9)

# %%
mask2 = epss_df["grade"] == 2
epss[mask2].shape
# Out:
# (16, 8)

# %%
mask3 = epss_df["grade"] == 3
epss_df[mask3].shape
# Out:
# (21, 9)

# %%
mask4 = epss_df["grade"] == 4
epss_df[mask4].shape
# Out:
# (78, 9)

# %%
g4 = epss_df[mask4]
g4.sort_values(by='name',ascending=True)
# Out:
#         name  year  quarter     q_amt     y_amt    aq_amt    ay_amt  \
# 1        ACE  2024        2    219602    315806    474822    590831
# 3         AH  2024        2    102734    409986    422226    971804
# 8      AMATA  2024        2    231166    313305    694747    805289
# 11        AP  2024        2   1268796   1544457   2277129   3022860
# 13       ASK  2024        2     82413    336578    256240    739375
# 14       ASP  2024        2     79229    110916    224954    238497
# 20       BAY  2024        2   8208926   8425299  15751540  17101587
# 26       BE8  2024        2     34571     67514     66008    124304
# 27    BEAUTY  2024        2    -29967     -2767    -31740     -8999
# 31     BGRIM  2024        2    228517    679230    607168   1079359
# 36       BPP  2024        2    981652   1337556   1658908   3451896
# 48   CPNREIT  2024        2   -348049    757225    537353   1391414
# 51       DCC  2024        2    270140    277537    610760    617147
# 52      DCON  2024        2      4172     54902     39748    111141
# 54       DIF  2024        2   2675677   2772676   5357976   5581078
# 57        EA  2024        2    541737   2160255   1430440   4480016
# 59       ECL  2024        2     20449     31429     34412     72535
# 61      EGCO  2024        2   1393139   1459868   3055541   3482063
# 62     FORTH  2024        2    104988    203629    189170    428143
# 63       FPT  2024        2    158526    316979    475067    631884
# 67       GGC  2024        2   -178339      7012   -232636     46825
# 73    GVREIT  2024        2    178836    193037    377143    389593
# 74      HANA  2024        2    376384    635381    689585    901871
# 79       III  2024        2    102746    157809    219366    301709
# 81       IMH  2024        2      2208     30581      2280     59520
# 84        IP  2024        2      3417     10440     19213     49607
# 86       IVL  2024        2 -22995725    411131 -21862730   1434528
# 88       JMT  2024        2    366881    551003    785143   1004068
# 91       KEX  2024        2  -1063044  -1041676  -2251333  -1832596
# 92       KKP  2024        2    768788   1408291   2274811   3493155
# 95     LALIN  2024        2    145902    207146    253120    440974
# 96     LANNA  2024        2    481947    641432   1065943   1422105
# 97        LH  2024        2   1017024   1449715   2248048   2803702
# 98      LHFG  2024        2    491417    532041    890615   1201909
# 99       LIT  2024        2    -35106    -28261    -62015    -51856
# 102        M  2024        2    400642    458918    747147    784214
# 103    MAJOR  2024        2    232223    532483    372535    602593
# 109      MST  2024        2     46823     66458    218136    230746
# 113     ONEE  2024        2    120040    121750    151191    174335
# 115      ORI  2024        2    451700    873074    915792   1670924
# 118    PCSGH  2024        2    145370    225995    313141    383200
# 124      PSH  2024        2    313718   1037865    379135   1690333
# 130       QH  2024        2    619997    669406   1110090   1261817
# 132      RBF  2024        2    102313    153281    274097    300019
# 136       RS  2024        2    -46523     92612   -176769    184542
# 137      S11  2024        2    -28911     33809    -52634     70964
# 138    SABUY  2024        2  -2914557    179618  -4875277    346563
# 140      SAT  2024        2    140196    223209    327280    497624
# 142       SC  2024        2    531284    593047    713891   1127654
# 143      SCB  2024        2  10014333  11868127  21295356  22863503
# 144      SCC  2024        2   3707928   8082241   6132786  24607976
# 147     SENA  2024        2     74601    127024    185547    213304
# 150     SIRI  2024        2   1387050   1621153   2702025   3202928
# 154      SKR  2024        2    164485    227411    401873    440066
# 156      SNC  2024        2      7332     50552    -16609    147562
# 157    SPALI  2024        2   1598899   1700727   2212541   2781141
# 159     SPCG  2024        2    143695    553403    473059   1149914
# 161   SPRIME  2024        2     61254     75961    125804    145877
# 162      SSP  2024        2    122667    228093    326891    467707
# 164     STEC  2024        2     25260    153644     37114    324631
# 166    SUPER  2024        2   -305969     47671   -115118    563074
# 170    TASCO  2024        2     99009    744030    106886   1872197
# 174    THANI  2024        2    254533    425055    597724    875297
# 175      THG  2024        2     42831    128187     49198    339410
# 177    TIPCO  2024        2    -34266     67867   -101412    299365
# 178     TIPH  2024        2    241156    321403    814916    960269
# 179    TISCO  2024        2   1748992   1853888   3482014   3646468
# 180       TK  2024        2      6619     23282    -24583     65378
# 182      TKS  2024        2   -144392     70079    -55739    146039
# 184      TOA  2024        2    476975    741367   1281023   1373340
# 186    TPIPL  2024        2    606365   1171019   1348468   1816659
# 187    TPIPP  2024        2    857734    935003   1557149   1981400
# 190      TSE  2024        2     86487    152201    183787    385475
# 193    TTLPF  2024        2     53357     59061    112141    117918
# 194      TTW  2024        2    622651    624859   1125894   1219705
# 197     TYCN  2024        2    -42895     61471    -21464    131298
# 198      UTP  2024        2    198894    216146    378256    426128
# 199      VGI  2024        2   1598899   1700727   2212541   2781141
#
#      ticker_id  grade
# 1          698      4
# 3            9      4
# 8           21      4
# 11          25      4
# 13          38      4
# 14          40      4
# 20          49      4
# 26         745      4
# 27          55      4
# 31          59      4
# 36          74      4
# 48         647      4
# 51         135      4
# 52         136      4
# 54         140      4
# 57         148      4
# 59         153      4
# 61         157      4
# 62         176      4
# 63         746      4
# 67         188      4
# 73         654      4
# 74         205      4
# 79         637      4
# 81         730      4
# 84         736      4
# 86         231      4
# 88         237      4
# 91         740      4
# 92         255      4
# 95         263      4
# 96         264      4
# 97         267      4
# 98         268      4
# 99         273      4
# 102        279      4
# 103        282      4
# 109        290      4
# 113        741      4
# 115        339      4
# 118        346      4
# 124        377      4
# 130        388      4
# 132        703      4
# 136        408      4
# 137        412      4
# 138        721      4
# 140        421      4
# 142        425      4
# 143        426      4
# 144        427      4
# 147        437      4
# 150        447      4
# 154        451      4
# 156        457      4
# 157        462      4
# 159        464      4
# 161        705      4
# 162        643      4
# 164        484      4
# 166        487      4
# 170        502      4
# 174        522      4
# 175        661      4
# 177        530      4
# 178        529      4
# 179        531      4
# 180        532      4
# 182        534      4
# 184        645      4
# 186        559      4
# 187        560      4
# 190        573      4
# 193        707      4
# 194        581      4
# 197        737      4
# 198        605      4
# 199        609      4

# %% [markdown]
# ### New feature: Exempt SET50 & SET100

# %%
sql = '''
SELECT name, market
FROM stocks
ORDER BY name'''
lt_stocks = pd.read_sql(sql, conlt)
lt_stocks.shape
# Out:
# (226, 2)

# %%
filters = [
   (lt_stocks.market.str.contains('SET50')),
   (lt_stocks.market.str.contains('SET100'))    
]
values = ['SET50','SET100']
lt_stocks["mrkt"] = np.select(filters, values, default='SETMAI')

# %%
g4.dtypes
# Out:
# name         object
# year          int64
# quarter       int64
# q_amt         int64
# y_amt         int64
# aq_amt        int64
# ay_amt        int64
# ticker_id     int64
# grade         int64
# dtype: object

# %%
g4_merge = pd.merge(g4,lt_stocks,on='name',how='inner')
g4_merge.dtypes
# Out:
# name         object
# year          int64
# quarter       int64
# q_amt         int64
# y_amt         int64
# aq_amt        int64
# ay_amt        int64
# ticker_id     int64
# grade         int64
# market       object
# mrkt         object
# dtype: object

# %%
mrkt_mask = g4_merge['mrkt'] == 'SETMAI'
g4_filter = g4_merge[mrkt_mask].copy()
g4_filter.shape
# Out:
# (52, 11)

# %%
format_dict = {
               'q_amt':'{:,}','y_amt':'{:,}','aq_amt':'{:,}','ay_amt':'{:,}'
}
pd.set_option("display.max_rows", None)

# %%
g4_filter.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d1fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >aq_amt</th>
#       <th class="col_heading level0 col6" >ay_amt</th>
#       <th class="col_heading level0 col7" >ticker_id</th>
#       <th class="col_heading level0 col8" >grade</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d1fb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8d1fb_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_8d1fb_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_8d1fb_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_8d1fb_row0_col3" class="data row0 col3" >102,734</td>
#       <td id="T_8d1fb_row0_col4" class="data row0 col4" >409,986</td>
#       <td id="T_8d1fb_row0_col5" class="data row0 col5" >422,226</td>
#       <td id="T_8d1fb_row0_col6" class="data row0 col6" >971,804</td>
#       <td id="T_8d1fb_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_8d1fb_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_8d1fb_row0_col9" class="data row0 col9" >sSET / SETTHSI    </td>
#       <td id="T_8d1fb_row0_col10" class="data row0 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8d1fb_row1_col0" class="data row1 col0" >ASK</td>
#       <td id="T_8d1fb_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_8d1fb_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_8d1fb_row1_col3" class="data row1 col3" >82,413</td>
#       <td id="T_8d1fb_row1_col4" class="data row1 col4" >336,578</td>
#       <td id="T_8d1fb_row1_col5" class="data row1 col5" >256,240</td>
#       <td id="T_8d1fb_row1_col6" class="data row1 col6" >739,375</td>
#       <td id="T_8d1fb_row1_col7" class="data row1 col7" >38</td>
#       <td id="T_8d1fb_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_8d1fb_row1_col9" class="data row1 col9" >SET    </td>
#       <td id="T_8d1fb_row1_col10" class="data row1 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_8d1fb_row2_col0" class="data row2 col0" >ASP</td>
#       <td id="T_8d1fb_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_8d1fb_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_8d1fb_row2_col3" class="data row2 col3" >79,229</td>
#       <td id="T_8d1fb_row2_col4" class="data row2 col4" >110,916</td>
#       <td id="T_8d1fb_row2_col5" class="data row2 col5" >224,954</td>
#       <td id="T_8d1fb_row2_col6" class="data row2 col6" >238,497</td>
#       <td id="T_8d1fb_row2_col7" class="data row2 col7" >40</td>
#       <td id="T_8d1fb_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_8d1fb_row2_col9" class="data row2 col9" >sSET    </td>
#       <td id="T_8d1fb_row2_col10" class="data row2 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_8d1fb_row3_col0" class="data row3 col0" >BAY</td>
#       <td id="T_8d1fb_row3_col1" class="data row3 col1" >2024</td>
#       <td id="T_8d1fb_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_8d1fb_row3_col3" class="data row3 col3" >8,208,926</td>
#       <td id="T_8d1fb_row3_col4" class="data row3 col4" >8,425,299</td>
#       <td id="T_8d1fb_row3_col5" class="data row3 col5" >15,751,540</td>
#       <td id="T_8d1fb_row3_col6" class="data row3 col6" >17,101,587</td>
#       <td id="T_8d1fb_row3_col7" class="data row3 col7" >49</td>
#       <td id="T_8d1fb_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_8d1fb_row3_col9" class="data row3 col9" >SET    </td>
#       <td id="T_8d1fb_row3_col10" class="data row3 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_8d1fb_row4_col0" class="data row4 col0" >BE8</td>
#       <td id="T_8d1fb_row4_col1" class="data row4 col1" >2024</td>
#       <td id="T_8d1fb_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_8d1fb_row4_col3" class="data row4 col3" >34,571</td>
#       <td id="T_8d1fb_row4_col4" class="data row4 col4" >67,514</td>
#       <td id="T_8d1fb_row4_col5" class="data row4 col5" >66,008</td>
#       <td id="T_8d1fb_row4_col6" class="data row4 col6" >124,304</td>
#       <td id="T_8d1fb_row4_col7" class="data row4 col7" >745</td>
#       <td id="T_8d1fb_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_8d1fb_row4_col9" class="data row4 col9" >mai    </td>
#       <td id="T_8d1fb_row4_col10" class="data row4 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_8d1fb_row5_col0" class="data row5 col0" >BEAUTY</td>
#       <td id="T_8d1fb_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_8d1fb_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_8d1fb_row5_col3" class="data row5 col3" >-29,967</td>
#       <td id="T_8d1fb_row5_col4" class="data row5 col4" >-2,767</td>
#       <td id="T_8d1fb_row5_col5" class="data row5 col5" >-31,740</td>
#       <td id="T_8d1fb_row5_col6" class="data row5 col6" >-8,999</td>
#       <td id="T_8d1fb_row5_col7" class="data row5 col7" >55</td>
#       <td id="T_8d1fb_row5_col8" class="data row5 col8" >4</td>
#       <td id="T_8d1fb_row5_col9" class="data row5 col9" >sSET    </td>
#       <td id="T_8d1fb_row5_col10" class="data row5 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_8d1fb_row6_col0" class="data row6 col0" >BPP</td>
#       <td id="T_8d1fb_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_8d1fb_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_8d1fb_row6_col3" class="data row6 col3" >981,652</td>
#       <td id="T_8d1fb_row6_col4" class="data row6 col4" >1,337,556</td>
#       <td id="T_8d1fb_row6_col5" class="data row6 col5" >1,658,908</td>
#       <td id="T_8d1fb_row6_col6" class="data row6 col6" >3,451,896</td>
#       <td id="T_8d1fb_row6_col7" class="data row6 col7" >74</td>
#       <td id="T_8d1fb_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_8d1fb_row6_col9" class="data row6 col9" >SETCLMV / SETTHSI    </td>
#       <td id="T_8d1fb_row6_col10" class="data row6 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_8d1fb_row7_col0" class="data row7 col0" >CPNREIT</td>
#       <td id="T_8d1fb_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_8d1fb_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_8d1fb_row7_col3" class="data row7 col3" >-348,049</td>
#       <td id="T_8d1fb_row7_col4" class="data row7 col4" >757,225</td>
#       <td id="T_8d1fb_row7_col5" class="data row7 col5" >537,353</td>
#       <td id="T_8d1fb_row7_col6" class="data row7 col6" >1,391,414</td>
#       <td id="T_8d1fb_row7_col7" class="data row7 col7" >647</td>
#       <td id="T_8d1fb_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_8d1fb_row7_col9" class="data row7 col9" >SET    </td>
#       <td id="T_8d1fb_row7_col10" class="data row7 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_8d1fb_level0_row8" class="row_heading level0 row8" >12</th>
#       <td id="T_8d1fb_row8_col0" class="data row8 col0" >DCC</td>
#       <td id="T_8d1fb_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_8d1fb_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_8d1fb_row8_col3" class="data row8 col3" >270,140</td>
#       <td id="T_8d1fb_row8_col4" class="data row8 col4" >277,537</td>
#       <td id="T_8d1fb_row8_col5" class="data row8 co

# %% [markdown]
# ### End of New feature

# %%
mask41 = g4_filter.aq_amt < 200_000
g4_filter[mask41].shape
# Out:
# (22, 11)

# %%
mask42 = g4_filter.q_amt < 100_000
g4_filter[mask42].shape
# Out:
# (26, 11)

# %%
mask43 = g4_filter.ay_amt < 200_000
g4_filter[mask43].shape
# Out:
# (16, 11)

# %%
mask44 = g4_filter.market.str.contains('mai')
g4_filter[mask44].shape
# Out:
# (4, 11)

# %%
filter1 = g4_filter[mask41 & mask42 & mask43 & ~mask44]
filter1.sort_values(by='name',ascending=True).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_14e69_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >q_amt</th>
#       <th class="col_heading level0 col4" >y_amt</th>
#       <th class="col_heading level0 col5" >aq_amt</th>
#       <th class="col_heading level0 col6" >ay_amt</th>
#       <th class="col_heading level0 col7" >ticker_id</th>
#       <th class="col_heading level0 col8" >grade</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14e69_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_14e69_row0_col0" class="data row0 col0" >BEAUTY</td>
#       <td id="T_14e69_row0_col1" class="data row0 col1" >2024</td>
#       <td id="T_14e69_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_14e69_row0_col3" class="data row0 col3" >-29,967</td>
#       <td id="T_14e69_row0_col4" class="data row0 col4" >-2,767</td>
#       <td id="T_14e69_row0_col5" class="data row0 col5" >-31,740</td>
#       <td id="T_14e69_row0_col6" class="data row0 col6" >-8,999</td>
#       <td id="T_14e69_row0_col7" class="data row0 col7" >55</td>
#       <td id="T_14e69_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_14e69_row0_col9" class="data row0 col9" >sSET    </td>
#       <td id="T_14e69_row0_col10" class="data row0 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_14e69_row1_col0" class="data row1 col0" >DCON</td>
#       <td id="T_14e69_row1_col1" class="data row1 col1" >2024</td>
#       <td id="T_14e69_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_14e69_row1_col3" class="data row1 col3" >4,172</td>
#       <td id="T_14e69_row1_col4" class="data row1 col4" >54,902</td>
#       <td id="T_14e69_row1_col5" class="data row1 col5" >39,748</td>
#       <td id="T_14e69_row1_col6" class="data row1 col6" >111,141</td>
#       <td id="T_14e69_row1_col7" class="data row1 col7" >136</td>
#       <td id="T_14e69_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_14e69_row1_col9" class="data row1 col9" >SET    </td>
#       <td id="T_14e69_row1_col10" class="data row1 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_14e69_row2_col0" class="data row2 col0" >ECL</td>
#       <td id="T_14e69_row2_col1" class="data row2 col1" >2024</td>
#       <td id="T_14e69_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_14e69_row2_col3" class="data row2 col3" >20,449</td>
#       <td id="T_14e69_row2_col4" class="data row2 col4" >31,429</td>
#       <td id="T_14e69_row2_col5" class="data row2 col5" >34,412</td>
#       <td id="T_14e69_row2_col6" class="data row2 col6" >72,535</td>
#       <td id="T_14e69_row2_col7" class="data row2 col7" >153</td>
#       <td id="T_14e69_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_14e69_row2_col9" class="data row2 col9" >SET    </td>
#       <td id="T_14e69_row2_col10" class="data row2 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_14e69_row3_col0" class="data row3 col0" >GGC</td>
#       <td id="T_14e69_row3_col1" class="data row3 col1" >2024</td>
#       <td id="T_14e69_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_14e69_row3_col3" class="data row3 col3" >-178,339</td>
#       <td id="T_14e69_row3_col4" class="data row3 col4" >7,012</td>
#       <td id="T_14e69_row3_col5" class="data row3 col5" >-232,636</td>
#       <td id="T_14e69_row3_col6" class="data row3 col6" >46,825</td>
#       <td id="T_14e69_row3_col7" class="data row3 col7" >188</td>
#       <td id="T_14e69_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_14e69_row3_col9" class="data row3 col9" >SET    </td>
#       <td id="T_14e69_row3_col10" class="data row3 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row4" class="row_heading level0 row4" >44</th>
#       <td id="T_14e69_row4_col0" class="data row4 col0" >RS</td>
#       <td id="T_14e69_row4_col1" class="data row4 col1" >2024</td>
#       <td id="T_14e69_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_14e69_row4_col3" class="data row4 col3" >-46,523</td>
#       <td id="T_14e69_row4_col4" class="data row4 col4" >92,612</td>
#       <td id="T_14e69_row4_col5" class="data row4 col5" >-176,769</td>
#       <td id="T_14e69_row4_col6" class="data row4 col6" >184,542</td>
#       <td id="T_14e69_row4_col7" class="data row4 col7" >408</td>
#       <td id="T_14e69_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_14e69_row4_col9" class="data row4 col9" >sSET / SETTHSI    </td>
#       <td id="T_14e69_row4_col10" class="data row4 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row5" class="row_heading level0 row5" >45</th>
#       <td id="T_14e69_row5_col0" class="data row5 col0" >S11</td>
#       <td id="T_14e69_row5_col1" class="data row5 col1" >2024</td>
#       <td id="T_14e69_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_14e69_row5_col3" class="data row5 col3" >-28,911</td>
#       <td id="T_14e69_row5_col4" class="data row5 col4" >33,809</td>
#       <td id="T_14e69_row5_col5" class="data row5 col5" >-52,634</td>
#       <td id="T_14e69_row5_col6" class="data row5 col6" >70,964</td>
#       <td id="T_14e69_row5_col7" class="data row5 col7" >412</td>
#       <td id="T_14e69_row5_col8" class="data row5 col8" >4</td>
#       <td id="T_14e69_row5_col9" class="data row5 col9" >sSET    </td>
#       <td id="T_14e69_row5_col10" class="data row5 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row6" class="row_heading level0 row6" >54</th>
#       <td id="T_14e69_row6_col0" class="data row6 col0" >SNC</td>
#       <td id="T_14e69_row6_col1" class="data row6 col1" >2024</td>
#       <td id="T_14e69_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_14e69_row6_col3" class="data row6 col3" >7,332</td>
#       <td id="T_14e69_row6_col4" class="data row6 col4" >50,552</td>
#       <td id="T_14e69_row6_col5" class="data row6 col5" >-16,609</td>
#       <td id="T_14e69_row6_col6" class="data row6 col6" >147,562</td>
#       <td id="T_14e69_row6_col7" class="data row6 col7" >457</td>
#       <td id="T_14e69_row6_col8" class="data row6 col8" >4</td>
#       <td id="T_14e69_row6_col9" class="data row6 col9" >sSET / SETTHSI    </td>
#       <td id="T_14e69_row6_col10" class="data row6 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row7" class="row_heading level0 row7" >57</th>
#       <td id="T_14e69_row7_col0" class="data row7 col0" >SPRIME</td>
#       <td id="T_14e69_row7_col1" class="data row7 col1" >2024</td>
#       <td id="T_14e69_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_14e69_row7_col3" class="data row7 col3" >61,254</td>
#       <td id="T_14e69_row7_col4" class="data row7 col4" >75,961</td>
#       <td id="T_14e69_row7_col5" class="data row7 col5" >125,804</td>
#       <td id="T_14e69_row7_col6" class="data row7 col6" >145,877</td>
#       <td id="T_14e69_row7_col7" class="data row7 col7" >705</td>
#       <td id="T_14e69_row7_col8" class="data row7 col8" >4</td>
#       <td id="T_14e69_row7_col9" class="data row7 col9" >SET    </td>
#       <td id="T_14e69_row7_col10" class="data row7 col10" >SETMAI</td>
#     </tr>
#     <tr>
#       <th id="T_14e69_level0_row8" class="row_heading level0 row8" >67</th>
#       <td id="T_14e69_row8_col0" class="data row8 col0" >TK</td>
#       <td id="T_14e69_row8_col1" class="data row8 col1" >2024</td>
#       <td id="T_14e69_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_14e69_row8_col3" class="data row8 col3" >6,619</td>
#       <td id="T_14e69_row8_col4" class="data row8 col4" >23,282</td>
#       <td id="T_14e69_row8_col5" class="data row8 col5" >-24,583</td>
#       <t

# %%
filter1.shape
# Out:
# (12, 11)

# %% [markdown]
# ### End of Modified Filter Criteria

# %%
#filter1 = filter1.drop(51)
filter1.shape
# Out:
# (12, 11)

# %%
loss = filter1['name']
file_name = 'loss.csv'
data_file = data_path + file_name
loss.to_csv(data_file, index=False, header=False)

# %%
### Backup exempts before insert new records

# %%
sql = '''
SELECT name
FROM exempts
ORDER BY name'''
exempts = pd.read_sql(sql, conlt)
exempts.tail()
# Out:
#       name
# 398     XO
# 399  YUASA
# 400    ZEN
# 401   ZIGA
# 402  ZMICO

# %%
file_name = 'exempts-24q2.csv'
data_file = data_path + file_name
data_file
# Out:
# '../data/exempts-24q2.csv'

# %%
exempts.to_csv(data_file, index=False, header=False)

# %% [markdown]
# ### End of Backup exempts before insert new records

# %% [markdown]
# ### Check whether record already existed

# %%
df_merge = pd.merge(filter1, exempts, on='name', how='outer', indicator=True)
df_merge1 = df_merge[df_merge['_merge'] == 'left_only']
df_merge1.shape
# Out:
# (12, 12)

# %% [markdown]
# ### Check with buys table in Portfolio database

# %%
sql = '''
SELECT DISTINCT name 
FROM buys B
JOIN stocks S
ON B.stock_id = S.id
ORDER BY name'''
buys = pd.read_sql(sql, conpf)
buys.shape
# Out:
# (150, 1)

# %%
df_merge1 = df_merge1.drop('_merge', 1)
df_merge1.shape
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20180\3427655093.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_merge1 = df_merge1.drop('_merge', 1)
# (12, 11)

# %%
df_merge2 = pd.merge(df_merge1, buys, on='name', how='outer', indicator=True)
final2 = df_merge2[df_merge2['_merge'] == 'left_only']
final2.shape
# Out:
# (5, 12)

# %%
df_merge2 = pd.merge(df_merge1, buys, on='name', how='outer', indicator=True)
tmp = df_merge2[df_merge2['_merge'] == 'both']
tmp
# Out:
#       name    year  quarter     q_amt    y_amt    aq_amt    ay_amt  ticker_id  \
# 0   BEAUTY  2024.0      2.0  -29967.0  -2767.0  -31740.0   -8999.0       55.0
# 1     DCON  2024.0      2.0    4172.0  54902.0   39748.0  111141.0      136.0
# 2      ECL  2024.0      2.0   20449.0  31429.0   34412.0   72535.0      153.0
# 6      SNC  2024.0      2.0    7332.0  50552.0  -16609.0  147562.0      457.0
# 9      TKS  2024.0      2.0 -144392.0  70079.0  -55739.0  146039.0      534.0
# 10   TTLPF  2024.0      2.0   53357.0  59061.0  112141.0  117918.0      707.0
# 11    TYCN  2024.0      2.0  -42895.0  61471.0  -21464.0  131298.0      737.0
#
#     grade              market    mrkt _merge
# 0     4.0            sSET      SETMAI   both
# 1     4.0             SET      SETMAI   both
# 2     4.0             SET      SETMAI   both
# 6     4.0  sSET / SETTHSI      SETMAI   both
# 9     4.0  sSET / SETTHSI      SETMAI   both
# 10    4.0             SET      SETMAI   both
# 11    4.0             SET      SETMAI   both

# %%
sr = final2['name']
file_name = 'loss.csv'
data_file = data_path + file_name
sr.to_csv(data_file, index=False, header=False)

# %%
rcds = sr.values.tolist()
rcds
# Out:
# ['GGC', 'RS', 'S11', 'SPRIME', 'TK']

# %%
for rcd in rcds:
    print(rcd)
# Out:
# GGC
# RS
# S11
# SPRIME
# TK

# %%
sql = '''
SELECT COUNT(*)
FROM exempts'''
tmp_bf = pd.read_sql(sql, conlt)
tmp_bf
# Out:
#    COUNT(*)
# 0       403

# %%
for rcd in rcds:
    conlt.execute("""INSERT INTO exempts (name) \
VALUES(?)""", rcd)

# %%
sql = '''
SELECT COUNT(*)
FROM exempts'''
tmp_af = pd.read_sql(sql, conlt)
tmp_af
# Out:
#    COUNT(*)
# 0       299
