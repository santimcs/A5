# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-02-21 2025-02-20

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-02-21
# yesterday: 2025-02-20

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-21 19:59:35

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 20    BSRC  5.25    0.31     6.28  5.15  5.40  5.10      20464710
# 75     RCL 26.75    1.50     5.94 25.25 27.25 25.25       8160952
# 36  DOHOME  7.40    0.40     5.71  7.00  7.45  6.95      12206742
# 28     CKP  2.74    0.10     3.79  2.64  2.76  2.64       6931412
# 41    GPSC 29.00    1.00     3.57 28.00 29.50 28.00       9043122
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 72   PTTGC 18.30   -0.90    -4.69 19.10 19.30 18.00      64522364
# 66     OSP 14.20   -0.70    -4.70 14.90 14.90 14.20      23854527
# 13    BCPG  6.70   -0.35    -4.96  6.60  6.80  6.55      20818247
# 50     IVL 21.00   -1.10    -4.98 22.20 22.30 21.00      27246451
# 82    SISB 22.90   -1.40    -5.76 25.00 25.25 22.30       9770964
#
#     Total Value (k)
# 20        106818.80
# 75        217842.72
# 36         88893.61
# 28         18736.44
# 41        261285.52
# ..              ...
# 72       1192064.23
# 66        343024.31
# 13        138744.12
# 50        583089.88
# 82        227925.36
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 56    KCE            - 20.50   -0.70    -3.30 21.10 21.20 20.50      50400
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 56       1033.20       5564641        115397.75    226600 20.50  20.70
#
#     Offer Size
# 56       23500

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 98      SSP  5.75    0.45     8.49  5.30  5.80  5.25       5195608
# 107    TEGH  3.46    0.26     8.12  3.24  3.52  3.24       9420812
# 58      NYT  3.40    0.22     6.92  3.50  3.52  3.36      11197531
# 50      MCS  7.25    0.45     6.62  7.45  7.45  7.20       1310064
# 54      NEO 30.50    1.75     6.09 28.75 30.50 28.50        608520
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 29     GFPT  8.80   -0.35    -3.83  9.05  9.05  8.80       4024605
# 99   STECON  3.58   -0.20    -5.29  3.82  3.86  3.38      15186780
# 83   SAMTEL  5.65   -0.40    -6.61  5.85  6.10  5.65        245612
# 40      KEX  1.14   -0.11    -8.80  1.21  1.21  1.14       1700020
# 18      CGD  0.26   -0.03   -10.34  0.29  0.29  0.26        695106
#
#      Total Value (k)
# 98          29143.28
# 107         32102.07
# 58          38451.20
# 50           9611.95
# 54          18069.75
# ..               ...
# 29          35782.03
# 99          54357.65
# 83           1429.74
# 40           1980.79
# 18            184.78
#
# [121 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.30    0.00     0.00  2.28  2.30  2.26          0
# 50      MCS            -  7.25    0.45     6.62  7.45  7.45  7.20          0
# 91   SINGER            -  5.90   -0.10    -1.67  6.00  6.05  5.90          0
# 105   SYNEX            - 10.50    0.00     0.00 10.50 10.60 10.30          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9               0        506524          1159.98    224600  2.28   2.30
# 50              0       1310064          9611.95    135200  7.20   7.25
# 91              0       1215666          7245.56    182600  5.90   5.95
# 105             0        617182          6452.27    179500 10.50  10.60
#
#      Offer Size
# 9          3200
# 50        20300
# 91        16900
# 105       32800

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 54    SSP  5.75    0.45     8.49  5.30  5.80  5.25       5195608
# 11   BSRC  5.25    0.31     6.28  5.15  5.40  5.10      20464710
# 44    RCL 26.75    1.50     5.94 25.25 27.25 25.25       8160952
# 56  SUPER  0.19    0.01     5.56  0.19  0.19  0.18       9595988
# 14    CKP  2.74    0.10     3.79  2.64  2.76  2.64       6931412
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 61    TOP 25.25   -1.00    -3.81 26.00 26.00 25.00      34862770
# 41  PTTGC 18.30   -0.90    -4.69 19.10 19.30 18.00      64522364
# 37    OSP 14.20   -0.70    -4.70 14.90 14.90 14.20      23854527
# 6    BCPG  6.70   -0.35    -4.96  6.60  6.80  6.55      20818247
# 27    IVL 21.00   -1.10    -4.98 22.20 22.30 21.00      27246451
#
#     Total Value (k)
# 54         29143.28
# 11        106818.80
# 44        217842.72
# 56          1762.47
# 14         18736.44
# ..              ...
# 61        884541.61
# 41       1192064.23
# 37        343024.31
# 6         138744.12
# 27        583089.88
#
# [63 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  15.60   -0.10    -0.64  15.40  15.80  15.40
# 41  PTTGC            -  18.30   -0.90    -4.69  19.10  19.30  18.00
# 49    SCC            - 141.50   -1.50    -1.05 142.50 143.50 140.50
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00       4504991         70251.76    118600  15.50
# 41          0          0.00      64522364       1192064.23   1736600  18.20
# 49          0          0.00       1983560        281707.01     33800 141.50
#
#     Offer  Offer Size
# 4   15.60       88500
# 41  18.30         100
# 49 142.00       65500

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 21     RCL  26.75    1.50     5.94  25.25  27.25  25.25       8160952
# 2      BAM   6.45    0.20     3.20   6.25   6.55   6.20      24251165
# 15    MEGA  33.25    1.00     3.10  32.25  33.75  31.75       1357038
# 1       AP   8.45    0.25     3.05   8.20   8.55   8.15      15285374
# 9   INTUCH  85.00    2.50     3.03  82.00  85.75  81.25      22106779
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 5      BCP  35.75   -0.75    -2.05  34.00  36.25  33.75      34168234
# 11   KBANK 159.00   -5.00    -3.05 163.00 163.50 159.00      13125627
# 4      BBL 155.50   -6.00    -3.72 159.50 159.50 155.00      21271684
# 27     TOP  25.25   -1.00    -3.81  26.00  26.00  25.00      34862770
# 6     BCPG   6.70   -0.35    -4.96   6.60   6.80   6.55      20818247
#
#     Total Value (k)
# 21        217842.72
# 2         154837.78
# 15         44845.77
# 1         128597.59
# 9        1868561.25
# ..              ...
# 5        1205336.22
# 11       2106882.82
# 4        3325775.87
# 27        884541.61
# 6         138744.12
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 13.80   -0.10    -0.72 13.80 13.90 13.70          0
# 21    RCL            - 26.75    1.50     5.94 25.25 27.25 25.25          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10          0.00       4872679         67263.74    399600 13.70  13.80
# 21          0.00       8160952        217842.72    272500 26.50  26.75
#
#     Offer Size
# 10       70500
# 21      277700

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 99      SSP  5.75    0.45     8.49  5.30  5.80  5.25       5195608
# 106   THANI  1.64    0.09     5.81  1.55  1.80  1.55      28677924
# 97     SNNP 12.40    0.50     4.20 11.90 12.50 11.90       2518241
# 25      CKP  2.74    0.10     3.79  2.64  2.76  2.64       6931412
# 79       RS  0.87    0.03     3.57  0.84  0.89  0.83      13952780
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 76    PTTGC 18.30   -0.90    -4.69 19.10 19.30 18.00      64522364
# 69      OSP 14.20   -0.70    -4.70 14.90 14.90 14.20      23854527
# 14     BCPG  6.70   -0.35    -4.96  6.60  6.80  6.55      20818247
# 48      IVL 21.00   -1.10    -4.98 22.20 22.30 21.00      27246451
# 101  STECON  3.58   -0.20    -5.29  3.82  3.86  3.38      15186780
#
#      Total Value (k)
# 99          29143.28
# 106         47896.48
# 97          30739.29
# 25          18736.44
# 79          11979.89
# ..               ...
# 76        1192064.23
# 69         343024.31
# 14         138744.12
# 48         583089.88
# 101         54357.65
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 14.00    0.00     0.00 14.00 14.00 13.90          0
# 7      AWC            -  3.14    0.00     0.00  3.14  3.16  3.12     277700
# 66     NER            -  4.96    0.10     2.06  4.88  4.96  4.88          0
# 68     ORI            -  3.18    0.04     1.27  3.16  3.22  3.16          0
# 110    TOA            - 12.20    0.00     0.00 12.20 12.40 12.10          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00        339069          4735.40    104300 13.90  14.00
# 7          871.98      20738466         65106.97   2108900  3.12   3.14
# 66           0.00      12870060         63477.89    496900  4.94   4.96
# 68           0.00       2605636          8326.12    130000  3.18   3.20
# 110          0.00       1662832         20331.49    219500 12.20  12.30
#
#      Offer Size
# 2         99300
# 7        682600
# 66        36000
# 68        67500
# 110      345100

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 17  DOHOME  7.40    0.40     5.71  7.00  7.45  6.95      12206742
# 9      BTS  6.20    0.20     3.33  6.00  6.25  5.95      66792135
# 15     CPF 22.50    0.70     3.21 21.90 22.50 21.90      11098929
# 7      BJC 22.90    0.70     3.15 22.20 23.00 22.10       3653787
# 22    MEGA 33.25    1.00     3.10 32.25 33.75 31.75       1357038
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 0      AAV  2.14   -0.02    -0.93  2.16  2.20  2.14      22635319
# 26   SAPPE 52.00   -0.50    -0.95 52.75 52.75 51.25        596294
# 21       M 19.00   -0.60    -3.06 19.60 19.60 19.00       1731563
# 20     ITC 17.90   -0.60    -3.24 18.50 18.70 17.90      10096647
# 24     OSP 14.20   -0.70    -4.70 14.90 14.90 14.20      23854527
#
#     Total Value (k)
# 17         88893.61
# 9         410901.62
# 15        247621.20
# 7          82794.39
# 22         44845.77
# ..              ...
# 0          48732.54
# 26         30985.85
# 21         33214.48
# 20        183972.49
# 24        343024.31
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 16.80    0.10     0.60 16.80 17.10 16.80          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00       6177552        104642.94    359000 16.80  16.90
#
#     Offer Size
# 27       22200

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 35  THANI 1.64   0.09    5.81 1.55 1.80 1.55     28677924        47896.48
# 11    FNS 1.70   0.09    5.59 1.59 1.70 1.59        51054           85.38
# 31   SCAP 1.42   0.07    5.19 1.35 1.45 1.33      3138293         4422.17
# 34     TH 0.64   0.03    4.92 0.61 0.64 0.61       783811          489.20
# 28    S11 2.60   0.10       4 2.50 2.64 2.48       188694          482.36
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 7     CGH 0.51  -0.01   -1.92 0.52 0.52 0.51       714906          364.64
# 10    ECL 0.89  -0.02   -2.20 0.91 0.91 0.89       645501          580.07
# 33     SM 0.96  -0.03   -3.03 0.98 0.98 0.96        55600           53.60
# 13    GBX 0.61  -0.02   -3.17 0.62 0.64 0.60      1499156          914.40
# 2    ASAP 1.39  -0.06   -4.14 1.45 1.49 1.38         9912           14.03
#
# [40 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK            - 7.20  -0.05   -0.69 7.25 7.35 7.15         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0      2497563        18022.88    95500 7.20  7.25     242900

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 10    MCS 7.25   0.45    6.62 7.45 7.45 7.20      1310064         9611.95
# 8    INOX 0.46   0.01    2.22 0.46 0.46 0.45      1215559          551.18
# 4    CITY 1.68   0.03    1.82 1.68 1.68 1.68          100            0.17
# 16   SSSC 2.06   0.02    0.98 2.04 2.06 2.04         3928            8.09
# 19    TMT 3.02   0.02    0.67    3 3.02    3        71842          216.88
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 20   TSTH 0.53  -0.01   -1.85 0.54 0.55 0.53      1254800          677.91
# 13   PERM 0.38  -0.01   -2.56 0.39 0.39 0.37       660901          248.75
# 14    SAM 0.17  -0.01   -5.56 0.17 0.18 0.17       531921           91.45
# 6     GJS 0.12  -0.01   -7.69 0.13 0.13 0.12       799320           98.03
# 11   MILL 0.09  -0.01     -10 0.09 0.10 0.09        97100            8.75
#
# [21 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High Low TR Volume  \
# 19    TMT            - 3.02   0.02    0.67    3 3.02   3         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size Bid Offer Offer Size
# 19            0        71842          216.88    47300   3  3.02       1100

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 21    JCK 0.20   0.02   11.11 0.19 0.20 0.18      1195500          229.57
# 28    MJD 0.72   0.04    5.88 0.68 0.75 0.68        73210           53.38
# 39   PLAT    2   0.09    4.71 2.10 2.14 1.98      5565502        11346.30
# 38    PIN 7.35   0.30    4.26 7.05 7.35    7      4071335        29287.30
# 19  GLAND 1.09   0.04    3.81 1.05 1.12 1.05         2800            2.95
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 47    RML 0.23  -0.01   -4.17 0.24 0.24 0.23      2580400          603.51
# 7     ASW 7.20  -0.35   -4.64 7.50 7.50 7.10      2290580        16560.01
# 29     MK 1.42  -0.08   -5.33 1.42 1.42 1.42        31900           45.30
# 12    CGD 0.26  -0.03  -10.34 0.29 0.29 0.26       695106          184.78
# 22     KC 0.06  -0.01  -14.29 0.06 0.07 0.06      6178100          371.90
#
# [59 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 53   SENA            - 2.24   0.02    0.90 2.22 2.24 2.20         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid  Offer  Offer Size
# 53            0       232442          516.92    31200 2.22   2.24       34200

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last Change %Change  Open  High   Low Total Volume  \
# 29    M-PAT  2.80   0.10    3.70  2.70  2.80  2.70          900
# 33      MIT  0.29   0.01    3.57  0.28  0.29  0.27         2300
# 37     MNRF  2.28   0.06    2.70  2.38  2.38  2.20        20000
# 55    WHAIR     6   0.15    2.56  5.85  6.05  5.85      2904805
# 20   IMPACT 10.60   0.20    1.92 10.50 10.80 10.40       758341
# ..      ...   ...    ...     ...   ...   ...   ...          ...
# 18      HPF  4.66  -0.04   -0.85  4.70  4.70  4.66       120301
# 4   AXTRART 11.10  -0.10   -0.89 11.20 11.20    11       472210
# 26  LHRREIT  5.15  -0.05   -0.96  5.15  5.15  5.10         2801
# 5    B-WORK  4.50  -0.06   -1.32  4.56  4.58  4.50       199333
# 28     LUXF  7.90  -0.15   -1.86  7.80  7.95  7.80       143002
#
#    Total Value (k)
# 29            2.47
# 33            0.63
# 37           44.27
# 55        17196.96
# 20         8056.60
# ..             ...
# 18          561.32
# 4          5249.54
# 26           14.42
# 5           904.69
# 28         1123.11
#
# [51 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.70      0       0 10.60 10.80 10.60         0
# 9   CPNREIT            - 12.30      0       0 12.30 12.30 12.10         0
# 17   GVREIT            -  6.90   0.05    0.73  6.80  6.90  6.75         0
# 55    WHAIR            -     6   0.15    2.56  5.85  6.05  5.85         0
# 56    WHART            - 10.30   0.10    0.98 10.10 10.40 10.10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0       159600         1707.52     89000 10.60  10.70
# 9             0       634284         7755.77     17000 12.20  12.30
# 17            0       205620         1405.32    143500  6.80   6.90
# 55            0      2904805        17196.96     71400  5.95   6.00
# 56            0      4001303        40959.18    143500 10.30  10.40
#
#     Offer Size
# 1         1000
# 9       175100
# 17       70900
# 55       32000
# 56      401100

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 26    TSTE 10.90   1.55   16.58 10.90 10.90 10.90          100            1.09
# 16     NYT  3.40   0.22    6.92  3.50  3.52  3.36     11197531        38451.20
# 20     RCL 26.75   1.50    5.94 25.25 27.25 25.25      8160952       217842.72
# 3   ASIMAR  1.70   0.07    4.29  1.69  1.70  1.63       418805          704.44
# 7      BTS  6.20   0.20    3.33     6  6.25  5.95     66792135       410901.62
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 9      DMT 10.40  -0.20   -1.89 10.50 10.50 10.20      2176150        22521.84
# 15    MENA  1.03  -0.02   -1.90  1.05  1.05  1.02       463986          477.89
# 21     SAV 18.60  -0.60   -3.12 19.20 19.20 18.50       774789        14577.00
# 13    KIAT  0.29  -0.01   -3.33  0.30  0.30  0.29       470808          137.36
# 12     KEX  1.14  -0.11   -8.80  1.21  1.21  1.14      1700020         1980.79
#
# [27 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 20    RCL            - 26.75   1.50    5.94 25.25 27.25 25.25         0
# 24  TFFIF            -  6.35  -0.05   -0.78  6.40  6.40  6.30         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size   Bid Offer Offer Size
# 20            0      8160952       217842.72   272500 26.50 26.75     277700
# 24            0      1717822        10906.04  1509800  6.30  6.35     306500

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 10   GABLE  3.20   0.28    9.59  3.40  3.40  3.14      4585121        14698.28
# 12     ICN  2.04   0.07    3.55  2.02  2.06  1.99      1039914         2102.44
# 9    FORTH  8.25   0.25    3.12     8  8.25  7.95       282611         2305.80
# 16  INTUCH    85   2.50    3.03    82 85.75 81.25     22106779      1868561.25
# 14    INET  5.65   0.10    1.80  5.60  5.70  5.40      5309251        29511.69
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 25  SAMART     7  -0.15   -2.10  7.15  7.20  6.90      4407701        31113.19
# 3      ALT  0.82  -0.02   -2.38  0.87  0.87  0.82        48900           40.83
# 29     SKY 19.60  -0.50   -2.49 20.30 20.30 19.20      1894844        37291.98
# 20     JTS 46.50  -1.75   -3.63    48 48.75 46.50       363395        17233.36
# 26  SAMTEL  5.65  -0.40   -6.61  5.85  6.10  5.65       245612         1429.74
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.30   0.05    0.95 5.25 5.30 5.20         0
# 6    DIF            - 8.05  -0.05   -0.62 8.10 8.15 8.05         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0     10499557        55404.34  2733400 5.25  5.30     372100
# 6            0      6325522        51050.30  3038900 8.05  8.10    1115800

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 34   PRIME  0.09    0.01    12.50  0.09  0.09  0.08       2856408
# 48     SSP  5.75    0.45     8.49  5.30  5.80  5.25       5195608
# 15    BSRC  5.25    0.31     6.28  5.15  5.40  5.10      20464710
# 2       AE  0.17    0.01     6.25  0.16  0.17  0.16       4487501
# 49   SUPER  0.19    0.01     5.56  0.19  0.19  0.18       9595988
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 29  KBSPIF  6.95   -0.25    -3.47  7.20  7.30  6.95        810668
# 55     TOP 25.25   -1.00    -3.81 26.00 26.00 25.00      34862770
# 10    BCPG  6.70   -0.35    -4.96  6.60  6.80  6.55      20818247
# 41     SCN  0.47   -0.03    -6.00  0.49  0.50  0.47        249100
# 57     TSE  0.63   -0.05    -7.35  0.68  0.68  0.63       2135380
#
#     Total Value (k)
# 34           232.41
# 48         29143.28
# 15        106818.80
# 2            724.37
# 49          1762.47
# ..              ...
# 29          5713.70
# 55        884541.61
# 10        138744.12
# 41           120.47
# 57          1390.88
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.65   -0.05    -0.65  7.70  7.70 7.50          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       1825196         13836.40     26400 7.60   7.65
#
#     Offer Size
# 35       60400

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (763, 16)

# %%
df.Symbol.nunique()
# Out:
# 415

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (415, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.36      0       0 2.40 2.40 2.32        20229           47.54
# 0    3BBIF 5.30   0.05    0.95 5.25 5.30 5.20     10499557        55404.34
# 0        A 4.80  -0.12   -2.44 4.92 4.92 4.80         4800           23.24
# 0       A5 2.54  -0.02   -0.78 2.54 2.54 2.52        39700          100.77
# 1      AAI 5.60   0.05    0.90 5.50 5.65 5.50      1119703         6261.01
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 59     WIN 0.39      0       0 0.39 0.40 0.39        80400           31.86
# 119   WORK 6.10   0.00    0.00 6.20 6.20 6.05       306795         1888.25
# 61      WP 3.26   0.00    0.00 3.26 3.30 3.14        33610          108.93
# 120    WPH 9.00   0.00    0.00 9.10 9.10 8.90       435930         3897.01
# 41     XPG 0.89      0       0 0.89 0.91 0.89      7041637         6294.15
#
# [415 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.65  -0.05   -0.65 7.70 7.70 7.50         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      1825196        13836.40    26400 7.60  7.65      60400

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 2, 21)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-02-21   2.14  -0.02   -0.93   2.16   2.20   2.14
# 1   ADVANC  2025-02-21 286.00   3.00    1.06 282.00 289.00 280.00
# 2   AEONTS  2025-02-21 110.50   0.50    0.45 109.00 110.50 108.50
# 3    AMATA  2025-02-21  25.25   0.35    1.41  24.90  25.50  24.90
# 4      AOT  2025-02-21  43.50  -0.25   -0.57  43.75  44.25  43.50
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-02-21   0.29   0.01    3.57   0.28   0.29   0.28
# 54     TGE  2025-02-21   1.71  -0.01   -0.58   1.69   1.74   1.67
# 56   TPIPP  2025-02-21   2.90   0.00    0.00   2.90   2.90   2.88
# 57     TSE  2025-02-21   0.63  -0.05   -7.35   0.68   0.68   0.63
# 61      WP  2025-02-21   3.26   0.00    0.00   3.26   3.30   3.14
#
#    Total-Volume Total-Value-(k)
# 0      22635319        48732.54
# 1       8135642      2321671.04
# 2        160408        17614.44
# 3       3549030        89307.19
# 4      20546003       900062.58
# ..          ...             ...
# 53       767320          216.98
# 54       123713          210.84
# 56      1124334         3249.67
# 57      2135380         1390.88
# 61        33610          108.93
#
# [415 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (415, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (182, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-21 19:59:36

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
