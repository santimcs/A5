# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-02-14 2025-02-13

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-02-14
# yesterday: 2025-02-13

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-14 21:15:08

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 49     ITC 18.00    1.20     7.14 16.90 18.10 16.80      14186608
# 61       M 18.60    1.20     6.90 17.50 18.60 17.50       5535269
# 37      EA  2.64    0.16     6.45  2.52  2.76  2.50     157941267
# 45   HMPRO  8.35    0.35     4.38  8.00  8.45  7.95      41546685
# 16   BGRIM 13.00    0.50     4.00 12.80 13.30 12.70      32276143
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 22     BTS  5.85   -0.25    -4.10  6.15  6.15  5.85      69643877
# 24    CCET  7.55   -0.40    -5.03  8.10  8.10  7.55      98191578
# 33     CPN 48.75   -3.50    -6.70 51.75 52.00 48.75      27101730
# 4      AOT 47.00   -7.50   -13.76 54.25 54.25 46.50     174982491
# 29  COCOCO  8.35   -1.55   -15.66  9.95  9.95  8.30      29330362
#
#     Total Value (k)
# 49        249845.83
# 61        100608.93
# 37        416624.42
# 45        342320.74
# 16        418630.70
# ..              ...
# 22        414165.16
# 24        766448.16
# 33       1339043.65
# 4        8720080.76
# 29        265652.90
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 56    KCE            - 20.80   -0.40    -1.89 21.40 21.50 20.80          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 56          0.00       8319654        175685.12    181400 20.70  20.80
#
#     Offer Size
# 56       23500

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 64       PM  9.30    0.75     8.77  9.30  9.35  9.00       2493150
# 49       MC 10.90    0.80     7.92 10.50 10.90 10.40       8502167
# 51      MGC  2.80    0.16     6.06  2.70  2.80  2.70        109100
# 102   SUPER  0.19    0.01     5.56  0.19  0.19  0.18      10326638
# 106   TEAMG  2.82    0.10     3.68  2.74  2.86  2.74       5680534
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 18      CGD  0.25   -0.01    -3.85  0.26  0.26  0.24       5424501
# 20    CHASE  0.61   -0.03    -4.69  0.65  0.65  0.59       4234000
# 22    DITTO 11.10   -0.60    -5.13 11.90 11.90 11.10       5234039
# 70   RABBIT  0.36   -0.02    -5.26  0.38  0.38  0.36       4336399
# 105   SYNEX 10.00   -0.90    -8.26 10.90 10.90 10.00       6435910
#
#      Total Value (k)
# 64          23011.35
# 49          90726.40
# 51            298.62
# 102          1911.01
# 106         15867.05
# ..               ...
# 18           1357.15
# 20           2587.72
# 22          59535.57
# 70           1603.57
# 105         66165.07
#
# [121 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.30    0.02     0.88  2.28  2.30  2.28          0
# 50      MCS            -  6.45   -0.05    -0.77  6.50  6.60  6.40          0
# 91   SINGER            -  5.80   -0.20    -3.33  6.10  6.10  5.75          0
# 105   SYNEX            - 10.00   -0.90    -8.26 10.90 10.90 10.00          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9               0        176323           402.92    293200  2.28   2.30
# 50              0        151005           974.36      3000  6.40   6.45
# 91              0       5493143         32441.33    159800  5.80   5.85
# 105             0       6435910         66165.07    282600 10.00  10.20
#
#      Offer Size
# 9        215900
# 50         9200
# 91          200
# 105      302700

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 56   SUPER   0.19    0.01     5.56   0.19   0.19   0.18      10326638
# 8    BGRIM  13.00    0.50     4.00  12.80  13.30  12.70      32276143
# 21    GPSC  27.50    1.00     3.77  27.00  28.00  26.75      12757680
# 28  KAMART   9.25    0.30     3.35   9.00   9.30   9.00       3363483
# 42   RATCH  27.75    0.75     2.78  27.00  27.75  27.00       2360626
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 54     SSP   5.20   -0.10    -1.89   5.15   5.25   5.00       1032031
# 11    BSRC   5.05   -0.10    -1.94   5.15   5.15   5.00       1871204
# 17   DELTA 113.00   -2.50    -2.16 116.50 117.00 112.00      16663915
# 33   MALEE   7.70   -0.20    -2.53   7.90   7.90   7.65        672847
# 48     SCB 120.50   -4.00    -3.21 124.50 125.00 118.50      26957293
#
#     Total Value (k)
# 56          1911.01
# 8         418630.70
# 21        350358.88
# 28         30941.49
# 42         64888.78
# ..              ...
# 54          5245.79
# 11          9484.00
# 17       1898493.67
# 33          5207.33
# 48       3266559.44
#
# [63 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  13.70   -0.10    -0.72  13.80  13.90  13.60
# 41  PTTGC            -  19.40    0.20     1.04  19.30  19.70  19.20
# 49    SCC            - 145.50    1.00     0.69 145.00 147.50 144.00
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00       3088959         42548.46    402600  13.70
# 41          0          0.00      23147032        449045.81     15100  19.40
# 49        100         14.55       1789129        260351.14     75200 145.00
#
#     Offer  Offer Size
# 4   13.80       19800
# 41  19.50     1857000
# 49 145.50       68000

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 8    HMPRO   8.35    0.35     4.38   8.00   8.45   7.95      41546685
# 20   RATCH  27.75    0.75     2.78  27.00  27.75  27.00       2360626
# 17     PTT  31.00    0.75     2.48  30.25  31.00  30.25      58968031
# 29     WHA   4.70    0.08     1.73   4.66   4.70   4.62      49833598
# 10     JMT  13.40    0.20     1.52  13.30  13.50  13.10       8082860
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 25    TCAP  48.75   -0.75    -1.52  49.50  49.75  48.75       3897110
# 0   ADVANC 299.00   -5.00    -1.64 303.00 304.00 295.00       9538567
# 24   TASCO  17.00   -0.30    -1.73  17.30  17.50  16.90       6224520
# 21     RCL  24.80   -0.45    -1.78  24.90  25.50  24.70       2824271
# 13     KTB  22.80   -0.50    -2.15  23.30  23.30  22.60      68644435
#
#     Total Value (k)
# 8         342320.74
# 20         64888.78
# 17       1812585.94
# 29        232403.63
# 10        107809.27
# ..              ...
# 25        191019.23
# 0        2848067.27
# 24        106624.30
# 21         70469.43
# 13       1575763.05
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 13.40    0.20     1.52 13.30 13.50 13.10          0
# 21    RCL            - 24.80   -0.45    -1.78 24.90 25.50 24.70          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10          0.00       8082860        107809.27     69700 13.30  13.40
# 21          0.00       2824271         70469.43     48200 24.70  24.80
#
#     Offer Size
# 10       68100
# 21        1700

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 61      MC 10.90    0.80     7.92 10.50 10.90 10.40       8502167
# 42   HMPRO  8.35    0.35     4.38  8.00  8.45  7.95      41546685
# 17   BGRIM 13.00    0.50     4.00 12.80 13.30 12.70      32276143
# 100    STA 15.90    0.60     3.92 15.40 16.10 15.30      11570969
# 37    GPSC 27.50    1.00     3.77 27.00 28.00 26.75      12757680
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 21     BTS  5.85   -0.25    -4.10  6.15  6.15  5.85      69643877
# 32   DITTO 11.10   -0.60    -5.13 11.90 11.90 11.10       5234039
# 29     CPN 48.75   -3.50    -6.70 51.75 52.00 48.75      27101730
# 103  SYNEX 10.00   -0.90    -8.26 10.90 10.90 10.00       6435910
# 4      AOT 47.00   -7.50   -13.76 54.25 54.25 46.50     174982491
#
#      Total Value (k)
# 61          90726.40
# 42         342320.74
# 17         418630.70
# 100        182405.20
# 37         350358.88
# ..               ...
# 21         414165.16
# 32          59535.57
# 29        1339043.65
# 103         66165.07
# 4         8720080.76
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 14.00    0.10     0.72 14.00 14.10 14.00          0
# 7      AWC            -  3.04    0.04     1.33  3.00  3.06  2.98     153600
# 66     NER            -  4.80    0.14     3.00  4.68  4.82  4.68          0
# 68     ORI            -  2.90   -0.08    -2.68  3.00  3.02  2.88          0
# 110    TOA            - 12.30   -0.10    -0.81 12.50 12.50 12.10          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00         26137           366.50      1600 14.00  14.10
# 7          466.94      32016625         96688.94   1222800  3.02   3.04
# 66           0.00       7018447         33460.94    268700  4.78   4.80
# 68           0.00       7054017         20745.76    229000  2.90   2.94
# 110          0.00       1937121         23801.10     11100 12.20  12.30
#
#      Offer Size
# 2          3200
# 7        506600
# 66        23100
# 68        22600
# 110       83600

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 20     ITC 18.00    1.20     7.14 16.90 18.10 16.80      14186608
# 21       M 18.60    1.20     6.90 17.50 18.60 17.50       5535269
# 19   HMPRO  8.35    0.35     4.38  8.00  8.45  7.95      41546685
# 27     STA 15.90    0.60     3.92 15.40 16.10 15.30      11570969
# 11  CENTEL 28.75    1.00     3.60 28.50 29.00 27.75       2060562
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 4     BDMS 22.40   -0.20    -0.88 22.40 22.70 22.20      46644755
# 8      BTG 17.20   -0.20    -1.15 17.40 17.40 17.00        642082
# 10     CBG 70.00   -1.00    -1.41 71.00 71.00 69.50       1670355
# 9      BTS  5.85   -0.25    -4.10  6.15  6.15  5.85      69643877
# 1      AOT 47.00   -7.50   -13.76 54.25 54.25 46.50     174982491
#
#     Total Value (k)
# 20        249845.83
# 21        100608.93
# 19        342320.74
# 27        182405.20
# 11         58687.55
# ..              ...
# 4        1045835.54
# 8          11026.56
# 10        117064.62
# 9         414165.16
# 1        8720080.76
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 15.90    0.60     3.92 15.40 16.10 15.30          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00      11570969        182405.20    269300 15.80  15.90
#
#     Offer Size
# 27       55400

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 28     S11 2.32   0.42   22.11 2.20 2.40 2.12      1655203         3816.94
# 16     IFS 2.46   0.18    7.89 2.26 2.46 2.26       130100          310.49
# 6      BYD 0.65   0.02    3.17 0.64 0.68 0.63     10640859         6967.15
# 10     ECL 0.92   0.02    2.22 0.92 0.92 0.90       425900          388.31
# 7      CGH 0.50   0.01    2.04 0.49 0.51 0.48      1401589          696.54
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 22   MICRO 0.93  -0.02   -2.11 0.96 0.96 0.87      1409010         1287.92
# 32     SGC 0.89  -0.02   -2.20 0.90 0.92 0.89      9024716         8130.05
# 2     ASAP 1.37  -0.06   -4.20 1.50 1.65 1.37        29900           42.04
# 8    CHASE 0.61  -0.03   -4.69 0.65 0.65 0.59      4234000         2587.72
# 1   AMANAH 0.71  -0.07   -8.97 0.81 0.81 0.69      7686998         5636.10
#
# [40 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK            - 7.60      0       0 7.60 7.75 7.55         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0       476649         3633.99    17300 7.60  7.65        500

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 8    INOX 0.44   0.03    7.32 0.42 0.46 0.42      2505771         1106.89
# 21    TWP 1.08   0.05    4.85 1.11 1.11 1.06         4700            5.20
# 13   PERM 0.40   0.01    2.56 0.41 0.41 0.38       709800          277.60
# 0      2S 2.46   0.06    2.50 2.48 2.48 2.40         2130            5.24
# 16   SSSC 2.06   0.04    1.98    2 2.06    2        30300           60.61
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 4    CITY 1.72  -0.03   -1.71 1.70 1.72 1.70         2400            4.10
# 5     CSP 0.55  -0.01   -1.79 0.56 0.57 0.55        33050           18.45
# 20   TSTH 0.54  -0.01   -1.82 0.55 0.56 0.54       500180          274.65
# 22   TYCN 1.81  -0.08   -4.23 1.83 1.83 1.81       205500          372.01
# 6     GJS 0.12  -0.01   -7.69 0.12 0.13 0.11      9921600         1210.66
#
# [22 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 19    TMT            - 3.04      0       0 3.06 3.06 3.04         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 19            0         1100            3.35      100 3.04  3.06       3700

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 22      KC  0.06    0.01    20.00  0.06  0.06  0.06      13344533
# 17    EVER  0.10    0.01    11.11  0.09  0.10  0.09        592000
# 21     JCK  0.20    0.01     5.26  0.19  0.20  0.19        854989
# 42   PROUD  1.26    0.04     3.28  1.25  1.26  1.23        121400
# 28     MJD  0.76    0.02     2.70  0.74  0.77  0.72         47300
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 12     CGD  0.25   -0.01    -3.85  0.26  0.26  0.24       5424501
# 11   BROCK  1.45   -0.06    -3.97  1.51  1.52  1.45          1203
# 45  RABBIT  0.36   -0.02    -5.26  0.38  0.38  0.36       4336399
# 33     NVD  1.24   -0.08    -6.06  1.30  1.30  1.24           300
# 15     CPN 48.75   -3.50    -6.70 51.75 52.00 48.75      27101730
#
#     Total Value (k)
# 22           800.67
# 17            54.21
# 21           162.66
# 42           150.72
# 28            34.45
# ..              ...
# 12          1357.15
# 11             1.76
# 45          1603.57
# 33             0.38
# 15       1339043.65
#
# [60 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 53   SENA            -  2.10    0.00     0.00  2.10  2.12 2.08          0
#
#     TR Value (k)  Total Volume  Total Value (k) Bid Size  Bid Offer Offer Size
# 53          0.00        161524           339.00   152900 2.08  2.10        400

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#       Symbol  Last Change %Change  Open  High   Low Total Volume  \
# 12     DREIT  5.10   0.10       2  5.10  5.10  5.10       111900
# 6     BAREIT  9.25   0.10    1.09  9.20  9.35  9.20       926500
# 1     AIMIRT 10.60   0.10    0.95 10.60 10.60 10.50       136232
# 27      LHSC 11.50   0.10    0.88 11.40 11.50 11.30       416100
# 55     WHAIR  6.25   0.05    0.81  6.30  6.30  6.20       230664
# ..       ...   ...    ...     ...   ...   ...   ...          ...
# 13    FTREIT 10.10  -0.20   -1.94 10.20 10.30 10.10      1484098
# 14  FUTURERT    10  -0.20   -1.96 10.10 10.10    10        17250
# 3     AMATAR  6.50  -0.15   -2.26  6.60  6.60  6.50        24100
# 46      SSPF  3.78  -0.12   -3.08  3.78  3.78  3.78          102
# 33       MIT  0.29  -0.01   -3.33  0.29  0.31  0.29        11100
#
#    Total Value (k)
# 12          570.69
# 6          8605.32
# 1          1430.54
# 27         4759.99
# 55         1437.04
# ..             ...
# 13        15073.34
# 14          173.96
# 3           156.68
# 46            0.38
# 33            3.34
#
# [48 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.60   0.10    0.95 10.60 10.60 10.50         0
# 9   CPNREIT            - 12.10      0       0 12.10 12.20    12         0
# 17   GVREIT            -  6.70   0.05    0.75  6.65  6.70  6.65         0
# 55    WHAIR            -  6.25   0.05    0.81  6.30  6.30  6.20         0
# 56    WHART            - 10.10  -0.10   -0.98 10.20 10.30 10.10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0       136232         1430.54     59600 10.50  10.60
# 9             0      1324539        16060.94     75000 12.10  12.20
# 17            0       112660          750.86    193500  6.65   6.70
# 55            0       230664         1437.04    191400  6.20   6.25
# 56            0      1677845        17112.76    132300 10.10  10.30
#
#     Offer Size
# 1       561600
# 9       307500
# 17      112800
# 55       87600
# 56      849800

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 23    SJWD  7.40   0.15    2.07  7.35  7.50  7.30      1595144        11803.94
# 3   ASIMAR  1.57   0.03    1.95  1.56  1.58  1.56       168603          264.01
# 5       BA 19.50   0.30    1.56 19.50 19.80 19.40      4203290        82495.90
# 11     III  4.82   0.06    1.26  4.76  4.84  4.76       360883         1727.90
# 0      AAV  2.12   0.02    0.95  2.08  2.14  2.08     26270653        55683.20
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 12     KEX  1.25  -0.02   -1.57  1.28  1.30  1.25       356035          451.50
# 20     RCL 24.80  -0.45   -1.78 24.90 25.50 24.70      2824271        70469.43
# 7      BTS  5.85  -0.25   -4.10  6.15  6.15  5.85     69643877       414165.16
# 10     ETL  0.55  -0.03   -5.17  0.58  0.58  0.55       119000           66.69
# 2      AOT    47  -7.50  -13.76 54.25 54.25 46.50    174982491      8720080.76
#
# [26 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 20    RCL            - 24.80  -0.45   -1.78 24.90 25.50 24.70         0
# 24  TFFIF            -  6.30  -0.05   -0.79  6.35  6.35  6.30         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size   Bid Offer Offer Size
# 20            0      2824271        70469.43    48200 24.70 24.80       1700
# 24            0       552802         3486.00  3300400  6.30  6.35     164900

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 29     SKY 21.10   0.60    2.93    21 21.30 20.70       688083        14506.43
# 13   ILINK  5.40   0.15    2.86  5.30  5.40  5.25       331640         1754.41
# 36    TRUE 12.80   0.30    2.40 12.50 12.80 12.40     75834288       960989.94
# 22     MSC  7.90   0.15    1.94  7.70  7.90  7.70          501            3.91
# 23      PT 10.80   0.20    1.89 10.90    11 10.50       588649         6331.56
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 1   ADVANC   299     -5   -1.64   303   304   295      9538567      2848067.27
# 32    SYMC  6.25  -0.15   -2.34  6.35  6.40  6.25       112125          705.77
# 7    DITTO 11.10  -0.60   -5.13 11.90 11.90 11.10      5234039        59535.57
# 3      ALT  0.78  -0.06   -7.14  0.84  0.86  0.78       299654          240.11
# 33   SYNEX    10  -0.90   -8.26 10.90 10.90    10      6435910        66165.07
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.35  -0.05   -0.93 5.40 5.40 5.35         0
# 6    DIF           XD 8.15  -0.05   -0.61 8.20 8.20 8.10         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0     10637178        57197.13  1659000 5.35  5.40    6681700
# 6            0      7994348        65303.25  3136500 8.10  8.15     545900

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 17      CV  0.08    0.01    14.29  0.08  0.08  0.07        182701
# 18      EA  2.64    0.16     6.45  2.52  2.76  2.50     157941267
# 2       AE  0.17    0.01     6.25  0.16  0.17  0.15       3289340
# 49   SUPER  0.19    0.01     5.56  0.19  0.19  0.18      10326638
# 11   BGRIM 13.00    0.50     4.00 12.80 13.30 12.70      32276143
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 48     SSP  5.20   -0.10    -1.89  5.15  5.25  5.00       1032031
# 15    BSRC  5.05   -0.10    -1.94  5.15  5.15  5.00       1871204
# 42  SEAOIL  2.54   -0.10    -3.79  2.44  2.60  2.44         14827
# 57     TSE  0.62   -0.03    -4.62  0.64  0.65  0.62        605871
# 12  BIOTEC  0.19   -0.01    -5.00  0.20  0.20  0.19       1316200
#
#     Total Value (k)
# 17            14.00
# 18        416624.42
# 2            527.99
# 49          1911.01
# 11        418630.70
# ..              ...
# 48          5245.79
# 15          9484.00
# 42            37.44
# 57           382.18
# 12           251.78
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.10    0.05     0.71  7.10  7.20 7.00          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       3002454         21325.40     37500 7.10   7.15
#
#     Offer Size
# 35      111200

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (761, 16)

# %%
df.Symbol.nunique()
# Out:
# 413

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (413, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.46   0.06    2.50 2.48 2.48 2.40         2130            5.24
# 0    3BBIF 5.35  -0.05   -0.93 5.40 5.40 5.35     10637178        57197.13
# 0        A 4.94   0.00    0.00 4.94 4.94 4.94          603            2.98
# 0       A5 2.50  -0.04   -1.57 2.54 2.56 2.48       308900          772.71
# 1      AAI 5.45   0.15    2.83 5.30 5.50 5.20      3618813        19540.75
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 59     WIN 0.39   0.00    0.00 0.40 0.42 0.39      2473100         1000.97
# 119   WORK 5.75   0.05    0.88 5.70 5.75 5.65       123910          710.47
# 61      WP 3.22   0.00    0.00 3.22 3.24 3.18        34302          110.44
# 120    WPH 8.45   0.05    0.60 8.60 8.60 8.30       433806         3657.54
# 41     XPG 0.88  -0.01   -1.12 0.89 0.90 0.88     11027319         9788.87
#
# [413 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.10   0.05    0.71 7.10 7.20 7.00         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      3002454        21325.40    37500 7.10  7.15     111200

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 2, 14)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-02-14   2.12   0.02    0.95   2.08   2.14   2.08
# 1   ADVANC  2025-02-14 299.00  -5.00   -1.64 303.00 304.00 295.00
# 2   AEONTS  2025-02-14 108.00   0.00    0.00 108.00 108.50 107.00
# 3    AMATA  2025-02-14  24.50  -0.10   -0.41  24.80  24.90  24.40
# 4      AOT  2025-02-14  47.00  -7.50  -13.76  54.25  54.25  46.50
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-02-14   0.28   0.00    0.00   0.28   0.29   0.28
# 54     TGE  2025-02-14   1.79   0.05    2.87   1.74   1.80   1.74
# 56   TPIPP  2025-02-14   2.90  -0.02   -0.68   2.94   2.94   2.88
# 57     TSE  2025-02-14   0.62  -0.03   -4.62   0.64   0.65   0.62
# 61      WP  2025-02-14   3.22   0.00    0.00   3.22   3.24   3.18
#
#    Total-Volume Total-Value-(k)
# 0      26270653        55683.20
# 1       9538567      2848067.27
# 2         61730         6655.59
# 3       6334598       155650.00
# 4     174982491      8720080.76
# ..          ...             ...
# 53       119611           33.61
# 54        39100           68.45
# 56      3099768         9005.50
# 57       605871          382.18
# 61        34302          110.44
#
# [413 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (413, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (182, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-14 21:15:09

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
