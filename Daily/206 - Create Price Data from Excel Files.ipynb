# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-02-20 2025-02-19

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-02-20
# yesterday: 2025-02-19

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-20 20:37:54

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 19     BLA 21.50    1.50     7.50 21.50 22.50 21.10       6907848
# 93     TLI 12.20    0.70     6.09 11.80 12.30 11.70      55249150
# 36  DOHOME  7.00    0.35     5.26  6.85  7.40  6.80      27411691
# 57     KKP 55.50    2.00     3.74 53.75 56.25 53.75      14857026
# 31   CPALL 52.25    1.00     1.95 51.00 52.25 50.75      34404588
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 5       AP  8.20   -0.50    -5.75  8.60  8.60  8.15      24160452
# 80    SCGP 14.50   -1.00    -6.45 15.20 15.40 14.50      24765733
# 28     CKP  2.64   -0.22    -7.69  2.86  2.88  2.58      18679352
# 42    GULF 51.25   -5.25    -9.29 56.25 56.50 51.25      56109506
# 47  INTUCH 82.50   -9.50   -10.33 91.25 91.25 82.50      32871089
#
#     Total Value (k)
# 19        148692.84
# 93        664930.57
# 36        192689.54
# 57        819533.01
# 31       1777648.36
# ..              ...
# 5         200732.54
# 80        368293.08
# 28         49830.64
# 42       2981780.40
# 47       2812942.15
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 56    KCE            - 21.20    0.00     0.00 21.00 21.60 20.70      25600
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 56        542.72      12998755        275134.77     98000 21.10  21.20
#
#     Offer Size
# 56      257200

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 84      SAT 12.20    1.30    11.93 12.00 12.50 11.90       5397109
# 18      CGD  0.29    0.02     7.41  0.27  0.29  0.26       2992400
# 16      BRR  4.50    0.16     3.69  4.34  4.50  4.34        664792
# 114     TTA  4.70    0.14     3.07  4.70  4.78  4.60      10654378
# 105   SYNEX 10.50    0.30     2.94 10.40 10.80 10.30       3129324
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 62      PIN  7.05   -0.30    -4.08  7.40  7.40  7.05       4331705
# 5       AIT  4.58   -0.20    -4.18  4.74  4.74  4.56      10541481
# 99   STECON  3.78   -0.18    -4.55  3.96  3.96  3.78       8216092
# 77    RSXYZ  0.68   -0.04    -5.56  0.72  0.74  0.68       3059827
# 53     NCAP  1.47   -0.09    -5.77  1.53  1.54  1.44      14389778
#
#      Total Value (k)
# 84          65647.84
# 18            808.23
# 16           2946.13
# 114         50089.54
# 105         33064.87
# ..               ...
# 62          31087.93
# 5           48944.18
# 99          31781.45
# 77           2179.62
# 53          21426.10
#
# [121 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.30   -0.02    -0.86  2.30  2.32  2.28          0
# 50      MCS            -  6.80   -0.10    -1.45  7.00  7.00  6.70          0
# 91   SINGER            -  6.00   -0.15    -2.44  6.10  6.25  5.90          0
# 105   SYNEX            - 10.50    0.30     2.94 10.40 10.80 10.30          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9               0        782684          1789.26     92400  2.28   2.30
# 50              0        228309          1566.94      4400  6.75   6.80
# 91              0       4625661         28095.04     66000  5.95   6.00
# 105             0       3129324         33064.87     64400 10.50  10.60
#
#      Offer Size
# 9        143900
# 50         5400
# 91          500
# 105        2900

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 10    BLA 21.50    1.50     7.50 21.50 22.50 21.10       6907848
# 30    KKP 55.50    2.00     3.74 53.75 56.25 53.75      14857026
# 54    SSP  5.30    0.10     1.92  5.20  5.30  5.15       1359710
# 53   SPRC  5.45    0.10     1.87  5.35  5.65  5.35      22812194
# 58  THCOM 11.80    0.20     1.72 11.70 12.00 11.60       6058898
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 11   BSRC  4.94   -0.26    -5.00  5.10  5.15  4.82       5952240
# 15    CPF 21.80   -1.20    -5.22 22.30 22.60 21.70      34599833
# 51   SCGP 14.50   -1.00    -6.45 15.20 15.40 14.50      24765733
# 14    CKP  2.64   -0.22    -7.69  2.86  2.88  2.58      18679352
# 22   GULF 51.25   -5.25    -9.29 56.25 56.50 51.25      56109506
#
#     Total Value (k)
# 10        148692.84
# 30        819533.01
# 54          7108.55
# 53        125198.74
# 58         71317.15
# ..              ...
# 11         29736.17
# 15        763505.45
# 51        368293.08
# 14         49830.64
# 22       2981780.40
#
# [63 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  15.70    0.00     0.00  15.80  15.90  15.50
# 41  PTTGC            -  19.20   -0.20    -1.03  19.20  20.00  19.00
# 49    SCC            - 143.00   -4.00    -2.72 146.00 149.00 143.00
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00       6623017        103942.88    106900  15.60
# 41      45400        871.68      34409810        668367.98    495300  19.10
# 49          0          0.00       2870531        418985.07    152200 143.00
#
#     Offer  Offer Size
# 4   15.70       59600
# 41  19.20       13300
# 49 143.50        4100

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 12     KKP  55.50    2.00     3.74  53.75  56.25  53.75      14857026
# 13     KTB  24.40    0.40     1.67  24.50  24.70  24.10     119987434
# 16     PRM   7.55    0.10     1.34   7.50   7.60   7.40       6235293
# 15    MEGA  32.25    0.25     0.78  32.50  33.00  31.75       1307276
# 4      BBL 161.50    1.00     0.62 160.50 161.50 159.00      13538360
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 14      LH   4.54   -0.16    -3.40   4.64   4.66   4.52      41436267
# 20   RATCH  27.75   -1.00    -3.48  28.50  28.75  27.75       2739445
# 0   ADVANC 283.00  -12.00    -4.07 288.00 289.00 283.00      10155861
# 1       AP   8.20   -0.50    -5.75   8.60   8.60   8.15      24160452
# 9   INTUCH  82.50   -9.50   -10.33  91.25  91.25  82.50      32871089
#
#     Total Value (k)
# 12        819533.01
# 13       2930274.30
# 16         47100.24
# 15         42221.68
# 4        2172539.30
# ..              ...
# 14        190455.74
# 20         76446.19
# 0        2899730.95
# 1         200732.54
# 9        2812942.15
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 13.90   -0.30    -2.11 14.10 14.20 13.70          0
# 21    RCL            - 25.25   -0.25    -0.98 25.75 25.75 25.00          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10          0.00       8013768        111658.30    265400 13.80  13.90
# 21          0.00       2168964         54967.56    231100 25.00  25.25
#
#     Offer Size
# 10        5800
# 21       23100

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 84      SAT 12.20    1.30    11.93 12.00 12.50 11.90       5397109
# 19      BLA 21.50    1.50     7.50 21.50 22.50 21.10       6907848
# 109     TLI 12.20    0.70     6.09 11.80 12.30 11.70      55249150
# 55      KKP 55.50    2.00     3.74 53.75 56.25 53.75      14857026
# 113     TTA  4.70    0.14     3.07  4.70  4.78  4.60      10654378
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 5        AP  8.20   -0.50    -5.75  8.60  8.60  8.15      24160452
# 91     SCGP 14.50   -1.00    -6.45 15.20 15.40 14.50      24765733
# 25      CKP  2.64   -0.22    -7.69  2.86  2.88  2.58      18679352
# 38     GULF 51.25   -5.25    -9.29 56.25 56.50 51.25      56109506
# 47   INTUCH 82.50   -9.50   -10.33 91.25 91.25 82.50      32871089
#
#      Total Value (k)
# 84          65647.84
# 19         148692.84
# 109        664930.57
# 55         819533.01
# 113         50089.54
# ..               ...
# 5          200732.54
# 91         368293.08
# 25          49830.64
# 38        2981780.40
# 47        2812942.15
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 14.00   -0.10    -0.71 14.10 14.40 13.90          0
# 7      AWC            -  3.14   -0.02    -0.63  3.12  3.18  3.10          0
# 66     NER            -  4.86   -0.19    -3.76  4.96  4.96  4.78          0
# 68     ORI            -  3.14   -0.12    -3.68  3.28  3.30  3.14          0
# 110    TOA            - 12.20   -0.40    -3.17 12.60 12.70 12.00          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00       1926266         27216.03     83900 13.90  14.00
# 7            0.00      37944460        119052.67   1993400  3.14   3.16
# 66           0.00      30536335        148279.79    795800  4.86   4.88
# 68           0.00       4652752         14896.54    270200  3.14   3.16
# 110          0.00       3056038         37499.94    127800 12.10  12.20
#
#      Offer Size
# 2         67200
# 7       1052200
# 66       489000
# 68        92500
# 110      201600

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 17  DOHOME  7.00    0.35     5.26  6.85  7.40  6.80      27411691
# 14   CPALL 52.25    1.00     1.95 51.00 52.25 50.75      34404588
# 21       M 19.60    0.30     1.55 19.30 19.70 19.10       2521385
# 25     PRM  7.55    0.10     1.34  7.50  7.60  7.40       6235293
# 27     STA 16.70    0.20     1.21 16.50 17.00 16.50       8451995
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 19   HMPRO  8.45   -0.25    -2.87  8.55  8.75  8.35      32480153
# 24     OSP 14.90   -0.50    -3.25 15.30 15.30 14.60      22224703
# 26   SAPPE 52.50   -2.00    -3.67 54.75 55.00 52.50        893602
# 8      BTG 18.00   -0.70    -3.74 18.60 18.60 18.00       2421860
# 15     CPF 21.80   -1.20    -5.22 22.30 22.60 21.70      34599833
#
#     Total Value (k)
# 17        192689.54
# 14       1777648.36
# 21         49180.36
# 25         47100.24
# 27        141542.56
# ..              ...
# 19        277087.63
# 24        331269.18
# 26         47960.79
# 8          44185.68
# 15        763505.45
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 16.70    0.20     1.21 16.50 17.00 16.50          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00       8451995        141542.56    144200 16.70  16.80
#
#     Offer Size
# 27      138100

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High  Low Total Volume Total Value (k)
# 7      CGH  0.52   0.01    1.96  0.51  0.52 0.51       787042          402.63
# 36  TIDLOR 18.40   0.20    1.10 18.30 18.50   18     13238400       241883.25
# 21     MFC 27.25   0.25    0.93 27.25 27.75   27        14401          392.75
# 16     IFS  2.48   0.02    0.81  2.46  2.48 2.44        56200          138.25
# 2     ASAP  1.45   0.01    0.69  1.44  1.45 1.36         5771            8.15
# ..     ...   ...    ...     ...   ...   ...  ...          ...             ...
# 32     SGC  0.90  -0.03   -3.23  0.92  0.94 0.89     10863513         9946.18
# 31    SCAP  1.35  -0.05   -3.57  1.42  1.42 1.34      2670329         3679.46
# 29     SAK  4.38  -0.18   -3.95  4.56  4.56 4.34      1793666         7957.74
# 23      ML  0.43  -0.02   -4.44  0.44  0.45 0.43       119700           51.85
# 26    NCAP  1.47  -0.09   -5.77  1.53  1.54 1.44     14389778        21426.10
#
# [40 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK            - 7.25      0       0 7.25 7.35 7.20         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0      1902646        13864.60    63100 7.25  7.30      39700

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 14    SAM 0.18   0.01    5.88 0.17 0.18 0.16      2032101          353.16
# 18    THE 0.72   0.02    2.86 0.70 0.72 0.69         8400            5.89
# 0      2S 2.36   0.02    0.85 2.34 2.40 2.34        23695           55.83
# 15   SMIT 3.82   0.02    0.53 3.82 3.82 3.78        18000           68.63
# 1     AMC 1.96      0       0 1.96 1.97 1.96       190930          375.60
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 5     CSP 0.55  -0.01   -1.79 0.55 0.56 0.55        27300           15.02
# 4    CITY 1.65  -0.03   -1.79 1.65 1.65 1.65         2000            3.30
# 13   PERM 0.39  -0.01   -2.50 0.40 0.40 0.37       818800          316.32
# 21    TWP 1.10  -0.03   -2.65 1.10 1.13 1.10         1803            2.00
# 2    BSBM 0.69  -0.02   -2.82 0.70 0.71 0.69        12601            8.94
#
# [21 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 19    TMT            -    3  -0.04   -1.32 3.04 3.04 2.98         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size Bid Offer Offer Size
# 19            0       233605          702.55    20300   3  3.02      20600

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 17    EVER 0.10   0.01   11.11 0.10 0.10 0.09       774300           76.68
# 12     CGD 0.29   0.02    7.41 0.27 0.29 0.26      2992400          808.23
# 40  PRECHA 0.85   0.02    2.41 0.90 0.90 0.83        16100           14.16
# 1       A5 2.56   0.06    2.40 2.50 2.56 2.50       538700         1362.73
# 13      CI 0.44   0.01    2.33 0.44 0.45 0.43       555400          240.89
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 21     JCK 0.18  -0.01   -5.26 0.19 0.20 0.18      1588100          299.65
# 6       AP 8.20  -0.50   -5.75 8.60 8.60 8.15     24160452       200732.54
# 56  STELLA 0.14  -0.01   -6.67 0.15 0.15 0.14      2928301          412.20
# 37      PF 0.12  -0.01   -7.69 0.13 0.13 0.12      1541235          186.22
# 28     MJD 0.68  -0.07   -9.33 0.73 0.78 0.68       154800          108.71
#
# [59 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 53   SENA            - 2.22   0.02    0.91 2.22 2.22 2.18         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid  Offer  Offer Size
# 53            0       264314          580.53     7000 2.20   2.22       41200

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#       Symbol  Last Change %Change  Open  High   Low Total Volume  \
# 36     MNIT2     5   0.34    7.30     5     5     5          100
# 51    TPRIME  7.20   0.10    1.41  7.10  7.20  7.10         1203
# 14  FUTURERT 10.10   0.10       1 10.10 10.20    10        26137
# 26   LHRREIT  5.20   0.05    0.97  5.15  5.20  5.15        24000
# 1     AIMIRT 10.70   0.10    0.94 10.60 10.80 10.60       385876
# ..       ...   ...    ...     ...   ...   ...   ...          ...
# 38      POPF  5.80  -0.10   -1.69  5.90  5.90  5.80       583070
# 5     B-WORK  4.56  -0.08   -1.72  4.58  4.58  4.52       419300
# 3     AMATAR  6.35  -0.25   -3.79  6.45  6.65  6.35        45001
# 33       MIT  0.28  -0.02   -6.67  0.30  0.30  0.28       204000
# 55     WHAIR  5.85  -0.50   -7.87  6.35  6.35  5.80      3246095
#
#    Total Value (k)
# 36            0.50
# 51            8.64
# 14          263.24
# 26          124.55
# 1          4113.08
# ..             ...
# 38         3402.91
# 5          1904.67
# 3           288.42
# 33           57.13
# 55        19689.21
#
# [51 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.70   0.10    0.94 10.60 10.80 10.60         0
# 9   CPNREIT            - 12.30   0.10    0.82 12.20 12.30 12.10         0
# 17   GVREIT            -  6.85      0       0  6.85  6.90  6.75         0
# 55    WHAIR            -  5.85  -0.50   -7.87  6.35  6.35  5.80         0
# 56    WHART            - 10.20      0       0 10.10 10.30 10.10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0       385876         4113.08      8100 10.60  10.70
# 9             0       800300         9770.57      4100 12.20  12.30
# 17            0       197604         1349.14    150400  6.80   6.85
# 55            0      3246095        19689.21    169300  5.85   5.90
# 56            0      2123085        21687.51    349900 10.10  10.20
#
#     Offer Size
# 1       124100
# 9       187700
# 17       49700
# 55        1000
# 56       24500

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High  Low Total Volume Total Value (k)
# 22    SINO  0.93   0.03    3.33  0.92  0.94 0.91       615948          571.94
# 27     TTA  4.70   0.14    3.07  4.70  4.78 4.60     10654378        50089.54
# 19     PSL  6.55   0.15    2.34  6.55  6.70 6.45     10054139        65787.31
# 21     SAV 19.20   0.40    2.13 19.10 19.90   19      2269210        44064.22
# 15    MENA  1.05   0.02    1.94  1.05  1.06 1.02       468205          487.00
# ..     ...   ...    ...     ...   ...   ...  ...          ...             ...
# 20     RCL 25.25  -0.25   -0.98 25.75 25.75   25      2168964        54967.56
# 28    WICE  3.26  -0.04   -1.21  3.30  3.36 3.24       368932         1211.59
# 23    SJWD  7.40  -0.10   -1.33  7.50  7.60 7.25      2680125        19901.45
# 3   ASIMAR  1.63  -0.04   -2.40  1.68  1.73 1.63       705000         1182.60
# 1      ANI  2.72  -0.10   -3.55  2.80  2.80 2.70       249420          683.52
#
# [26 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign  Last Change %Change  Open  High  Low TR Volume  \
# 20    RCL            - 25.25  -0.25   -0.98 25.75 25.75   25         0
# 24  TFFIF            -  6.40  -0.05   -0.78  6.45  6.45 6.35         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 20            0      2168964        54967.56   231100   25 25.25      23100
# 24            0      2385730        15245.83   293700 6.35  6.40     381400

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 33   SYNEX 10.50   0.30    2.94 10.40 10.80 10.30      3129324        33064.87
# 34   THCOM 11.80   0.20    1.72 11.70    12 11.60      6058898        71317.15
# 26  SAMTEL  6.05   0.10    1.68  6.05  6.20  5.90       523103         3146.79
# 30  SPREME  1.45   0.02    1.40  1.43  1.46  1.42       241407          345.84
# 3      ALT  0.84   0.01    1.20  0.87  0.88  0.84       129400          111.15
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 7    DITTO 11.60  -0.40   -3.33 11.90 12.20 11.50      3585078        42339.83
# 14    INET  5.55  -0.20   -3.48  5.65  5.70  5.50      5704312        31933.13
# 1   ADVANC   283    -12   -4.07   288   289   283     10155861      2899730.95
# 2      AIT  4.58  -0.20   -4.18  4.74  4.74  4.56     10541481        48944.18
# 16  INTUCH 82.50  -9.50  -10.33 91.25 91.25 82.50     32871089      2812942.15
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.25  -0.05   -0.94 5.25 5.30 5.25         0
# 6    DIF            - 8.10  -0.05   -0.61 8.15 8.20 8.10         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0      2385626        12556.66  7602800 5.25  5.30    3640200
# 6            0      6395933        51931.74   632400 8.10  8.15     711900

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 5     AIE  1.58    0.30    23.44  1.43  1.65  1.40      39235366
# 17     CV  0.14    0.02    16.67  0.12  0.15  0.11      28117606
# 44    SKE  0.24    0.01     4.35  0.24  0.25  0.23        615100
# 45  SOLAR  0.31    0.01     3.33  0.31  0.32  0.30        186225
# 48    SSP  5.30    0.10     1.92  5.20  5.30  5.15       1359710
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 32   NOVA  8.65   -0.55    -5.98  9.20  9.20  8.65          1500
# 39    RPC  0.28   -0.02    -6.67  0.30  0.30  0.28        767500
# 16    CKP  2.64   -0.22    -7.69  2.86  2.88  2.58      18679352
# 4      AI  3.90   -0.36    -8.45  4.10  4.22  3.90       3693186
# 26   GULF 51.25   -5.25    -9.29 56.25 56.50 51.25      56109506
#
#     Total Value (k)
# 5          61280.60
# 17          3852.78
# 44           147.38
# 45            57.92
# 48          7108.55
# ..              ...
# 32            13.18
# 39           223.78
# 16         49830.64
# 4          14994.88
# 26       2981780.40
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.70   -0.05    -0.65  7.70  7.70 7.50          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       3221405         24607.80     15000 7.65   7.70
#
#     Offer Size
# 35       25900

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (762, 16)

# %%
df.Symbol.nunique()
# Out:
# 414

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (414, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.36   0.02    0.85 2.34 2.40 2.34        23695           55.83
# 0    3BBIF 5.25  -0.05   -0.94 5.25 5.30 5.25      2385626        12556.66
# 0        A 4.92      0       0 4.92 4.92 4.92          253            1.24
# 0       A5 2.56   0.06    2.40 2.50 2.56 2.50       538700         1362.73
# 1      AAI 5.55  -0.20   -3.48 5.75 5.75 5.50      2562623        14425.27
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 59     WIN 0.39      0       0 0.39 0.41 0.39      2631300         1051.17
# 119   WORK 6.10   0.00    0.00 6.10 6.15 6.00       210733         1280.49
# 61      WP 3.26   0.06    1.88 3.22 3.28 3.20        54994          177.11
# 120    WPH 9.00   0.10    1.12 8.85 9.05 8.80       306167         2741.52
# 41     XPG 0.89  -0.02   -2.20 0.90 0.91 0.88     10423145         9305.90
#
# [414 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.70  -0.05   -0.65 7.70 7.70 7.50         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      3221405        24607.80    15000 7.65  7.70      25900

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 2, 20)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-02-20   2.16  -0.02   -0.92   2.18   2.24   2.16
# 1   ADVANC  2025-02-20 283.00 -12.00   -4.07 288.00 289.00 283.00
# 2   AEONTS  2025-02-20 110.00  -2.00   -1.79 111.50 112.00 108.50
# 3    AMATA  2025-02-20  24.90  -0.10   -0.40  24.90  25.25  24.60
# 4      AOT  2025-02-20  43.75   0.50    1.16  43.00  44.25  42.75
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-02-20   0.28  -0.01   -3.45   0.30   0.30   0.28
# 54     TGE  2025-02-20   1.72  -0.02   -1.15   1.72   1.75   1.72
# 56   TPIPP  2025-02-20   2.90   0.00    0.00   2.90   2.92   2.88
# 57     TSE  2025-02-20   0.68  -0.02   -2.86   0.69   0.70   0.67
# 61      WP  2025-02-20   3.26   0.06    1.88   3.22   3.28   3.20
#
#    Total-Volume Total-Value-(k)
# 0      41056084        89943.56
# 1      10155861      2899730.95
# 2        142522        15628.26
# 3       8540470       211779.50
# 4      40913617      1783783.40
# ..          ...             ...
# 53       221100           64.14
# 54        32765           56.52
# 56      2966564         8578.98
# 57       585201          396.92
# 61        54994          177.11
#
# [414 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (414, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (181, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-20 20:37:55

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
