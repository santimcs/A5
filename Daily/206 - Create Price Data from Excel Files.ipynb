# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-02-28 2025-02-27

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-02-28
# yesterday: 2025-02-27

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-28 20:37:47

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 66     OSP  14.90    0.60     4.20  14.00  15.10  13.90      26648709
# 98     VGI   3.10    0.12     4.03   2.92   3.10   2.86     134548238
# 30   CPALL  54.00    1.75     3.35  51.75  54.00  51.50      86533082
# 11     BCH  16.20    0.50     3.18  14.60  16.50  14.60      25756065
# 10     BBL 151.50    4.50     3.06 146.00 151.50 145.50      18845939
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 55     KCE  18.30   -1.40    -7.11  17.00  18.80  17.00      16588638
# 28  COCOCO   7.55   -0.70    -8.48   8.15   8.20   7.45      21847297
# 53     JTS  39.00   -4.75   -10.86  42.00  42.75  39.00        510848
# 23    CCET   5.85   -0.75   -11.36   5.85   6.05   5.40     274510396
# 43    HANA  16.10   -4.00   -19.90  16.00  16.80  15.90      51929956
#
#     Total Value (k)
# 66        390766.52
# 98        403700.16
# 30       4587915.10
# 11        403519.28
# 10       2794132.35
# ..              ...
# 55        301065.69
# 28        168457.50
# 53         20698.15
# 23       1575445.19
# 43        845773.22
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 55    KCE            - 18.30   -1.40    -7.11 17.00 18.80 17.00          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 55          0.00      16588638        301065.69    234700 18.30  18.40
#
#     Offer Size
# 55      153100

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 33   HUMAN  7.95    0.85    11.97  7.70  8.00  7.30        633101
# 40     KEX  0.96    0.08     9.09  0.91  1.05  0.91       2283140
# 37    ITEL  1.60    0.07     4.58  1.52  1.60  1.50       7893140
# 51     MGC  2.94    0.12     4.26  2.84  3.38  2.72        218300
# 95     SPA  5.15    0.21     4.25  4.90  5.15  4.82       3811650
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 101  SUPER  0.18   -0.01    -5.26  0.18  0.19  0.17      18807583
# 75      RS  0.68   -0.05    -6.85  0.73  0.73  0.65      17745057
# 29    GFPT  8.15   -0.60    -6.86  8.75  8.75  8.15      21696859
# 46   MAJOR 11.60   -1.00    -7.94 12.40 12.50 11.50       2624594
# 99    STPI  2.40   -0.24    -9.09  2.62  2.62  2.26       1971518
#
#      Total Value (k)
# 33           4846.81
# 40           2276.61
# 37          12182.30
# 51            631.01
# 95          18963.26
# ..               ...
# 101          3386.61
# 75          12013.14
# 29         179511.54
# 46          31003.66
# 99           4698.31
#
# [120 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.24   -0.02    -0.88  2.26  2.26  2.24          0
# 50      MCS            -  7.10   -0.05    -0.70  7.10  7.15  7.05          0
# 90   SINGER            -  5.40   -0.10    -1.82  5.50  5.55  5.30          0
# 104   SYNEX            - 10.90    0.30     2.83 10.30 11.10 10.20          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9               0        308559           693.02     97000  2.24   2.26
# 50              0        337080          2390.79     12100  7.10   7.15
# 90              0       2218318         12006.37    163900  5.40   5.45
# 104             0       2966411         31927.58     13700 10.90  11.00
#
#      Offer Size
# 9        590000
# 50        24300
# 90         1100
# 104      223200

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 36    OSP  14.90    0.60     4.20  14.00  15.10  13.90      26648709
# 4     BCH  16.20    0.50     3.18  14.60  16.50  14.60      25756065
# 3     BBL 151.50    4.50     3.06 146.00 151.50 145.50      18845939
# 49   SCCC 162.50    4.50     2.85 157.50 163.00 157.50        201633
# 46  SAWAD  34.50    0.75     2.22  32.75  35.25  32.00      17834645
# ..    ...    ...     ...      ...    ...    ...    ...           ...
# 55  SUPER   0.18   -0.01    -5.26   0.18   0.19   0.17      18807583
# 13    CKP   2.64   -0.16    -5.71   2.80   2.80   2.64       6778229
# 45  SAPPE  45.25   -2.75    -5.73  47.50  47.50  44.25       5290893
# 31  MAJOR  11.60   -1.00    -7.94  12.40  12.50  11.50       2624594
# 23   HANA  16.10   -4.00   -19.90  16.00  16.80  15.90      51929956
#
#     Total Value (k)
# 36        390766.52
# 4         403519.28
# 3        2794132.35
# 49         32325.88
# 46        606547.09
# ..              ...
# 55          3386.61
# 13         18088.08
# 45        240851.03
# 31         31003.66
# 23        845773.22
#
# [62 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  16.20    0.50     3.18  14.60  16.50  14.60
# 40  PTTGC            -  15.90   -0.20    -1.24  15.50  16.30  15.50
# 48    SCC            - 127.50    0.00     0.00 125.00 128.50 124.50
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00      25756065        403519.28    479300  16.20
# 40          0          0.00     236732461       3766655.34   1684100  15.90
# 48        200         25.50       7279826        924118.78     37400 127.50
#
#     Offer  Offer Size
# 4   16.30       59700
# 40  16.00      357200
# 48 128.00       27300

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 4      BBL 151.50    4.50     3.06 146.00 151.50 145.50      18845939
# 1       AP   8.95    0.25     2.87   8.65   8.95   8.60      25859521
# 5      BCP  38.50    0.75     1.99  37.75  38.75  37.25      19626984
# 23   SPALI  17.20    0.30     1.78  16.90  17.40  16.70       8477683
# 8    HMPRO   8.45    0.10     1.20   8.10   8.45   8.00      59418509
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 0   ADVANC 276.00   -5.00    -1.78 277.00 278.00 273.00      15113754
# 20   RATCH  26.00   -0.50    -1.89  26.25  26.75  26.00       4277207
# 12     KKP  55.00   -1.25    -2.22  55.50  56.00  54.50       3509475
# 21     RCL  24.40   -0.60    -2.40  24.70  24.90  24.40       4483884
# 27     TOP  22.80   -0.80    -3.39  23.10  23.70  22.50     140704420
#
#     Total Value (k)
# 4        2794132.35
# 1         226851.26
# 5         748947.49
# 23        144788.96
# 8         490892.40
# ..              ...
# 0        4161751.96
# 20        112372.57
# 12        193658.07
# 21        110217.03
# 27       3214768.34
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 11.90   -0.20    -1.65 11.80 12.10 11.50          0
# 21    RCL            - 24.40   -0.60    -2.40 24.70 24.90 24.40          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10          0.00      14325369        168748.13     41500 11.90  12.00
# 21          0.00       4483884        110217.03     41000 24.40  24.60
#
#     Offer Size
# 10       98000
# 21       34000

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 69     OSP 14.90    0.60     4.20 14.00 15.10 13.90      26648709
# 118    VGI  3.10    0.12     4.03  2.92  3.10  2.86     134548238
# 0      ACE  1.31    0.05     3.97  1.25  1.31  1.24       4879348
# 27   CPALL 54.00    1.75     3.35 51.75 54.00 51.50      86533082
# 13     BCH 16.20    0.50     3.18 14.60 16.50 14.60      25756065
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 112    TQM 15.30   -1.20    -7.27 16.40 16.40 15.30       1681021
# 59   MAJOR 11.60   -1.00    -7.94 12.40 12.50 11.50       2624594
# 51     JTS 39.00   -4.75   -10.86 42.00 42.75 39.00        510848
# 72     PSH  4.80   -0.80   -14.29  5.60  5.60  4.80      18016173
# 40    HANA 16.10   -4.00   -19.90 16.00 16.80 15.90      51929956
#
#      Total Value (k)
# 69         390766.52
# 118        403700.16
# 0            6114.14
# 27        4587915.10
# 13         403519.28
# ..               ...
# 112         26157.45
# 59          31003.66
# 51          20698.15
# 72          89227.22
# 40         845773.22
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 13.50   -0.10    -0.74 13.70 14.10 13.50          0
# 7      AWC            -  2.92   -0.18    -5.81  3.00  3.02  2.84          0
# 66     NER            -  4.96    0.02     0.40  4.92  4.96  4.86          0
# 68     ORI            -  2.96   -0.08    -2.63  3.00  3.00  2.88          0
# 110    TOA            - 11.40   -0.30    -2.56 11.60 11.70 11.30          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00        506903          6950.31     21000 13.50  13.70
# 7            0.00     129183493        378153.70   1604800  2.92   2.94
# 66           0.00      11829371         58190.95     26500  4.94   4.96
# 68           0.00       7639744         22393.44     61900  2.94   2.96
# 110          0.00       2850872         32644.11    217900 11.40  11.50
#
#      Offer Size
# 2         13100
# 7        477300
# 66       243100
# 68        35800
# 110       70000

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 24    OSP  14.90    0.60     4.20  14.00  15.10  13.90      26648709
# 14  CPALL  54.00    1.75     3.35  51.75  54.00  51.50      86533082
# 3     BCH  16.20    0.50     3.18  14.60  16.50  14.60      25756065
# 15    CPF  24.40    0.40     1.67  23.50  24.40  23.50      30275631
# 6      BH 195.50    2.50     1.30 191.00 198.50 190.00      10541960
# ..    ...    ...     ...      ...    ...    ...    ...           ...
# 7     BJC  21.90   -0.60    -2.67  22.00  22.40  21.90       3744129
# 20    ITC  16.40   -0.50    -2.96  16.90  16.90  16.20       8318881
# 9     BTS   5.80   -0.20    -3.33   5.80   5.90   5.80      86348107
# 12    CHG   2.16   -0.10    -4.42   1.82   2.16   1.71     203605937
# 26  SAPPE  45.25   -2.75    -5.73  47.50  47.50  44.25       5290893
#
#     Total Value (k)
# 24        390766.52
# 14       4587915.10
# 3         403519.28
# 15        732133.41
# 6        2060156.99
# ..              ...
# 7          82607.57
# 20        137260.23
# 9         502728.71
# 12        393852.59
# 26        240851.03
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 15.80    0.00     0.00 15.50 15.80 15.20          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00       9976496        154785.45     49000 15.70  15.80
#
#     Offer Size
# 27       91700

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 30  SAWAD 34.50   0.75    2.22 32.75 35.25    32     17834645       606547.09
# 40  UOBKH  4.58   0.08    1.78  4.50  4.58  4.50        18700           84.57
# 8   CHASE  0.62   0.01    1.64  0.61  0.62  0.60      1692210         1023.32
# 6     BYD  0.62   0.01    1.64  0.61  0.62  0.60      2785240         1703.24
# 37     TK  3.78   0.06    1.61  3.70  3.78  3.70        47200          176.18
# ..    ...   ...    ...     ...   ...   ...   ...          ...             ...
# 21    MFC    25  -1.25   -4.76    26    26 24.80        45600         1151.33
# 12    FSX  1.60  -0.09   -5.33  1.62  1.65  1.52       102601          160.92
# 34     TH  0.66  -0.04   -5.71  0.68  0.68  0.64      7672841         5039.27
# 11    FNS  1.46  -0.11   -7.01  1.57  1.57  1.46       116500          175.97
# 27     PL  1.16  -0.30  -20.55  1.37  1.37  1.15       790102          967.20
#
# [41 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK           XD    7  -0.35   -4.76 6.90 7.05 6.85         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0      1713489        11874.39   103500 6.95     7       1100

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 6     GJS 0.13   0.01    8.33 0.12 0.13 0.12      1456203          174.82
# 20   TSTH 0.50   0.01    2.04 0.49 0.50 0.48      2059528         1002.98
# 5     CSP 0.52   0.01    1.96 0.52 0.53 0.51        43510           22.37
# 15   SMIT 3.86   0.06    1.58 3.94 3.94 3.74        37607          143.87
# 21    TWP 1.03   0.01    0.98 1.03 1.03 1.02         7200            7.40
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 4    CITY 1.63  -0.02   -1.21 1.65 1.65 1.57        47700           75.28
# 12    PAP 1.54  -0.02   -1.28 1.55 1.55 1.48        94606          141.60
# 19    TMT 2.68  -0.08   -2.90 2.74 2.74 2.62       192860          511.13
# 22   TYCN 1.72  -0.11   -6.01 1.76 1.76 1.72       224400          394.13
# 11   MILL 0.09  -0.01     -10 0.10 0.10 0.09       264168           23.81
#
# [21 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 19    TMT            - 2.68  -0.08   -2.90 2.74 2.74 2.62         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 19            0       192860          511.13     3400 2.66  2.68        600

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 22      KC 0.07   0.01   16.67 0.05 0.07 0.05      7448050          463.37
# 11   BROCK 1.56   0.08    5.41 1.87 1.87 1.45         1400            2.10
# 12     CGD 0.26   0.01       4 0.25 0.26 0.24       795510          198.13
# 6       AP 8.95   0.25    2.87 8.65 8.95 8.60     25859521       226851.26
# 28     MJD 0.74   0.02    2.78 0.74 0.74 0.74          500            0.37
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 16   ESTAR 0.17  -0.01   -5.56 0.18 0.19 0.15     18201210         3053.52
# 8      AWC 2.92  -0.18   -5.81    3 3.02 2.84    129183493       378153.70
# 56  STELLA 0.14  -0.01   -6.67 0.15 0.15 0.14      1460305          212.70
# 29      MK 1.38  -0.10   -6.76 1.41 1.41 1.38        25412           35.32
# 43     PSH 4.80  -0.80  -14.29 5.60 5.60 4.80     18016173        89227.22
#
# [57 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 53   SENA            - 2.20      0       0 2.18 2.22 2.14         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid  Offer  Offer Size
# 53            0       228767          498.87    33300 2.18   2.20       14500

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#       Symbol  Last Change %Change  Open  High   Low Total Volume  \
# 32      MIPF 11.60   2.50   27.47 11.10 11.80 11.10         4800
# 49     TLHPF  2.82   0.56   24.78  2.82  2.92  2.82       318500
# 42      QHOP  3.38   0.08    2.42  3.38  3.38  3.38          100
# 15   GAHREIT  6.85   0.15    2.24  6.80  6.85  6.75        40700
# 10   CPTREIT  4.22   0.08    1.93  4.14  4.60  4.12       539200
# ..       ...   ...    ...     ...   ...   ...   ...          ...
# 43   SIRIPRT  7.80  -0.20   -2.50  7.80  7.80  7.80         1000
# 38      POPF  5.55  -0.20   -3.48  5.70  5.70  5.55       877376
# 33       MIT  0.27  -0.01   -3.57  0.29  0.29  0.27         3302
# 2       ALLY  4.90  -0.20   -3.92  4.96  4.96  4.90       302399
# 45  SRIPANWA  4.94  -0.26      -5  5.15  5.15  4.94       321524
#
#    Total Value (k)
# 32           55.72
# 49          926.79
# 42            0.34
# 15          276.12
# 10         2235.69
# ..             ...
# 43            7.80
# 38         4917.97
# 33            0.93
# 2          1488.83
# 45         1616.47
#
# [52 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.60      0       0 10.60 10.70 10.50         0
# 9   CPNREIT           XA 11.70  -0.20   -1.68 11.90 11.90 11.50         0
# 17   GVREIT            -  6.55  -0.05   -0.76  6.60  6.65  6.45         0
# 55    WHAIR            -  5.65  -0.05   -0.88  5.75  5.75  5.55         0
# 56    WHART            - 10.20      0       0 10.10 10.20    10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0       257923         2733.50      4700 10.60  10.70
# 9             0      2474696        28946.09    679900 11.60  11.70
# 17            0       120567          780.93      7700  6.50   6.55
# 55            0      1160213         6525.40     42600  5.60   5.65
# 56            0      1291024        13068.57       100 10.10  10.20
#
#     Offer Size
# 1        84700
# 9          500
# 17        9100
# 55       40200
# 56     1263300

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 12     KEX  0.96   0.08    9.09  0.91  1.05  0.91      2283140         2276.61
# 27     TTA  4.50   0.08    1.81  4.44  4.66  4.28     12020698        54011.84
# 3   ASIMAR  1.65   0.02    1.23  1.66  1.68  1.63       336500          557.76
# 24   TFFIF  6.30   0.05    0.80  6.25  6.30  6.20      3838610        23941.83
# 23    SJWD  6.75   0.05    0.75  6.65  6.95  6.65      2952126        19910.05
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 7      BTS  5.80  -0.20   -3.33  5.80  5.90  5.80     86348107       502728.71
# 21     SAV 16.90  -0.60   -3.43 17.30 17.40 16.80       567281         9639.33
# 13    KIAT  0.28  -0.01   -3.45  0.28  0.29  0.28      1475654          414.18
# 28    WICE  2.80  -0.10   -3.45  2.84  2.86  2.80       686027         1927.93
# 17    PORT  1.01  -0.07   -6.48  1.06  1.06  1.01        26200           27.36
#
# [26 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 20    RCL            - 24.40  -0.60   -2.40 24.70 24.90 24.40         0
# 24  TFFIF           XD  6.30   0.05    0.80  6.25  6.30  6.20         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size   Bid Offer Offer Size
# 20            0      4483884       110217.03    41000 24.40 24.60      34000
# 24            0      3838610        23941.83   270300  6.25  6.30     396300

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 11  HUMAN  7.95   0.85   11.97  7.70     8  7.30       633101         4846.81
# 17   ITEL  1.60   0.07    4.58  1.52  1.60  1.50      7893140        12182.30
# 33  SYNEX 10.90   0.30    2.83 10.30 11.10 10.20      2966411        31927.58
# 32   SYMC  5.60   0.15    2.75  5.40  5.60  5.30       433092         2337.13
# 21   MFEC  6.10   0.15    2.52  5.90  6.10  5.90       467401         2806.40
# ..    ...   ...    ...     ...   ...   ...   ...          ...             ...
# 18    JAS  1.64  -0.08   -4.65  1.72  1.72  1.64     22637576        37557.06
# 4     AMR  0.61  -0.04   -6.15  0.64  0.64  0.60       661429          402.16
# 14   INET  5.05  -0.35   -6.48  4.88  5.25  4.76     16443451        81907.34
# 20    JTS    39  -4.75  -10.86    42 42.75    39       510848        20698.15
# 27    SDC  0.04  -0.01     -20  0.04  0.05  0.04      9133901          366.43
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.35   0.05    0.94 5.30 5.40 5.25         0
# 6    DIF            - 7.85  -0.15   -1.88 7.95 7.95 7.80         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0     16053874        85893.74  1014300 5.35  5.40     150500
# 6            0     16881503       132669.42   697100 7.85  7.90    1325100

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High  Low  Total Volume  \
# 54    TGE  1.76    0.12     7.32  1.70  1.79 1.64        110629
# 41    SCN  0.47    0.02     4.44  0.42  0.47 0.42        688314
# 59    UBE  0.52    0.02     4.00  0.50  0.53 0.50       4301528
# 1     ACE  1.31    0.05     3.97  1.25  1.31 1.24       4879348
# 39    RPC  0.27    0.01     3.85  0.26  0.27 0.25       2856710
# ..    ...   ...     ...      ...   ...   ...  ...           ...
# 2      AE  0.16   -0.01    -5.88  0.16  0.17 0.16       4746215
# 57    TSE  0.42   -0.03    -6.67  0.44  0.44 0.38       6100503
# 17     CV  0.10   -0.01    -9.09  0.11  0.12 0.09      18892801
# 34  PRIME  0.08   -0.01   -11.11  0.08  0.09 0.07      17643879
# 45  SOLAR  0.25   -0.04   -13.79  0.28  0.28 0.25       1514000
#
#     Total Value (k)
# 54           193.12
# 41           301.76
# 59          2218.93
# 1           6114.14
# 39           765.52
# ..              ...
# 2            760.45
# 57          2508.70
# 17          1948.72
# 34          1411.66
# 45           400.00
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.20   -0.15    -2.04  7.05  7.30 7.05          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       2803874         20060.37    294600 7.15   7.20
#
#     Offer Size
# 35       14300

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (760, 16)

# %%
df.Symbol.nunique()
# Out:
# 414

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (414, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.34      0       0 2.30 2.34 2.28        23655           54.36
# 0    3BBIF 5.35   0.05    0.94 5.30 5.40 5.25     16053874        85893.74
# 0       A5 2.44  -0.02   -0.81 2.46 2.50 2.44       104805          257.71
# 1      AAI 5.45   0.10    1.87 5.30 5.50 5.30      1988344        10768.52
# 0      AAV 2.04   0.00    0.00 2.02 2.06 2.00     38309493        78035.69
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 59     WIN 0.38      0       0 0.38 0.39 0.38       200810           78.14
# 118   WORK 5.85   0.00    0.00 5.90 5.95 5.65       212985         1227.02
# 61      WP 3.22   0.04    1.26 3.18 3.22 3.16       153400          490.69
# 119    WPH 8.80   0.15    1.73 8.65 8.80 8.50       902065         7779.58
# 41     XPG 0.86  -0.01   -1.15 0.87 0.87 0.84     11638997         9975.06
#
# [414 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.20  -0.15   -2.04 7.05 7.30 7.05         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      2803874        20060.37   294600 7.15  7.20      14300

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 2, 28)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-02-28   2.04   0.00    0.00   2.02   2.06   2.00
# 1   ADVANC  2025-02-28 276.00  -5.00   -1.78 277.00 278.00 273.00
# 2   AEONTS  2025-02-28 108.50   1.50    1.40 105.00 108.50 104.50
# 3    AMATA  2025-02-28  23.50  -0.40   -1.67  23.20  23.60  22.90
# 4      AOT  2025-02-28  43.25  -0.25   -0.57  42.75  43.25  42.00
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-02-28   0.28  -0.01   -3.45   0.29   0.29   0.27
# 54     TGE  2025-02-28   1.76   0.12    7.32   1.70   1.79   1.64
# 56   TPIPP  2025-02-28   2.70  -0.10   -3.57   2.80   2.80   2.70
# 57     TSE  2025-02-28   0.42  -0.03   -6.67   0.44   0.44   0.38
# 61      WP  2025-02-28   3.22   0.04    1.26   3.18   3.22   3.16
#
#    Total-Volume Total-Value-(k)
# 0      38309493        78035.69
# 1      15113754      4161751.96
# 2        298806        32020.81
# 3       6600962       153618.79
# 4      47007896      2003834.93
# ..          ...             ...
# 53       349811           97.32
# 54       110629          193.12
# 56      5036969        13785.17
# 57      6100503         2508.70
# 61       153400          490.69
#
# [414 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (414, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (182, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-28 20:37:48

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
