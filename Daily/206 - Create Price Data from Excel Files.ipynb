# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2025, 1, 24), datetime.date(2025, 1, 23))

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-01-24
# yesterday: 2025-01-23

# %%
current_time = datetime.now()
current_time
# Out:
# datetime.datetime(2025, 1, 24, 20, 50, 25, 432149)

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 72   PTTGC  22.40    1.70     8.21  20.90  22.40  20.90      30854250
# 94     TOP  27.00    1.50     5.88  25.50  27.00  25.50      33189738
# 22     BTS   6.15    0.30     5.13   5.85   6.15   5.80      86352495
# 43  GUNKUL   2.12    0.10     4.95   2.06   2.12   2.04      17119646
# 50     IVL  23.70    1.10     4.87  22.80  23.90  22.80      19688852
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 17      BH 186.00   -3.00    -1.59 188.00 188.00 185.00       4219628
# 88    STGT   8.85   -0.15    -1.67   9.00   9.00   8.85       2873184
# 3    AMATA  26.25   -0.50    -1.87  27.00  27.00  25.50       6683052
# 99     WHA   4.90   -0.10    -2.00   5.05   5.05   4.88     136475781
# 46    ICHI  13.00   -0.30    -2.26  13.30  13.30  12.80       7459279
#
#     Total Value (k)
# 72        675505.19
# 94        877869.64
# 22        520296.85
# 43         35638.32
# 50        463840.03
# ..              ...
# 17        788006.32
# 88         25665.11
# 3         174330.61
# 99        673237.23
# 46         96841.18
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 56    KCE            - 23.10    0.40     1.76 22.90 23.20 22.80          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 56          0.00       6315867        145219.52    123300 23.00  23.10
#
#     Offer Size
# 56       56400

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 92      SIS 27.75    1.50     5.71 26.25 27.75 26.00        335306
# 0        A5  2.66    0.12     4.72  2.50  2.66  2.46       2107917
# 118    WICE  3.66    0.16     4.57  3.52  3.96  3.52       2590747
# 11     BBGI  4.70    0.18     3.98  4.56  4.74  4.54      11311408
# 12      BEC  4.22    0.16     3.94  4.14  4.22  4.08       1469923
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 3    ADVICE  5.25   -0.15    -2.78  5.40  5.40  5.25       4647441
# 40      KEX  1.40   -0.04    -2.78  1.47  1.47  1.38        739924
# 108   THANI  1.32   -0.04    -2.94  1.35  1.38  1.32       2271361
# 96      SPA  5.80   -0.25    -4.13  6.10  6.10  5.70      10006285
# 77    RSXYZ  0.69   -0.04    -5.48  0.73  0.74  0.69      12940144
#
#      Total Value (k)
# 92           9061.69
# 0            5372.64
# 118          9685.69
# 11          52598.74
# 12           6121.12
# ..               ...
# 3           24702.06
# 40           1034.52
# 108          3028.98
# 96          58310.86
# 77           9117.08
#
# [121 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.32    0.00     0.00  2.32  2.34  2.32          0
# 50      MCS            -  6.35    0.05     0.79  6.30  6.35  6.30          0
# 91   SINGER            -  7.10    0.25     3.65  6.95  7.10  6.95          0
# 105   SYNEX            - 13.20    0.00     0.00 13.20 13.40 13.10          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9               0        131322           305.03     21000  2.32   2.34
# 50              0         79508           502.99       100  6.30   6.35
# 91              0       1890796         13288.27     26200  7.05   7.10
# 105             0        607629          8031.26     35500 13.20  13.30
#
#      Offer Size
# 9        244700
# 50        71600
# 91       124400
# 105        1800

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 41   PTTGC  22.40    1.70     8.21  20.90  22.40  20.90      30854250
# 61     TOP  27.00    1.50     5.88  25.50  27.00  25.50      33189738
# 23  GUNKUL   2.12    0.10     4.95   2.06   2.12   2.04      17119646
# 27     IVL  23.70    1.10     4.87  22.80  23.90  22.80      19688852
# 5      BCP  35.50    1.50     4.41  34.00  35.75  34.00      16981680
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 9       BH 186.00   -3.00    -1.59 188.00 188.00 185.00       4219628
# 55    STGT   8.85   -0.15    -1.67   9.00   9.00   8.85       2873184
# 28  KAMART  10.60   -0.20    -1.85  10.80  10.80  10.50       2126752
# 0    AMATA  26.25   -0.50    -1.87  27.00  27.00  25.50       6683052
# 25    ICHI  13.00   -0.30    -2.26  13.30  13.30  12.80       7459279
#
#     Total Value (k)
# 41        675505.19
# 61        877869.64
# 23         35638.32
# 27        463840.03
# 5         596943.75
# ..              ...
# 9         788006.32
# 55         25665.11
# 28         22624.24
# 0         174330.61
# 25         96841.18
#
# [63 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  15.00    0.00     0.00  15.00  15.10  14.90
# 41  PTTGC            -  22.40    1.70     8.21  20.90  22.40  20.90
# 49    SCC            - 156.00    6.00     4.00 151.50 156.00 151.00
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00        931968         13963.03    732400  15.00
# 41        100          2.24      30854250        675505.19    121700  22.30
# 49       7200       1123.20       4768755        731812.13     22300 155.50
#
#     Offer  Offer Size
# 4   15.10       79700
# 41  22.40      642500
# 49 156.00       98400

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 27    TOP  27.00    1.50     5.88  25.50  27.00  25.50      33189738
# 5     BCP  35.50    1.50     4.41  34.00  35.75  34.00      16981680
# 20  RATCH  29.25    1.00     3.54  28.50  29.25  28.25       3958419
# 3   BANPU   5.30    0.15     2.91   5.20   5.35   5.15      37035455
# 8   HMPRO   8.90    0.25     2.89   8.70   8.95   8.70      14803916
# ..    ...    ...     ...      ...    ...    ...    ...           ...
# 22   SIRI   1.71    0.00     0.00   1.71   1.72   1.70      20494095
# 11  KBANK 158.50   -0.50    -0.31 159.00 161.00 158.00       7188501
# 13    KTB  22.60   -0.10    -0.44  22.80  23.00  22.60      41027898
# 4     BBL 152.50   -1.50    -0.97 154.50 155.50 152.50       8496470
# 29    WHA   4.90   -0.10    -2.00   5.05   5.05   4.88     136475781
#
#     Total Value (k)
# 27        877869.64
# 5         596943.75
# 20        113725.56
# 3         194427.72
# 8         130917.79
# ..              ...
# 22         35053.67
# 11       1142979.10
# 13        933021.82
# 4        1302839.88
# 29        673237.23
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 15.40    0.40     2.67 15.20 15.50 15.10     101000
# 21    RCL            - 25.00    0.10     0.40 24.90 25.25 24.80          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10       1555.40       8009254        122213.01    265600 15.30  15.40
# 21          0.00       1397754         34881.36    145900 25.00  25.25
#
#     Offer Size
# 10        7000
# 21       79900

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#      Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 76    PTTGC 22.40    1.70     8.21 20.90 22.40 20.90      30854250
# 111     TOP 27.00    1.50     5.88 25.50 27.00 25.50      33189738
# 21      BTS  6.15    0.30     5.13  5.85  6.15  5.80      86352495
# 39   GUNKUL  2.12    0.10     4.95  2.06  2.12  2.04      17119646
# 48      IVL 23.70    1.10     4.87 22.80 23.90 22.80      19688852
# ..      ...   ...     ...      ...   ...   ...   ...           ...
# 3     AMATA 26.25   -0.50    -1.87 27.00 27.00 25.50       6683052
# 120     WHA  4.90   -0.10    -2.00  5.05  5.05  4.88     136475781
# 2        AH 13.80   -0.30    -2.13 14.00 14.00 13.70        441483
# 44     ICHI 13.00   -0.30    -2.26 13.30 13.30 12.80       7459279
# 106   THANI  1.32   -0.04    -2.94  1.35  1.38  1.32       2271361
#
#      Total Value (k)
# 76         675505.19
# 111        877869.64
# 21         520296.85
# 39          35638.32
# 48         463840.03
# ..               ...
# 3          174330.61
# 120        673237.23
# 2            6113.97
# 44          96841.18
# 106          3028.98
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 13.80   -0.30    -2.13 14.00 14.00 13.70          0
# 7      AWC            -  3.12    0.04     1.30  3.10  3.14  3.08     263100
# 66     NER            -  4.94    0.02     0.41  4.94  4.98  4.90          0
# 68     ORI            -  3.42    0.02     0.59  3.42  3.46  3.40          0
# 110    TOA            - 13.30    0.20     1.53 13.00 13.40 13.00          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00        441483          6113.97     22900 13.80  13.90
# 7          820.87      24676701         76934.20   3331900  3.10   3.12
# 66           0.00       5020762         24811.82    722100  4.92   4.94
# 68           0.00       2340854          7993.35     32200  3.42   3.44
# 110          0.00       2010915         26619.25    227100 13.30  13.40
#
#      Offer Size
# 2          5100
# 7        126300
# 66         1700
# 68       123800
# 110       50300

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 9      BTS   6.15    0.30     5.13   5.85   6.15   5.80      86352495
# 11  CENTEL  30.50    1.00     3.39  29.75  30.75  29.75       2966542
# 15     CPF  22.20    0.70     3.26  21.70  22.30  21.70       8465476
# 19   HMPRO   8.90    0.25     2.89   8.70   8.95   8.70      14803916
# 28      TU  11.60    0.30     2.65  11.40  11.60  11.30      35723298
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 7      BJC  22.10   -0.10    -0.45  21.80  22.20  21.80       3561974
# 24     OSP  20.70   -0.10    -0.48  20.80  20.80  20.30       9096047
# 0      AAV   2.26   -0.02    -0.88   2.30   2.32   2.24      27979269
# 1      AOT  56.25   -0.75    -1.32  57.25  57.50  56.00      17716087
# 6       BH 186.00   -3.00    -1.59 188.00 188.00 185.00       4219628
#
#     Total Value (k)
# 9         520296.85
# 11         89757.72
# 15        187185.46
# 19        130917.79
# 28        409407.33
# ..              ...
# 7          78290.59
# 24        186695.40
# 0          63359.34
# 1         998184.54
# 6         788006.32
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 16.60    0.00     0.00 16.70 16.80 16.50          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00       4042653         67137.26    308200 16.50  16.60
#
#     Offer Size
# 27       59700

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 41    XPG  1.05   0.10   10.53  0.95  1.07  0.95    147190298       150377.51
# 28    S11  2.10   0.12    6.06     2  2.10  1.98        28991           59.19
# 26   NCAP  1.41   0.05    3.68  1.36  1.41  1.33      3954433         5429.53
# 9   CHAYO  2.52   0.08    3.28  2.46  2.52  2.46       860030         2139.58
# 32    SGC  1.04   0.03    2.97  1.02  1.04  1.01      6995100         7179.67
# ..    ...   ...    ...     ...   ...   ...   ...          ...             ...
# 39    TNL 35.25  -0.25   -0.70 34.25 35.75    34         6900          240.30
# 21    MFC 29.50  -0.25   -0.84 29.75 29.75 29.25        10002          296.86
# 12    FSX  1.75  -0.02   -1.13  1.79  1.79  1.72        43400           75.61
# 35  THANI  1.32  -0.04   -2.94  1.35  1.38  1.32      2271361         3028.98
# 40  UOBKH  5.10  -0.20   -3.77  5.10  5.10  5.10          201            1.03
#
# [39 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK            - 8.85   0.15    1.72 8.75 8.85 8.75         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0       276146         2430.64     1000 8.85  8.90      21300

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 11   MILL 0.11   0.01      10 0.09 0.11 0.09      5382147          543.13
# 6     GJS 0.14   0.01    7.69 0.13 0.14 0.13       431300           56.17
# 5     CSP 0.58   0.02    3.57 0.57 0.58 0.57        50229           28.79
# 18    THE 0.73   0.02    2.82 0.72 0.73 0.71        16900           12.16
# 16   SSSC 2.04   0.04       2 2.02 2.04    2         2700            5.47
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 3     CEN 1.91      0       0 1.91 1.92 1.91        52500          100.33
# 21    TWP 1.45      0       0 1.33 1.46 1.33         3300            4.70
# 22   TYCN 1.83      0       0 1.83 1.83 1.83        10000           18.30
# 15   SMIT 3.88  -0.02   -0.51 3.90 3.90 3.86        25741           99.58
# 8    INOX 0.46  -0.02   -4.17 0.48 0.48 0.45      1441502          673.60
#
# [21 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 19    TMT            - 3.20      0       0 3.20 3.26 3.16         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 19            0        15339           49.64      400 3.20  3.24       5000

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 13     CI  0.53    0.13    32.50  0.41  0.53  0.41       4777619
# 17   EVER  0.11    0.01    10.00  0.11  0.11  0.10        133527
# 48    RML  0.26    0.02     8.33  0.25  0.26  0.24       1301901
# 33    NVD  1.39    0.09     6.92  1.37  1.39  1.27          1200
# 11  BROCK  1.67    0.10     6.37  1.58  1.67  1.58           200
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 3   AMATA 26.25   -0.50    -1.87 27.00 27.00 25.50       6683052
# 9   BLAND  0.51   -0.01    -1.92  0.52  0.52  0.50      20157816
# 59    WHA  4.90   -0.10    -2.00  5.05  5.05  4.88     136475781
# 18    FPT  8.80   -0.20    -2.22  9.00  9.00  8.80         51000
# 28    MJD  0.82   -0.04    -4.65  0.85  0.86  0.82        260010
#
#     Total Value (k)
# 13          2447.22
# 17            14.59
# 48           322.73
# 33             1.61
# 11             0.33
# ..              ...
# 3         174330.61
# 9          10287.92
# 59        673237.23
# 18           452.36
# 28           215.11
#
# [61 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 54   SENA            -  2.20    0.00     0.00  2.20  2.20 2.18          0
#
#     TR Value (k)  Total Volume  Total Value (k) Bid Size  Bid Offer Offer Size
# 54          0.00        159420           347.70    27800 2.18  2.20      67000

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#       Symbol Last Change %Change Open  High  Low Total Volume Total Value (k)
# 49     TLHPF 2.68   0.14    5.51 2.56  2.68 2.56         2500            6.41
# 36     MNIT2 5.10   0.20    4.08 5.10  5.10 5.10      8956293        45677.09
# 51    TPRIME 7.75   0.25    3.33 7.55  7.75 7.50       204100         1531.55
# 12     DREIT 5.15   0.10    1.98 5.10  5.15 5.05         5400           27.45
# 26   LHRREIT 5.20   0.10    1.96 5.10  5.20 5.10         5005           26.02
# ..       ...  ...    ...     ...  ...   ...  ...          ...             ...
# 11    CTARAF 4.32  -0.06   -1.37 4.36  4.36 4.32       236700         1023.13
# 45  SRIPANWA    5  -0.15   -2.91 5.05  5.10    5        39900          199.79
# 37      MNRF 2.20  -0.08   -3.51 2.20  2.20 2.20          100            0.22
# 53     TU-PF 0.67  -0.05   -6.94 0.67  0.67 0.67          401            0.27
# 32      MIPF   10  -1.10   -9.91   10 10.20 9.95         2800           27.95
#
# [53 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.50   0.10    0.96 10.40 10.50 10.40         0
# 9   CPNREIT            - 12.20      0       0 12.20 12.30 12.10         0
# 17   GVREIT            -  6.55   0.05    0.77  6.50  6.55  6.50         0
# 55    WHAIR            -  6.45      0       0  6.45  6.50  6.40         0
# 56    WHART            - 10.30   0.10    0.98 10.20 10.30 10.10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0       145282         1512.79    143800 10.40  10.50
# 9             0       488639         5978.58   1250800 12.20  12.30
# 17            0        77816          507.23     56700  6.50   6.55
# 55            0       263311         1697.85     24600  6.45   6.50
# 56            0       857543         8753.05      5900 10.20  10.30
#
#     Offer Size
# 1       175000
# 9       101800
# 17      132600
# 55      560400
# 56      899400

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last Change %Change  Open  High  Low Total Volume Total Value (k)
# 4       B  0.07   0.01   16.67  0.07  0.07 0.06      1915862          131.68
# 7     BTS  6.15   0.30    5.13  5.85  6.15 5.80     86352495       520296.85
# 10    ETL  0.66   0.03    4.76  0.64  0.69 0.63       975900          644.19
# 28   WICE  3.66   0.16    4.57  3.52  3.96 3.52      2590747         9685.69
# 15   MENA  1.11   0.04    3.74  1.07  1.16 1.07      2070206         2324.81
# ..    ...   ...    ...     ...   ...   ...  ...          ...             ...
# 1     ANI  3.14  -0.04   -1.26  3.20  3.20 3.14       200801          634.37
# 2     AOT 56.25  -0.75   -1.32 57.25 57.50   56     17716087       998184.54
# 16    NYT  3.08  -0.06   -1.91  3.14  3.16 3.06      1697170         5224.70
# 12    KEX  1.40  -0.04   -2.78  1.47  1.47 1.38       739924         1034.52
# 13   KIAT  0.30  -0.01   -3.23  0.30  0.31 0.29      1376032          413.45
#
# [27 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign Last Change %Change  Open  High   Low TR Volume  \
# 20    RCL            -   25   0.10    0.40 24.90 25.25 24.80         0
# 24  TFFIF            - 6.40   0.10    1.59  6.30  6.40  6.25         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 20            0      1397754        34881.36   145900   25 25.25      79900
# 24            0      2823437        17865.34     5100 6.35  6.40     485800

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 14    INET  5.90   0.85   16.83  5.15  6.10  5.15     34339074       196495.99
# 15   INSET  2.96   0.18    6.47  2.80  3.04  2.80     37056446       108479.56
# 28     SIS 27.75   1.50    5.71 26.25 27.75    26       335306         9061.69
# 24  ROCTEC  1.06   0.04    3.92  1.03  1.08  1.02     15109913        16007.66
# 2      AIT  4.38   0.12    2.82  4.26  4.38  4.26      3022713        13106.84
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 21    MFEC  5.75      0       0  5.80  5.80  5.70        68800          394.54
# 37     TWZ  0.03      0       0  0.03  0.04  0.03      9106401          273.36
# 20     JTS 61.50  -0.50   -0.81    63 63.50 61.50       203537        12663.09
# 35     TKC 11.70  -0.10   -0.85 11.90 11.90 11.70         7400           86.74
# 27     SDC  0.04  -0.01     -20  0.05  0.05  0.04      1744900           70.59
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.20   0.05    0.97 5.15 5.20 5.10         0
# 6    DIF            - 8.40      0       0 8.40 8.45 8.35         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0      6887249        35559.35  5633200 5.15  5.20    9085600
# 6            0      2233265        18762.32   607100 8.40  8.45    2042600

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 5      AIE  0.85    0.07     8.97  0.77  0.90  0.77       1940508
# 55     TOP 27.00    1.50     5.88 25.50 27.00 25.50      33189738
# 27  GUNKUL  2.12    0.10     4.95  2.06  2.12  2.04      17119646
# 19   EASTW  2.26    0.10     4.63  2.16  2.26  2.16       1409608
# 9      BCP 35.50    1.50     4.41 34.00 35.75 34.00      16981680
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 1      ACE  1.25   -0.01    -0.79  1.26  1.27  1.25        916091
# 57     TSE  0.72   -0.01    -1.37  0.72  0.72  0.71        819848
# 52     TAE  0.70   -0.01    -1.41  0.70  0.71  0.68        116379
# 2       AE  0.19   -0.01    -5.00  0.20  0.20  0.19       2252541
# 17      CV  0.09   -0.01   -10.00  0.09  0.10  0.07      32318469
#
#     Total Value (k)
# 5           1648.86
# 55        877869.64
# 27         35638.32
# 19          3121.49
# 9         596943.75
# ..              ...
# 1           1149.40
# 57           583.71
# 52            80.60
# 2            436.15
# 17          2622.72
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.60    0.10     1.33  7.55  7.60 7.45          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       1354094         10226.89    173100 7.55   7.60
#
#     Offer Size
# 35       11100

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (766, 16)

# %%
df.Symbol.nunique()
# Out:
# 418

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (418, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.58   0.04    1.57 2.54 2.60 2.54         6630           16.93
# 0    3BBIF 5.20   0.05    0.97 5.15 5.20 5.10      6887249        35559.35
# 0        A 4.94   0.00    0.00 4.94 4.94 4.94          100            0.49
# 0       A5 2.66   0.12    4.72 2.50 2.66 2.46      2107917         5372.64
# 1      AAI 5.45  -0.05   -0.91 5.50 5.55 5.45      1051260         5762.79
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 60     WIN 0.42   0.00    0.00 0.41 0.46 0.41      1697400          733.20
# 119   WORK 5.20  -0.05   -0.95 5.20 5.20 5.00       682834         3482.42
# 61      WP 3.24   0.02    0.62 3.20 3.26 3.20         4055           13.20
# 120    WPH 8.70   0.20    2.35 8.55 8.70 8.55       298177         2575.38
# 41     XPG 1.05   0.10   10.53 0.95 1.07 0.95    147190298       150377.51
#
# [418 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.60   0.10    1.33 7.55 7.60 7.45         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      1354094        10226.89   173100 7.55  7.60      11100

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 1, 24)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-01-24   2.26  -0.02   -0.88   2.30   2.32   2.24
# 1   ADVANC  2025-01-24 287.00   4.00    1.41 285.00 287.00 284.00
# 2   AEONTS  2025-01-24 115.50   2.00    1.76 115.50 116.50 114.50
# 3    AMATA  2025-01-24  26.25  -0.50   -1.87  27.00  27.00  25.50
# 4      AOT  2025-01-24  56.25  -0.75   -1.32  57.25  57.50  56.00
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-01-24   0.31   0.01    3.33   0.30   0.31   0.30
# 54     TGE  2025-01-24   1.97  -0.01   -0.51   1.98   1.98   1.96
# 56   TPIPP  2025-01-24   2.96   0.00    0.00   2.96   2.96   2.94
# 57     TSE  2025-01-24   0.72  -0.01   -1.37   0.72   0.72   0.71
# 61      WP  2025-01-24   3.24   0.02    0.62   3.20   3.26   3.20
#
#    Total-Volume Total-Value-(k)
# 0      27979269        63359.34
# 1       3361436       959939.02
# 2         93876        10872.41
# 3       6683052       174330.61
# 4      17716087       998184.54
# ..          ...             ...
# 53       289000           88.26
# 54        24600           48.39
# 56       296142          873.29
# 57       819848          583.71
# 61         4055           13.20
#
# [418 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (418, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (181, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
