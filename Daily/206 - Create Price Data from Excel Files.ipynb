# %% [markdown]
# ### Must check that there are data for all sector

# %% [markdown]
# ### Input file: name-ttl.csv
# ### Output files: Price.csv, Price-Today.csv

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta, datetime
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

##pd.reset_option('display.max_rows')
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 11

today = date.today()
yesterday = today - timedelta(days=1)
print(today, yesterday)
# Out:
# 2025-02-11 2025-02-10

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2025-02-11
# yesterday: 2025-02-10

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-11 20:19:31

# %% [markdown]
# ### Restart & Run All Cells

# %%
# Get the user's home directory
user_path = os.path.expanduser('~')
# Get the current working directory
current_path = os.getcwd()
# Derive the base directory (base_dir) by removing the last folder ('Daily')
base_path = os.path.dirname(current_path)
#C:\Users\PC1\OneDrive\A5\Data
dts_path = os.path.join(user_path, "Downloads", "Datasets")
#print(f"Datasets path: {dts_path}")
dat_path = os.path.join(base_path, "Data")
#C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data>
god_path = os.path.join(user_path, "OneDrive","Imports","santisoontarinka@gmail.com - Google Drive","Data")
#C:\Users\PC1\iCloudDrive\data
icd_path = os.path.join(user_path, "iCloudDrive", "Data")
#C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data
osd_path = os.path.join(user_path, "OneDrive","Documents","obsidian-git-sync","Data")

# %%
print("User path:", user_path)
print(f"Current path: {current_path}")
print(f"Base path: {base_path}")
print(f"Datasets path : {dts_path}") 
print(f"Data path : {dat_path}") 
print(f"Google Drive path : {god_path}")
print(f"iCloudDrive path : {icd_path}") 
print(f"Obsidian path : {osd_path}")
# Out:
# User path: C:\Users\PC1
# Current path: C:\Users\PC1\OneDrive\A5\Daily
# Base path: C:\Users\PC1\OneDrive\A5
# Datasets path : C:\Users\PC1\Downloads\Datasets
# Data path : C:\Users\PC1\OneDrive\A5\Data
# Google Drive path : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data
# iCloudDrive path : C:\Users\PC1\iCloudDrive\Data
# Obsidian path : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data

# %%
colu = 'Symbol Last Change %Change Open High Low'.split()
vol = 'Total Volume'
colu.append(vol)
val = 'Total Value (k)'
colu.append(val)
colu
# Out:
# ['Symbol',
#  'Last',
#  'Change',
#  '%Change',
#  'Open',
#  'High',
#  'Low',
#  'Total Volume',
#  'Total Value (k)']

# %%
format_dict = {'Bid Size':'{:,}','Offer Size':'{:,}',
              'Last':'{:,.2f}','Open':'{:,.2f}','High':'{:,.2f}','Low':'{:,.2f}','Bid':'{:,.2f}','Offer':'{:,.2f}',
              'Total Volume':'{:,}','Total-Volume':'{:,}','Total Value (k)':'{:,.3f}','Total-Value-(k)':'{:,.3f}',
              'TR Volume':'{:,}','TR Value (k)':'{:,.3f}',               
              'Change':'{:,.2f}','%Change':'{:.2f}%'}

# %% [markdown]
# ### If use style.format(format_dict), number of maximum rows will be ineffective

# %%
### SET100 b
file_name = "StockQuotation.xlsx"
input_file = os.path.join(dts_path, file_name)
df_S100 = pd.read_excel(input_file, header=8)
df_S100 = df_S100[df_S100['%Change'] != '-']
df_S100[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 24   CCET  8.10    0.80    10.96  7.45  8.20  7.40     141044346
# 7      BA 19.40    1.40     7.78 18.30 19.50 18.30       6957828
# 56    KCE 21.20    1.40     7.07 19.80 21.20 19.70      13788336
# 11    BCH 14.20    0.80     5.97 13.40 14.50 13.40       6062786
# 82   SISB 26.75    1.50     5.94 25.50 27.00 25.50       4306466
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 42   GULF 56.50   -0.75    -1.31 56.75 57.00 55.50      54111570
# 58    KTB 23.30   -0.40    -1.69 23.70 23.70 23.20      41015050
# 41   GPSC 25.75   -0.50    -1.90 26.25 26.75 25.75      11889998
# 80   SCGP 15.20   -0.40    -2.56 15.70 15.70 15.20      15189785
# 54    JTS 48.75   -1.75    -3.47 50.50 52.00 48.75        390462
#
#     Total Value (k)
# 24       1106370.26
# 7         131812.26
# 56        284122.31
# 11         85208.55
# 82        114138.71
# ..              ...
# 42       3047896.84
# 58        959656.43
# 41        309877.81
# 80        233966.72
# 54         19523.32
#
# [100 rows x 9 columns]

# %%
df_S100.query('Symbol == ("KCE")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 56    KCE            - 21.20    1.40     7.07 19.80 21.20 19.70     144400
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 56       3061.28      13788336        284122.31     61700 21.20  21.30
#
#     Offer Size
# 56      103400

# %%
### sSET 1
file_name = "StockQuotation (1).xlsx"
input_file = os.path.join(dts_path, file_name)
df_sSET = pd.read_excel(input_file, header=8)
df_sSET = df_sSET[df_sSET['%Change'] != '-']
df_sSET[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High  Low  Total Volume  \
# 66     PSL  6.25    0.55     9.65  5.90  6.30 5.90       6146321
# 77   RSXYZ  0.59    0.05     9.26  0.55  0.68 0.55      17522763
# 111    TKC  9.65    0.65     7.22  9.15  9.70 9.15         99400
# 50     MCS  6.25    0.40     6.84  5.85  6.25 5.85        198223
# 120    WPH  8.10    0.50     6.58  7.65  8.30 7.65        903376
# ..     ...   ...     ...      ...   ...   ...  ...           ...
# 14     BLC  4.10   -0.06    -1.44  4.16  4.16 4.06       1694508
# 2      ACE  1.29   -0.02    -1.53  1.31  1.31 1.27        771208
# 25     EKH  6.30   -0.10    -1.56  6.30  6.40 6.30        504523
# 98     SSP  5.10   -0.15    -2.86  5.15  5.35 5.05        848601
# 18     CGD  0.26   -0.01    -3.70  0.26  0.26 0.26       1303300
#
#      Total Value (k)
# 66          37703.85
# 77          10829.01
# 111           945.59
# 50           1211.71
# 120          7307.34
# ..               ...
# 14           6946.58
# 2             987.42
# 25           3187.62
# 98           4360.09
# 18            338.86
#
# [121 rows x 9 columns]

# %%
df_sSET.query('Symbol == ("ASP","MCS","SINGER","SYNEX")')
# Out:
#      Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 9       ASP            -  2.30    0.00     0.00  2.28  2.30  2.28          0
# 50      MCS            -  6.25    0.40     6.84  5.85  6.25  5.85          0
# 91   SINGER            -  6.40    0.10     1.59  6.30  6.55  6.30          0
# 105   SYNEX            - 10.50   -0.10    -0.94 10.60 10.80 10.10          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 9            0.00        554070          1266.53     77300  2.28   2.30
# 50           0.00        198223          1211.71     15000  6.15   6.25
# 91           0.00       2988806         19069.80     54700  6.40   6.45
# 105          0.00       6005349         62674.51    237200 10.50  10.60
#
#      Offer Size
# 9         69600
# 50        19600
# 91        27200
# 105       51100

# %%
### SETCLMV 2
file_name = "StockQuotation (2).xlsx"
input_file = os.path.join(dts_path, file_name)
df_CLMV = pd.read_excel(input_file, header=8)
df_CLMV = df_CLMV[df_CLMV['%Change'] != '-']
df_CLMV[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 1      BA 19.40    1.40     7.78 18.30 19.50 18.30       6957828
# 4     BCH 14.20    0.80     5.97 13.40 14.50 13.40       6062786
# 44    RCL 23.40    1.10     4.93 22.30 23.50 22.30       2133486
# 24   HANA 21.80    1.00     4.81 20.90 21.90 20.90       7703834
# 12    CBG 71.50    3.25     4.76 68.25 71.50 68.25       4620109
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 30    KKP 51.00   -0.50    -0.97 51.25 51.75 50.50       4257973
# 22   GULF 56.50   -0.75    -1.31 56.75 57.00 55.50      54111570
# 21   GPSC 25.75   -0.50    -1.90 26.25 26.75 25.75      11889998
# 51   SCGP 15.20   -0.40    -2.56 15.70 15.70 15.20      15189785
# 54    SSP  5.10   -0.15    -2.86  5.15  5.35  5.05        848601
#
#     Total Value (k)
# 1         131812.26
# 4          85208.55
# 44         49316.28
# 24        165078.32
# 12        323181.37
# ..              ...
# 30        217580.66
# 22       3047896.84
# 21        309877.81
# 51        233966.72
# 54          4360.09
#
# [63 rows x 9 columns]

# %%
df_CLMV.query('Symbol == ("BCH","PTTGC","SCC")')
# Out:
#    Symbol Trading Sign   Last  Change  %Change   Open   High    Low  \
# 4     BCH            -  14.20    0.80     5.97  13.40  14.50  13.40
# 41  PTTGC            -  20.40    0.80     4.08  19.60  20.40  19.50
# 49    SCC            - 147.00    1.50     1.03 146.00 147.50 145.00
#
#     TR Volume  TR Value (k)  Total Volume  Total Value (k)  Bid Size    Bid  \
# 4           0          0.00       6062786         85208.55      8000  14.20
# 41        100          2.04      12299772        247065.47     88300  20.30
# 49          0          0.00       1165436        170515.25       500 147.00
#
#     Offer  Offer Size
# 4   14.30       20500
# 41  20.40      322700
# 49 147.50      171500

# %%
### SETHD 3
file_name = "StockQuotation (3).xlsx"
input_file = os.path.join(dts_path, file_name)
df_HD = pd.read_excel(input_file, header=8)
df_HD = df_HD[df_HD['%Change'] != '-']
df_HD[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 21     RCL  23.40    1.10     4.93  22.30  23.50  22.30       2133486
# 8    HMPRO   8.45    0.35     4.32   8.10   8.45   8.10      21224408
# 1       AP   7.95    0.30     3.92   7.70   8.00   7.70      11438781
# 23   SPALI  15.70    0.50     3.29  15.20  15.90  15.20       7970970
# 5      BCP  36.25    1.00     2.84  35.50  36.25  35.00       9918535
# ..     ...    ...     ...      ...    ...    ...    ...           ...
# 11   KBANK 158.00   -1.00    -0.63 159.00 160.00 158.00       8679927
# 12     KKP  51.00   -0.50    -0.97  51.25  51.75  50.50       4257973
# 9   INTUCH  98.50   -1.00    -1.01  99.00  99.00  96.75      25493130
# 28     TTB   1.94   -0.02    -1.02   1.95   1.96   1.94     192563219
# 13     KTB  23.30   -0.40    -1.69  23.70  23.70  23.20      41015050
#
#     Total Value (k)
# 21         49316.28
# 8         177560.09
# 1          89942.17
# 23        124877.74
# 5         353890.26
# ..              ...
# 11       1377044.32
# 12        217580.66
# 9        2495962.04
# 28        374954.22
# 13        959656.43
#
# [30 rows x 9 columns]

# %%
df_HD.query('Symbol == ("JMT","RCL")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 10    JMT            - 14.10    0.30     2.17 14.00 14.40 13.90          0
# 21    RCL            - 23.40    1.10     4.93 22.30 23.50 22.30          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 10          0.00       5750212         81265.52    190700 14.10  14.20
# 21          0.00       2133486         49316.28      3800 23.40  23.50
#
#     Offer Size
# 10       36200
# 21       48700

# %%
### SETESG 4
file_name = "StockQuotation (4).xlsx"
input_file = os.path.join(dts_path, file_name)
df_THSI = pd.read_excel(input_file, header=8)
df_THSI = df_THSI[df_THSI['%Change'] != '-']
df_THSI[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 73    PSL  6.25    0.55     9.65  5.90  6.30  5.90       6146321
# 8      BA 19.40    1.40     7.78 18.30 19.50 18.30       6957828
# 53    KCE 21.20    1.40     7.07 19.80 21.20 19.70      13788336
# 6     ASK  7.90    0.45     6.04  7.50  8.00  7.50        543018
# 13    BCH 14.20    0.80     5.97 13.40 14.50 13.40       6062786
# ..    ...   ...     ...      ...   ...   ...   ...           ...
# 56    KTB 23.30   -0.40    -1.69 23.70 23.70 23.20      41015050
# 37   GPSC 25.75   -0.50    -1.90 26.25 26.75 25.75      11889998
# 91   SCGP 15.20   -0.40    -2.56 15.70 15.70 15.20      15189785
# 99    SSP  5.10   -0.15    -2.86  5.15  5.35  5.05        848601
# 51    JTS 48.75   -1.75    -3.47 50.50 52.00 48.75        390462
#
#     Total Value (k)
# 73         37703.85
# 8         131812.26
# 53        284122.31
# 6           4292.57
# 13         85208.55
# ..              ...
# 56        959656.43
# 37        309877.81
# 91        233966.72
# 99          4360.09
# 51         19523.32
#
# [122 rows x 9 columns]

# %%
df_THSI.query('Symbol == ("AH","AWC","NER","ORI","TOA")')
# Out:
#     Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 2       AH            - 14.00   -0.10    -0.71 14.20 14.20 14.00          0
# 7      AWC            -  3.00    0.06     2.04  2.92  3.04  2.92          0
# 66     NER            -  4.70    0.08     1.73  4.64  4.70  4.64          0
# 68     ORI            -  3.10    0.06     1.97  3.04  3.12  3.04          0
# 110    TOA            - 12.20    0.20     1.67 12.00 12.40 12.00          0
#
#      TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 2            0.00         71623          1010.44      6300 14.00  14.10
# 7            0.00      49439881        148178.44   2237600  3.00   3.02
# 66           0.00       4662442         21794.01       100  4.68   4.70
# 68           0.00       4283453         13174.28     29600  3.10   3.12
# 110          0.00        879329         10719.58     80700 12.10  12.20
#
#      Offer Size
# 2           400
# 7        621600
# 66       269500
# 68        23700
# 110        4400

# %%
### SETWB 5
file_name = "StockQuotation (5).xlsx"
input_file = os.path.join(dts_path, file_name)
df_WB = pd.read_excel(input_file, header=8)
df_WB = df_WB[df_WB['%Change'] != '-']
df_WB[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol   Last  Change  %Change   Open   High    Low  Total Volume  \
# 2      BA  19.40    1.40     7.78  18.30  19.50  18.30       6957828
# 3     BCH  14.20    0.80     5.97  13.40  14.50  13.40       6062786
# 12    CHG   2.16    0.12     5.88   2.04   2.18   2.04      18971849
# 21      M  18.20    1.00     5.81  17.30  18.30  17.20       4974785
# 10    CBG  71.50    3.25     4.76  68.25  71.50  68.25       4620109
# ..    ...    ...     ...      ...    ...    ...    ...           ...
# 6      BH 175.50    2.00     1.15 173.50 176.50 173.00       3049696
# 23   MINT  25.75    0.25     0.98  25.50  26.00  25.25      17384919
# 13   COM7  21.40    0.20     0.94  21.10  21.50  21.00      11022845
# 1     AOT  54.75    0.50     0.92  54.25  55.50  54.00      23481999
# 28     TU  11.50    0.00     0.00  11.50  11.60  11.40      10440930
#
#     Total Value (k)
# 2         131812.26
# 3          85208.55
# 12         40225.24
# 21         89465.59
# 10        323181.37
# ..              ...
# 6         532917.85
# 23        446696.02
# 13        234026.34
# 1        1292030.62
# 28        120053.10
#
# [30 rows x 9 columns]

# %%
df_WB.query('Symbol == ("STA")')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High   Low  TR Volume  \
# 27    STA            - 14.60    0.20     1.39 14.30 14.70 14.30          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size   Bid  Offer  \
# 27          0.00       6511392         94626.55    213300 14.50  14.60
#
#     Offer Size
# 27      118800

# %%
### FIN 6
file_name = "StockQuotation (6).xlsx"
input_file = os.path.join(dts_path, file_name)
df_FIN = pd.read_excel(input_file, header=9)
df_FIN = df_FIN[df_FIN['%Change'] != '-']
df_FIN[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 3      ASK  7.90   0.45    6.04  7.50     8  7.50       543018         4292.57
# 34      TH  0.60   0.03    5.26  0.58  0.61  0.58       382300          228.12
# 36  TIDLOR 17.60   0.80    4.76 16.80 17.60 16.80     14985907       259194.00
# 9    CHAYO  2.24   0.10    4.67  2.14  2.26  2.14      2346728         5137.55
# 32     SGC  0.91   0.04    4.60  0.87  0.92  0.87      7532068         6738.37
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 38   TNITY  2.80  -0.04   -1.41  2.80  2.90  2.76        75000          209.65
# 11     FNS  1.61  -0.03   -1.83  1.64  1.64  1.61        20051           32.28
# 23      ML  0.45  -0.01   -2.17  0.43  0.46  0.43       129700           57.08
# 21     MFC 26.75  -0.75   -2.73 26.50    27 26.50         6710          179.04
# 13     GBX  0.62  -0.02   -3.12  0.64  0.64  0.62       979900          612.86
#
# [40 rows x 9 columns]

# %%
df_FIN.query('Symbol == ("ASK")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 3    ASK            - 7.90   0.45    6.04 7.50    8 7.50         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 3            0       543018         4292.57    91700 7.90  7.95      10000

# %%
### STEEL 7
file_name = "StockQuotation (7).xlsx"
input_file = os.path.join(dts_path, file_name)
df_STEEL = pd.read_excel(input_file, header=9)
df_STEEL = df_STEEL[df_STEEL['%Change'] != '-']
df_STEEL[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 17  TGPRO 0.08   0.01   14.29 0.08 0.08 0.07        38300            3.05
# 11   MILL 0.10   0.01   11.11 0.10 0.10 0.09        25842            2.33
# 10    MCS 6.25   0.40    6.84 5.85 6.25 5.85       198223         1211.71
# 13   PERM 0.41   0.01    2.50 0.40 0.42 0.40       674500          274.90
# 20   TSTH 0.53   0.01    1.92 0.52 0.55 0.52      1296100          687.57
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 2    BSBM 0.71      0       0 0.69 0.71 0.69       382000          268.11
# 22   TYCN 1.88  -0.01   -0.53 1.88 1.88 1.88          100            0.19
# 4    CITY 1.66  -0.01   -0.60 1.66 1.66 1.66          200            0.33
# 19    TMT 3.04  -0.02   -0.65 3.04 3.04 3.02        39400          119.34
# 21    TWP 1.13  -0.03   -2.59 1.20 1.20 1.10        91801          102.60
#
# [22 rows x 9 columns]

# %%
df_STEEL.query('Symbol == ("TMT")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 19    TMT            - 3.04  -0.02   -0.65 3.04 3.04 3.02         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 19            0        39400          119.34     4900 3.04  3.06       2600

# %%
### PROP 8
file_name = "StockQuotation (8).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PROP = pd.read_excel(input_file, header=9)
df_PROP = df_PROP[df_PROP['%Change'] != '-']
df_PROP[colu].sort_values(['%Change'],ascending=[False])
# Out:
#    Symbol Last Change %Change Open High  Low Total Volume Total Value (k)
# 35    ORN 0.72   0.06    9.09 0.66 0.74 0.66      7663777         5470.56
# 47    RML 0.25   0.02    8.70 0.23 0.25 0.23       803200          192.77
# 41   PRIN 1.63   0.13    8.67 1.62 1.63 1.62          200            0.33
# 28    MJD 0.75   0.04    5.63 0.73 0.81 0.72      1714708         1331.40
# 43    PSH 6.10   0.25    4.27 5.90 6.10 5.85       833522         4961.14
# ..    ...  ...    ...     ...  ...  ...  ...          ...             ...
# 20      J 1.05  -0.02   -1.87 1.06 1.08 1.01       392958          404.45
# 12    CGD 0.26  -0.01   -3.70 0.26 0.26 0.26      1303300          338.86
# 18    FPT 7.10  -0.30   -4.05 7.30 7.30 7.05        65300          466.06
# 16  ESTAR 0.19  -0.01      -5 0.19 0.20 0.19      1416380          269.15
# 46  RICHY 0.34  -0.02   -5.56 0.36 0.37 0.34       195371           68.98
#
# [59 rows x 9 columns]

# %%
df_PROP.query('Symbol == ("SENA")')
# Out:
#    Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 53   SENA            - 2.14      0       0 2.12 2.14 2.10         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size  Bid  Offer  Offer Size
# 53            0       276101          584.60    13600 2.12   2.14       75000

# %%
### PFREIT 9
file_name = "StockQuotation (9).xlsx"
input_file = os.path.join(dts_path, file_name)
df_PFREIT = pd.read_excel(input_file, header=9)
df_PFREIT = df_PFREIT[df_PFREIT['%Change'] != '-']
df_PFREIT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 29   M-PAT  2.34   0.14    6.36  2.20  2.86  2.10         1400            3.37
# 36   MNIT2  4.98   0.16    3.32  4.98  4.98  4.60         5700           26.72
# 52   TTLPF 13.90   0.30    2.21    14    14 13.90        46705          651.26
# 56   WHART 10.20   0.20       2    10 10.20    10      1360033        13833.51
# 13  FTREIT 10.30   0.20    1.98 10.20 10.40 10.10      1473261        15245.78
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 49   TLHPF  2.40  -0.06   -2.44  2.40  2.46  2.38        41700          100.81
# 3   AMATAR  6.70  -0.20   -2.90  6.85  6.85  6.35         2437           15.78
# 42    QHOP  3.28  -0.10   -2.96  3.22  3.28  3.12         5400           17.39
# 33     MIT  0.30  -0.01   -3.23  0.31  0.31  0.30        44000           13.48
# 37    MNRF  2.24  -0.08   -3.45  2.40  2.40  2.10        87000          189.65
#
# [52 rows x 9 columns]

# %%
df_PFREIT.query('Symbol == ("AIMIRT","CPNREIT","GVREIT","WHAIR","WHART")')
# Out:
#      Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 1    AIMIRT            - 10.50      0       0 10.40 10.50 10.40         0
# 9   CPNREIT            -    12      0       0    12    12 11.80         0
# 17   GVREIT            -  6.65   0.05    0.76  6.60  6.65  6.55         0
# 55    WHAIR            -  6.25   0.10    1.63  6.15  6.25  6.15         0
# 56    WHART            - 10.20   0.20       2    10 10.20    10         0
#
#    TR Value (k) Total Volume Total Value (k)  Bid Size   Bid  Offer  \
# 1             0        64123          669.39    123400 10.40  10.50
# 9             0       966300        11564.10    296600 11.90  12.00
# 17            0       197110         1300.67    223600  6.55   6.65
# 55            0       362100         2250.30    165800  6.20   6.25
# 56            0      1360033        13833.51     20000 10.10  10.20
#
#     Offer Size
# 1        97100
# 9       263200
# 17      120600
# 55       84300
# 56      226500

# %%
### TRANS 10
file_name = "StockQuotation (10).xlsx"
input_file = os.path.join(dts_path, file_name)
df_TRANS = pd.read_excel(input_file, header=9)
df_TRANS = df_TRANS[df_TRANS['%Change'] != '-']
df_TRANS[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 19     PSL  6.25   0.55    9.65  5.90  6.30  5.90      6146321        37703.85
# 5       BA 19.40   1.40    7.78 18.30 19.50 18.30      6957828       131812.26
# 27     TTA  4.28   0.24    5.94  4.04  4.30  4.04      5802084        24407.65
# 10     ETL  0.58   0.03    5.45  0.57  0.58  0.56       127320           72.27
# 20     RCL 23.40   1.10    4.93 22.30 23.50 22.30      2133486        49316.28
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 24   TFFIF  6.30      0       0  6.30  6.40  6.30      4558490        28911.73
# 28    WICE  3.30      0       0  3.30  3.30  3.24       111000          362.99
# 4        B  0.06      0       0  0.06  0.07  0.05     90875989         5453.85
# 8   BTSGIF  2.96  -0.02   -0.67  2.96  2.98  2.94      3642236        10786.90
# 13    KIAT  0.29  -0.01   -3.33  0.29  0.30  0.28      2475900          719.05
#
# [26 rows x 9 columns]

# %%
df_TRANS.query('Symbol == ("RCL","TFFIF")')
# Out:
#    Symbol Trading Sign  Last Change %Change  Open  High   Low TR Volume  \
# 20    RCL            - 23.40   1.10    4.93 22.30 23.50 22.30         0
# 24  TFFIF            -  6.30      0       0  6.30  6.40  6.30         0
#
#    TR Value (k) Total Volume Total Value (k) Bid Size   Bid Offer Offer Size
# 20            0      2133486        49316.28     3800 23.40 23.50      48700
# 24            0      4558490        28911.73  2143800  6.30  6.35     524600

# %%
### ICT 11
file_name = "StockQuotation (11).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ICT = pd.read_excel(input_file, header=9)
df_ICT = df_ICT[df_ICT['%Change'] != '-']
df_ICT[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last Change %Change  Open  High   Low Total Volume Total Value (k)
# 37     TWZ  0.04   0.01   33.33  0.03  0.04  0.03     19427878          588.95
# 27     SDC  0.05   0.01      25  0.04  0.05  0.04      9676500          393.11
# 35     TKC  9.65   0.65    7.22  9.15  9.70  9.15        99400          945.59
# 2      AIT  4.62   0.26    5.96  4.36  4.62  4.36     11128536        50729.74
# 14    INET  5.45   0.20    3.81  5.25  5.55  5.25      4677962        25475.63
# ..     ...   ...    ...     ...   ...   ...   ...          ...             ...
# 36    TRUE 12.60  -0.10   -0.79 12.60 12.70 12.40     80869180      1014989.47
# 33   SYNEX 10.50  -0.10   -0.94 10.60 10.80 10.10      6005349        62674.51
# 16  INTUCH 98.50     -1   -1.01    99    99 96.75     25493130      2495962.04
# 3      ALT  0.86  -0.01   -1.15  0.87  0.87  0.84       129190          110.39
# 20     JTS 48.75  -1.75   -3.47 50.50    52 48.75       390462        19523.32
#
# [37 rows x 9 columns]

# %%
df_ICT.query('Symbol == ("DIF","3BBIF")')
# Out:
#   Symbol Trading Sign Last Change %Change Open High  Low TR Volume  \
# 0  3BBIF            - 5.45   0.05    0.93 5.40 5.45 5.35         0
# 6    DIF            - 8.45   0.05    0.60 8.45 8.50 8.40         0
#
#   TR Value (k) Total Volume Total Value (k) Bid Size  Bid Offer Offer Size
# 0            0      8414482        45510.72  1657300 5.40  5.45    6041800
# 6            0     12999223       110002.56    49400 8.45  8.50    2818100

# %% [markdown]
# ## Add section ENERG for PTG

# %%
### ENERG 12
file_name = "StockQuotation (12).xlsx"
input_file = os.path.join(dts_path, file_name)
df_ENG = pd.read_excel(input_file, header=9)
df_ENG = df_ENG[df_ENG['%Change'] != '-']
df_ENG[colu].sort_values(['%Change'],ascending=[False])
# Out:
#     Symbol  Last  Change  %Change  Open  High   Low  Total Volume  \
# 45   SOLAR  0.29    0.02     7.41  0.27  0.30  0.27       2192420
# 60   WHAUP  3.60    0.16     4.65  3.46  3.62  3.46       3541288
# 54     TGE  1.75    0.07     4.17  1.79  1.79  1.74        140435
# 23     ETC  1.26    0.05     4.13  1.24  1.27  1.17        615204
# 16     CKP  2.74    0.10     3.79  2.64  2.74  2.64       3395836
# ..     ...   ...     ...      ...   ...   ...   ...           ...
# 24    GPSC 25.75   -0.50    -1.90 26.25 26.75 25.75      11889998
# 0      ACC  0.39   -0.01    -2.50  0.40  0.41  0.39       2000039
# 48     SSP  5.10   -0.15    -2.86  5.15  5.35  5.05        848601
# 12  BIOTEC  0.21   -0.01    -4.55  0.21  0.21  0.20       3895433
# 25   GREEN  0.89   -0.05    -5.32  0.87  0.90  0.87        106500
#
#     Total Value (k)
# 45           625.80
# 60         12638.31
# 54           245.76
# 23           767.25
# 16          9172.79
# ..              ...
# 24        309877.81
# 0            799.23
# 48          4360.09
# 12           781.39
# 25            93.47
#
# [62 rows x 9 columns]

# %%
df_ENG.query('Symbol == "PTG"')
# Out:
#    Symbol Trading Sign  Last  Change  %Change  Open  High  Low  TR Volume  \
# 35    PTG            -  7.10   -0.05    -0.70  7.15  7.15 7.00          0
#
#     TR Value (k)  Total Volume  Total Value (k)  Bid Size  Bid  Offer  \
# 35          0.00       1615176         11416.86    247900 7.05   7.10
#
#     Offer Size
# 35       47800

# %% [markdown]
# ### ------------ End of Individual Category

# %%
df = pd.concat([df_S100, df_sSET, df_CLMV, df_HD, df_THSI, df_WB, df_FIN, df_STEEL, df_PROP, df_PFREIT, df_TRANS, df_ICT, df_ENG])
df.shape
# Out:
# (764, 16)

# %%
df.Symbol.nunique()
# Out:
# 416

# %%
### First equals to latest published pdf file
df = df.drop_duplicates(subset='Symbol', keep='first')
df.shape
# Out:
# (416, 16)

# %%
df.rename(columns={col: col.replace(" ", "-") for col in df.columns}, inplace=True)
df.columns
# Out:
# Index(['Symbol', 'Trading-Sign', 'Last', 'Change', '%Change', 'Open', 'High',
#        'Low', 'TR-Volume', 'TR-Value-(k)', 'Total-Volume', 'Total-Value-(k)',
#        'Bid-Size', 'Bid', 'Offer', 'Offer-Size'],
#       dtype='object')

# %%
cols = 'Symbol Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[cols].sort_values('Symbol',ascending=True)
# Out:
#     Symbol Last Change %Change Open High  Low Total-Volume Total-Value-(k)
# 0       2S 2.38      0       0 2.38 2.40 2.38         8398           19.98
# 0    3BBIF 5.45   0.05    0.93 5.40 5.45 5.35      8414482        45510.72
# 0        A 4.90   0.06    1.24 4.90 4.90 4.90          200            0.98
# 0       A5 2.54   0.06    2.42 2.46 2.54 2.46       773801         1939.98
# 1      AAI 5.30   0.10    1.92 5.35 5.35 5.25      1409995         7481.58
# ..     ...  ...    ...     ...  ...  ...  ...          ...             ...
# 59     WIN 0.38   0.01    2.70 0.38 0.38 0.37       114900           43.35
# 119   WORK 5.70  -0.05   -0.87 5.70 5.80 5.55       313101         1765.43
# 61      WP 3.26  -0.02   -0.61 3.24 3.26 3.04        74401          232.65
# 120    WPH 8.10   0.50    6.58 7.65 8.30 7.65       903376         7307.34
# 41     XPG 0.90   0.02    2.27 0.89 0.91 0.88      6539517         5839.06
#
# [416 rows x 9 columns]

# %%
df.query('Symbol == ("PTG","PTG")')
# Out:
#    Symbol Trading-Sign Last Change %Change Open High  Low TR-Volume  \
# 35    PTG            - 7.10  -0.05   -0.70 7.15 7.15 7.00         0
#
#    TR-Value-(k) Total-Volume Total-Value-(k) Bid-Size  Bid Offer Offer-Size
# 35         0.00      1615176        11416.86   247900 7.05  7.10      47800

# %%
# If run after actual work day
#today = today - timedelta(days=2)
today
# Out:
# datetime.date(2025, 2, 11)

# %%
df.insert(1, 'Date', today)

# %%
colt = 'Symbol Date Last Change %Change Open High Low Total-Volume Total-Value-(k)'.split()
df[colt]
# Out:
#     Symbol        Date   Last Change %Change   Open   High    Low  \
# 0      AAV  2025-02-11   2.10   0.08    3.96   2.02   2.14   2.00
# 1   ADVANC  2025-02-11 284.00   1.00    0.35 284.00 285.00 280.00
# 2   AEONTS  2025-02-11 110.00   2.50    2.33 107.50 110.50 107.50
# 3    AMATA  2025-02-11  24.70   0.80    3.35  24.20  24.80  24.20
# 4      AOT  2025-02-11  54.75   0.50    0.92  54.25  55.50  54.00
# ..     ...         ...    ...    ...     ...    ...    ...    ...
# 53     TCC  2025-02-11   0.28   0.01    3.70   0.28   0.29   0.28
# 54     TGE  2025-02-11   1.75   0.07    4.17   1.79   1.79   1.74
# 56   TPIPP  2025-02-11   2.94   0.00    0.00   2.94   2.94   2.92
# 57     TSE  2025-02-11   0.64   0.02    3.23   0.62   0.64   0.62
# 61      WP  2025-02-11   3.26  -0.02   -0.61   3.24   3.26   3.04
#
#    Total-Volume Total-Value-(k)
# 0      37031445        77335.61
# 1      11075069      3126985.81
# 2        265475        29106.58
# 3      21490621       527332.64
# 4      23481999      1292030.62
# ..          ...             ...
# 53       355116           99.44
# 54       140435          245.76
# 56       733456         2149.85
# 57       296214          186.10
# 61        74401          232.65
#
# [416 rows x 10 columns]

# %%
file_name = "name-ttl.csv"
input_file = os.path.join(dat_path, file_name)
print(f"Input file: {input_file}")
# Out:
# Input file: C:\Users\PC1\OneDrive\A5\Data\name-ttl.csv

# %%
df_name = pd.read_csv(input_file, header=None, names=['Symbol'])
df_name.shape
# Out:
# (221, 1)

# %%
df_out = df[colt]
df_out.shape
# Out:
# (416, 10)

# %%
df_merge = pd.merge(df_name, df_out, on = 'Symbol', how='inner')
df_merge.shape
# Out:
# (182, 10)

# %%
df_merge.columns = df_merge.columns.str.lower()
df_merge.columns
# Out:
# Index(['symbol', 'date', 'last', 'change', '%change', 'open', 'high', 'low',
#        'total-volume', 'total-value-(k)'],
#       dtype='object')

# %%
df_merge.rename(columns={'symbol':'name','last':'price','total-volume':'volume',
                         'total-value-(k)':'value(m)'},inplace=True)
df_merge.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
colp = 'name date price high low volume open'.split()

file_name = "Price.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price.csv

# %%
df_merge[colp].to_csv(output_file, header=True, index=False)
df_merge[colp].to_csv(god_file, header=True, index=False)
df_merge[colp].to_csv(icd_file, header=True, index=False)
df_merge[colp].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### End of daily process to export Price to MySql Stock database

# %%
file_name = "Price-Today.csv"
output_file = os.path.join(dat_path, file_name)
god_file = os.path.join(god_path, file_name)
icd_file = os.path.join(icd_path, file_name)
osd_file = os.path.join(osd_path, file_name)

# %%
print(f"output_file : {output_file}") 
print(f"icd_file : {icd_file}") 
print(f"god_file : {god_file}") 
print(f"osd_file : {osd_file}")
# Out:
# output_file : C:\Users\PC1\OneDrive\A5\Data\Price-Today.csv
# icd_file : C:\Users\PC1\iCloudDrive\Data\Price-Today.csv
# god_file : C:\Users\PC1\OneDrive\Imports\santisoontarinka@gmail.com - Google Drive\Data\Price-Today.csv
# osd_file : C:\Users\PC1\OneDrive\Documents\obsidian-git-sync\Data\Price-Today.csv

# %%
df_merge.to_csv(output_file, header=True, index=False)
df_merge.to_csv(god_file, header=True, index=False)
df_merge.to_csv(icd_file, header=True, index=False)
df_merge.to_csv(osd_file, header=True, index=False)

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-02-11 20:19:33

# %% [markdown]
# ### End of daily process to export Price-Today for Market-all, Create Dailies & Daily out processes
