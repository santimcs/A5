# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import os
import pandas as pd
import datetime as dt
from datetime import date, timedelta, datetime
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

format_dict = {
     'price':'{:.2f}', 'change':'{:.2f}', '%change':'{:.2f}%', 'open':'{:.2f}',
     'high':'{:.2f}', 'low':'{:.2f}','volume':'{:,}','value(m)':'{:,}'
}

# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-09-10 20:36:48

# %%
#df_dailies = pd.read_csv('../data/dailies.csv')
df_dailies = pd.read_csv('../data/Price-Today.csv')
#df_dailies.rename(columns={'daily_volume':'value(m)'},inplace=True)
df_dailies.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
#df_dailies.loc[(df_dailies['value(m)'] == '-') ,df_dailies['value(m)']] = 0

df_dailies['value(m)'] = df_dailies['value(m)'].astype(float)
df_dailies['value(m)'] = round(df_dailies['value(m)'] / 1000,0)
df_dailies['value(m)'] = df_dailies['value(m)'].astype(int)
#df_dailies.dtypes

# %%
df_dailies.query("name == 'DELTA'").style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_45637">
#   <thead>
#     <tr>
#       <th id="T_45637_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_45637_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_45637_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_45637_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_45637_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_45637_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_45637_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_45637_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_45637_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_45637_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45637_row0_col0" class="data row0 col0" >DELTA</td>
#       <td id="T_45637_row0_col1" class="data row0 col1" >2025-09-10</td>
#       <td id="T_45637_row0_col2" class="data row0 col2" >148.00</td>
#       <td id="T_45637_row0_col3" class="data row0 col3" >2.50</td>
#       <td id="T_45637_row0_col4" class="data row0 col4" >1.72%</td>
#       <td id="T_45637_row0_col5" class="data row0 col5" >148.00</td>
#       <td id="T_45637_row0_col6" class="data row0 col6" >149.50</td>
#       <td id="T_45637_row0_col7" class="data row0 col7" >146.00</td>
#       <td id="T_45637_row0_col8" class="data row0 col8" >10,449,680</td>
#       <td id="T_45637_row0_col9" class="data row0 col9" >1,546</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['%change'],ascending=[False]).head(10).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5a4f">
#   <thead>
#     <tr>
#       <th id="T_d5a4f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d5a4f_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_d5a4f_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_d5a4f_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_d5a4f_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_d5a4f_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_d5a4f_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_d5a4f_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_d5a4f_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_d5a4f_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5a4f_row0_col0" class="data row0 col0" >TPIPL</td>
#       <td id="T_d5a4f_row0_col1" class="data row0 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row0_col2" class="data row0 col2" >0.84</td>
#       <td id="T_d5a4f_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_d5a4f_row0_col4" class="data row0 col4" >20.00%</td>
#       <td id="T_d5a4f_row0_col5" class="data row0 col5" >0.71</td>
#       <td id="T_d5a4f_row0_col6" class="data row0 col6" >0.86</td>
#       <td id="T_d5a4f_row0_col7" class="data row0 col7" >0.70</td>
#       <td id="T_d5a4f_row0_col8" class="data row0 col8" >343,809,779</td>
#       <td id="T_d5a4f_row0_col9" class="data row0 col9" >271</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row1_col0" class="data row1 col0" >SINGER</td>
#       <td id="T_d5a4f_row1_col1" class="data row1 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row1_col2" class="data row1 col2" >7.45</td>
#       <td id="T_d5a4f_row1_col3" class="data row1 col3" >0.50</td>
#       <td id="T_d5a4f_row1_col4" class="data row1 col4" >7.19%</td>
#       <td id="T_d5a4f_row1_col5" class="data row1 col5" >6.95</td>
#       <td id="T_d5a4f_row1_col6" class="data row1 col6" >8.15</td>
#       <td id="T_d5a4f_row1_col7" class="data row1 col7" >6.95</td>
#       <td id="T_d5a4f_row1_col8" class="data row1 col8" >31,044,730</td>
#       <td id="T_d5a4f_row1_col9" class="data row1 col9" >235</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row2_col0" class="data row2 col0" >PSL</td>
#       <td id="T_d5a4f_row2_col1" class="data row2 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row2_col2" class="data row2 col2" >7.20</td>
#       <td id="T_d5a4f_row2_col3" class="data row2 col3" >0.45</td>
#       <td id="T_d5a4f_row2_col4" class="data row2 col4" >6.67%</td>
#       <td id="T_d5a4f_row2_col5" class="data row2 col5" >6.85</td>
#       <td id="T_d5a4f_row2_col6" class="data row2 col6" >7.20</td>
#       <td id="T_d5a4f_row2_col7" class="data row2 col7" >6.75</td>
#       <td id="T_d5a4f_row2_col8" class="data row2 col8" >16,882,489</td>
#       <td id="T_d5a4f_row2_col9" class="data row2 col9" >119</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row3_col0" class="data row3 col0" >BGRIM</td>
#       <td id="T_d5a4f_row3_col1" class="data row3 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row3_col2" class="data row3 col2" >14.30</td>
#       <td id="T_d5a4f_row3_col3" class="data row3 col3" >0.80</td>
#       <td id="T_d5a4f_row3_col4" class="data row3 col4" >5.93%</td>
#       <td id="T_d5a4f_row3_col5" class="data row3 col5" >13.90</td>
#       <td id="T_d5a4f_row3_col6" class="data row3 col6" >14.30</td>
#       <td id="T_d5a4f_row3_col7" class="data row3 col7" >13.70</td>
#       <td id="T_d5a4f_row3_col8" class="data row3 col8" >43,106,609</td>
#       <td id="T_d5a4f_row3_col9" class="data row3 col9" >603</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row4_col0" class="data row4 col0" >RCL</td>
#       <td id="T_d5a4f_row4_col1" class="data row4 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row4_col2" class="data row4 col2" >28.25</td>
#       <td id="T_d5a4f_row4_col3" class="data row4 col3" >1.25</td>
#       <td id="T_d5a4f_row4_col4" class="data row4 col4" >4.63%</td>
#       <td id="T_d5a4f_row4_col5" class="data row4 col5" >27.25</td>
#       <td id="T_d5a4f_row4_col6" class="data row4 col6" >28.25</td>
#       <td id="T_d5a4f_row4_col7" class="data row4 col7" >27.25</td>
#       <td id="T_d5a4f_row4_col8" class="data row4 col8" >5,221,811</td>
#       <td id="T_d5a4f_row4_col9" class="data row4 col9" >146</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row5_col0" class="data row5 col0" >IMPACT</td>
#       <td id="T_d5a4f_row5_col1" class="data row5 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row5_col2" class="data row5 col2" >10.50</td>
#       <td id="T_d5a4f_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_d5a4f_row5_col4" class="data row5 col4" >3.96%</td>
#       <td id="T_d5a4f_row5_col5" class="data row5 col5" >10.10</td>
#       <td id="T_d5a4f_row5_col6" class="data row5 col6" >10.50</td>
#       <td id="T_d5a4f_row5_col7" class="data row5 col7" >10.10</td>
#       <td id="T_d5a4f_row5_col8" class="data row5 col8" >933,100</td>
#       <td id="T_d5a4f_row5_col9" class="data row5 col9" >10</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row6_col0" class="data row6 col0" >IVL</td>
#       <td id="T_d5a4f_row6_col1" class="data row6 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row6_col2" class="data row6 col2" >24.10</td>
#       <td id="T_d5a4f_row6_col3" class="data row6 col3" >0.90</td>
#       <td id="T_d5a4f_row6_col4" class="data row6 col4" >3.88%</td>
#       <td id="T_d5a4f_row6_col5" class="data row6 col5" >23.40</td>
#       <td id="T_d5a4f_row6_col6" class="data row6 col6" >24.50</td>
#       <td id="T_d5a4f_row6_col7" class="data row6 col7" >23.10</td>
#       <td id="T_d5a4f_row6_col8" class="data row6 col8" >32,846,268</td>
#       <td id="T_d5a4f_row6_col9" class="data row6 col9" >782</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row7_col0" class="data row7 col0" >TTA</td>
#       <td id="T_d5a4f_row7_col1" class="data row7 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row7_col2" class="data row7 col2" >4.50</td>
#       <td id="T_d5a4f_row7_col3" class="data row7 col3" >0.14</td>
#       <td id="T_d5a4f_row7_col4" class="data row7 col4" >3.21%</td>
#       <td id="T_d5a4f_row7_col5" class="data row7 col5" >4.38</td>
#       <td id="T_d5a4f_row7_col6" class="data row7 col6" >4.50</td>
#       <td id="T_d5a4f_row7_col7" class="data row7 col7" >4.38</td>
#       <td id="T_d5a4f_row7_col8" class="data row7 col8" >12,751,034</td>
#       <td id="T_d5a4f_row7_col9" class="data row7 col9" >57</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row8_col0" class="data row8 col0" >IRPC</td>
#       <td id="T_d5a4f_row8_col1" class="data row8 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row8_col2" class="data row8 col2" >1.32</td>
#       <td id="T_d5a4f_row8_col3" class="data row8 col3" >0.04</td>
#       <td id="T_d5a4f_row8_col4" class="data row8 col4" >3.12%</td>
#       <td id="T_d5a4f_row8_col5" class="data row8 col5" >1.28</td>
#       <td id="T_d5a4f_row8_col6" class="data row8 col6" >1.34</td>
#       <td id="T_d5a4f_row8_col7" class="data row8 col7" >1.27</td>
#       <td id="T_d5a4f_row8_col8" class="data row8 col8" >166,031,116</td>
#       <td id="T_d5a4f_row8_col9" class="data row8 col9" >218</td>
#     </tr>
#     <tr>
#       <td id="T_d5a4f_row9_col0" class="data row9 col0" >EA</td>
#       <td id="T_d5a4f_row9_col1" class="data row9 col1" >2025-09-10</td>
#       <td id="T_d5a4f_row9_col2" class="data row9 col2" >2.92</td>
#       <td id="T_d5a4f_row9_col3" class="data row9 col3" >0.08</td>
#       <td id="T_d5a4f_row9_col4" class="data row9 col4" >2.82%</td>
#       <td id="T_d5a4f_row9_col5" class="data row9 col5" >2.88</td>
#       <td id="T_d5a4f_row9_col6" class="data row9 col6" >2.92</td>
#       <td id="T_d5a4f_row9_col7" class="data row9 col7" >2.82</td>
#       <td id="T_d5a4f_row9_col8" class="data row9 col8" >140,882,128</td>
#       <td id="T_d5a4f_row9_col9" class="data row9 col9" >406</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['%change'],ascending=[True]).head(10).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_30e78">
#   <thead>
#     <tr>
#       <th id="T_30e78_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_30e78_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_30e78_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_30e78_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_30e78_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_30e78_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_30e78_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_30e78_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_30e78_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_30e78_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_30e78_row0_col0" class="data row0 col0" >ORI</td>
#       <td id="T_30e78_row0_col1" class="data row0 col1" >2025-09-10</td>
#       <td id="T_30e78_row0_col2" class="data row0 col2" >2.88</td>
#       <td id="T_30e78_row0_col3" class="data row0 col3" >-0.12</td>
#       <td id="T_30e78_row0_col4" class="data row0 col4" >-4.00%</td>
#       <td id="T_30e78_row0_col5" class="data row0 col5" >3.02</td>
#       <td id="T_30e78_row0_col6" class="data row0 col6" >3.04</td>
#       <td id="T_30e78_row0_col7" class="data row0 col7" >2.84</td>
#       <td id="T_30e78_row0_col8" class="data row0 col8" >14,886,724</td>
#       <td id="T_30e78_row0_col9" class="data row0 col9" >43</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row1_col0" class="data row1 col0" >CENTEL</td>
#       <td id="T_30e78_row1_col1" class="data row1 col1" >2025-09-10</td>
#       <td id="T_30e78_row1_col2" class="data row1 col2" >32.00</td>
#       <td id="T_30e78_row1_col3" class="data row1 col3" >-1.25</td>
#       <td id="T_30e78_row1_col4" class="data row1 col4" >-3.76%</td>
#       <td id="T_30e78_row1_col5" class="data row1 col5" >33.25</td>
#       <td id="T_30e78_row1_col6" class="data row1 col6" >33.25</td>
#       <td id="T_30e78_row1_col7" class="data row1 col7" >31.75</td>
#       <td id="T_30e78_row1_col8" class="data row1 col8" >4,888,133</td>
#       <td id="T_30e78_row1_col9" class="data row1 col9" >156</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row2_col0" class="data row2 col0" >BA</td>
#       <td id="T_30e78_row2_col1" class="data row2 col1" >2025-09-10</td>
#       <td id="T_30e78_row2_col2" class="data row2 col2" >13.80</td>
#       <td id="T_30e78_row2_col3" class="data row2 col3" >-0.50</td>
#       <td id="T_30e78_row2_col4" class="data row2 col4" >-3.50%</td>
#       <td id="T_30e78_row2_col5" class="data row2 col5" >13.90</td>
#       <td id="T_30e78_row2_col6" class="data row2 col6" >13.90</td>
#       <td id="T_30e78_row2_col7" class="data row2 col7" >13.60</td>
#       <td id="T_30e78_row2_col8" class="data row2 col8" >12,425,980</td>
#       <td id="T_30e78_row2_col9" class="data row2 col9" >171</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row3_col0" class="data row3 col0" >COM7</td>
#       <td id="T_30e78_row3_col1" class="data row3 col1" >2025-09-10</td>
#       <td id="T_30e78_row3_col2" class="data row3 col2" >24.40</td>
#       <td id="T_30e78_row3_col3" class="data row3 col3" >-0.85</td>
#       <td id="T_30e78_row3_col4" class="data row3 col4" >-3.37%</td>
#       <td id="T_30e78_row3_col5" class="data row3 col5" >25.00</td>
#       <td id="T_30e78_row3_col6" class="data row3 col6" >25.25</td>
#       <td id="T_30e78_row3_col7" class="data row3 col7" >24.20</td>
#       <td id="T_30e78_row3_col8" class="data row3 col8" >27,089,935</td>
#       <td id="T_30e78_row3_col9" class="data row3 col9" >664</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row4_col0" class="data row4 col0" >TISCO</td>
#       <td id="T_30e78_row4_col1" class="data row4 col1" >2025-09-10</td>
#       <td id="T_30e78_row4_col2" class="data row4 col2" >99.50</td>
#       <td id="T_30e78_row4_col3" class="data row4 col3" >-3.00</td>
#       <td id="T_30e78_row4_col4" class="data row4 col4" >-2.93%</td>
#       <td id="T_30e78_row4_col5" class="data row4 col5" >101.00</td>
#       <td id="T_30e78_row4_col6" class="data row4 col6" >101.00</td>
#       <td id="T_30e78_row4_col7" class="data row4 col7" >99.00</td>
#       <td id="T_30e78_row4_col8" class="data row4 col8" >12,066,856</td>
#       <td id="T_30e78_row4_col9" class="data row4 col9" >1,204</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row5_col0" class="data row5 col0" >THG</td>
#       <td id="T_30e78_row5_col1" class="data row5 col1" >2025-09-10</td>
#       <td id="T_30e78_row5_col2" class="data row5 col2" >6.70</td>
#       <td id="T_30e78_row5_col3" class="data row5 col3" >-0.20</td>
#       <td id="T_30e78_row5_col4" class="data row5 col4" >-2.90%</td>
#       <td id="T_30e78_row5_col5" class="data row5 col5" >6.95</td>
#       <td id="T_30e78_row5_col6" class="data row5 col6" >6.95</td>
#       <td id="T_30e78_row5_col7" class="data row5 col7" >6.70</td>
#       <td id="T_30e78_row5_col8" class="data row5 col8" >2,166,135</td>
#       <td id="T_30e78_row5_col9" class="data row5 col9" >15</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row6_col0" class="data row6 col0" >TTW</td>
#       <td id="T_30e78_row6_col1" class="data row6 col1" >2025-09-10</td>
#       <td id="T_30e78_row6_col2" class="data row6 col2" >9.00</td>
#       <td id="T_30e78_row6_col3" class="data row6 col3" >-0.25</td>
#       <td id="T_30e78_row6_col4" class="data row6 col4" >-2.70%</td>
#       <td id="T_30e78_row6_col5" class="data row6 col5" >9.00</td>
#       <td id="T_30e78_row6_col6" class="data row6 col6" >9.00</td>
#       <td id="T_30e78_row6_col7" class="data row6 col7" >8.90</td>
#       <td id="T_30e78_row6_col8" class="data row6 col8" >5,750,165</td>
#       <td id="T_30e78_row6_col9" class="data row6 col9" >52</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row7_col0" class="data row7 col0" >BEM</td>
#       <td id="T_30e78_row7_col1" class="data row7 col1" >2025-09-10</td>
#       <td id="T_30e78_row7_col2" class="data row7 col2" >5.40</td>
#       <td id="T_30e78_row7_col3" class="data row7 col3" >-0.15</td>
#       <td id="T_30e78_row7_col4" class="data row7 col4" >-2.70%</td>
#       <td id="T_30e78_row7_col5" class="data row7 col5" >5.55</td>
#       <td id="T_30e78_row7_col6" class="data row7 col6" >5.60</td>
#       <td id="T_30e78_row7_col7" class="data row7 col7" >5.40</td>
#       <td id="T_30e78_row7_col8" class="data row7 col8" >36,638,554</td>
#       <td id="T_30e78_row7_col9" class="data row7 col9" >201</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row8_col0" class="data row8 col0" >HMPRO</td>
#       <td id="T_30e78_row8_col1" class="data row8 col1" >2025-09-10</td>
#       <td id="T_30e78_row8_col2" class="data row8 col2" >7.65</td>
#       <td id="T_30e78_row8_col3" class="data row8 col3" >-0.20</td>
#       <td id="T_30e78_row8_col4" class="data row8 col4" >-2.55%</td>
#       <td id="T_30e78_row8_col5" class="data row8 col5" >7.70</td>
#       <td id="T_30e78_row8_col6" class="data row8 col6" >7.75</td>
#       <td id="T_30e78_row8_col7" class="data row8 col7" >7.65</td>
#       <td id="T_30e78_row8_col8" class="data row8 col8" >24,451,057</td>
#       <td id="T_30e78_row8_col9" class="data row8 col9" >188</td>
#     </tr>
#     <tr>
#       <td id="T_30e78_row9_col0" class="data row9 col0" >HFT</td>
#       <td id="T_30e78_row9_col1" class="data row9 col1" >2025-09-10</td>
#       <td id="T_30e78_row9_col2" class="data row9 col2" >4.14</td>
#       <td id="T_30e78_row9_col3" class="data row9 col3" >-0.10</td>
#       <td id="T_30e78_row9_col4" class="data row9 col4" >-2.36%</td>
#       <td id="T_30e78_row9_col5" class="data row9 col5" >4.20</td>
#       <td id="T_30e78_row9_col6" class="data row9 col6" >4.20</td>
#       <td id="T_30e78_row9_col7" class="data row9 col7" >4.14</td>
#       <td id="T_30e78_row9_col8" class="data row9 col8" >759,812</td>
#       <td id="T_30e78_row9_col9" class="data row9 col9" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_dailies.sort_values(['value(m)'],ascending=[False]).head(10).style.format(format_dict).hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_2887f">
#   <thead>
#     <tr>
#       <th id="T_2887f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2887f_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_2887f_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_2887f_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_2887f_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_2887f_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_2887f_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_2887f_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_2887f_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_2887f_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2887f_row0_col0" class="data row0 col0" >PTT</td>
#       <td id="T_2887f_row0_col1" class="data row0 col1" >2025-09-10</td>
#       <td id="T_2887f_row0_col2" class="data row0 col2" >32.25</td>
#       <td id="T_2887f_row0_col3" class="data row0 col3" >-0.25</td>
#       <td id="T_2887f_row0_col4" class="data row0 col4" >-0.77%</td>
#       <td id="T_2887f_row0_col5" class="data row0 col5" >32.50</td>
#       <td id="T_2887f_row0_col6" class="data row0 col6" >32.75</td>
#       <td id="T_2887f_row0_col7" class="data row0 col7" >32.25</td>
#       <td id="T_2887f_row0_col8" class="data row0 col8" >78,630,011</td>
#       <td id="T_2887f_row0_col9" class="data row0 col9" >2,557</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row1_col0" class="data row1 col0" >KTB</td>
#       <td id="T_2887f_row1_col1" class="data row1 col1" >2025-09-10</td>
#       <td id="T_2887f_row1_col2" class="data row1 col2" >25.75</td>
#       <td id="T_2887f_row1_col3" class="data row1 col3" >-0.25</td>
#       <td id="T_2887f_row1_col4" class="data row1 col4" >-0.96%</td>
#       <td id="T_2887f_row1_col5" class="data row1 col5" >25.75</td>
#       <td id="T_2887f_row1_col6" class="data row1 col6" >26.25</td>
#       <td id="T_2887f_row1_col7" class="data row1 col7" >25.50</td>
#       <td id="T_2887f_row1_col8" class="data row1 col8" >68,442,014</td>
#       <td id="T_2887f_row1_col9" class="data row1 col9" >1,775</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row2_col0" class="data row2 col0" >DELTA</td>
#       <td id="T_2887f_row2_col1" class="data row2 col1" >2025-09-10</td>
#       <td id="T_2887f_row2_col2" class="data row2 col2" >148.00</td>
#       <td id="T_2887f_row2_col3" class="data row2 col3" >2.50</td>
#       <td id="T_2887f_row2_col4" class="data row2 col4" >1.72%</td>
#       <td id="T_2887f_row2_col5" class="data row2 col5" >148.00</td>
#       <td id="T_2887f_row2_col6" class="data row2 col6" >149.50</td>
#       <td id="T_2887f_row2_col7" class="data row2 col7" >146.00</td>
#       <td id="T_2887f_row2_col8" class="data row2 col8" >10,449,680</td>
#       <td id="T_2887f_row2_col9" class="data row2 col9" >1,546</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row3_col0" class="data row3 col0" >ADVANC</td>
#       <td id="T_2887f_row3_col1" class="data row3 col1" >2025-09-10</td>
#       <td id="T_2887f_row3_col2" class="data row3 col2" >290.00</td>
#       <td id="T_2887f_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_2887f_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_2887f_row3_col5" class="data row3 col5" >290.00</td>
#       <td id="T_2887f_row3_col6" class="data row3 col6" >292.00</td>
#       <td id="T_2887f_row3_col7" class="data row3 col7" >288.00</td>
#       <td id="T_2887f_row3_col8" class="data row3 col8" >5,144,629</td>
#       <td id="T_2887f_row3_col9" class="data row3 col9" >1,493</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row4_col0" class="data row4 col0" >BDMS</td>
#       <td id="T_2887f_row4_col1" class="data row4 col1" >2025-09-10</td>
#       <td id="T_2887f_row4_col2" class="data row4 col2" >21.10</td>
#       <td id="T_2887f_row4_col3" class="data row4 col3" >0.40</td>
#       <td id="T_2887f_row4_col4" class="data row4 col4" >1.93%</td>
#       <td id="T_2887f_row4_col5" class="data row4 col5" >20.90</td>
#       <td id="T_2887f_row4_col6" class="data row4 col6" >21.20</td>
#       <td id="T_2887f_row4_col7" class="data row4 col7" >20.90</td>
#       <td id="T_2887f_row4_col8" class="data row4 col8" >62,323,377</td>
#       <td id="T_2887f_row4_col9" class="data row4 col9" >1,312</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row5_col0" class="data row5 col0" >BBL</td>
#       <td id="T_2887f_row5_col1" class="data row5 col1" >2025-09-10</td>
#       <td id="T_2887f_row5_col2" class="data row5 col2" >150.00</td>
#       <td id="T_2887f_row5_col3" class="data row5 col3" >-2.50</td>
#       <td id="T_2887f_row5_col4" class="data row5 col4" >-1.64%</td>
#       <td id="T_2887f_row5_col5" class="data row5 col5" >150.50</td>
#       <td id="T_2887f_row5_col6" class="data row5 col6" >151.50</td>
#       <td id="T_2887f_row5_col7" class="data row5 col7" >150.00</td>
#       <td id="T_2887f_row5_col8" class="data row5 col8" >8,329,853</td>
#       <td id="T_2887f_row5_col9" class="data row5 col9" >1,252</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row6_col0" class="data row6 col0" >TISCO</td>
#       <td id="T_2887f_row6_col1" class="data row6 col1" >2025-09-10</td>
#       <td id="T_2887f_row6_col2" class="data row6 col2" >99.50</td>
#       <td id="T_2887f_row6_col3" class="data row6 col3" >-3.00</td>
#       <td id="T_2887f_row6_col4" class="data row6 col4" >-2.93%</td>
#       <td id="T_2887f_row6_col5" class="data row6 col5" >101.00</td>
#       <td id="T_2887f_row6_col6" class="data row6 col6" >101.00</td>
#       <td id="T_2887f_row6_col7" class="data row6 col7" >99.00</td>
#       <td id="T_2887f_row6_col8" class="data row6 col8" >12,066,856</td>
#       <td id="T_2887f_row6_col9" class="data row6 col9" >1,204</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row7_col0" class="data row7 col0" >KBANK</td>
#       <td id="T_2887f_row7_col1" class="data row7 col1" >2025-09-10</td>
#       <td id="T_2887f_row7_col2" class="data row7 col2" >168.50</td>
#       <td id="T_2887f_row7_col3" class="data row7 col3" >-2.50</td>
#       <td id="T_2887f_row7_col4" class="data row7 col4" >-1.46%</td>
#       <td id="T_2887f_row7_col5" class="data row7 col5" >169.50</td>
#       <td id="T_2887f_row7_col6" class="data row7 col6" >169.50</td>
#       <td id="T_2887f_row7_col7" class="data row7 col7" >168.00</td>
#       <td id="T_2887f_row7_col8" class="data row7 col8" >6,924,321</td>
#       <td id="T_2887f_row7_col9" class="data row7 col9" >1,168</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row8_col0" class="data row8 col0" >TRUE</td>
#       <td id="T_2887f_row8_col1" class="data row8 col1" >2025-09-10</td>
#       <td id="T_2887f_row8_col2" class="data row8 col2" >11.30</td>
#       <td id="T_2887f_row8_col3" class="data row8 col3" >-0.10</td>
#       <td id="T_2887f_row8_col4" class="data row8 col4" >-0.88%</td>
#       <td id="T_2887f_row8_col5" class="data row8 col5" >11.40</td>
#       <td id="T_2887f_row8_col6" class="data row8 col6" >11.50</td>
#       <td id="T_2887f_row8_col7" class="data row8 col7" >11.20</td>
#       <td id="T_2887f_row8_col8" class="data row8 col8" >100,030,433</td>
#       <td id="T_2887f_row8_col9" class="data row8 col9" >1,135</td>
#     </tr>
#     <tr>
#       <td id="T_2887f_row9_col0" class="data row9 col0" >CPALL</td>
#       <td id="T_2887f_row9_col1" class="data row9 col1" >2025-09-10</td>
#       <td id="T_2887f_row9_col2" class="data row9 col2" >47.75</td>
#       <td id="T_2887f_row9_col3" class="data row9 col3" >-0.50</td>
#       <td id="T_2887f_row9_col4" class="data row9 col4" >-1.04%</td>
#       <td id="T_2887f_row9_col5" class="data row9 col5" >48.25</td>
#       <td id="T_2887f_row9_col6" class="data row9 col6" >48.50</td>
#       <td id="T_2887f_row9_col7" class="data row9 col7" >47.50</td>
#       <td id="T_2887f_row9_col8" class="data row9 col8" >18,639,396</td>
#       <td id="T_2887f_row9_col9" class="data row9 col9" >892</td>
#     </tr>
#   </

# %%
# Get the current time
current_time = datetime.now()
# Format the time to remove milliseconds
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(formatted_time)
# Out:
# 2025-09-10 20:36:49
