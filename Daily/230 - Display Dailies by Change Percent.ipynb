# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import os
import pandas as pd
import datetime as dt
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

data_path = "../data/"
csv_path = os.path.join(os.path.expanduser("~"), "iCloudDrive")
one_path = os.path.join(os.path.expanduser("~"), "OneDrive","Documents","Data")
osd_path = os.path.join(os.path.expanduser("~"),"OneDrive","Documents","obsidian-git-sync","Data")
dts_path = os.path.join(os.path.expanduser("~"),"Downloads","Datasets")

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

format_dict = {
     'price':'{:.2f}', 'change':'{:.2f}', '%change':'{:.2f}%', 'open':'{:.2f}',
     'high':'{:.2f}', 'low':'{:.2f}','volume':'{:,}','value(m)':'{:,}'
}

today = date.today()
today
# Out:
# datetime.date(2025, 1, 17)

# %%
#df_dailies = pd.read_csv('../data/dailies.csv')
df_dailies = pd.read_csv('../data/Price-Today.csv')
#df_dailies.rename(columns={'daily_volume':'value(m)'},inplace=True)
df_dailies.columns
# Out:
# Index(['name', 'date', 'price', 'change', '%change', 'open', 'high', 'low',
#        'volume', 'value(m)'],
#       dtype='object')

# %%
#df_dailies.loc[(df_dailies['value(m)'] == '-') ,df_dailies['value(m)']] = 0

df_dailies['value(m)'] = df_dailies['value(m)'].astype(float)
df_dailies['value(m)'] = round(df_dailies['value(m)'] / 1000,0)
df_dailies['value(m)'] = df_dailies['value(m)'].astype(int)
df_dailies.dtypes
# Out:
# name         object
# date         object
# price       float64
# change      float64
# %change     float64
# open        float64
# high        float64
# low         float64
# volume        int64
# value(m)      int32
# dtype: object

# %%
df_dailies.query("name == 'DELTA'").style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0e83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0e83_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_e0e83_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_e0e83_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_e0e83_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_e0e83_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_e0e83_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_e0e83_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_e0e83_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_e0e83_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_e0e83_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df_dailies.sort_values(['%change'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76a8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76a8b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_76a8b_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_76a8b_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_76a8b_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_76a8b_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_76a8b_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_76a8b_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_76a8b_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_76a8b_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_76a8b_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df_dailies.sort_values(['%change'],ascending=[True]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9edbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9edbe_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_9edbe_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_9edbe_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_9edbe_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_9edbe_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_9edbe_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_9edbe_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_9edbe_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_9edbe_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_9edbe_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df_dailies.sort_values(['value(m)'],ascending=[False]).head(10).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_75dc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75dc8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_75dc8_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_75dc8_level0_col2" class="col_heading level0 col2" >price</th>
#       <th id="T_75dc8_level0_col3" class="col_heading level0 col3" >change</th>
#       <th id="T_75dc8_level0_col4" class="col_heading level0 col4" >%change</th>
#       <th id="T_75dc8_level0_col5" class="col_heading level0 col5" >open</th>
#       <th id="T_75dc8_level0_col6" class="col_heading level0 col6" >high</th>
#       <th id="T_75dc8_level0_col7" class="col_heading level0 col7" >low</th>
#       <th id="T_75dc8_level0_col8" class="col_heading level0 col8" >volume</th>
#       <th id="T_75dc8_level0_col9" class="col_heading level0 col9" >value(m)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
