# %% [markdown]
# ### Modify SET index then run all

# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### Output files: 5-day-average, extremes

# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format

today = date.today()
today
# Out:
# datetime.date(2024, 1, 2)

# %%
num_business_days = BDay(3)
yesterday = today - num_business_days
yesterday = yesterday.date()
today, yesterday
# Out:
# (datetime.date(2024, 1, 2), datetime.date(2023, 12, 28))

# %%
#yesterday = date(2023, 3, 3)
yesterday
# Out:
# datetime.date(2023, 12, 28)

# %%
value = 1433.38
sqlIns = f"""
INSERT INTO setindex VALUES('{today}', {value})
"""
print(sqlIns)
# Out:
# INSERT INTO setindex VALUES('2024-01-02', 1433.38)

# %%
rp = const.execute(sqlIns)
rp.rowcount
# Out:
# 1

# %%
sql = """SELECT * FROM setindex ORDER BY date DESC LIMIT 2"""
df_tmp = pd.read_sql(sql, const)
df_tmp
# Out:
#          date  setindex
# 0  2024-01-02   1433.38
# 1  2023-12-28   1415.85

# %%
###sqlUpd = """UPDATE setindex SET date='2023-12-08' WHERE date = '2023-12-11'"""
###print(sqlUpd)

# %%
###rp = const.execute(sqlUpd)
###rp.rowcount

# %%
###sqlDel = """DELETE FROM setindex WHERE date='2023-12-11'"""
###print(sqlDel)

# %%
###rp = const.execute(sqlDel)
###rp.rowcount

# %% [markdown]
# ### Restart and run all cells

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}', 'volbuy':'{:,}',   
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}',
    'opnp':'{:.2f}','price_x':'{:.2f}','price_y':'{:.2f}',
    'price_today':'{:.2f}','price_yesterday':'{:.2f}',   
    'date':'{:%Y-%m-%d}',
    
    'price_mean':'{:.2f}','price_today':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}','dividend':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_mean':'{:,}','qty_today':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}',   
    'value(m)':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
#sql = sql % yesterday
print(sql)

prices = pd.read_sql(sql, const)
#prices.sample(5).style.format(format_dict)
prices.shape
# Out:
# SELECT *
# FROM price
# WHERE date = '2023-12-28'
# ORDER BY name
# (188, 7)

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f80cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >market</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >min_price</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >paid_up</th>
#       <th class="col_heading level0 col9" >market_cap</th>
#       <th class="col_heading level0 col10" >daily_volume</th>
#       <th class="col_heading level0 col11" >beta</th>
#       <th class="col_heading level0 col12" >ticker_id</th>
#       <th class="col_heading level0 col13" >created_at</th>
#       <th class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f80cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f80cc_row0_col0" class="data row0 col0" >718</td>
#       <td id="T_f80cc_row0_col1" class="data row0 col1" >ACE</td>
#       <td id="T_f80cc_row0_col2" class="data row0 col2" >SET100 / SETTHSI    </td>
#       <td id="T_f80cc_row0_col3" class="data row0 col3" >2.56</td>
#       <td id="T_f80cc_row0_col4" class="data row0 col4" >3.42</td>
#       <td id="T_f80cc_row0_col5" class="data row0 col5" >2.52</td>
#       <td id="T_f80cc_row0_col6" class="data row0 col6" >17.72</td>
#       <td id="T_f80cc_row0_col7" class="data row0 col7" >1.82</td>
#       <td id="T_f80cc_row0_col8" class="data row0 col8" >5,088.00</td>
#       <td id="T_f80cc_row0_col9" class="data row0 col9" >26,050.56</td>
#       <td id="T_f80cc_row0_col10" class="data row0 col10" >54.630000</td>
#       <td id="T_f80cc_row0_col11" class="data row0 col11" >0.92</td>
#       <td id="T_f80cc_row0_col12" class="data row0 col12" >667</td>
#       <td id="T_f80cc_row0_col13" class="data row0 col13" >2022-05-17</td>
#       <td id="T_f80cc_row0_col14" class="data row0 col14" >2023-01-31</td>
#     </tr>
#     <tr>
#       <th id="T_f80cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f80cc_row1_col0" class="data row1 col0" >719</td>
#       <td id="T_f80cc_row1_col1" class="data row1 col1" >ADVANC</td>
#       <td id="T_f80cc_row1_col2" class="data row1 col2" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_f80cc_row1_col3" class="data row1 col3" >197.50</td>
#       <td id="T_f80cc_row1_col4" class="data row1 col4" >242.00</td>
#       <td id="T_f80cc_row1_col5" class="data row1 col5" >181.50</td>
#       <td id="T_f80cc_row1_col6" class="data row1 col6" >23.03</td>
#       <td id="T_f80cc_row1_col7" class="data row1 col7" >7.52</td>
#       <td id="T_f80cc_row1_col8" class="data row1 col8" >2,974.21</td>
#       <td id="T_f80cc_row1_col9" class="data row1 col9" >587,406.42</td>
#       <td id="T_f80cc_row1_col10" class="data row1 col10" >954.230000</td>
#       <td id="T_f80cc_row1_col11" class="data row1 col11" >0.79</td>
#       <td id="T_f80cc_row1_col12" class="data row1 col12" >8</td>
#       <td id="T_f80cc_row1_col13" class="data row1 col13" >2022-05-17</td>
#       <td id="T_f80cc_row1_col14" class="data row1 col14" >2023-01-31</td>
#     </tr>
#     <tr>
#       <th id="T_f80cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f80cc_row2_col0" class="data row2 col0" >720</td>
#       <td id="T_f80cc_row2_col1" class="data row2 col1" >AEONTS</td>
#       <td id="T_f80cc_row2_col2" class="data row2 col2" >SET    </td>
#       <td id="T_f80cc_row2_col3" class="data row2 col3" >196.50</td>
#       <td id="T_f80cc_row2_col4" class="data row2 col4" >209.00</td>
#       <td id="T_f80cc_row2_col5" class="data row2 col5" >152.00</td>
#       <td id="T_f80cc_row2_col6" class="data row2 col6" >12.18</td>
#       <td id="T_f80cc_row2_col7" class="data row2 col7" >2.26</td>
#       <td id="T_f80cc_row2_col8" class="data row2 col8" >250.00</td>
#       <td id="T_f80cc_row2_col9" class="data row2 col9" >49,125.00</td>
#       <td id="T_f80cc_row2_col10" class="data row2 col10" >100.950000</td>
#       <td id="T_f80cc_row2_col11" class="data row2 col11" >1.15</td>
#       <td id="T_f80cc_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_f80cc_row2_col13" class="data row2 col13" >2022-05-17</td>
#       <td id="T_f80cc_row2_col14" class="data row2 col14" >2023-01-31</td>
#     </tr>
#     <tr>
#       <th id="T_f80cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f80cc_row3_col0" class="data row3 col0" >721</td>
#       <td id="T_f80cc_row3_col1" class="data row3 col1" >AH</td>
#       <td id="T_f80cc_row3_col2" class="data row3 col2" >sSET / SETTHSI    </td>
#       <td id="T_f80cc_row3_col3" class="data row3 col3" >32.50</td>
#       <td id="T_f80cc_row3_col4" class="data row3 col4" >35.75</td>
#       <td id="T_f80cc_row3_col5" class="data row3 col5" >19.40</td>
#       <td id="T_f80cc_row3_col6" class="data row3 col6" >7.48</td>
#       <td id="T_f80cc_row3_col7" class="data row3 col7" >1.21</td>
#       <td id="T_f80cc_row3_col8" class="data row3 col8" >354.84</td>
#       <td id="T_f80cc_row3_col9" class="data row3 col9" >11,532.37</td>
#       <td id="T_f80cc_row3_col10" class="data row3 col10" >70.310000</td>
#       <td id="T_f80cc_row3_col11" class="data row3 col11" >1.51</td>
#       <td id="T_f80cc_row3_col12" class="data row3 col12" >11</td>
#       <td id="T_f80cc_row3_col13" class="data row3 col13" >2022-05-17</td>
#       <td id="T_f80cc_row3_col14" class="data row3 col14" >2023-01-31</td>
#     </tr>
#     <tr>
#       <th id="T_f80cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f80cc_row4_col0" class="data row4 col0" >722</td>
#       <td id="T_f80cc_row4_col1" class="data row4 col1" >AIE</td>
#       <td id="T_f80cc_row4_col2" class="data row4 col2" >sSET    </td>
#       <td id="T_f80cc_row4_col3" class="data row4 col3" >2.82</td>
#       <td id="T_f80cc_row4_col4" class="data row4 col4" >5.10</td>
#       <td id="T_f80cc_row4_col5" class="data row4 col5" >2.56</td>
#       <td id="T_f80cc_row4_col6" class="data row4 col6" >21.16</td>
#       <td id="T_f80cc_row4_col7" class="data row4 col7" >1.83</td>
#       <td id="T_f80cc_row4_col8" class="data row4 col8" >1,326.61</td>
#       <td id="T_f80cc_row4_col9" class="data row4 col9" >3,741.05</td>
#       <td id="T_f80cc_row4_col10" class="data row4 col10" >7.190000</td>
#       <td id="T_f80cc_row4_col11" class="data row4 col11" >1.17</td>
#       <td id="T_f80cc_row4_col12" class="data row4 col12" >691</td>
#       <td id="T_f80cc_row4_col13" class="data row4 col13" >2022-05-17</td>
#       <td id="T_f80cc_row4_col14" class="data row4 col14" >2023-01-31</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(prices, stocks, on="name", how="inner")
df_merge.drop(columns=['id','ticker_id','created_at','updated_at','paid_up','market_cap'],inplace=True)
#df_merge.sample(5).style.format(format_dict)
df_merge.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2974a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2974a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2974a_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_2974a_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_2974a_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_2974a_row0_col3" class="data row0 col3" >1.54</td>
#       <td id="T_2974a_row0_col4" class="data row0 col4" >1.50</td>
#       <td id="T_2974a_row0_col5" class="data row0 col5" >8,608,162</td>
#       <td id="T_2974a_row0_col6" class="data row0 col6" >1.51</td>
#       <td id="T_2974a_row0_col7" class="data row0 col7" >SET100 / SETTHSI    </td>
#       <td id="T_2974a_row0_col8" class="data row0 col8" >2.56</td>
#       <td id="T_2974a_row0_col9" class="data row0 col9" >3.42</td>
#       <td id="T_2974a_row0_col10" class="data row0 col10" >2.52</td>
#       <td id="T_2974a_row0_col11" class="data row0 col11" >17.72</td>
#       <td id="T_2974a_row0_col12" class="data row0 col12" >1.82</td>
#       <td id="T_2974a_row0_col13" class="data row0 col13" >54.630000</td>
#       <td id="T_2974a_row0_col14" class="data row0 col14" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2974a_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_2974a_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_2974a_row1_col2" class="data row1 col2" >217.00</td>
#       <td id="T_2974a_row1_col3" class="data row1 col3" >219.00</td>
#       <td id="T_2974a_row1_col4" class="data row1 col4" >216.00</td>
#       <td id="T_2974a_row1_col5" class="data row1 col5" >6,051,288</td>
#       <td id="T_2974a_row1_col6" class="data row1 col6" >219.00</td>
#       <td id="T_2974a_row1_col7" class="data row1 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_2974a_row1_col8" class="data row1 col8" >197.50</td>
#       <td id="T_2974a_row1_col9" class="data row1 col9" >242.00</td>
#       <td id="T_2974a_row1_col10" class="data row1 col10" >181.50</td>
#       <td id="T_2974a_row1_col11" class="data row1 col11" >23.03</td>
#       <td id="T_2974a_row1_col12" class="data row1 col12" >7.52</td>
#       <td id="T_2974a_row1_col13" class="data row1 col13" >954.230000</td>
#       <td id="T_2974a_row1_col14" class="data row1 col14" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2974a_row2_col0" class="data row2 col0" >AEONTS</td>
#       <td id="T_2974a_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_2974a_row2_col2" class="data row2 col2" >160.00</td>
#       <td id="T_2974a_row2_col3" class="data row2 col3" >160.00</td>
#       <td id="T_2974a_row2_col4" class="data row2 col4" >152.00</td>
#       <td id="T_2974a_row2_col5" class="data row2 col5" >215,899</td>
#       <td id="T_2974a_row2_col6" class="data row2 col6" >152.00</td>
#       <td id="T_2974a_row2_col7" class="data row2 col7" >SET    </td>
#       <td id="T_2974a_row2_col8" class="data row2 col8" >196.50</td>
#       <td id="T_2974a_row2_col9" class="data row2 col9" >209.00</td>
#       <td id="T_2974a_row2_col10" class="data row2 col10" >152.00</td>
#       <td id="T_2974a_row2_col11" class="data row2 col11" >12.18</td>
#       <td id="T_2974a_row2_col12" class="data row2 col12" >2.26</td>
#       <td id="T_2974a_row2_col13" class="data row2 col13" >100.950000</td>
#       <td id="T_2974a_row2_col14" class="data row2 col14" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2974a_row3_col0" class="data row3 col0" >AH</td>
#       <td id="T_2974a_row3_col1" class="data row3 col1" >2023-12-28</td>
#       <td id="T_2974a_row3_col2" class="data row3 col2" >28.00</td>
#       <td id="T_2974a_row3_col3" class="data row3 col3" >28.00</td>
#       <td id="T_2974a_row3_col4" class="data row3 col4" >27.50</td>
#       <td id="T_2974a_row3_col5" class="data row3 col5" >933,730</td>
#       <td id="T_2974a_row3_col6" class="data row3 col6" >27.75</td>
#       <td id="T_2974a_row3_col7" class="data row3 col7" >sSET / SETTHSI    </td>
#       <td id="T_2974a_row3_col8" class="data row3 col8" >32.50</td>
#       <td id="T_2974a_row3_col9" class="data row3 col9" >35.75</td>
#       <td id="T_2974a_row3_col10" class="data row3 col10" >19.40</td>
#       <td id="T_2974a_row3_col11" class="data row3 col11" >7.48</td>
#       <td id="T_2974a_row3_col12" class="data row3 col12" >1.21</td>
#       <td id="T_2974a_row3_col13" class="data row3 col13" >70.310000</td>
#       <td id="T_2974a_row3_col14" class="data row3 col14" >1.51</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2974a_row4_col0" class="data row4 col0" >AIMIRT</td>
#       <td id="T_2974a_row4_col1" class="data row4 col1" >2023-12-28</td>
#       <td id="T_2974a_row4_col2" class="data row4 col2" >10.40</td>
#       <td id="T_2974a_row4_col3" class="data row4 col3" >10.50</td>
#       <td id="T_2974a_row4_col4" class="data row4 col4" >10.40</td>
#       <td id="T_2974a_row4_col5" class="data row4 col5" >196,901</td>
#       <td id="T_2974a_row4_col6" class="data row4 col6" >10.50</td>
#       <td id="T_2974a_row4_col7" class="data row4 col7" >SET    </td>
#       <td id="T_2974a_row4_col8" class="data row4 col8" >12.30</td>
#       <td id="T_2974a_row4_col9" class="data row4 col9" >13.00</td>
#       <td id="T_2974a_row4_col10" class="data row4 col10" >11.70</td>
#       <td id="T_2974a_row4_col11" class="data row4 col11" >999.99</td>
#       <td id="T_2974a_row4_col12" class="data row4 col12" >1.00</td>
#       <td id="T_2974a_row4_col13" class="data row4 col13" >2.580000</td>
#       <td id="T_2974a_row4_col14" class="data row4 col14" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2974a_row5_col0" class="data row5 col0" >AIT</td>
#       <td id="T_2974a_row5_col1" class="data row5 col1" >2023-12-28</td>
#       <td id="T_2974a_row5_col2" class="data row5 col2" >3.78</td>
#       <td id="T_2974a_row5_col3" class="data row5 col3" >3.80</td>
#       <td id="T_2974a_row5_col4" class="data row5 col4" >3.76</td>
#       <td id="T_2974a_row5_col5" class="data row5 col5" >643,188</td>
#       <td id="T_2974a_row5_col6" class="data row5 col6" >3.78</td>
#       <td id="T_2974a_row5_col7" class="data row5 col7" >sSET    </td>
#       <td id="T_2974a_row5_col8" class="data row5 col8" >6.70</td>
#       <td id="T_2974a_row5_col9" class="data row5 col9" >8.35</td>
#       <td id="T_2974a_row5_col10" class="data row5 col10" >5.40</td>
#       <td id="T_2974a_row5_col11" class="data row5 col11" >15.32</td>
#       <td id="T_2974a_row5_col12" class="data row5 col12" >2.46</td>
#       <td id="T_2974a_row5_col13" class="data row5 col13" >40.180000</td>
#       <td id="T_2974a_row5_col14" class="data row5 col14" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_2974a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2974a_row6_col0" class="data row6 col0" >AJ</td>
#       <td id="T_2974a_ro

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_79f06_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79f06_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_79f06_row0_col0" class="data row0 col0" >AMATA</td>
#       <td id="T_79f06_row0_col1" class="data row0 col1" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_79f06_row0_col2" class="data row0 col2" >26.75</td>
#       <td id="T_79f06_row0_col3" class="data row0 col3" >27.25</td>
#       <td id="T_79f06_row0_col4" class="data row0 col4" >23.00</td>
#       <td id="T_79f06_row0_col5" class="data row0 col5" >3,143,905</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row1" class="row_heading level0 row1" >16</th>
#       <td id="T_79f06_row1_col0" class="data row1 col0" >BA</td>
#       <td id="T_79f06_row1_col1" class="data row1 col1" >SET    </td>
#       <td id="T_79f06_row1_col2" class="data row1 col2" >15.70</td>
#       <td id="T_79f06_row1_col3" class="data row1 col3" >15.80</td>
#       <td id="T_79f06_row1_col4" class="data row1 col4" >14.80</td>
#       <td id="T_79f06_row1_col5" class="data row1 col5" >6,203,787</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_79f06_row2_col0" class="data row2 col0" >BCP</td>
#       <td id="T_79f06_row2_col1" class="data row2 col1" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_79f06_row2_col2" class="data row2 col2" >43.50</td>
#       <td id="T_79f06_row2_col3" class="data row2 col3" >43.75</td>
#       <td id="T_79f06_row2_col4" class="data row2 col4" >39.00</td>
#       <td id="T_79f06_row2_col5" class="data row2 col5" >1,122,266</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row3" class="row_heading level0 row3" >69</th>
#       <td id="T_79f06_row3_col0" class="data row3 col0" >ICHI</td>
#       <td id="T_79f06_row3_col1" class="data row3 col1" >sSET / SETCLMV / SETTHSI    </td>
#       <td id="T_79f06_row3_col2" class="data row3 col2" >15.70</td>
#       <td id="T_79f06_row3_col3" class="data row3 col3" >15.70</td>
#       <td id="T_79f06_row3_col4" class="data row3 col4" >12.40</td>
#       <td id="T_79f06_row3_col5" class="data row3 col5" >7,074,761</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row4" class="row_heading level0 row4" >85</th>
#       <td id="T_79f06_row4_col0" class="data row4 col0" >KTB</td>
#       <td id="T_79f06_row4_col1" class="data row4 col1" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_79f06_row4_col2" class="data row4 col2" >18.40</td>
#       <td id="T_79f06_row4_col3" class="data row4 col3" >18.50</td>
#       <td id="T_79f06_row4_col4" class="data row4 col4" >18.40</td>
#       <td id="T_79f06_row4_col5" class="data row4 col5" >62,295,247</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row5" class="row_heading level0 row5" >94</th>
#       <td id="T_79f06_row5_col0" class="data row5 col0" >MC</td>
#       <td id="T_79f06_row5_col1" class="data row5 col1" >sSET    </td>
#       <td id="T_79f06_row5_col2" class="data row5 col2" >13.20</td>
#       <td id="T_79f06_row5_col3" class="data row5 col3" >13.30</td>
#       <td id="T_79f06_row5_col4" class="data row5 col4" >11.90</td>
#       <td id="T_79f06_row5_col5" class="data row5 col5" >1,472,918</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row6" class="row_heading level0 row6" >125</th>
#       <td id="T_79f06_row6_col0" class="data row6 col0" >SAPPE</td>
#       <td id="T_79f06_row6_col1" class="data row6 col1" >sSET / SETTHSI    </td>
#       <td id="T_79f06_row6_col2" class="data row6 col2" >86.50</td>
#       <td id="T_79f06_row6_col3" class="data row6 col3" >86.75</td>
#       <td id="T_79f06_row6_col4" class="data row6 col4" >48.25</td>
#       <td id="T_79f06_row6_col5" class="data row6 col5" >536,317</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row7" class="row_heading level0 row7" >153</th>
#       <td id="T_79f06_row7_col0" class="data row7 col0" >TCAP</td>
#       <td id="T_79f06_row7_col1" class="data row7 col1" >SET100 / SETHD    </td>
#       <td id="T_79f06_row7_col2" class="data row7 col2" >49.50</td>
#       <td id="T_79f06_row7_col3" class="data row7 col3" >49.75</td>
#       <td id="T_79f06_row7_col4" class="data row7 col4" >45.00</td>
#       <td id="T_79f06_row7_col5" class="data row7 col5" >2,103,095</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row8" class="row_heading level0 row8" >174</th>
#       <td id="T_79f06_row8_col0" class="data row8 col0" >TTB</td>
#       <td id="T_79f06_row8_col1" class="data row8 col1" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_79f06_row8_col2" class="data row8 col2" >1.67</td>
#       <td id="T_79f06_row8_col3" class="data row8 col3" >1.68</td>
#       <td id="T_79f06_row8_col4" class="data row8 col4" >1.47</td>
#       <td id="T_79f06_row8_col5" class="data row8 col5" >422,951,773</td>
#     </tr>
#     <tr>
#       <th id="T_79f06_level0_row9" class="row_heading level0 row9" >181</th>
#       <td id="T_79f06_row9_col0" class="data row9 col0" >WHA</td>
#       <td id="T_79f06_row9_col1" class="data row9 col1" >SET100 / SETHD / SETTHSI    </td>
#       <td id="T_79f06_row9_col2" class="data row9 col2" >5.30</td>
#       <td id="T_79f06_row9_col3" class="data row9 col3" >5.35</td>
#       <td id="T_79f06_row9_col4" class="data row9 col4" >4.22</td>
#       <td id="T_79f06_row9_col5" class="data row9 col5" >31,300,196</td>
#     </tr>
#   </tbody>
# </table>

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 10 stocks'

# %% [markdown]
# ### High or Low by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2157d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2157d_level0_row0" class="row_heading level0 row0" >85</th>
#       <td id="T_2157d_row0_col0" class="data row0 col0" >KTB</td>
#       <td id="T_2157d_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_2157d_row0_col2" class="data row0 col2" >18.40</td>
#       <td id="T_2157d_row0_col3" class="data row0 col3" >18.50</td>
#       <td id="T_2157d_row0_col4" class="data row0 col4" >18.10</td>
#       <td id="T_2157d_row0_col5" class="data row0 col5" >62,295,247</td>
#       <td id="T_2157d_row0_col6" class="data row0 col6" >18.10</td>
#       <td id="T_2157d_row0_col7" class="data row0 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_2157d_row0_col8" class="data row0 col8" >17.80</td>
#       <td id="T_2157d_row0_col9" class="data row0 col9" >18.40</td>
#       <td id="T_2157d_row0_col10" class="data row0 col10" >12.90</td>
#       <td id="T_2157d_row0_col11" class="data row0 col11" >8.15</td>
#       <td id="T_2157d_row0_col12" class="data row0 col12" >0.69</td>
#       <td id="T_2157d_row0_col13" class="data row0 col13" >896.430000</td>
#       <td id="T_2157d_row0_col14" class="data row0 col14" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_2157d_level0_row1" class="row_heading level0 row1" >174</th>
#       <td id="T_2157d_row1_col0" class="data row1 col0" >TTB</td>
#       <td id="T_2157d_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_2157d_row1_col2" class="data row1 col2" >1.67</td>
#       <td id="T_2157d_row1_col3" class="data row1 col3" >1.68</td>
#       <td id="T_2157d_row1_col4" class="data row1 col4" >1.62</td>
#       <td id="T_2157d_row1_col5" class="data row1 col5" >422,951,773</td>
#       <td id="T_2157d_row1_col6" class="data row1 col6" >1.62</td>
#       <td id="T_2157d_row1_col7" class="data row1 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_2157d_row1_col8" class="data row1 col8" >1.47</td>
#       <td id="T_2157d_row1_col9" class="data row1 col9" >1.47</td>
#       <td id="T_2157d_row1_col10" class="data row1 col10" >1.09</td>
#       <td id="T_2157d_row1_col11" class="data row1 col11" >10.82</td>
#       <td id="T_2157d_row1_col12" class="data row1 col12" >0.66</td>
#       <td id="T_2157d_row1_col13" class="data row1 col13" >427.040000</td>
#       <td id="T_2157d_row1_col14" class="data row1 col14" >1.04</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100H = Final_High["market"].str.contains("SET100")
Final_High[set100H].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_870ab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_870ab_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_870ab_row0_col0" class="data row0 col0" >AMATA</td>
#       <td id="T_870ab_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_870ab_row0_col2" class="data row0 col2" >26.75</td>
#       <td id="T_870ab_row0_col3" class="data row0 col3" >27.25</td>
#       <td id="T_870ab_row0_col4" class="data row0 col4" >26.50</td>
#       <td id="T_870ab_row0_col5" class="data row0 col5" >3,143,905</td>
#       <td id="T_870ab_row0_col6" class="data row0 col6" >27.00</td>
#       <td id="T_870ab_row0_col7" class="data row0 col7" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_870ab_row0_col8" class="data row0 col8" >20.00</td>
#       <td id="T_870ab_row0_col9" class="data row0 col9" >23.00</td>
#       <td id="T_870ab_row0_col10" class="data row0 col10" >17.10</td>
#       <td id="T_870ab_row0_col11" class="data row0 col11" >10.02</td>
#       <td id="T_870ab_row0_col12" class="data row0 col12" >1.20</td>
#       <td id="T_870ab_row0_col13" class="data row0 col13" >177.040000</td>
#       <td id="T_870ab_row0_col14" class="data row0 col14" >1.61</td>
#     </tr>
#     <tr>
#       <th id="T_870ab_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_870ab_row1_col0" class="data row1 col0" >BCP</td>
#       <td id="T_870ab_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_870ab_row1_col2" class="data row1 col2" >43.50</td>
#       <td id="T_870ab_row1_col3" class="data row1 col3" >43.75</td>
#       <td id="T_870ab_row1_col4" class="data row1 col4" >43.25</td>
#       <td id="T_870ab_row1_col5" class="data row1 col5" >1,122,266</td>
#       <td id="T_870ab_row1_col6" class="data row1 col6" >43.50</td>
#       <td id="T_870ab_row1_col7" class="data row1 col7" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_870ab_row1_col8" class="data row1 col8" >36.75</td>
#       <td id="T_870ab_row1_col9" class="data row1 col9" >39.00</td>
#       <td id="T_870ab_row1_col10" class="data row1 col10" >27.25</td>
#       <td id="T_870ab_row1_col11" class="data row1 col11" >3.63</td>
#       <td id="T_870ab_row1_col12" class="data row1 col12" >0.80</td>
#       <td id="T_870ab_row1_col13" class="data row1 col13" >511.260000</td>
#       <td id="T_870ab_row1_col14" class="data row1 col14" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_870ab_level0_row2" class="row_heading level0 row2" >153</th>
#       <td id="T_870ab_row2_col0" class="data row2 col0" >TCAP</td>
#       <td id="T_870ab_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_870ab_row2_col2" class="data row2 col2" >49.50</td>
#       <td id="T_870ab_row2_col3" class="data row2 col3" >49.75</td>
#       <td id="T_870ab_row2_col4" class="data row2 col4" >48.75</td>
#       <td id="T_870ab_row2_col5" class="data row2 col5" >2,103,095</td>
#       <td id="T_870ab_row2_col6" class="data row2 col6" >48.75</td>
#       <td id="T_870ab_row2_col7" class="data row2 col7" >SET100 / SETHD    </td>
#       <td id="T_870ab_row2_col8" class="data row2 col8" >43.00</td>
#       <td id="T_870ab_row2_col9" class="data row2 col9" >45.00</td>
#       <td id="T_870ab_row2_col10" class="data row2 col10" >35.75</td>
#       <td id="T_870ab_row2_col11" class="data row2 col11" >7.64</td>
#       <td id="T_870ab_row2_col12" class="data row2 col12" >0.67</td>
#       <td id="T_870ab_row2_col13" class="data row2 col13" >129.870000</td>
#       <td id="T_870ab_row2_col14" class="data row2 col14" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_870ab_level0_row3" class="row_heading level0 row3" >181</th>
#       <td id="T_870ab_row3_col0" class="data row3 col0" >WHA</td>
#       <td id="T_870ab_row3_col1" class="data row3 col1" >2023-12-28</td>
#       <td id="T_870ab_row3_col2" class="data row3 col2" >5.30</td>
#       <td id="T_870ab_row3_col3" class="data row3 col3" >5.35</td>
#       <td id="T_870ab_row3_col4" class="data row3 col4" >5.25</td>
#       <td id="T_870ab_row3_col5" class="data row3 col5" >31,300,196</td>
#       <td id="T_870ab_row3_col6" class="data row3 col6" >5.30</td>
#       <td id="T_870ab_row3_col7" class="data row3 col7" >SET100 / SETHD / SETTHSI    </td>
#       <td id="T_870ab_row3_col8" class="data row3 col8" >3.82</td>
#       <td id="T_870ab_row3_col9" class="data row3 col9" >4.22</td>
#       <td id="T_870ab_row3_col10" class="data row3 col10" >2.84</td>
#       <td id="T_870ab_row3_col11" class="data row3 col11" >17.63</td>
#       <td id="T_870ab_row3_col12" class="data row3 col12" >1.89</td>
#       <td id="T_870ab_row3_col13" class="data row3 col13" >393.780000</td>
#       <td id="T_870ab_row3_col14" class="data row3 col14" >1.14</td>
#     </tr>
#   </tbody>
# </table>

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a484_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a484_level0_row0" class="row_heading level0 row0" >69</th>
#       <td id="T_0a484_row0_col0" class="data row0 col0" >ICHI</td>
#       <td id="T_0a484_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_0a484_row0_col2" class="data row0 col2" >15.70</td>
#       <td id="T_0a484_row0_col3" class="data row0 col3" >15.70</td>
#       <td id="T_0a484_row0_col4" class="data row0 col4" >15.30</td>
#       <td id="T_0a484_row0_col5" class="data row0 col5" >7,074,761</td>
#       <td id="T_0a484_row0_col6" class="data row0 col6" >15.60</td>
#       <td id="T_0a484_row0_col7" class="data row0 col7" >sSET / SETCLMV / SETTHSI    </td>
#       <td id="T_0a484_row0_col8" class="data row0 col8" >12.10</td>
#       <td id="T_0a484_row0_col9" class="data row0 col9" >12.40</td>
#       <td id="T_0a484_row0_col10" class="data row0 col10" >7.20</td>
#       <td id="T_0a484_row0_col11" class="data row0 col11" >27.06</td>
#       <td id="T_0a484_row0_col12" class="data row0 col12" >2.63</td>
#       <td id="T_0a484_row0_col13" class="data row0 col13" >60.250000</td>
#       <td id="T_0a484_row0_col14" class="data row0 col14" >1.71</td>
#     </tr>
#     <tr>
#       <th id="T_0a484_level0_row1" class="row_heading level0 row1" >94</th>
#       <td id="T_0a484_row1_col0" class="data row1 col0" >MC</td>
#       <td id="T_0a484_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_0a484_row1_col2" class="data row1 col2" >13.20</td>
#       <td id="T_0a484_row1_col3" class="data row1 col3" >13.30</td>
#       <td id="T_0a484_row1_col4" class="data row1 col4" >12.70</td>
#       <td id="T_0a484_row1_col5" class="data row1 col5" >1,472,918</td>
#       <td id="T_0a484_row1_col6" class="data row1 col6" >12.90</td>
#       <td id="T_0a484_row1_col7" class="data row1 col7" >sSET    </td>
#       <td id="T_0a484_row1_col8" class="data row1 col8" >11.80</td>
#       <td id="T_0a484_row1_col9" class="data row1 col9" >11.90</td>
#       <td id="T_0a484_row1_col10" class="data row1 col10" >8.70</td>
#       <td id="T_0a484_row1_col11" class="data row1 col11" >16.17</td>
#       <td id="T_0a484_row1_col12" class="data row1 col12" >2.47</td>
#       <td id="T_0a484_row1_col13" class="data row1 col13" >14.200000</td>
#       <td id="T_0a484_row1_col14" class="data row1 col14" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_0a484_level0_row2" class="row_heading level0 row2" >125</th>
#       <td id="T_0a484_row2_col0" class="data row2 col0" >SAPPE</td>
#       <td id="T_0a484_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_0a484_row2_col2" class="data row2 col2" >86.50</td>
#       <td id="T_0a484_row2_col3" class="data row2 col3" >86.75</td>
#       <td id="T_0a484_row2_col4" class="data row2 col4" >85.00</td>
#       <td id="T_0a484_row2_col5" class="data row2 col5" >536,317</td>
#       <td id="T_0a484_row2_col6" class="data row2 col6" >86.00</td>
#       <td id="T_0a484_row2_col7" class="data row2 col7" >sSET / SETTHSI    </td>
#       <td id="T_0a484_row2_col8" class="data row2 col8" >45.75</td>
#       <td id="T_0a484_row2_col9" class="data row2 col9" >48.25</td>
#       <td id="T_0a484_row2_col10" class="data row2 col10" >23.70</td>
#       <td id="T_0a484_row2_col11" class="data row2 col11" >25.45</td>
#       <td id="T_0a484_row2_col12" class="data row2 col12" >4.53</td>
#       <td id="T_0a484_row2_col13" class="data row2 col13" >28.600000</td>
#       <td id="T_0a484_row2_col14" class="data row2 col14" >1.03</td>
#     </tr>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76949_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ecbd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >minp</th>
#       <th class="col_heading level0 col4" >min_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ecbd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ecbd_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_5ecbd_row0_col1" class="data row0 col1" >SET100 / SETTHSI    </td>
#       <td id="T_5ecbd_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_5ecbd_row0_col3" class="data row0 col3" >1.50</td>
#       <td id="T_5ecbd_row0_col4" class="data row0 col4" >2.52</td>
#       <td id="T_5ecbd_row0_col5" class="data row0 col5" >8,608,162</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_5ecbd_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_5ecbd_row1_col1" class="data row1 col1" >SET    </td>
#       <td id="T_5ecbd_row1_col2" class="data row1 col2" >10.40</td>
#       <td id="T_5ecbd_row1_col3" class="data row1 col3" >10.40</td>
#       <td id="T_5ecbd_row1_col4" class="data row1 col4" >11.70</td>
#       <td id="T_5ecbd_row1_col5" class="data row1 col5" >196,901</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_5ecbd_row2_col0" class="data row2 col0" >AIT</td>
#       <td id="T_5ecbd_row2_col1" class="data row2 col1" >sSET    </td>
#       <td id="T_5ecbd_row2_col2" class="data row2 col2" >3.78</td>
#       <td id="T_5ecbd_row2_col3" class="data row2 col3" >3.76</td>
#       <td id="T_5ecbd_row2_col4" class="data row2 col4" >5.40</td>
#       <td id="T_5ecbd_row2_col5" class="data row2 col5" >643,188</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_5ecbd_row3_col0" class="data row3 col0" >ANAN</td>
#       <td id="T_5ecbd_row3_col1" class="data row3 col1" >sSET    </td>
#       <td id="T_5ecbd_row3_col2" class="data row3 col2" >0.77</td>
#       <td id="T_5ecbd_row3_col3" class="data row3 col3" >0.76</td>
#       <td id="T_5ecbd_row3_col4" class="data row3 col4" >1.11</td>
#       <td id="T_5ecbd_row3_col5" class="data row3 col5" >2,725,748</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_5ecbd_row4_col0" class="data row4 col0" >AOT</td>
#       <td id="T_5ecbd_row4_col1" class="data row4 col1" >SET50 / SETTHSI    </td>
#       <td id="T_5ecbd_row4_col2" class="data row4 col2" >59.75</td>
#       <td id="T_5ecbd_row4_col3" class="data row4 col3" >59.50</td>
#       <td id="T_5ecbd_row4_col4" class="data row4 col4" >61.25</td>
#       <td id="T_5ecbd_row4_col5" class="data row4 col5" >34,315,673</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_5ecbd_row5_col0" class="data row5 col0" >ASIAN</td>
#       <td id="T_5ecbd_row5_col1" class="data row5 col1" >sSET / SETTHSI    </td>
#       <td id="T_5ecbd_row5_col2" class="data row5 col2" >6.95</td>
#       <td id="T_5ecbd_row5_col3" class="data row5 col3" >6.90</td>
#       <td id="T_5ecbd_row5_col4" class="data row5 col4" >12.90</td>
#       <td id="T_5ecbd_row5_col5" class="data row5 col5" >1,406,073</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_5ecbd_row6_col0" class="data row6 col0" >ASK</td>
#       <td id="T_5ecbd_row6_col1" class="data row6 col1" >SET    </td>
#       <td id="T_5ecbd_row6_col2" class="data row6 col2" >19.90</td>
#       <td id="T_5ecbd_row6_col3" class="data row6 col3" >19.90</td>
#       <td id="T_5ecbd_row6_col4" class="data row6 col4" >28.25</td>
#       <td id="T_5ecbd_row6_col5" class="data row6 col5" >661,350</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row7" class="row_heading level0 row7" >13</th>
#       <td id="T_5ecbd_row7_col0" class="data row7 col0" >ASP</td>
#       <td id="T_5ecbd_row7_col1" class="data row7 col1" >sSET    </td>
#       <td id="T_5ecbd_row7_col2" class="data row7 col2" >2.84</td>
#       <td id="T_5ecbd_row7_col3" class="data row7 col3" >2.80</td>
#       <td id="T_5ecbd_row7_col4" class="data row7 col4" >2.92</td>
#       <td id="T_5ecbd_row7_col5" class="data row7 col5" >1,156,972</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row8" class="row_heading level0 row8" >15</th>
#       <td id="T_5ecbd_row8_col0" class="data row8 col0" >AWC</td>
#       <td id="T_5ecbd_row8_col1" class="data row8 col1" >SET50 / SETTHSI    </td>
#       <td id="T_5ecbd_row8_col2" class="data row8 col2" >3.56</td>
#       <td id="T_5ecbd_row8_col3" class="data row8 col3" >3.54</td>
#       <td id="T_5ecbd_row8_col4" class="data row8 col4" >4.56</td>
#       <td id="T_5ecbd_row8_col5" class="data row8 col5" >61,566,521</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row9" class="row_heading level0 row9" >17</th>
#       <td id="T_5ecbd_row9_col0" class="data row9 col0" >BAM</td>
#       <td id="T_5ecbd_row9_col1" class="data row9 col1" >SET100 / SETTHSI    </td>
#       <td id="T_5ecbd_row9_col2" class="data row9 col2" >8.15</td>
#       <td id="T_5ecbd_row9_col3" class="data row9 col3" >7.95</td>
#       <td id="T_5ecbd_row9_col4" class="data row9 col4" >14.50</td>
#       <td id="T_5ecbd_row9_col5" class="data row9 col5" >7,364,592</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row10" class="row_heading level0 row10" >18</th>
#       <td id="T_5ecbd_row10_col0" class="data row10 col0" >BANPU</td>
#       <td id="T_5ecbd_row10_col1" class="data row10 col1" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_5ecbd_row10_col2" class="data row10 col2" >6.80</td>
#       <td id="T_5ecbd_row10_col3" class="data row10 col3" >6.70</td>
#       <td id="T_5ecbd_row10_col4" class="data row10 col4" >10.50</td>
#       <td id="T_5ecbd_row10_col5" class="data row10 col5" >38,417,325</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row11" class="row_heading level0 row11" >22</th>
#       <td id="T_5ecbd_row11_col0" class="data row11 col0" >BCPG</td>
#       <td id="T_5ecbd_row11_col1" class="data row11 col1" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_5ecbd_row11_col2" class="data row11 col2" >8.80</td>
#       <td id="T_5ecbd_row11_col3" class="data row11 col3" >8.65</td>
#       <td id="T_5ecbd_row11_col4" class="data row11 col4" >8.70</td>
#       <td id="T_5ecbd_row11_col5" class="data row11 col5" >2,081,893</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row12" class="row_heading level0 row12" >24</th>
#       <td id="T_5ecbd_row12_col0" class="data row12 col0" >BEAUTY</td>
#       <td id="T_5ecbd_row12_col1" class="data row12 col1" >sSET    </td>
#       <td id="T_5ecbd_row12_col2" class="data row12 col2" >0.46</td>
#       <td id="T_5ecbd_row12_col3" class="data row12 col3" >0.45</td>
#       <td id="T_5ecbd_row12_col4" class="data row12 col4" >1.21</td>
#       <td id="T_5ecbd_row12_col5" class="data row12 col5" >2,625,218</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row13" class="row_heading level0 row13" >25</th>
#       <td id="T_5ecbd_row13_col0" class="data row13 col0" >BEM</td>
#       <td id="T_5ecbd_row13_col1" class="data row13 col1" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_5ecbd_row13_col2" class="data row13 col2" >7.95</td>
#       <td id="T_5ecbd_row13_col3" class="data row13 col3" >7.85</td>
#       <td id="T_5ecbd_row13_col4" class="data row13 col4" >7.90</td>
#       <td id="T_5ecbd_row13_col5" class="data row13 col5" >15,978,880</td>
#     </tr>
#     <tr>
#       <th id="T_5ecbd_level0_row14" class="row_heading level0 row14" >27</th>
#       <td id="T_5ecbd_row14_col0" class="data row14 col0" >BGRIM</td>
#       <td id="T_5ecbd_row14_col1" class="data row14 col1" >SET50 / SETCLMV / SETTHSI    </td>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 107 stocks'

# %% [markdown]
# ### New High or Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_10c90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10c90_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_10c90_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_10c90_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_10c90_row0_col2" class="data row0 col2" >59.75</td>
#       <td id="T_10c90_row0_col3" class="data row0 col3" >60.50</td>
#       <td id="T_10c90_row0_col4" class="data row0 col4" >59.50</td>
#       <td id="T_10c90_row0_col5" class="data row0 col5" >34,315,673</td>
#       <td id="T_10c90_row0_col6" class="data row0 col6" >60.00</td>
#       <td id="T_10c90_row0_col7" class="data row0 col7" >SET50 / SETTHSI    </td>
#       <td id="T_10c90_row0_col8" class="data row0 col8" >75.25</td>
#       <td id="T_10c90_row0_col9" class="data row0 col9" >76.50</td>
#       <td id="T_10c90_row0_col10" class="data row0 col10" >61.25</td>
#       <td id="T_10c90_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_10c90_row0_col12" class="data row0 col12" >10.61</td>
#       <td id="T_10c90_row0_col13" class="data row0 col13" >1967.440000</td>
#       <td id="T_10c90_row0_col14" class="data row0 col14" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_10c90_row1_col0" class="data row1 col0" >AWC</td>
#       <td id="T_10c90_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_10c90_row1_col2" class="data row1 col2" >3.56</td>
#       <td id="T_10c90_row1_col3" class="data row1 col3" >3.60</td>
#       <td id="T_10c90_row1_col4" class="data row1 col4" >3.54</td>
#       <td id="T_10c90_row1_col5" class="data row1 col5" >61,566,521</td>
#       <td id="T_10c90_row1_col6" class="data row1 col6" >3.56</td>
#       <td id="T_10c90_row1_col7" class="data row1 col7" >SET50 / SETTHSI    </td>
#       <td id="T_10c90_row1_col8" class="data row1 col8" >6.05</td>
#       <td id="T_10c90_row1_col9" class="data row1 col9" >6.55</td>
#       <td id="T_10c90_row1_col10" class="data row1 col10" >4.56</td>
#       <td id="T_10c90_row1_col11" class="data row1 col11" >56.69</td>
#       <td id="T_10c90_row1_col12" class="data row1 col12" >2.38</td>
#       <td id="T_10c90_row1_col13" class="data row1 col13" >316.900000</td>
#       <td id="T_10c90_row1_col14" class="data row1 col14" >1.13</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_10c90_row2_col0" class="data row2 col0" >BANPU</td>
#       <td id="T_10c90_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_10c90_row2_col2" class="data row2 col2" >6.80</td>
#       <td id="T_10c90_row2_col3" class="data row2 col3" >6.85</td>
#       <td id="T_10c90_row2_col4" class="data row2 col4" >6.70</td>
#       <td id="T_10c90_row2_col5" class="data row2 col5" >38,417,325</td>
#       <td id="T_10c90_row2_col6" class="data row2 col6" >6.70</td>
#       <td id="T_10c90_row2_col7" class="data row2 col7" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_10c90_row2_col8" class="data row2 col8" >12.00</td>
#       <td id="T_10c90_row2_col9" class="data row2 col9" >15.00</td>
#       <td id="T_10c90_row2_col10" class="data row2 col10" >10.50</td>
#       <td id="T_10c90_row2_col11" class="data row2 col11" >2.29</td>
#       <td id="T_10c90_row2_col12" class="data row2 col12" >0.91</td>
#       <td id="T_10c90_row2_col13" class="data row2 col13" >1482.620000</td>
#       <td id="T_10c90_row2_col14" class="data row2 col14" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row3" class="row_heading level0 row3" >25</th>
#       <td id="T_10c90_row3_col0" class="data row3 col0" >BEM</td>
#       <td id="T_10c90_row3_col1" class="data row3 col1" >2023-12-28</td>
#       <td id="T_10c90_row3_col2" class="data row3 col2" >7.95</td>
#       <td id="T_10c90_row3_col3" class="data row3 col3" >7.95</td>
#       <td id="T_10c90_row3_col4" class="data row3 col4" >7.85</td>
#       <td id="T_10c90_row3_col5" class="data row3 col5" >15,978,880</td>
#       <td id="T_10c90_row3_col6" class="data row3 col6" >7.85</td>
#       <td id="T_10c90_row3_col7" class="data row3 col7" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_10c90_row3_col8" class="data row3 col8" >9.80</td>
#       <td id="T_10c90_row3_col9" class="data row3 col9" >10.10</td>
#       <td id="T_10c90_row3_col10" class="data row3 col10" >7.90</td>
#       <td id="T_10c90_row3_col11" class="data row3 col11" >67.20</td>
#       <td id="T_10c90_row3_col12" class="data row3 col12" >3.97</td>
#       <td id="T_10c90_row3_col13" class="data row3 col13" >720.960000</td>
#       <td id="T_10c90_row3_col14" class="data row3 col14" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row4" class="row_heading level0 row4" >27</th>
#       <td id="T_10c90_row4_col0" class="data row4 col0" >BGRIM</td>
#       <td id="T_10c90_row4_col1" class="data row4 col1" >2023-12-28</td>
#       <td id="T_10c90_row4_col2" class="data row4 col2" >27.25</td>
#       <td id="T_10c90_row4_col3" class="data row4 col3" >27.50</td>
#       <td id="T_10c90_row4_col4" class="data row4 col4" >27.00</td>
#       <td id="T_10c90_row4_col5" class="data row4 col5" >7,784,477</td>
#       <td id="T_10c90_row4_col6" class="data row4 col6" >27.50</td>
#       <td id="T_10c90_row4_col7" class="data row4 col7" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_10c90_row4_col8" class="data row4 col8" >40.25</td>
#       <td id="T_10c90_row4_col9" class="data row4 col9" >42.75</td>
#       <td id="T_10c90_row4_col10" class="data row4 col10" >29.75</td>
#       <td id="T_10c90_row4_col11" class="data row4 col11" >999.99</td>
#       <td id="T_10c90_row4_col12" class="data row4 col12" >3.33</td>
#       <td id="T_10c90_row4_col13" class="data row4 col13" >416.870000</td>
#       <td id="T_10c90_row4_col14" class="data row4 col14" >1.29</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row5" class="row_heading level0 row5" >34</th>
#       <td id="T_10c90_row5_col0" class="data row5 col0" >BTS</td>
#       <td id="T_10c90_row5_col1" class="data row5 col1" >2023-12-28</td>
#       <td id="T_10c90_row5_col2" class="data row5 col2" >7.25</td>
#       <td id="T_10c90_row5_col3" class="data row5 col3" >7.25</td>
#       <td id="T_10c90_row5_col4" class="data row5 col4" >7.15</td>
#       <td id="T_10c90_row5_col5" class="data row5 col5" >16,088,191</td>
#       <td id="T_10c90_row5_col6" class="data row5 col6" >7.20</td>
#       <td id="T_10c90_row5_col7" class="data row5 col7" >SET50 / SETHD / SETTHSI / SETWB    </td>
#       <td id="T_10c90_row5_col8" class="data row5 col8" >8.55</td>
#       <td id="T_10c90_row5_col9" class="data row5 col9" >10.20</td>
#       <td id="T_10c90_row5_col10" class="data row5 col10" >7.85</td>
#       <td id="T_10c90_row5_col11" class="data row5 col11" >39.14</td>
#       <td id="T_10c90_row5_col12" class="data row5 col12" >1.84</td>
#       <td id="T_10c90_row5_col13" class="data row5 col13" >196.530000</td>
#       <td id="T_10c90_row5_col14" class="data row5 col14" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_10c90_level0_row6" class="row_heading level0 row6" >41</th>
#       <td id="T_1

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_58306_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58306_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58306_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_58306_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_58306_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_58306_row0_col3" class="data row0 col3" >1.54</td>
#       <td id="T_58306_row0_col4" class="data row0 col4" >1.50</td>
#       <td id="T_58306_row0_col5" class="data row0 col5" >8,608,162</td>
#       <td id="T_58306_row0_col6" class="data row0 col6" >1.51</td>
#       <td id="T_58306_row0_col7" class="data row0 col7" >SET100 / SETTHSI    </td>
#       <td id="T_58306_row0_col8" class="data row0 col8" >2.56</td>
#       <td id="T_58306_row0_col9" class="data row0 col9" >3.42</td>
#       <td id="T_58306_row0_col10" class="data row0 col10" >2.52</td>
#       <td id="T_58306_row0_col11" class="data row0 col11" >17.72</td>
#       <td id="T_58306_row0_col12" class="data row0 col12" >1.82</td>
#       <td id="T_58306_row0_col13" class="data row0 col13" >54.630000</td>
#       <td id="T_58306_row0_col14" class="data row0 col14" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_58306_row1_col0" class="data row1 col0" >BAM</td>
#       <td id="T_58306_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_58306_row1_col2" class="data row1 col2" >8.15</td>
#       <td id="T_58306_row1_col3" class="data row1 col3" >8.15</td>
#       <td id="T_58306_row1_col4" class="data row1 col4" >7.95</td>
#       <td id="T_58306_row1_col5" class="data row1 col5" >7,364,592</td>
#       <td id="T_58306_row1_col6" class="data row1 col6" >7.95</td>
#       <td id="T_58306_row1_col7" class="data row1 col7" >SET100 / SETTHSI    </td>
#       <td id="T_58306_row1_col8" class="data row1 col8" >15.90</td>
#       <td id="T_58306_row1_col9" class="data row1 col9" >22.30</td>
#       <td id="T_58306_row1_col10" class="data row1 col10" >14.50</td>
#       <td id="T_58306_row1_col11" class="data row1 col11" >18.06</td>
#       <td id="T_58306_row1_col12" class="data row1 col12" >1.20</td>
#       <td id="T_58306_row1_col13" class="data row1 col13" >411.040000</td>
#       <td id="T_58306_row1_col14" class="data row1 col14" >1.35</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_58306_row2_col0" class="data row2 col0" >BCPG</td>
#       <td id="T_58306_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_58306_row2_col2" class="data row2 col2" >8.80</td>
#       <td id="T_58306_row2_col3" class="data row2 col3" >8.80</td>
#       <td id="T_58306_row2_col4" class="data row2 col4" >8.65</td>
#       <td id="T_58306_row2_col5" class="data row2 col5" >2,081,893</td>
#       <td id="T_58306_row2_col6" class="data row2 col6" >8.65</td>
#       <td id="T_58306_row2_col7" class="data row2 col7" >SET100 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_58306_row2_col8" class="data row2 col8" >9.90</td>
#       <td id="T_58306_row2_col9" class="data row2 col9" >13.40</td>
#       <td id="T_58306_row2_col10" class="data row2 col10" >8.70</td>
#       <td id="T_58306_row2_col11" class="data row2 col11" >11.19</td>
#       <td id="T_58306_row2_col12" class="data row2 col12" >0.97</td>
#       <td id="T_58306_row2_col13" class="data row2 col13" >56.360000</td>
#       <td id="T_58306_row2_col14" class="data row2 col14" >1.18</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_58306_row3_col0" class="data row3 col0" >BLA</td>
#       <td id="T_58306_row3_col1" class="data row3 col1" >2023-12-28</td>
#       <td id="T_58306_row3_col2" class="data row3 col2" >20.00</td>
#       <td id="T_58306_row3_col3" class="data row3 col3" >20.30</td>
#       <td id="T_58306_row3_col4" class="data row3 col4" >19.90</td>
#       <td id="T_58306_row3_col5" class="data row3 col5" >1,852,174</td>
#       <td id="T_58306_row3_col6" class="data row3 col6" >20.20</td>
#       <td id="T_58306_row3_col7" class="data row3 col7" >SET100 / SETTHSI    </td>
#       <td id="T_58306_row3_col8" class="data row3 col8" >29.50</td>
#       <td id="T_58306_row3_col9" class="data row3 col9" >48.00</td>
#       <td id="T_58306_row3_col10" class="data row3 col10" >27.00</td>
#       <td id="T_58306_row3_col11" class="data row3 col11" >15.71</td>
#       <td id="T_58306_row3_col12" class="data row3 col12" >1.21</td>
#       <td id="T_58306_row3_col13" class="data row3 col13" >123.990000</td>
#       <td id="T_58306_row3_col14" class="data row3 col14" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row4" class="row_heading level0 row4" >40</th>
#       <td id="T_58306_row4_col0" class="data row4 col0" >CKP</td>
#       <td id="T_58306_row4_col1" class="data row4 col1" >2023-12-28</td>
#       <td id="T_58306_row4_col2" class="data row4 col2" >3.26</td>
#       <td id="T_58306_row4_col3" class="data row4 col3" >3.38</td>
#       <td id="T_58306_row4_col4" class="data row4 col4" >3.22</td>
#       <td id="T_58306_row4_col5" class="data row4 col5" >12,877,011</td>
#       <td id="T_58306_row4_col6" class="data row4 col6" >3.38</td>
#       <td id="T_58306_row4_col7" class="data row4 col7" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_58306_row4_col8" class="data row4 col8" >4.52</td>
#       <td id="T_58306_row4_col9" class="data row4 col9" >5.90</td>
#       <td id="T_58306_row4_col10" class="data row4 col10" >4.48</td>
#       <td id="T_58306_row4_col11" class="data row4 col11" >14.78</td>
#       <td id="T_58306_row4_col12" class="data row4 col12" >1.44</td>
#       <td id="T_58306_row4_col13" class="data row4 col13" >54.600000</td>
#       <td id="T_58306_row4_col14" class="data row4 col14" >1.04</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row5" class="row_heading level0 row5" >56</th>
#       <td id="T_58306_row5_col0" class="data row5 col0" >EPG</td>
#       <td id="T_58306_row5_col1" class="data row5 col1" >2023-12-28</td>
#       <td id="T_58306_row5_col2" class="data row5 col2" >8.30</td>
#       <td id="T_58306_row5_col3" class="data row5 col3" >8.30</td>
#       <td id="T_58306_row5_col4" class="data row5 col4" >8.10</td>
#       <td id="T_58306_row5_col5" class="data row5 col5" >3,495,882</td>
#       <td id="T_58306_row5_col6" class="data row5 col6" >8.30</td>
#       <td id="T_58306_row5_col7" class="data row5 col7" >SET100 / SETTHSI    </td>
#       <td id="T_58306_row5_col8" class="data row5 col8" >8.60</td>
#       <td id="T_58306_row5_col9" class="data row5 col9" >10.90</td>
#       <td id="T_58306_row5_col10" class="data row5 col10" >8.35</td>
#       <td id="T_58306_row5_col11" class="data row5 col11" >17.83</td>
#       <td id="T_58306_row5_col12" class="data row5 col12" >2.01</td>
#       <td id="T_58306_row5_col13" class="data row5 col13" >37.370000</td>
#       <td id="T_58306_row5_col14" class="data row5 col14" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_58306_level0_row6" class="row_heading level0 row6" >63</th>
#       <td id="T_58306_row6_col0" class="data row6

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4a14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4a14_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_e4a14_row0_col0" class="data row0 col0" >AIT</td>
#       <td id="T_e4a14_row0_col1" class="data row0 col1" >2023-12-28</td>
#       <td id="T_e4a14_row0_col2" class="data row0 col2" >3.78</td>
#       <td id="T_e4a14_row0_col3" class="data row0 col3" >3.80</td>
#       <td id="T_e4a14_row0_col4" class="data row0 col4" >3.76</td>
#       <td id="T_e4a14_row0_col5" class="data row0 col5" >643,188</td>
#       <td id="T_e4a14_row0_col6" class="data row0 col6" >3.78</td>
#       <td id="T_e4a14_row0_col7" class="data row0 col7" >sSET    </td>
#       <td id="T_e4a14_row0_col8" class="data row0 col8" >6.70</td>
#       <td id="T_e4a14_row0_col9" class="data row0 col9" >8.35</td>
#       <td id="T_e4a14_row0_col10" class="data row0 col10" >5.40</td>
#       <td id="T_e4a14_row0_col11" class="data row0 col11" >15.32</td>
#       <td id="T_e4a14_row0_col12" class="data row0 col12" >2.46</td>
#       <td id="T_e4a14_row0_col13" class="data row0 col13" >40.180000</td>
#       <td id="T_e4a14_row0_col14" class="data row0 col14" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_e4a14_row1_col0" class="data row1 col0" >ANAN</td>
#       <td id="T_e4a14_row1_col1" class="data row1 col1" >2023-12-28</td>
#       <td id="T_e4a14_row1_col2" class="data row1 col2" >0.77</td>
#       <td id="T_e4a14_row1_col3" class="data row1 col3" >0.77</td>
#       <td id="T_e4a14_row1_col4" class="data row1 col4" >0.76</td>
#       <td id="T_e4a14_row1_col5" class="data row1 col5" >2,725,748</td>
#       <td id="T_e4a14_row1_col6" class="data row1 col6" >0.77</td>
#       <td id="T_e4a14_row1_col7" class="data row1 col7" >sSET    </td>
#       <td id="T_e4a14_row1_col8" class="data row1 col8" >1.43</td>
#       <td id="T_e4a14_row1_col9" class="data row1 col9" >1.60</td>
#       <td id="T_e4a14_row1_col10" class="data row1 col10" >1.11</td>
#       <td id="T_e4a14_row1_col11" class="data row1 col11" >999.99</td>
#       <td id="T_e4a14_row1_col12" class="data row1 col12" >0.41</td>
#       <td id="T_e4a14_row1_col13" class="data row1 col13" >29.540000</td>
#       <td id="T_e4a14_row1_col14" class="data row1 col14" >1.24</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_e4a14_row2_col0" class="data row2 col0" >ASIAN</td>
#       <td id="T_e4a14_row2_col1" class="data row2 col1" >2023-12-28</td>
#       <td id="T_e4a14_row2_col2" class="data row2 col2" >6.95</td>
#       <td id="T_e4a14_row2_col3" class="data row2 col3" >7.05</td>
#       <td id="T_e4a14_row2_col4" class="data row2 col4" >6.90</td>
#       <td id="T_e4a14_row2_col5" class="data row2 col5" >1,406,073</td>
#       <td id="T_e4a14_row2_col6" class="data row2 col6" >7.05</td>
#       <td id="T_e4a14_row2_col7" class="data row2 col7" >sSET / SETTHSI    </td>
#       <td id="T_e4a14_row2_col8" class="data row2 col8" >13.70</td>
#       <td id="T_e4a14_row2_col9" class="data row2 col9" >19.40</td>
#       <td id="T_e4a14_row2_col10" class="data row2 col10" >12.90</td>
#       <td id="T_e4a14_row2_col11" class="data row2 col11" >10.93</td>
#       <td id="T_e4a14_row2_col12" class="data row2 col12" >2.61</td>
#       <td id="T_e4a14_row2_col13" class="data row2 col13" >16.120000</td>
#       <td id="T_e4a14_row2_col14" class="data row2 col14" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_e4a14_row3_col0" class="data row3 col0" >ASP</td>
#       <td id="T_e4a14_row3_col1" class="data row3 col1" >2023-12-28</td>
#       <td id="T_e4a14_row3_col2" class="data row3 col2" >2.84</td>
#       <td id="T_e4a14_row3_col3" class="data row3 col3" >2.84</td>
#       <td id="T_e4a14_row3_col4" class="data row3 col4" >2.80</td>
#       <td id="T_e4a14_row3_col5" class="data row3 col5" >1,156,972</td>
#       <td id="T_e4a14_row3_col6" class="data row3 col6" >2.82</td>
#       <td id="T_e4a14_row3_col7" class="data row3 col7" >sSET    </td>
#       <td id="T_e4a14_row3_col8" class="data row3 col8" >3.10</td>
#       <td id="T_e4a14_row3_col9" class="data row3 col9" >3.98</td>
#       <td id="T_e4a14_row3_col10" class="data row3 col10" >2.92</td>
#       <td id="T_e4a14_row3_col11" class="data row3 col11" >13.34</td>
#       <td id="T_e4a14_row3_col12" class="data row3 col12" >1.39</td>
#       <td id="T_e4a14_row3_col13" class="data row3 col13" >7.020000</td>
#       <td id="T_e4a14_row3_col14" class="data row3 col14" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_e4a14_row4_col0" class="data row4 col0" >BEAUTY</td>
#       <td id="T_e4a14_row4_col1" class="data row4 col1" >2023-12-28</td>
#       <td id="T_e4a14_row4_col2" class="data row4 col2" >0.46</td>
#       <td id="T_e4a14_row4_col3" class="data row4 col3" >0.47</td>
#       <td id="T_e4a14_row4_col4" class="data row4 col4" >0.45</td>
#       <td id="T_e4a14_row4_col5" class="data row4 col5" >2,625,218</td>
#       <td id="T_e4a14_row4_col6" class="data row4 col6" >0.47</td>
#       <td id="T_e4a14_row4_col7" class="data row4 col7" >sSET    </td>
#       <td id="T_e4a14_row4_col8" class="data row4 col8" >1.40</td>
#       <td id="T_e4a14_row4_col9" class="data row4 col9" >1.60</td>
#       <td id="T_e4a14_row4_col10" class="data row4 col10" >1.21</td>
#       <td id="T_e4a14_row4_col11" class="data row4 col11" >999.99</td>
#       <td id="T_e4a14_row4_col12" class="data row4 col12" >5.84</td>
#       <td id="T_e4a14_row4_col13" class="data row4 col13" >53.590000</td>
#       <td id="T_e4a14_row4_col14" class="data row4 col14" >1.30</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row5" class="row_heading level0 row5" >53</th>
#       <td id="T_e4a14_row5_col0" class="data row5 col0" >EASTW</td>
#       <td id="T_e4a14_row5_col1" class="data row5 col1" >2023-12-28</td>
#       <td id="T_e4a14_row5_col2" class="data row5 col2" >4.18</td>
#       <td id="T_e4a14_row5_col3" class="data row5 col3" >4.20</td>
#       <td id="T_e4a14_row5_col4" class="data row5 col4" >4.14</td>
#       <td id="T_e4a14_row5_col5" class="data row5 col5" >277,156</td>
#       <td id="T_e4a14_row5_col6" class="data row5 col6" >4.14</td>
#       <td id="T_e4a14_row5_col7" class="data row5 col7" >sSET / SETTHSI    </td>
#       <td id="T_e4a14_row5_col8" class="data row5 col8" >5.40</td>
#       <td id="T_e4a14_row5_col9" class="data row5 col9" >9.50</td>
#       <td id="T_e4a14_row5_col10" class="data row5 col10" >4.90</td>
#       <td id="T_e4a14_row5_col11" class="data row5 col11" >11.05</td>
#       <td id="T_e4a14_row5_col12" class="data row5 col12" >0.80</td>
#       <td id="T_e4a14_row5_col13" class="data row5 col13" >10.630000</td>
#       <td id="T_e4a14_row5_col14" class="data row5 col14" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_e4a14_level0_row6" class="row_heading level0 row6" >68</th>
#       <td id="T_e4a14_row6_col0" class="data row6 col0" >HTC</td>
#       <td id="T_e4a14_row6_col1" class="data row6 col1" >2023-12-28</td>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT name, qty, price, date As today
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict)
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = '2023-12-28'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_3d2ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qty</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d2ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d2ec_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_3d2ec_row0_col1" class="data row0 col1" >8,608,162</td>
#       <td id="T_3d2ec_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_3d2ec_row0_col3" class="data row0 col3" >2023-12-28</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d2ec_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_3d2ec_row1_col1" class="data row1 col1" >6,051,288</td>
#       <td id="T_3d2ec_row1_col2" class="data row1 col2" >217.00</td>
#       <td id="T_3d2ec_row1_col3" class="data row1 col3" >2023-12-28</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d2ec_row2_col0" class="data row2 col0" >AEONTS</td>
#       <td id="T_3d2ec_row2_col1" class="data row2 col1" >215,899</td>
#       <td id="T_3d2ec_row2_col2" class="data row2 col2" >160.00</td>
#       <td id="T_3d2ec_row2_col3" class="data row2 col3" >2023-12-28</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d2ec_row3_col0" class="data row3 col0" >AH</td>
#       <td id="T_3d2ec_row3_col1" class="data row3 col1" >933,730</td>
#       <td id="T_3d2ec_row3_col2" class="data row3 col2" >28.00</td>
#       <td id="T_3d2ec_row3_col3" class="data row3 col3" >2023-12-28</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d2ec_row4_col0" class="data row4 col0" >AIMIRT</td>
#       <td id="T_3d2ec_row4_col1" class="data row4 col1" >196,901</td>
#       <td id="T_3d2ec_row4_col2" class="data row4 col2" >10.40</td>
#       <td id="T_3d2ec_row4_col3" class="data row4 col3" >2023-12-28</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2023, 12, 27)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head()
# Out:
#      name      qty  price       today   end_date
# 0     ACE  8608162   1.53  2023-12-28 2023-12-27
# 1  ADVANC  6051288 217.00  2023-12-28 2023-12-27
# 2  AEONTS   215899 160.00  2023-12-28 2023-12-27
# 3      AH   933730  28.00  2023-12-28 2023-12-27
# 4  AIMIRT   196901  10.40  2023-12-28 2023-12-27

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2023, 12, 26)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['start_date'] = today_vol['end_date'] - num_business_days
today_vol.head()
# Out:
#      name      qty  price       today   end_date start_date
# 0     ACE  8608162   1.53  2023-12-28 2023-12-27 2023-12-26
# 1  ADVANC  6051288 217.00  2023-12-28 2023-12-27 2023-12-26
# 2  AEONTS   215899 160.00  2023-12-28 2023-12-27 2023-12-26
# 3      AH   933730  28.00  2023-12-28 2023-12-27 2023-12-26
# 4  AIMIRT   196901  10.40  2023-12-28 2023-12-27 2023-12-26

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (start_date, end_date)
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name','date'],ascending=[True,True]).head().style.format(format_dict)
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN '2023-12-26' AND '2023-12-27'
# <style type="text/css">
# </style>
# <table id="T_2f568_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f568_level0_row0" class="row_heading level0 row0" >377</th>
#       <td id="T_2f568_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_2f568_row0_col1" class="data row0 col1" >2023-12-26</td>
#       <td id="T_2f568_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_2f568_row0_col3" class="data row0 col3" >1.53</td>
#       <td id="T_2f568_row0_col4" class="data row0 col4" >1.47</td>
#       <td id="T_2f568_row0_col5" class="data row0 col5" >15,229,204</td>
#       <td id="T_2f568_row0_col6" class="data row0 col6" >1.47</td>
#     </tr>
#     <tr>
#       <th id="T_2f568_level0_row1" class="row_heading level0 row1" >188</th>
#       <td id="T_2f568_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_2f568_row1_col1" class="data row1 col1" >2023-12-27</td>
#       <td id="T_2f568_row1_col2" class="data row1 col2" >1.50</td>
#       <td id="T_2f568_row1_col3" class="data row1 col3" >1.55</td>
#       <td id="T_2f568_row1_col4" class="data row1 col4" >1.50</td>
#       <td id="T_2f568_row1_col5" class="data row1 col5" >6,775,279</td>
#       <td id="T_2f568_row1_col6" class="data row1 col6" >1.55</td>
#     </tr>
#     <tr>
#       <th id="T_2f568_level0_row2" class="row_heading level0 row2" >376</th>
#       <td id="T_2f568_row2_col0" class="data row2 col0" >ADVANC</td>
#       <td id="T_2f568_row2_col1" class="data row2 col1" >2023-12-26</td>
#       <td id="T_2f568_row2_col2" class="data row2 col2" >219.00</td>
#       <td id="T_2f568_row2_col3" class="data row2 col3" >222.00</td>
#       <td id="T_2f568_row2_col4" class="data row2 col4" >218.00</td>
#       <td id="T_2f568_row2_col5" class="data row2 col5" >4,790,696</td>
#       <td id="T_2f568_row2_col6" class="data row2 col6" >220.00</td>
#     </tr>
#     <tr>
#       <th id="T_2f568_level0_row3" class="row_heading level0 row3" >187</th>
#       <td id="T_2f568_row3_col0" class="data row3 col0" >ADVANC</td>
#       <td id="T_2f568_row3_col1" class="data row3 col1" >2023-12-27</td>
#       <td id="T_2f568_row3_col2" class="data row3 col2" >219.00</td>
#       <td id="T_2f568_row3_col3" class="data row3 col3" >220.00</td>
#       <td id="T_2f568_row3_col4" class="data row3 col4" >218.00</td>
#       <td id="T_2f568_row3_col5" class="data row3 col5" >5,367,364</td>
#       <td id="T_2f568_row3_col6" class="data row3 col6" >219.00</td>
#     </tr>
#     <tr>
#       <th id="T_2f568_level0_row4" class="row_heading level0 row4" >375</th>
#       <td id="T_2f568_row4_col0" class="data row4 col0" >AEONTS</td>
#       <td id="T_2f568_row4_col1" class="data row4 col1" >2023-12-26</td>
#       <td id="T_2f568_row4_col2" class="data row4 col2" >155.00</td>
#       <td id="T_2f568_row4_col3" class="data row4 col3" >156.00</td>
#       <td id="T_2f568_row4_col4" class="data row4 col4" >152.50</td>
#       <td id="T_2f568_row4_col5" class="data row4 col5" >83,062</td>
#       <td id="T_2f568_row4_col6" class="data row4 col6" >155.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner", 
                     suffixes=( "_today","_mean"))
df_merge2.columns
# Out:
# Index(['name', 'qty_today', 'price_today', 'today', 'end_date', 'start_date',
#        'qty_mean', 'price_mean'],
#       dtype='object')

# %%
df_merge2["qty_mean"] = df_merge2.qty_mean.astype("int64")
df_merge2.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d3388_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qty_today</th>
#       <th class="col_heading level0 col2" >price_today</th>
#       <th class="col_heading level0 col3" >today</th>
#       <th class="col_heading level0 col4" >end_date</th>
#       <th class="col_heading level0 col5" >start_date</th>
#       <th class="col_heading level0 col6" >qty_mean</th>
#       <th class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3388_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3388_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_d3388_row0_col1" class="data row0 col1" >8,608,162</td>
#       <td id="T_d3388_row0_col2" class="data row0 col2" >1.53</td>
#       <td id="T_d3388_row0_col3" class="data row0 col3" >2023-12-28</td>
#       <td id="T_d3388_row0_col4" class="data row0 col4" >2023-12-27</td>
#       <td id="T_d3388_row0_col5" class="data row0 col5" >2023-12-26</td>
#       <td id="T_d3388_row0_col6" class="data row0 col6" >11,002,241</td>
#       <td id="T_d3388_row0_col7" class="data row0 col7" >1.52</td>
#     </tr>
#     <tr>
#       <th id="T_d3388_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3388_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_d3388_row1_col1" class="data row1 col1" >6,051,288</td>
#       <td id="T_d3388_row1_col2" class="data row1 col2" >217.00</td>
#       <td id="T_d3388_row1_col3" class="data row1 col3" >2023-12-28</td>
#       <td id="T_d3388_row1_col4" class="data row1 col4" >2023-12-27</td>
#       <td id="T_d3388_row1_col5" class="data row1 col5" >2023-12-26</td>
#       <td id="T_d3388_row1_col6" class="data row1 col6" >5,079,030</td>
#       <td id="T_d3388_row1_col7" class="data row1 col7" >219.00</td>
#     </tr>
#     <tr>
#       <th id="T_d3388_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3388_row2_col0" class="data row2 col0" >AEONTS</td>
#       <td id="T_d3388_row2_col1" class="data row2 col1" >215,899</td>
#       <td id="T_d3388_row2_col2" class="data row2 col2" >160.00</td>
#       <td id="T_d3388_row2_col3" class="data row2 col3" >2023-12-28</td>
#       <td id="T_d3388_row2_col4" class="data row2 col4" >2023-12-27</td>
#       <td id="T_d3388_row2_col5" class="data row2 col5" >2023-12-26</td>
#       <td id="T_d3388_row2_col6" class="data row2 col6" >118,704</td>
#       <td id="T_d3388_row2_col7" class="data row2 col7" >154.00</td>
#     </tr>
#     <tr>
#       <th id="T_d3388_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3388_row3_col0" class="data row3 col0" >AH</td>
#       <td id="T_d3388_row3_col1" class="data row3 col1" >933,730</td>
#       <td id="T_d3388_row3_col2" class="data row3 col2" >28.00</td>
#       <td id="T_d3388_row3_col3" class="data row3 col3" >2023-12-28</td>
#       <td id="T_d3388_row3_col4" class="data row3 col4" >2023-12-27</td>
#       <td id="T_d3388_row3_col5" class="data row3 col5" >2023-12-26</td>
#       <td id="T_d3388_row3_col6" class="data row3 col6" >914,447</td>
#       <td id="T_d3388_row3_col7" class="data row3 col7" >27.50</td>
#     </tr>
#     <tr>
#       <th id="T_d3388_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3388_row4_col0" class="data row4 col0" >AIMIRT</td>
#       <td id="T_d3388_row4_col1" class="data row4 col1" >196,901</td>
#       <td id="T_d3388_row4_col2" class="data row4 col2" >10.40</td>
#       <td id="T_d3388_row4_col3" class="data row4 col3" >2023-12-28</td>
#       <td id="T_d3388_row4_col4" class="data row4 col4" >2023-12-27</td>
#       <td id="T_d3388_row4_col5" class="data row4 col5" >2023-12-26</td>
#       <td id="T_d3388_row4_col6" class="data row4 col6" >304,685</td>
#       <td id="T_d3388_row4_col7" class="data row4 col7" >10.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
break_five_day_mean = df_merge2[(df_merge2.qty_today > df_merge2.qty_mean)]
break_five_day_mean.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_47a66_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qty_today</th>
#       <th class="col_heading level0 col2" >price_today</th>
#       <th class="col_heading level0 col3" >today</th>
#       <th class="col_heading level0 col4" >end_date</th>
#       <th class="col_heading level0 col5" >start_date</th>
#       <th class="col_heading level0 col6" >qty_mean</th>
#       <th class="col_heading level0 col7" >price_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47a66_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_47a66_row0_col0" class="data row0 col0" >ADVANC</td>
#       <td id="T_47a66_row0_col1" class="data row0 col1" >6,051,288</td>
#       <td id="T_47a66_row0_col2" class="data row0 col2" >217.00</td>
#       <td id="T_47a66_row0_col3" class="data row0 col3" >2023-12-28</td>
#       <td id="T_47a66_row0_col4" class="data row0 col4" >2023-12-27</td>
#       <td id="T_47a66_row0_col5" class="data row0 col5" >2023-12-26</td>
#       <td id="T_47a66_row0_col6" class="data row0 col6" >5,079,030</td>
#       <td id="T_47a66_row0_col7" class="data row0 col7" >219.00</td>
#     </tr>
#     <tr>
#       <th id="T_47a66_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_47a66_row1_col0" class="data row1 col0" >AEONTS</td>
#       <td id="T_47a66_row1_col1" class="data row1 col1" >215,899</td>
#       <td id="T_47a66_row1_col2" class="data row1 col2" >160.00</td>
#       <td id="T_47a66_row1_col3" class="data row1 col3" >2023-12-28</td>
#       <td id="T_47a66_row1_col4" class="data row1 col4" >2023-12-27</td>
#       <td id="T_47a66_row1_col5" class="data row1 col5" >2023-12-26</td>
#       <td id="T_47a66_row1_col6" class="data row1 col6" >118,704</td>
#       <td id="T_47a66_row1_col7" class="data row1 col7" >154.00</td>
#     </tr>
#     <tr>
#       <th id="T_47a66_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_47a66_row2_col0" class="data row2 col0" >AH</td>
#       <td id="T_47a66_row2_col1" class="data row2 col1" >933,730</td>
#       <td id="T_47a66_row2_col2" class="data row2 col2" >28.00</td>
#       <td id="T_47a66_row2_col3" class="data row2 col3" >2023-12-28</td>
#       <td id="T_47a66_row2_col4" class="data row2 col4" >2023-12-27</td>
#       <td id="T_47a66_row2_col5" class="data row2 col5" >2023-12-26</td>
#       <td id="T_47a66_row2_col6" class="data row2 col6" >914,447</td>
#       <td id="T_47a66_row2_col7" class="data row2 col7" >27.50</td>
#     </tr>
#     <tr>
#       <th id="T_47a66_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_47a66_row3_col0" class="data row3 col0" >AMATA</td>
#       <td id="T_47a66_row3_col1" class="data row3 col1" >3,143,905</td>
#       <td id="T_47a66_row3_col2" class="data row3 col2" >26.75</td>
#       <td id="T_47a66_row3_col3" class="data row3 col3" >2023-12-28</td>
#       <td id="T_47a66_row3_col4" class="data row3 col4" >2023-12-27</td>
#       <td id="T_47a66_row3_col5" class="data row3 col5" >2023-12-26</td>
#       <td id="T_47a66_row3_col6" class="data row3 col6" >2,468,636</td>
#       <td id="T_47a66_row3_col7" class="data row3 col7" >27.00</td>
#     </tr>
#     <tr>
#       <th id="T_47a66_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_47a66_row4_col0" class="data row4 col0" >ANAN</td>
#       <td id="T_47a66_row4_col1" class="data row4 col1" >2,725,748</td>
#       <td id="T_47a66_row4_col2" class="data row4 col2" >0.77</td>
#       <td id="T_47a66_row4_col3" class="data row4 col3" >2023-12-28</td>
#       <td id="T_47a66_row4_col4" class="data row4 col4" >2023-12-27</td>
#       <td id="T_47a66_row4_col5" class="data row4 col5" >2023-12-26</td>
#       <td id="T_47a66_row4_col6" class="data row4 col6" >2,190,904</td>
#       <td id="T_47a66_row4_col7" class="data row4 col7" >0.76</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT name, date, volbuy, price, dividend 
FROM buy 
WHERE active = 1
"""
buys = pd.read_sql(sql, const)
buys.volbuy = buys.volbuy.astype("int64")
buys.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a31f8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >volbuy</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a31f8_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_a31f8_row0_col0" class="data row0 col0" >KCE</td>
#       <td id="T_a31f8_row0_col1" class="data row0 col1" >2021-10-07</td>
#       <td id="T_a31f8_row0_col2" class="data row0 col2" >10,000</td>
#       <td id="T_a31f8_row0_col3" class="data row0 col3" >77.25</td>
#       <td id="T_a31f8_row0_col4" class="data row0 col4" >1.20</td>
#     </tr>
#     <tr>
#       <th id="T_a31f8_level0_row1" class="row_heading level0 row1" >29</th>
#       <td id="T_a31f8_row1_col0" class="data row1 col0" >CPNREIT</td>
#       <td id="T_a31f8_row1_col1" class="data row1 col1" >2022-08-16</td>
#       <td id="T_a31f8_row1_col2" class="data row1 col2" >60,000</td>
#       <td id="T_a31f8_row1_col3" class="data row1 col3" >17.55</td>
#       <td id="T_a31f8_row1_col4" class="data row1 col4" >0.85</td>
#     </tr>
#     <tr>
#       <th id="T_a31f8_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_a31f8_row2_col0" class="data row2 col0" >STA</td>
#       <td id="T_a31f8_row2_col1" class="data row2 col1" >2021-06-15</td>
#       <td id="T_a31f8_row2_col2" class="data row2 col2" >7,500</td>
#       <td id="T_a31f8_row2_col3" class="data row2 col3" >32.00</td>
#       <td id="T_a31f8_row2_col4" class="data row2 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_a31f8_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_a31f8_row3_col0" class="data row3 col0" >WHAIR</td>
#       <td id="T_a31f8_row3_col1" class="data row3 col1" >2021-10-11</td>
#       <td id="T_a31f8_row3_col2" class="data row3 col2" >50,000</td>
#       <td id="T_a31f8_row3_col3" class="data row3 col3" >8.70</td>
#       <td id="T_a31f8_row3_col4" class="data row3 col4" >0.53</td>
#     </tr>
#     <tr>
#       <th id="T_a31f8_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_a31f8_row4_col0" class="data row4 col0" >JMT</td>
#       <td id="T_a31f8_row4_col1" class="data row4 col1" >2023-01-26</td>
#       <td id="T_a31f8_row4_col2" class="data row4 col2" >4,200</td>
#       <td id="T_a31f8_row4_col3" class="data row4 col3" >55.50</td>
#       <td id="T_a31f8_row4_col4" class="data row4 col4" >0.93</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner", suffixes=("_mean","_today"))
df_merge3["qty_pct"] = round((df_merge3.qty_today - df_merge3.qty_mean) / abs(df_merge3.qty_mean) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_today - df_merge3.price_mean) / abs(df_merge3.price_mean) * 100,2)
df_merge3.rename(columns={'price_mean':'avg_price','price_today':'tdy_price',
                          'qty_mean':'avg_qty','qty_today':'tdy_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3495f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >prc_pct</th>
#       <th class="col_heading level0 col2" >tdy_price</th>
#       <th class="col_heading level0 col3" >avg_price</th>
#       <th class="col_heading level0 col4" >qty_pct</th>
#       <th class="col_heading level0 col5" >tdy_qty</th>
#       <th class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3495f_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_3495f_row0_col0" class="data row0 col0" >PTG</td>
#       <td id="T_3495f_row0_col1" class="data row0 col1" >6.38%</td>
#       <td id="T_3495f_row0_col2" class="data row0 col2" >8.75</td>
#       <td id="T_3495f_row0_col3" class="data row0 col3" >8.23</td>
#       <td id="T_3495f_row0_col4" class="data row0 col4" >127.68%</td>
#       <td id="T_3495f_row0_col5" class="data row0 col5" >24,060,672</td>
#       <td id="T_3495f_row0_col6" class="data row0 col6" >10,567,574</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_3495f_row1_col0" class="data row1 col0" >STA</td>
#       <td id="T_3495f_row1_col1" class="data row1 col1" >5.57%</td>
#       <td id="T_3495f_row1_col2" class="data row1 col2" >16.10</td>
#       <td id="T_3495f_row1_col3" class="data row1 col3" >15.25</td>
#       <td id="T_3495f_row1_col4" class="data row1 col4" >351.48%</td>
#       <td id="T_3495f_row1_col5" class="data row1 col5" >9,804,694</td>
#       <td id="T_3495f_row1_col6" class="data row1 col6" >2,171,656</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_3495f_row2_col0" class="data row2 col0" >NER</td>
#       <td id="T_3495f_row2_col1" class="data row2 col1" >2.48%</td>
#       <td id="T_3495f_row2_col2" class="data row2 col2" >4.96</td>
#       <td id="T_3495f_row2_col3" class="data row2 col3" >4.84</td>
#       <td id="T_3495f_row2_col4" class="data row2 col4" >170.03%</td>
#       <td id="T_3495f_row2_col5" class="data row2 col5" >14,936,690</td>
#       <td id="T_3495f_row2_col6" class="data row2 col6" >5,531,491</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_3495f_row3_col0" class="data row3 col0" >SYNEX</td>
#       <td id="T_3495f_row3_col1" class="data row3 col1" >1.96%</td>
#       <td id="T_3495f_row3_col2" class="data row3 col2" >10.40</td>
#       <td id="T_3495f_row3_col3" class="data row3 col3" >10.20</td>
#       <td id="T_3495f_row3_col4" class="data row3 col4" >320.13%</td>
#       <td id="T_3495f_row3_col5" class="data row3 col5" >926,522</td>
#       <td id="T_3495f_row3_col6" class="data row3 col6" >220,533</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_3495f_row4_col0" class="data row4 col0" >AH</td>
#       <td id="T_3495f_row4_col1" class="data row4 col1" >1.82%</td>
#       <td id="T_3495f_row4_col2" class="data row4 col2" >28.00</td>
#       <td id="T_3495f_row4_col3" class="data row4 col3" >27.50</td>
#       <td id="T_3495f_row4_col4" class="data row4 col4" >2.11%</td>
#       <td id="T_3495f_row4_col5" class="data row4 col5" >933,730</td>
#       <td id="T_3495f_row4_col6" class="data row4 col6" >914,447</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_3495f_row5_col0" class="data row5 col0" >WHART</td>
#       <td id="T_3495f_row5_col1" class="data row5 col1" >1.73%</td>
#       <td id="T_3495f_row5_col2" class="data row5 col2" >10.30</td>
#       <td id="T_3495f_row5_col3" class="data row5 col3" >10.12</td>
#       <td id="T_3495f_row5_col4" class="data row5 col4" >106.92%</td>
#       <td id="T_3495f_row5_col5" class="data row5 col5" >2,598,890</td>
#       <td id="T_3495f_row5_col6" class="data row5 col6" >1,255,993</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_3495f_row6_col0" class="data row6 col0" >ASP</td>
#       <td id="T_3495f_row6_col1" class="data row6 col1" >1.43%</td>
#       <td id="T_3495f_row6_col2" class="data row6 col2" >2.84</td>
#       <td id="T_3495f_row6_col3" class="data row6 col3" >2.80</td>
#       <td id="T_3495f_row6_col4" class="data row6 col4" >121.92%</td>
#       <td id="T_3495f_row6_col5" class="data row6 col5" >1,156,972</td>
#       <td id="T_3495f_row6_col6" class="data row6 col6" >521,341</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_3495f_row7_col0" class="data row7 col0" >BCH</td>
#       <td id="T_3495f_row7_col1" class="data row7 col1" >0.90%</td>
#       <td id="T_3495f_row7_col2" class="data row7 col2" >22.40</td>
#       <td id="T_3495f_row7_col3" class="data row7 col3" >22.20</td>
#       <td id="T_3495f_row7_col4" class="data row7 col4" >37.49%</td>
#       <td id="T_3495f_row7_col5" class="data row7 col5" >18,064,208</td>
#       <td id="T_3495f_row7_col6" class="data row7 col6" >13,138,150</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_3495f_row8_col0" class="data row8 col0" >ASK</td>
#       <td id="T_3495f_row8_col1" class="data row8 col1" >0.51%</td>
#       <td id="T_3495f_row8_col2" class="data row8 col2" >19.90</td>
#       <td id="T_3495f_row8_col3" class="data row8 col3" >19.80</td>
#       <td id="T_3495f_row8_col4" class="data row8 col4" >122.27%</td>
#       <td id="T_3495f_row8_col5" class="data row8 col5" >661,350</td>
#       <td id="T_3495f_row8_col6" class="data row8 col6" >297,547</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_3495f_row9_col0" class="data row9 col0" >KCE</td>
#       <td id="T_3495f_row9_col1" class="data row9 col1" >0.46%</td>
#       <td id="T_3495f_row9_col2" class="data row9 col2" >55.00</td>
#       <td id="T_3495f_row9_col3" class="data row9 col3" >54.75</td>
#       <td id="T_3495f_row9_col4" class="data row9 col4" >104.13%</td>
#       <td id="T_3495f_row9_col5" class="data row9 col5" >14,580,034</td>
#       <td id="T_3495f_row9_col6" class="data row9 col6" >7,142,493</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_3495f_row10_col0" class="data row10 col0" >TFFIF</td>
#       <td id="T_3495f_row10_col1" class="data row10 col1" >0.38%</td>
#       <td id="T_3495f_row10_col2" class="data row10 col2" >6.55</td>
#       <td id="T_3495f_row10_col3" class="data row10 col3" >6.53</td>
#       <td id="T_3495f_row10_col4" class="data row10 col4" >121.07%</td>
#       <td id="T_3495f_row10_col5" class="data row10 col5" >1,342,206</td>
#       <td id="T_3495f_row10_col6" class="data row10 col6" >607,130</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_3495f_row11_col0" class="data row11 col0" >PTTGC</td>
#       <td id="T_3495f_row11_col1" class="data row11 col1" >0.33%</td>
#       <td id="T_3495f_row11_col2" class="data row11 col2" >38.50</td>
#       <td id="T_3495f_row11_col3" class="data row11 col3" >38.38</td>
#       <td id="T_3495f_row11_col4" class="data row11 col4" >11.07%</td>
#       <td id="T_3495f_row11_col5" class="data row11 col5" >5,687,630</td>
#       <td id="T_3495f_row11_col6" class="data row11 col6" >5,120,739</td>
#     </tr>
#     <tr>
#       <th id="T_3495f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3495f_row12_col0" class="data row12 col0" >TMT</td>
#       <td id="T_3495f_row12_col1" class="data row12 col1" >-0.41%</td>
#       <td id="T_3495f_row12_col2" class="data row12 col2" >6.10</td>
#       <td id="T_3495f_row12_col3" class="data row12 col3" >6.12</td>
#       <td id="T_3495f_row12_col4" class="data row12 col4" >236.27%</td>
#       <td id="T_3495f_row12_col5" class="data row12 col5" >130,171

# %%
file_name = '5-day-average.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(data_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(one_file, header=True, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9ed7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9ed7_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_a9ed7_row0_col0" class="data row0 col0" >PTTGC</td>
#       <td id="T_a9ed7_row0_col1" class="data row0 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_a9ed7_level0_row1" class="row_heading level0 row1" >36</th>
#       <td id="T_a9ed7_row1_col0" class="data row1 col0" >KTB</td>
#       <td id="T_a9ed7_row1_col1" class="data row1 col1" >O</td>
#     </tr>
#     <tr>
#       <th id="T_a9ed7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9ed7_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_a9ed7_row2_col1" class="data row2 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_a9ed7_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_a9ed7_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_a9ed7_row3_col1" class="data row3 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_a9ed7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a9ed7_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_a9ed7_row4_col1" class="data row4 col1" >I</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = stocks["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'WHAIR', 'WHART', 'BBL', 'BEM', 'BH', 'CK', 'CPN', 'HANA', 'ICHI', 'KTB', 'SAPPE', 'TOA', 'TTB'"

# %%
type(in_p)
# Out:
# str

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
print(sql)

tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2023-12-28' AND name IN ('AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'WHAIR', 'WHART', 'BBL', 'BEM', 'BH', 'CK', 'CPN', 'HANA', 'ICHI', 'KTB', 'SAPPE', 'TOA', 'TTB')
# ORDER BY name
# '40 stocks'

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)

ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2023-12-27' AND name IN ('AH', 'AIMIRT', 'ASK', 'ASP', 'AWC', 'BCH', 'CPNREIT', 'DIF', 'GVREIT', 'IVL', 'JASIF', 'JMART', 'JMT', 'KCE', 'MCS', 'NER', 'ORI', 'PTG', 'PTTGC', 'RCL', 'SCC', 'SENA', 'SINGER', 'STA', 'SYNEX', 'TFFIF', 'TMT', 'WHAIR', 'WHART', 'BBL', 'BEM', 'BH', 'CK', 'CPN', 'HANA', 'ICHI', 'KTB', 'SAPPE', 'TOA', 'TTB')
# ORDER BY name
# '40 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner',suffixes=("_today","_yesterday"))
compare1.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_59c9c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_today</th>
#       <th class="col_heading level0 col2" >price_yesterday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59c9c_level0_row0" class="row_heading level0 row0" >33</th>
#       <td id="T_59c9c_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_59c9c_row0_col1" class="data row0 col1" >10.40</td>
#       <td id="T_59c9c_row0_col2" class="data row0 col2" >10.20</td>
#     </tr>
#     <tr>
#       <th id="T_59c9c_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_59c9c_row1_col0" class="data row1 col0" >ORI</td>
#       <td id="T_59c9c_row1_col1" class="data row1 col1" >8.45</td>
#       <td id="T_59c9c_row1_col2" class="data row1 col2" >8.40</td>
#     </tr>
#     <tr>
#       <th id="T_59c9c_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_59c9c_row2_col0" class="data row2 col0" >CK</td>
#       <td id="T_59c9c_row2_col1" class="data row2 col1" >20.80</td>
#       <td id="T_59c9c_row2_col2" class="data row2 col2" >20.40</td>
#     </tr>
#     <tr>
#       <th id="T_59c9c_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_59c9c_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_59c9c_row3_col1" class="data row3 col1" >7.75</td>
#       <td id="T_59c9c_row3_col2" class="data row3 col2" >7.65</td>
#     </tr>
#     <tr>
#       <th id="T_59c9c_level0_row4" class="row_heading level0 row4" >29</th>
#       <td id="T_59c9c_row4_col0" class="data row4 col0" >SCC</td>
#       <td id="T_59c9c_row4_col1" class="data row4 col1" >306.00</td>
#       <td id="T_59c9c_row4_col2" class="data row4 col2" >301.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4943_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_today</th>
#       <th class="col_heading level0 col2" >price_yesterday</th>
#       <th class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4943_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4943_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_f4943_row0_col1" class="data row0 col1" >28.00</td>
#       <td id="T_f4943_row0_col2" class="data row0 col2" >27.75</td>
#       <td id="T_f4943_row0_col3" class="data row0 col3" >B</td>
#     </tr>
#     <tr>
#       <th id="T_f4943_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4943_row1_col0" class="data row1 col0" >AIMIRT</td>
#       <td id="T_f4943_row1_col1" class="data row1 col1" >10.40</td>
#       <td id="T_f4943_row1_col2" class="data row1 col2" >10.40</td>
#       <td id="T_f4943_row1_col3" class="data row1 col3" >I</td>
#     </tr>
#     <tr>
#       <th id="T_f4943_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4943_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_f4943_row2_col1" class="data row2 col1" >19.90</td>
#       <td id="T_f4943_row2_col2" class="data row2 col2" >19.90</td>
#       <td id="T_f4943_row2_col3" class="data row2 col3" >B</td>
#     </tr>
#     <tr>
#       <th id="T_f4943_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4943_row3_col0" class="data row3 col0" >ASP</td>
#       <td id="T_f4943_row3_col1" class="data row3 col1" >2.84</td>
#       <td id="T_f4943_row3_col2" class="data row3 col2" >2.80</td>
#       <td id="T_f4943_row3_col3" class="data row3 col3" >I</td>
#     </tr>
#     <tr>
#       <th id="T_f4943_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4943_row4_col0" class="data row4 col0" >AWC</td>
#       <td id="T_f4943_row4_col1" class="data row4 col1" >3.56</td>
#       <td id="T_f4943_row4_col2" class="data row4 col2" >3.56</td>
#       <td id="T_f4943_row4_col3" class="data row4 col3" >I</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2.columns
# Out:
# Index(['name', 'price_today', 'price_yesterday', 'status'], dtype='object')

# %%
colx = ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']
colx
# Out:
# ['name', 'pct', 'price_today', 'price_yesterday', 'status', 'diff']

# %%
compare2['diff'] = round((compare2.price_today - compare2.price_yesterday),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_yesterday'] * 100,2)
compare2[colx].sort_values(['pct'],ascending=[False]).sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_54c16_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >pct</th>
#       <th class="col_heading level0 col2" >price_today</th>
#       <th class="col_heading level0 col3" >price_yesterday</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54c16_level0_row0" class="row_heading level0 row0" >29</th>
#       <td id="T_54c16_row0_col0" class="data row0 col0" >SCC</td>
#       <td id="T_54c16_row0_col1" class="data row0 col1" >1.66%</td>
#       <td id="T_54c16_row0_col2" class="data row0 col2" >306.00</td>
#       <td id="T_54c16_row0_col3" class="data row0 col3" >301.00</td>
#       <td id="T_54c16_row0_col4" class="data row0 col4" >I</td>
#       <td id="T_54c16_row0_col5" class="data row0 col5" >5.00</td>
#     </tr>
#     <tr>
#       <th id="T_54c16_level0_row1" class="row_heading level0 row1" >23</th>
#       <td id="T_54c16_row1_col0" class="data row1 col0" >NER</td>
#       <td id="T_54c16_row1_col1" class="data row1 col1" >2.48%</td>
#       <td id="T_54c16_row1_col2" class="data row1 col2" >4.96</td>
#       <td id="T_54c16_row1_col3" class="data row1 col3" >4.84</td>
#       <td id="T_54c16_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_54c16_row1_col5" class="data row1 col5" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_54c16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54c16_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_54c16_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_54c16_row2_col2" class="data row2 col2" >19.90</td>
#       <td id="T_54c16_row2_col3" class="data row2 col3" >19.90</td>
#       <td id="T_54c16_row2_col4" class="data row2 col4" >B</td>
#       <td id="T_54c16_row2_col5" class="data row2 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_54c16_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_54c16_row3_col0" class="data row3 col0" >KTB</td>
#       <td id="T_54c16_row3_col1" class="data row3 col1" >1.66%</td>
#       <td id="T_54c16_row3_col2" class="data row3 col2" >18.40</td>
#       <td id="T_54c16_row3_col3" class="data row3 col3" >18.10</td>
#       <td id="T_54c16_row3_col4" class="data row3 col4" >O</td>
#       <td id="T_54c16_row3_col5" class="data row3 col5" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_54c16_level0_row4" class="row_heading level0 row4" >32</th>
#       <td id="T_54c16_row4_col0" class="data row4 col0" >STA</td>
#       <td id="T_54c16_row4_col1" class="data row4 col1" >5.92%</td>
#       <td id="T_54c16_row4_col2" class="data row4 col2" >16.10</td>
#       <td id="T_54c16_row4_col3" class="data row4 col3" >15.20</td>
#       <td id="T_54c16_row4_col4" class="data row4 col4" >I</td>
#       <td id="T_54c16_row4_col5" class="data row4 col5" >0.90</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2dd8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >pct</th>
#       <th class="col_heading level0 col2" >price_today</th>
#       <th class="col_heading level0 col3" >price_yesterday</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2dd8_level0_row0" class="row_heading level0 row0" >25</th>
#       <td id="T_a2dd8_row0_col0" class="data row0 col0" >PTG</td>
#       <td id="T_a2dd8_row0_col1" class="data row0 col1" >5.42%</td>
#       <td id="T_a2dd8_row0_col2" class="data row0 col2" >8.75</td>
#       <td id="T_a2dd8_row0_col3" class="data row0 col3" >8.30</td>
#       <td id="T_a2dd8_row0_col4" class="data row0 col4" >B</td>
#       <td id="T_a2dd8_row0_col5" class="data row0 col5" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_a2dd8_level0_row1" class="row_heading level0 row1" >32</th>
#       <td id="T_a2dd8_row1_col0" class="data row1 col0" >STA</td>
#       <td id="T_a2dd8_row1_col1" class="data row1 col1" >5.92%</td>
#       <td id="T_a2dd8_row1_col2" class="data row1 col2" >16.10</td>
#       <td id="T_a2dd8_row1_col3" class="data row1 col3" >15.20</td>
#       <td id="T_a2dd8_row1_col4" class="data row1 col4" >I</td>
#       <td id="T_a2dd8_row1_col5" class="data row1 col5" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_a2dd8_level0_row2" class="row_heading level0 row2" >37</th>
#       <td id="T_a2dd8_row2_col0" class="data row2 col0" >TTB</td>
#       <td id="T_a2dd8_row2_col1" class="data row2 col1" >3.73%</td>
#       <td id="T_a2dd8_row2_col2" class="data row2 col2" >1.67</td>
#       <td id="T_a2dd8_row2_col3" class="data row2 col3" >1.61</td>
#       <td id="T_a2dd8_row2_col4" class="data row2 col4" >O</td>
#       <td id="T_a2dd8_row2_col5" class="data row2 col5" >0.06</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(data_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(one_file, index=False)
extremes[colx].sort_values(['status','pct'],ascending=[True,False]).to_csv(osd_file, index=False)
