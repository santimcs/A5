# %% [markdown]
# ### Must run step by step as there are command lines to be executed in the middle of the flow

# %%
import numpy as np
import os
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
#data_path = "\\users\\user\\onedrive\\a7\\Data"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2023, 12, 28)

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-12-28
# yesterday: 2023-12-27

# %%
cols = 'name fm_date to_date fm_price to_price qty max_price min_price percent status'.split()

format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'volume':'{:,.2f}','beta':'{:,.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}',
}

# %% [markdown]
# ### Begin of Tables in the process

# %%
sql = """
SELECT * 
FROM sales 
ORDER BY id DESC LIMIT 1
"""
tmp = pd.read_sql(sql, conlite)
tmp["fm_date"] = pd.to_datetime(tmp["fm_date"])
tmp["to_date"] = pd.to_datetime(tmp["to_date"])
tmp["created_at"] = pd.to_datetime(tmp["created_at"])
tmp["updated_at"] = pd.to_datetime(tmp["updated_at"])
tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af53a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >fm_date</th>
#       <th class="col_heading level0 col3" >to_date</th>
#       <th class="col_heading level0 col4" >days</th>
#       <th class="col_heading level0 col5" >fm_price</th>
#       <th class="col_heading level0 col6" >to_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#       <th class="col_heading level0 col8" >pct</th>
#       <th class="col_heading level0 col9" >ttl_spread</th>
#       <th class="col_heading level0 col10" >avg_spread</th>
#       <th class="col_heading level0 col11" >max_price</th>
#       <th class="col_heading level0 col12" >min_price</th>
#       <th class="col_heading level0 col13" >qty</th>
#       <th class="col_heading level0 col14" >created_at</th>
#       <th class="col_heading level0 col15" >updated_at</th>
#       <th class="col_heading level0 col16" >latest_date_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af53a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af53a_row0_col0" class="data row0 col0" >1393885</td>
#       <td id="T_af53a_row0_col1" class="data row0 col1" >WHAIR</td>
#       <td id="T_af53a_row0_col2" class="data row0 col2" >2023-12-28</td>
#       <td id="T_af53a_row0_col3" class="data row0 col3" >2023-12-28</td>
#       <td id="T_af53a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_af53a_row0_col5" class="data row0 col5" >5.55</td>
#       <td id="T_af53a_row0_col6" class="data row0 col6" >5.50</td>
#       <td id="T_af53a_row0_col7" class="data row0 col7" >-0.05</td>
#       <td id="T_af53a_row0_col8" class="data row0 col8" >-0.90%</td>
#       <td id="T_af53a_row0_col9" class="data row0 col9" >-1</td>
#       <td id="T_af53a_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_af53a_row0_col11" class="data row0 col11" >5.55</td>
#       <td id="T_af53a_row0_col12" class="data row0 col12" >5.30</td>
#       <td id="T_af53a_row0_col13" class="data row0 col13" >4,970,224</td>
#       <td id="T_af53a_row0_col14" class="data row0 col14" >2023-12-28</td>
#       <td id="T_af53a_row0_col15" class="data row0 col15" >2023-12-28</td>
#       <td id="T_af53a_row0_col16" class="data row0 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = tmp["name"]
name = names.to_string(index=False)
name
# Out:
# 'WHAIR'

# %%
sql = """
SELECT * 
FROM stocks
WHERE name = '%s'
"""
sql = sql % name
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM stocks
# WHERE name = 'WHAIR'
# <style type="text/css">
# </style>
# <table id="T_abcc4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >max_price</th>
#       <th class="col_heading level0 col3" >min_price</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >buy_target</th>
#       <th class="col_heading level0 col6" >sell_target</th>
#       <th class="col_heading level0 col7" >volume</th>
#       <th class="col_heading level0 col8" >beta</th>
#       <th class="col_heading level0 col9" >cost</th>
#       <th class="col_heading level0 col10" >qty</th>
#       <th class="col_heading level0 col11" >buy_spread</th>
#       <th class="col_heading level0 col12" >sell_spread</th>
#       <th class="col_heading level0 col13" >available_qty</th>
#       <th class="col_heading level0 col14" >bl</th>
#       <th class="col_heading level0 col15" >sh</th>
#       <th class="col_heading level0 col16" >reason</th>
#       <th class="col_heading level0 col17" >market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abcc4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abcc4_row0_col0" class="data row0 col0" >127</td>
#       <td id="T_abcc4_row0_col1" class="data row0 col1" >WHAIR</td>
#       <td id="T_abcc4_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_abcc4_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_abcc4_row0_col4" class="data row0 col4" >B</td>
#       <td id="T_abcc4_row0_col5" class="data row0 col5" >4.85</td>
#       <td id="T_abcc4_row0_col6" class="data row0 col6" >7.75</td>
#       <td id="T_abcc4_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_abcc4_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_abcc4_row0_col9" class="data row0 col9" >8.70</td>
#       <td id="T_abcc4_row0_col10" class="data row0 col10" >5,000</td>
#       <td id="T_abcc4_row0_col11" class="data row0 col11" >-4</td>
#       <td id="T_abcc4_row0_col12" class="data row0 col12" >4</td>
#       <td id="T_abcc4_row0_col13" class="data row0 col13" >50,000</td>
#       <td id="T_abcc4_row0_col14" class="data row0 col14" >6.000000</td>
#       <td id="T_abcc4_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_abcc4_row0_col16" class="data row0 col16" >RD45pct</td>
#       <td id="T_abcc4_row0_col17" class="data row0 col17" >SET</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### End of Tables in the process

# %%
sql = """
SELECT DISTINCT a.name
FROM sales a 
WHERE to_date = '%s'
ORDER BY a.name
"""
sql = sql % yesterday
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp.shape
# Out:
# SELECT DISTINCT a.name
# FROM sales a
# WHERE to_date = '2023-12-27'
# ORDER BY a.name
# (17, 1)

# %%
sql = """
SELECT a.name,fm_date,to_date,fm_price,to_price,
a.qty,a.max_price,a.min_price,t.status,t.market
FROM sales a 
JOIN stocks t ON a.name = t.name 
WHERE to_date = '%s' AND t.status IN ("B","I", "O", "S") 
ORDER BY t.status, a.name
"""
sql = sql % yesterday
print(sql)
# Out:
# SELECT a.name,fm_date,to_date,fm_price,to_price,
# a.qty,a.max_price,a.min_price,t.status,t.market
# FROM sales a
# JOIN stocks t ON a.name = t.name
# WHERE to_date = '2023-12-27' AND t.status IN ("B","I", "O", "S")
# ORDER BY t.status, a.name

# %% [markdown]
# ### This statement causes program to hang when there is no data

# %%
df = pd.read_sql(sql, conlite)
#df.set_index(["name"], inplace=True)
df['fm_date'] = pd.to_datetime(df['fm_date'])
df['to_date'] = pd.to_datetime(df['to_date'])
df.eval('diff = to_price - fm_price',inplace=True)
df['percent'] = round(df['diff']/df['fm_price']*100,2)
#df.style.format(format_dict)
df
# Out:
#       name    fm_date    to_date  fm_price  to_price        qty  max_price  \
# 0      JMT 2023-12-22 2023-12-27     26.25     25.25   78699560      27.00
# 1      ORI 2023-12-27 2023-12-27      8.45      8.40   17549640       8.55
# 2    PTTGC 2023-12-27 2023-12-27     38.50     38.25   28807478      38.75
# 3     SENA 2023-12-26 2023-12-27      2.36      2.34     702596       2.36
# 4   SINGER 2023-12-22 2023-12-27     12.00     11.50   71489728      12.30
# 5    SYNEX 2023-12-22 2023-12-27     10.30     10.20    5965336      10.50
# 6      TMT 2023-12-27 2023-12-27      6.10      6.15     183560       6.20
# 7    WHAIR 2023-12-20 2023-12-27      5.40      5.55    4970224       5.55
# 8      ASP 2023-12-26 2023-12-27      2.82      2.80    2060352       2.82
# 9      KCE 2023-12-22 2023-12-27     56.25     54.25   38505728      57.00
# 10     MCS 2023-12-22 2023-12-27      6.45      6.55     880816       6.55
# 11     RCL 2023-12-27 2023-12-27     23.40     24.50  107581798      24.80
# 12     STA 2023-12-27 2023-12-27     15.30     15.20    5141028      15.30
# 13     BEM 2023-12-27 2023-12-27      7.95      7.90  172930926       8.10
# 14      BH 2023-12-27 2023-12-27    222.00    220.00    9107256     222.00
# 15    HANA 2023-12-27 2023-12-27     54.00     52.25   63904489      54.75
# 16     KTB 2023-12-18 2023-12-27     18.40     18.10  847406624      18.50
#
#     min_price status  market  diff  percent
# 0       25.25      B   SET50 -1.00    -3.81
# 1        8.20      B  SET100 -0.05    -0.59
# 2       37.50      B   SET50 -0.25    -0.65
# 3        2.32      B     SET -0.02    -0.85
# 4       11.50      B  SET100 -0.50    -4.17
# 5       10.20      B     SET -0.10    -0.97
# 6        6.10      B     SET  0.05     0.82
# 7        5.30      B     SET  0.15     2.78
# 8        2.80      I     SET -0.02    -0.71
# 9       54.25      I  SET100 -2.00    -3.56
# 10       6.45      I     SET  0.10     1.55
# 11      19.80      I  SET100  1.10     4.70
# 12      14.80      I  SET100 -0.10    -0.65
# 13       7.80      O   SET50 -0.05    -0.63
# 14     214.00      O   SET50 -2.00    -0.90
# 15      48.75      O  SET100 -1.75    -3.24
# 16      18.10      O   SET50 -0.30    -1.63

# %% [markdown]
# ### IF the above count not equal number of orders, there must be something incorrect

# %% [markdown]
# ### Create daily-sales from sales

# %%
df[cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06977_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >percent</th>
#       <th class="col_heading level0 col9" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06977_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06977_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_06977_row0_col1" class="data row0 col1" >2023-12-26</td>
#       <td id="T_06977_row0_col2" class="data row0 col2" >2023-12-26</td>
#       <td id="T_06977_row0_col3" class="data row0 col3" >27.50</td>
#       <td id="T_06977_row0_col4" class="data row0 col4" >27.25</td>
#       <td id="T_06977_row0_col5" class="data row0 col5" >1,598,752</td>
#       <td id="T_06977_row0_col6" class="data row0 col6" >27.50</td>
#       <td id="T_06977_row0_col7" class="data row0 col7" >26.75</td>
#       <td id="T_06977_row0_col8" class="data row0 col8" >-0.91%</td>
#       <td id="T_06977_row0_col9" class="data row0 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06977_row1_col0" class="data row1 col0" >ASK</td>
#       <td id="T_06977_row1_col1" class="data row1 col1" >2023-12-26</td>
#       <td id="T_06977_row1_col2" class="data row1 col2" >2023-12-26</td>
#       <td id="T_06977_row1_col3" class="data row1 col3" >20.00</td>
#       <td id="T_06977_row1_col4" class="data row1 col4" >19.70</td>
#       <td id="T_06977_row1_col5" class="data row1 col5" >412,252</td>
#       <td id="T_06977_row1_col6" class="data row1 col6" >20.10</td>
#       <td id="T_06977_row1_col7" class="data row1 col7" >19.70</td>
#       <td id="T_06977_row1_col8" class="data row1 col8" >-1.50%</td>
#       <td id="T_06977_row1_col9" class="data row1 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06977_row2_col0" class="data row2 col0" >CPNREIT</td>
#       <td id="T_06977_row2_col1" class="data row2 col1" >2023-12-21</td>
#       <td id="T_06977_row2_col2" class="data row2 col2" >2023-12-26</td>
#       <td id="T_06977_row2_col3" class="data row2 col3" >11.00</td>
#       <td id="T_06977_row2_col4" class="data row2 col4" >11.20</td>
#       <td id="T_06977_row2_col5" class="data row2 col5" >7,311,248</td>
#       <td id="T_06977_row2_col6" class="data row2 col6" >11.20</td>
#       <td id="T_06977_row2_col7" class="data row2 col7" >10.90</td>
#       <td id="T_06977_row2_col8" class="data row2 col8" >1.82%</td>
#       <td id="T_06977_row2_col9" class="data row2 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06977_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_06977_row3_col1" class="data row3 col1" >2023-12-22</td>
#       <td id="T_06977_row3_col2" class="data row3 col2" >2023-12-26</td>
#       <td id="T_06977_row3_col3" class="data row3 col3" >7.50</td>
#       <td id="T_06977_row3_col4" class="data row3 col4" >7.60</td>
#       <td id="T_06977_row3_col5" class="data row3 col5" >70,326,416</td>
#       <td id="T_06977_row3_col6" class="data row3 col6" >7.60</td>
#       <td id="T_06977_row3_col7" class="data row3 col7" >7.40</td>
#       <td id="T_06977_row3_col8" class="data row3 col8" >1.33%</td>
#       <td id="T_06977_row3_col9" class="data row3 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06977_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_06977_row4_col1" class="data row4 col1" >2023-12-20</td>
#       <td id="T_06977_row4_col2" class="data row4 col2" >2023-12-26</td>
#       <td id="T_06977_row4_col3" class="data row4 col3" >5.60</td>
#       <td id="T_06977_row4_col4" class="data row4 col4" >5.65</td>
#       <td id="T_06977_row4_col5" class="data row4 col5" >11,403,200</td>
#       <td id="T_06977_row4_col6" class="data row4 col6" >5.70</td>
#       <td id="T_06977_row4_col7" class="data row4 col7" >5.45</td>
#       <td id="T_06977_row4_col8" class="data row4 col8" >0.89%</td>
#       <td id="T_06977_row4_col9" class="data row4 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06977_row5_col0" class="data row5 col0" >JASIF</td>
#       <td id="T_06977_row5_col1" class="data row5 col1" >2023-12-20</td>
#       <td id="T_06977_row5_col2" class="data row5 col2" >2023-12-26</td>
#       <td id="T_06977_row5_col3" class="data row5 col3" >5.85</td>
#       <td id="T_06977_row5_col4" class="data row5 col4" >6.15</td>
#       <td id="T_06977_row5_col5" class="data row5 col5" >61,035,160</td>
#       <td id="T_06977_row5_col6" class="data row5 col6" >6.15</td>
#       <td id="T_06977_row5_col7" class="data row5 col7" >5.75</td>
#       <td id="T_06977_row5_col8" class="data row5 col8" >5.13%</td>
#       <td id="T_06977_row5_col9" class="data row5 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06977_row6_col0" class="data row6 col0" >JMT</td>
#       <td id="T_06977_row6_col1" class="data row6 col1" >2023-12-22</td>
#       <td id="T_06977_row6_col2" class="data row6 col2" >2023-12-26</td>
#       <td id="T_06977_row6_col3" class="data row6 col3" >26.25</td>
#       <td id="T_06977_row6_col4" class="data row6 col4" >25.25</td>
#       <td id="T_06977_row6_col5" class="data row6 col5" >39,349,780</td>
#       <td id="T_06977_row6_col6" class="data row6 col6" >27.00</td>
#       <td id="T_06977_row6_col7" class="data row6 col7" >25.25</td>
#       <td id="T_06977_row6_col8" class="data row6 col8" >-3.81%</td>
#       <td id="T_06977_row6_col9" class="data row6 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06977_row7_col0" class="data row7 col0" >NER</td>
#       <td id="T_06977_row7_col1" class="data row7 col1" >2023-12-21</td>
#       <td id="T_06977_row7_col2" class="data row7 col2" >2023-12-26</td>
#       <td id="T_06977_row7_col3" class="data row7 col3" >4.68</td>
#       <td id="T_06977_row7_col4" class="data row7 col4" >4.84</td>
#       <td id="T_06977_row7_col5" class="data row7 col5" >24,608,052</td>
#       <td id="T_06977_row7_col6" class="data row7 col6" >4.84</td>
#       <td id="T_06977_row7_col7" class="data row7 col7" >4.62</td>
#       <td id="T_06977_row7_col8" class="data row7 col8" >3.42%</td>
#       <td id="T_06977_row7_col9" class="data row7 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06977_row8_col0" class="data row8 col0" >ORI</td>
#       <td id="T_06977_row8_col1" class="data row8 col1" >2023-12-26</td>
#       <td id="T_06977_row8_col2" class="data row8 col2" >2023-12-26</td>
#       <td id="T_06977_row8_col3" class="data row8 col3" >8.40</td>
#       <td id="T_06977_row8_col4" class="data row8 col4" >8.45</td>
#       <td id="T_06977_row8_col5" class="data row8 col5" >17,549,640</td>
#       <td id="T_06977_row8_col6" class="data row8 col6" >8.55</td>
#       <td id="T_06977_row8_col7" class="data row8 col7" >8.20</td>
#       <td id="T_06977_row8_col8" class="data row8 col8" >0.60%</td>
#       <td id="T_06977_row8_col9" class="data row8 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_06977_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06977_row9_col0" class="data row9 col0" >PTG</td>
#       <td id="T_06977_row9_col1" class="data row9 col1" >2023-12-18</td>
#       <td id="T_06977_row9_col2" clas

# %%
file_name = "daily-sales.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(output_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(data_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(one_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(osd_file, header=True, index=False)

# %%
sales = df[cols]
sales.shape
# Out:
# (40, 10)

# %%
file_name = "Price-Today.csv"
input_file = data_path + file_name
prices = pd.read_csv(input_file)
prices.shape
# Out:
# (189, 10)

# %%
df_merge = pd.merge(sales,prices,on='name', how='inner')
df_merge.shape
# Out:
# (40, 19)

# %%
colu = 'name fm_date to_date fm_price to_price qty max_price min_price percent status \
price change volume date'.split()
df_merge[colu]
# Out:
#        name    fm_date    to_date  fm_price  to_price        qty  max_price  \
# 0        AH 2023-12-26 2023-12-26     27.50     27.25    1598752      27.50
# 1       ASK 2023-12-26 2023-12-26     20.00     19.70     412252      20.10
# 2   CPNREIT 2023-12-21 2023-12-26     11.00     11.20    7311248      11.20
# 3       DIF 2023-12-22 2023-12-26      7.50      7.60   70326416       7.60
# 4    GVREIT 2023-12-20 2023-12-26      5.60      5.65   11403200       5.70
# 5     JASIF 2023-12-20 2023-12-26      5.85      6.15   61035160       6.15
# 6       JMT 2023-12-22 2023-12-26     26.25     25.25   39349780      27.00
# 7       NER 2023-12-21 2023-12-26      4.68      4.84   24608052       4.84
# 8       ORI 2023-12-26 2023-12-26      8.40      8.45   17549640       8.55
# 9       PTG 2023-12-18 2023-12-26      8.95      8.15  161397152       9.15
# 10    PTTGC 2023-12-26 2023-12-26     38.00     38.50   28807478      38.75
# 11     SENA 2023-12-26 2023-12-26      2.36      2.34     351298       2.36
# 12   SINGER 2023-12-22 2023-12-26     12.00     11.60   35744864      12.30
# 13    SYNEX 2023-12-22 2023-12-26     10.30     10.20    2982668      10.50
# 14    TFFIF 2023-12-26 2023-12-26      6.55      6.50    2901000       6.60
# 15      TMT 2023-12-25 2023-12-26      6.20      6.10     183560       6.20
# 16    WHAIR 2023-12-20 2023-12-26      5.40      5.55    2485112       5.55
# 17    WHART 2023-12-21 2023-12-26      9.80      9.95   13241008       9.95
# 18   AIMIRT 2023-12-26 2023-12-26     10.20     10.30    2904020      10.40
# 19      ASP 2023-12-26 2023-12-26      2.82      2.80    1030176       2.82
# 20      AWC 2023-12-25 2023-12-26      3.48      3.50  490443566       3.64
# 21      BCH 2023-12-20 2023-12-26     21.70     22.00   73792604      22.00
# 22      IVL 2023-12-26 2023-12-26     26.75     27.00   75003478      27.75
# 23    JMART 2023-12-22 2023-12-26     18.00     17.40   75158172      18.40
# 24      KCE 2023-12-22 2023-12-26     56.25     55.25   19252864      57.00
# 25      MCS 2023-12-22 2023-12-26      6.45      6.55     440408       6.55
# 26      RCL 2023-12-25 2023-12-26     24.40     23.40  107581798      24.80
# 27      SCC 2023-12-22 2023-12-26    296.00    301.00    5436916     301.00
# 28      STA 2023-12-22 2023-12-26     15.00     15.30    5141028      15.30
# 29      TOA 2023-12-14 2023-12-26     21.90     22.80   20672120      22.80
# 30      BBL 2023-12-26 2023-12-26    149.50    151.00   12805346     152.50
# 31      BEM 2023-12-26 2023-12-26      7.85      7.95  172930926       8.10
# 32       BH 2023-12-22 2023-12-26    216.00    222.00    9107256     222.00
# 33       CK 2023-12-26 2023-12-26     20.30     20.40    2088208      21.10
# 34      CPN 2023-12-26 2023-12-26     67.50     68.50    8463376      68.50
# 35     HANA 2023-12-26 2023-12-26     53.50     54.00   63904489      54.75
# 36     ICHI 2023-12-21 2023-12-26     14.80     15.30   66646960      15.30
# 37      KTB 2023-12-18 2023-12-26     18.40     18.20  423703312      18.50
# 38    SAPPE 2023-12-26 2023-12-26     84.75     84.00    2008156      86.50
# 39      TTB 2023-12-22 2023-12-26      1.59      1.61  290546152       1.61
#
#     min_price  percent status   price  change     volume        date
# 0       26.75    -0.91      B   27.75    0.50    1419668  2023-12-27
# 1       19.70    -1.50      B   19.90    0.20     231243  2023-12-27
# 2       10.90     1.82      B   11.30    0.10    1067518  2023-12-27
# 3        7.40     1.33      B    7.65    0.05    8859045  2023-12-27
# 4        5.45     0.89      B    5.65    0.00    1465861  2023-12-27
# 5        5.75     5.13      B    6.20    0.05    5169807  2023-12-27
# 6       25.25    -3.81      B   25.25    0.00    7195184  2023-12-27
# 7        4.62     3.42      B    4.84    0.00    2930449  2023-12-27
# 8        8.20     0.60      B    8.40   -0.05    5017199  2023-12-27
# 9        8.15    -8.94      B    8.30    0.15    7525624  2023-12-27
# 10      37.50     1.32      B   38.25   -0.25    4106377  2023-12-27
# 11       2.32    -0.85      B    2.34    0.00     524683  2023-12-27
# 12      11.60    -3.33      B   11.50   -0.10    6701639  2023-12-27
# 13      10.20    -0.97      B   10.20    0.00     333500  2023-12-27
# 14       6.45    -0.76      B    6.55    0.05     419715  2023-12-27
# 15       6.10    -1.61      B    6.15    0.05      26720  2023-12-27
# 16       5.30     2.78      B    5.55    0.00     234601  2023-12-27
# 17       9.70     1.53      B   10.30    0.35    2042124  2023-12-27
# 18      10.20     0.98      I   10.40    0.10     355501  2023-12-27
# 19       2.80    -0.71      I    2.80    0.00     251114  2023-12-27
# 20       3.42     0.57      I    3.56    0.06  168231874  2023-12-27
# 21      21.50     1.38      I   22.40    0.40   21283355  2023-12-27
# 22      26.75     0.93      I   27.00    0.00   14484420  2023-12-27
# 23      17.40    -3.33      I   17.30   -0.10   11279390  2023-12-27
# 24      55.25    -1.78      I   54.25   -1.00    8997897  2023-12-27
# 25       6.45     1.55      I    6.55    0.00      74400  2023-12-27
# 26      19.80    -4.10      I   24.50    1.10   15573577  2023-12-27
# 27     292.00     1.69      I  301.00    0.00    1625033  2023-12-27
# 28      14.80     2.00      I   15.20   -0.10    2372032  2023-12-27
# 29      21.90     4.11      I   22.60   -0.20     440505  2023-12-27
# 30     149.50     1.00      O  152.00    1.00   10564959  2023-12-27
# 31       7.80     1.27      O    7.90   -0.05   13564386  2023-12-27
# 32     214.00     2.78      O  220.00   -2.00    1186789  2023-12-27
# 33      20.30     0.49      O   20.40    0.00    1094800  2023-12-27
# 34      66.25     1.48      O   69.25    0.75   11540066  2023-12-27
# 35      48.75     0.93      O   52.25   -1.75   10577016  2023-12-27
# 36      14.60     3.38      O   15.60    0.30   19168176  2023-12-27
# 37      18.20    -1.09      O   18.10   -0.10   45579531  2023-12-27
# 38      83.75    -0.88      O   86.25    2.25     814038  2023-12-27
# 39       1.59     1.26      O    1.61    0.00  104292512  2023-12-27

# %%
file_name = "daily-sales-prices.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(output_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(data_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(one_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Call ruby ruby\daily-out-new.rb

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\OneDrive\\A7\\Daily'

# %%
os.chdir("C:\\users\\user\\onedrive\\a7")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7'

# %%
# !ruby ruby\\daily-out-new.rb
# Out:
# Name      From Date    To Date   From     To     Pct      Shares    Max    Min S Action
# ---------------------------------------------------------------------------------------
# AH       2023-12-27 2023-12-27  27.25  27.75   1.83%   1,598,752  27.75  26.75 B Insert
# AIMIRT   2023-12-26 2023-12-27  10.20  10.40   1.96%   2,904,020  10.40  10.20 I Update
# ASK      2023-12-27 2023-12-27  19.70  19.90   1.02%     412,252  20.10  19.70 B Insert
# ASP      2023-12-26 2023-12-27   2.82   2.80  -0.71%   1,030,176   2.82   2.80 I Update
# AWC      2023-12-25 2023-12-27   3.48   3.56    2.3% 490,443,566   3.64   3.42 I Update
# BBL      2023-12-26 2023-12-27 149.50 152.00   1.67%  12,805,346 152.50 149.50 O Update
# BCH      2023-12-20 2023-12-27  21.70  22.40   3.23%  73,792,604  22.40  21.50 I Update
# BEM      2023-12-27 2023-12-27   7.95   7.90  -0.63% 172,930,926   8.10   7.80 O Insert
# BH       2023-12-27 2023-12-27 222.00 220.00   -0.9%   9,107,256 222.00 214.00 O Insert
# CK       2023-12-26 2023-12-27  20.30  20.40   0.49%   2,088,208  21.10  20.30 O Update
# CPN      2023-12-26 2023-12-27  67.50  69.25   2.59%   8,463,376  69.25  66.25 O Update
# CPNREIT  2023-12-21 2023-12-27  11.00  11.30   2.73%   7,311,248  11.30  10.90 B Update
# DIF      2023-12-22 2023-12-27   7.50   7.65    2.0%  70,326,416   7.65   7.40 B Update
# GVREIT   2023-12-20 2023-12-27   5.60   5.65   0.89%  11,403,200   5.70   5.45 B Update
# HANA     2023-12-27 2023-12-27  54.00  52.25  -3.24%  63,904,489  54.75  48.75 O Insert
# ICHI     2023-12-21 2023-12-27  14.80  15.60   5.41%  66,646,960  15.60  14.60 O Update
# IVL      2023-12-26 2023-12-27  26.75  27.00   0.93%  75,003,478  27.75  26.75 I Update
# JASIF    2023-12-20 2023-12-27   5.85   6.20   5.98%  61,035,160   6.20   5.75 B Update
# JMART    2023-12-22 2023-12-27  18.00  17.30  -3.89%  75,158,172  18.40  17.30 I Update
# JMT      2023-12-22 2023-12-27  26.25  25.25  -3.81%  39,349,780  27.00  25.25 B Update
# KCE      2023-12-22 2023-12-27  56.25  54.25  -3.56%  19,252,864  57.00  54.25 I Update
# KTB      2023-12-18 2023-12-27  18.40  18.10  -1.63% 423,703,312  18.50  18.10 O Update
# MCS      2023-12-22 2023-12-27   6.45   6.55   1.55%     440,408   6.55   6.45 I Update
# NER      2023-12-21 2023-12-27   4.68   4.84   3.42%  24,608,052   4.84   4.62 B Update
# ORI      2023-12-27 2023-12-27   8.45   8.40  -0.59%  17,549,640   8.55   8.20 B Insert
# PTG      2023-12-27 2023-12-27   8.15   8.30   1.84% 161,397,152   9.15   8.15 B Insert
# PTTGC    2023-12-27 2023-12-27  38.50  38.25  -0.65%  28,807,478  38.75  37.50 B Insert
# RCL      2023-12-27 2023-12-27  23.40  24.50    4.7% 107,581,798  24.80  19.80 I Insert
# SAPPE    2023-12-27 2023-12-27  84.00  86.25   2.68%   2,008,156  86.50  83.75 O Insert
# SCC      2023-12-22 2023-12-27 296.00 301.00   1.69%   5,436,916 301.00 292.00 I Update
# SENA     2023-12-26 2023-12-27   2.36   2.34  -0.85%     351,298   2.36   2.32 B Update
# SINGER   2023-12-22 2023-12-27  12.00  11.50  -4.17%  35,744,864  12.30  11.50 B Update
# STA      2023-12-27 2023-12-27  15.30  15.20  -0.65%   5,141,028  15.30  14.80 I Insert
# SYNEX    2023-12-22 2023-12-27  10.30  10.20  -0.97%   2,982,668  10.50  10.20 B Update
# TFFIF    2023-12-27 2023-12-27   6.50   6.55   0.77%   2,901,000   6.60   6.45 B Insert
# TMT      2023-12-27 2023-12-27   6.10   6.15   0.82%     183,560   6.20   6.10 B Insert
# TOA      2023-12-27 2023-12-27  22.80  22.60  -0.88%  20,672,120  22.80  21.90 I Insert
# TTB      2023-12-22 2023-12-27   1.59   1.61   1.26% 290,546,152   1.61   1.59 O Update
# WHAIR    2023-12-20 2023-12-27   5.40   5.55   2.78%   2,485,112   5.55   5.30 B Update
# WHART    2023-12-21 2023-12-27   9.80  10.30    5.1%  13,241,008  10.30   9.70 B Update
# =======================================================================================

# %%
os.chdir("C:\\users\\user\\onedrive\\a7\\Daily")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7\\Daily'

# %% [markdown]
# ### cd\ruby\port_lite
# ### rails runner db/ins_sales.rb

# %%
sql = """
SELECT a.name,fm_date,to_date,fm_price,to_price,
a.qty,a.max_price,a.min_price,t.status,t.market
FROM sales a 
JOIN stocks t ON a.name = t.name 
WHERE to_date = '%s' AND t.status IN ("B","I", "O", "S") 
ORDER BY t.status, a.name
"""
sql = sql % today
print(sql)
# Out:
# SELECT a.name,fm_date,to_date,fm_price,to_price,
# a.qty,a.max_price,a.min_price,t.status,t.market
# FROM sales a
# JOIN stocks t ON a.name = t.name
# WHERE to_date = '2023-12-27' AND t.status IN ("B","I", "O", "S")
# ORDER BY t.status, a.name

# %%
df = pd.read_sql(sql, conlite)
#df.set_index(["name"], inplace=True)
df['fm_date'] = pd.to_datetime(df['fm_date'])
df['to_date'] = pd.to_datetime(df['to_date'])
df.eval('diff = to_price - fm_price',inplace=True)
df['percent'] = round(df['diff']/df['fm_price']*100,2)
df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_336b0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >status</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >diff</th>
#       <th class="col_heading level0 col11" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_336b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_336b0_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_336b0_row0_col1" class="data row0 col1" >2023-12-27</td>
#       <td id="T_336b0_row0_col2" class="data row0 col2" >2023-12-27</td>
#       <td id="T_336b0_row0_col3" class="data row0 col3" >27.25</td>
#       <td id="T_336b0_row0_col4" class="data row0 col4" >27.75</td>
#       <td id="T_336b0_row0_col5" class="data row0 col5" >1,598,752</td>
#       <td id="T_336b0_row0_col6" class="data row0 col6" >27.75</td>
#       <td id="T_336b0_row0_col7" class="data row0 col7" >26.75</td>
#       <td id="T_336b0_row0_col8" class="data row0 col8" >B</td>
#       <td id="T_336b0_row0_col9" class="data row0 col9" >SET</td>
#       <td id="T_336b0_row0_col10" class="data row0 col10" >0.50</td>
#       <td id="T_336b0_row0_col11" class="data row0 col11" >1.83%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_336b0_row1_col0" class="data row1 col0" >ASK</td>
#       <td id="T_336b0_row1_col1" class="data row1 col1" >2023-12-27</td>
#       <td id="T_336b0_row1_col2" class="data row1 col2" >2023-12-27</td>
#       <td id="T_336b0_row1_col3" class="data row1 col3" >19.70</td>
#       <td id="T_336b0_row1_col4" class="data row1 col4" >19.90</td>
#       <td id="T_336b0_row1_col5" class="data row1 col5" >412,252</td>
#       <td id="T_336b0_row1_col6" class="data row1 col6" >20.10</td>
#       <td id="T_336b0_row1_col7" class="data row1 col7" >19.70</td>
#       <td id="T_336b0_row1_col8" class="data row1 col8" >B</td>
#       <td id="T_336b0_row1_col9" class="data row1 col9" >SET</td>
#       <td id="T_336b0_row1_col10" class="data row1 col10" >0.20</td>
#       <td id="T_336b0_row1_col11" class="data row1 col11" >1.02%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_336b0_row2_col0" class="data row2 col0" >CPNREIT</td>
#       <td id="T_336b0_row2_col1" class="data row2 col1" >2023-12-21</td>
#       <td id="T_336b0_row2_col2" class="data row2 col2" >2023-12-27</td>
#       <td id="T_336b0_row2_col3" class="data row2 col3" >11.00</td>
#       <td id="T_336b0_row2_col4" class="data row2 col4" >11.30</td>
#       <td id="T_336b0_row2_col5" class="data row2 col5" >14,622,496</td>
#       <td id="T_336b0_row2_col6" class="data row2 col6" >11.30</td>
#       <td id="T_336b0_row2_col7" class="data row2 col7" >10.90</td>
#       <td id="T_336b0_row2_col8" class="data row2 col8" >B</td>
#       <td id="T_336b0_row2_col9" class="data row2 col9" >SET</td>
#       <td id="T_336b0_row2_col10" class="data row2 col10" >0.30</td>
#       <td id="T_336b0_row2_col11" class="data row2 col11" >2.73%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_336b0_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_336b0_row3_col1" class="data row3 col1" >2023-12-22</td>
#       <td id="T_336b0_row3_col2" class="data row3 col2" >2023-12-27</td>
#       <td id="T_336b0_row3_col3" class="data row3 col3" >7.50</td>
#       <td id="T_336b0_row3_col4" class="data row3 col4" >7.65</td>
#       <td id="T_336b0_row3_col5" class="data row3 col5" >140,652,832</td>
#       <td id="T_336b0_row3_col6" class="data row3 col6" >7.65</td>
#       <td id="T_336b0_row3_col7" class="data row3 col7" >7.40</td>
#       <td id="T_336b0_row3_col8" class="data row3 col8" >B</td>
#       <td id="T_336b0_row3_col9" class="data row3 col9" >SET</td>
#       <td id="T_336b0_row3_col10" class="data row3 col10" >0.15</td>
#       <td id="T_336b0_row3_col11" class="data row3 col11" >2.00%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_336b0_row4_col0" class="data row4 col0" >GVREIT</td>
#       <td id="T_336b0_row4_col1" class="data row4 col1" >2023-12-20</td>
#       <td id="T_336b0_row4_col2" class="data row4 col2" >2023-12-27</td>
#       <td id="T_336b0_row4_col3" class="data row4 col3" >5.60</td>
#       <td id="T_336b0_row4_col4" class="data row4 col4" >5.65</td>
#       <td id="T_336b0_row4_col5" class="data row4 col5" >22,806,400</td>
#       <td id="T_336b0_row4_col6" class="data row4 col6" >5.70</td>
#       <td id="T_336b0_row4_col7" class="data row4 col7" >5.45</td>
#       <td id="T_336b0_row4_col8" class="data row4 col8" >B</td>
#       <td id="T_336b0_row4_col9" class="data row4 col9" >SET</td>
#       <td id="T_336b0_row4_col10" class="data row4 col10" >0.05</td>
#       <td id="T_336b0_row4_col11" class="data row4 col11" >0.89%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_336b0_row5_col0" class="data row5 col0" >JASIF</td>
#       <td id="T_336b0_row5_col1" class="data row5 col1" >2023-12-20</td>
#       <td id="T_336b0_row5_col2" class="data row5 col2" >2023-12-27</td>
#       <td id="T_336b0_row5_col3" class="data row5 col3" >5.85</td>
#       <td id="T_336b0_row5_col4" class="data row5 col4" >6.20</td>
#       <td id="T_336b0_row5_col5" class="data row5 col5" >122,070,320</td>
#       <td id="T_336b0_row5_col6" class="data row5 col6" >6.20</td>
#       <td id="T_336b0_row5_col7" class="data row5 col7" >5.75</td>
#       <td id="T_336b0_row5_col8" class="data row5 col8" >B</td>
#       <td id="T_336b0_row5_col9" class="data row5 col9" >SET</td>
#       <td id="T_336b0_row5_col10" class="data row5 col10" >0.35</td>
#       <td id="T_336b0_row5_col11" class="data row5 col11" >5.98%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_336b0_row6_col0" class="data row6 col0" >JMT</td>
#       <td id="T_336b0_row6_col1" class="data row6 col1" >2023-12-22</td>
#       <td id="T_336b0_row6_col2" class="data row6 col2" >2023-12-27</td>
#       <td id="T_336b0_row6_col3" class="data row6 col3" >26.25</td>
#       <td id="T_336b0_row6_col4" class="data row6 col4" >25.25</td>
#       <td id="T_336b0_row6_col5" class="data row6 col5" >78,699,560</td>
#       <td id="T_336b0_row6_col6" class="data row6 col6" >27.00</td>
#       <td id="T_336b0_row6_col7" class="data row6 col7" >25.25</td>
#       <td id="T_336b0_row6_col8" class="data row6 col8" >B</td>
#       <td id="T_336b0_row6_col9" class="data row6 col9" >SET50</td>
#       <td id="T_336b0_row6_col10" class="data row6 col10" >-1.00</td>
#       <td id="T_336b0_row6_col11" class="data row6 col11" >-3.81%</td>
#     </tr>
#     <tr>
#       <th id="T_336b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_336b0_row7_col0" class="data row7 col0" >NER</td>
#       <td id="T_336b0_row7_col1" class="data row7 col1" >2023-12-21</td>
#       <td id="T_336b0_row7_col2" class="data row7 col2" >2023-12-27</td>
#       <td id="T_336b0_row7_col3" class="data row7 col3" >4.68</td>
#       <td id="T_336b0_row7_col4" class="data row7 col4" >4.84</td>
#       <td id="T_336b0_row7_col5" class="data row7 col5" >49,216,104</td>
#       <td id="T_336b0_row7_col6" class="data row7 col6" >4.84</td>
#       <td id="T_336b0_row7_col7" class="data row7 col7" >4.62</td>
#       <td id="T_336b0_row7_col8" class="data row7 col8" >B</td>
#       <td id="T_336b0_row7_col9" class="data

# %%
df_sort = df.sort_values(by=['percent'],ascending=[True]).copy()

# %%
df_sort.query('percent <= -5.00').style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a23f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >status</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >diff</th>
#       <th class="col_heading level0 col11" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
df_sort.query('percent >= 5.00').style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a794c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >status</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >diff</th>
#       <th class="col_heading level0 col11" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a794c_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_a794c_row0_col0" class="data row0 col0" >WHART</td>
#       <td id="T_a794c_row0_col1" class="data row0 col1" >2023-12-21</td>
#       <td id="T_a794c_row0_col2" class="data row0 col2" >2023-12-27</td>
#       <td id="T_a794c_row0_col3" class="data row0 col3" >9.80</td>
#       <td id="T_a794c_row0_col4" class="data row0 col4" >10.30</td>
#       <td id="T_a794c_row0_col5" class="data row0 col5" >26,482,016</td>
#       <td id="T_a794c_row0_col6" class="data row0 col6" >10.30</td>
#       <td id="T_a794c_row0_col7" class="data row0 col7" >9.70</td>
#       <td id="T_a794c_row0_col8" class="data row0 col8" >B</td>
#       <td id="T_a794c_row0_col9" class="data row0 col9" >SET</td>
#       <td id="T_a794c_row0_col10" class="data row0 col10" >0.50</td>
#       <td id="T_a794c_row0_col11" class="data row0 col11" >5.10%</td>
#     </tr>
#     <tr>
#       <th id="T_a794c_level0_row1" class="row_heading level0 row1" >36</th>
#       <td id="T_a794c_row1_col0" class="data row1 col0" >ICHI</td>
#       <td id="T_a794c_row1_col1" class="data row1 col1" >2023-12-21</td>
#       <td id="T_a794c_row1_col2" class="data row1 col2" >2023-12-27</td>
#       <td id="T_a794c_row1_col3" class="data row1 col3" >14.80</td>
#       <td id="T_a794c_row1_col4" class="data row1 col4" >15.60</td>
#       <td id="T_a794c_row1_col5" class="data row1 col5" >133,293,920</td>
#       <td id="T_a794c_row1_col6" class="data row1 col6" >15.60</td>
#       <td id="T_a794c_row1_col7" class="data row1 col7" >14.60</td>
#       <td id="T_a794c_row1_col8" class="data row1 col8" >O</td>
#       <td id="T_a794c_row1_col9" class="data row1 col9" >SET</td>
#       <td id="T_a794c_row1_col10" class="data row1 col10" >0.80</td>
#       <td id="T_a794c_row1_col11" class="data row1 col11" >5.41%</td>
#     </tr>
#     <tr>
#       <th id="T_a794c_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_a794c_row2_col0" class="data row2 col0" >JASIF</td>
#       <td id="T_a794c_row2_col1" class="data row2 col1" >2023-12-20</td>
#       <td id="T_a794c_row2_col2" class="data row2 col2" >2023-12-27</td>
#       <td id="T_a794c_row2_col3" class="data row2 col3" >5.85</td>
#       <td id="T_a794c_row2_col4" class="data row2 col4" >6.20</td>
#       <td id="T_a794c_row2_col5" class="data row2 col5" >122,070,320</td>
#       <td id="T_a794c_row2_col6" class="data row2 col6" >6.20</td>
#       <td id="T_a794c_row2_col7" class="data row2 col7" >5.75</td>
#       <td id="T_a794c_row2_col8" class="data row2 col8" >B</td>
#       <td id="T_a794c_row2_col9" class="data row2 col9" >SET</td>
#       <td id="T_a794c_row2_col10" class="data row2 col10" >0.35</td>
#       <td id="T_a794c_row2_col11" class="data row2 col11" >5.98%</td>
#     </tr>
#   </tbody>
# </table>
