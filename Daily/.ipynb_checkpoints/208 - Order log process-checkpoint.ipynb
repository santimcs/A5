# %%
### Input files: Price

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()
engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

format_dict = {'qty':'{:,}',
              'sell_price':'{:,.2f}','buy_price':'{:,.2f}','diff':'{:,.2f}',
              'sell_amt':'{:,.2f}','buy_amt':'{:,.2f}','gross':'{:,.2f}','amount':'{:,.2f}',
              'pct':'{:,.2f}','net':'{:,.2f}'}

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"
dts_path = "/Users/User/Downloads/Datasets/"

# Directory to be monitored
directory = '/Users/User/Downloads'
# Dictionary of file categories and their extensions
categories = {
    'Images': ['jpeg', 'jpg', 'png'],
    'PDFs': ['pdf'],
    'Datasets': ['csv', 'xlsx', 'xls', 'json'],
    'Videos': ['mp4','m4a'],
    'Zips': ['zip'],
    'EXEs': ['exe', 'msi'],
    'Pythons': ['ipynb'],
}
pd.options.display.max_rows = 50
pd.options.display.float_format = '{:.2f}'.format
year = 2023
month = 12
today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2023, 12, 28), datetime.date(2023, 12, 27))

# %%
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-12-28
# yesterday: 2023-12-27

# %% [markdown]
# ### Restart and Run All Cells

# %% [markdown]
# ## Must rerun whenever there is change in orders

# %%
sql = """
SELECT trade, name, qty, price AS target, active, reason, market, xdate 
FROM orders
ORDER BY trade, name"""
orders = pd.read_sql(sql, conlite)
orders.shape
# Out:
# (40, 8)

# %%
file_name = "Price-Today.csv"
input_file = data_path + file_name
input_file
# Out:
# '../data/Price-Today.csv'

# %%
prices = pd.read_csv(input_file)
prices.shape
# Out:
# (189, 10)

# %%
df_merge  = pd.merge(orders, prices, on = 'name', how='inner')
df_merge.shape
# Out:
# (40, 17)

# %%
df_merge['spd'] = 0

# %%
colo = ['trade', 'name', 'spd', 'reason', 'market', 'qty', 'target', 'price', 'change', '%change',
        'active', 'xdate']
df_merge[colo].shape
# Out:
# (40, 12)

# %%
file_name = "Price-for-Order.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

df_merge[colo].to_csv(output_file, header=True, index=False)
df_merge[colo].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### call ruby ruby\order-log-new.rb

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\OneDrive\\A7\\Daily'

# %%
os.chdir("C:\\users\\user\\onedrive\\a7")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7'

# %%
# !ruby ruby\\order-log-new.rb
# Out:
# trade,name,spd,reason,market,qty,target,current,change,%change,active,xdate
# B,AH,-8,RD30pct,SET,600,25.75,27.75,0.5,1.834862,1,2023-08-29
# B,ASK,-19,RD40pct,SET,1500,18.0,19.9,0.2,1.015228,0,2023-02-28
# B,BBL,-14,XXX,SET50,400,145.0,152.0,1.0,0.662252,0,2023-09-06
# B,BEM,-4,XXX,SET50,2500,7.7,7.9,-0.05,-0.628931,1,2022-12-22
# B,BH,-10,XXX,SET50,100,210.0,220.0,-2.0,-0.900901,1,2022-12-22
# B,CK,-26,XXX,SET100,1000,17.8,20.4,0.0,0.0,0,2022-12-22
# B,CPN,-33,XXX,SET50,300,61.0,69.25,0.75,1.094891,0,2022-12-22
# B,CPNREIT,-29,RD50pct,SET,3000,9.15,11.3,0.1,0.892857,0,2023-11-23
# B,DIF,-13,RD55pct,SET,3000,7.0,7.65,0.05,0.657895,0,2023-11-14
# B,GVREIT,-10,RD35pct,SET,6000,5.15,5.65,0.0,0.0,0,2023-12-12
# B,HANA,-49,XXX,SET100,500,40.0,52.25,-1.75,-3.240741,0,2022-12-22
# B,ICHI,-16,XXX,SET,1500,14.0,15.6,0.3,1.960784,0,2022-12-22
# B,JASIF,-44,RD55pct,SET,5000,4.6,6.2,0.05,0.813008,0,2023-11-17
# B,JMT,-46,RD65pct,SET50,800,20.5,25.25,0.0,0.0,1,2023-08-24
# B,KTB,-1,XXX,SET50,1000,18.0,18.1,-0.1,-0.549451,1,2023-04-20
# B,NER,-20,RD40pct,SET,3000,4.44,4.84,0.0,0.0,0,2023-08-25
# B,ORI,-12,RD30pct,SET100,3000,7.8,8.4,-0.05,-0.591716,0,2023-08-28
# B,PTG,-8,RD30pct,SET100,3600,7.9,8.3,0.15,1.840491,1,2022-12-22
# B,PTTGC,-26,RD4,SET50,600,31.75,38.25,-0.25,-0.649351,0,2023-08-29
# B,SAPPE,-65,XXX,SET,300,70.0,86.25,2.25,2.678571,0,2022-12-22
# B,SENA,-5,RD50pct,SET,7000,2.24,2.34,0.0,0.0,1,2023-08-28
# B,SINGER,-48,RD70pct,SET100,3000,8.3,11.5,-0.1,-0.862069,0,2023-08-03
# B,SYNEX,-35,RD70pct,SET,2000,8.3,10.2,0.0,0.0,0,2023-08-25
# B,TFFIF,-6,RD15pct,SET,2500,6.25,6.55,0.05,0.769231,1,2023-12-12
# B,TMT,-10,RD45pct,SET,3000,5.65,6.15,0.05,0.819672,0,2023-08-24
# B,TTB,-11,XXX,SET50,20000,1.5,1.61,0.0,0.0,1,2022-12-22
# B,WHAIR,-18,RD45pct,SET,5000,4.85,5.55,0.0,0.0,0,2023-11-24
# B,WHART,-26,RD30pct,SET,5000,8.8,10.3,0.35,3.517588,0,2023-11-24
# S,AIMIRT,10,DOS,SET,10000,11.4,10.4,0.1,0.970874,0,2023-11-24
# S,ASP,51,RD30pct,SET,10000,3.82,2.8,0.0,0.0,0,2023-08-28
# S,AWC,74,RD30pct,SET50,4000,5.1,3.56,0.06,1.714286,0,2022-12-22
# S,BCH,5,5pct,SET100,2000,22.9,22.4,0.4,1.818182,2,2023-08-31
# S,IVL,-608,RD45pct,SET50,800,0.0,27.0,0.0,0.0,0,2023-11-29
# S,JMART,68,5pct,SET50,2000,24.1,17.3,-0.1,-0.574713,0,2023-08-24
# S,KCE,30,COS,SET100,1000,61.75,54.25,-1.0,-1.809955,0,2023-08-21
# S,MCS,22,COS,SET,3000,7.65,6.55,0.0,0.0,0,2023-03-17
# S,RCL,27,COS,SET100,3000,30.5,24.5,1.1,4.700855,0,2023-08-24
# S,SCC,84,COS,SET50,300,385.0,301.0,0.0,0.0,0,2023-08-09
# S,STA,17,5pct,SET100,2500,16.9,15.2,-0.1,-0.653595,0,2023-08-24
# S,TOA,32,RD25pct,SET,1000,27.25,22.6,-0.2,-0.877193,0,2023-08-30

# %%
os.chdir("C:\\users\\user\\onedrive\\a7\\daily")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7\\daily'

# %%
file_name   = 'orders-log.csv'
input_file = data_path + file_name

df = pd.read_csv(input_file, sep=',', index_col=None)
df['amount'] = df['qty'] * df['target']
df.query('spd >= -3 and spd <= 3')
# Out:
#    trade name  spd reason market   qty  target  current  change  %change  \
# 14     B  KTB   -1    XXX  SET50  1000   18.00    18.10   -0.10    -0.55
#
#     active       xdate   amount
# 14       1  2023-04-20 18000.00

# %%
df.query('active == 2')
# Out:
#    trade name  spd reason  market   qty  target  current  change  %change  \
# 31     S  BCH    5   5pct  SET100  2000   22.90    22.40    0.40     1.82
#
#     active       xdate   amount
# 31       2  2023-08-31 45800.00

# %%
df.query('active == 1')
# Out:
#    trade   name  spd   reason  market    qty  target  current  change  \
# 0      B     AH   -8  RD30pct     SET    600   25.75    27.75    0.50
# 3      B    BEM   -4      XXX   SET50   2500    7.70     7.90   -0.05
# 4      B     BH  -10      XXX   SET50    100  210.00   220.00   -2.00
# 13     B    JMT  -46  RD65pct   SET50    800   20.50    25.25    0.00
# 14     B    KTB   -1      XXX   SET50   1000   18.00    18.10   -0.10
# 17     B    PTG   -8  RD30pct  SET100   3600    7.90     8.30    0.15
# 20     B   SENA   -5  RD50pct     SET   7000    2.24     2.34    0.00
# 23     B  TFFIF   -6  RD15pct     SET   2500    6.25     6.55    0.05
# 25     B    TTB  -11      XXX   SET50  20000    1.50     1.61    0.00
#
#     %change  active       xdate   amount
# 0      1.83       1  2023-08-29 15450.00
# 3     -0.63       1  2022-12-22 19250.00
# 4     -0.90       1  2022-12-22 21000.00
# 13     0.00       1  2023-08-24 16400.00
# 14    -0.55       1  2023-04-20 18000.00
# 17     1.84       1  2022-12-22 28440.00
# 20     0.00       1  2023-08-28 15680.00
# 23     0.77       1  2023-12-12 15625.00
# 25     0.00       1  2022-12-22 30000.00

# %%
df.query('name == "IVL"')
# Out:
#    trade name  spd   reason market  qty  target  current  change  %change  \
# 32     S  IVL -608  RD45pct  SET50  800    0.00    27.00    0.00     0.00
#
#     active       xdate  amount
# 32       0  2023-11-29    0.00

# %%
df.query('active == 0')
# Out:
#    trade     name  spd   reason  market    qty  target  current  change  \
# 1      B      ASK  -19  RD40pct     SET   1500   18.00    19.90    0.20
# 2      B      BBL  -14      XXX   SET50    400  145.00   152.00    1.00
# 5      B       CK  -26      XXX  SET100   1000   17.80    20.40    0.00
# 6      B      CPN  -33      XXX   SET50    300   61.00    69.25    0.75
# 7      B  CPNREIT  -29  RD50pct     SET   3000    9.15    11.30    0.10
# 8      B      DIF  -13  RD55pct     SET   3000    7.00     7.65    0.05
# 9      B   GVREIT  -10  RD35pct     SET   6000    5.15     5.65    0.00
# %%
df.query('spd <= -40 and trade == "B"')
# Out:
#    trade    name  spd   reason  market   qty  target  current  change  \
# 10     B    HANA  -49      XXX  SET100   500   40.00    52.25   -1.75
# 12     B   JASIF  -44  RD55pct     SET  5000    4.60     6.20    0.05
# 13     B     JMT  -46  RD65pct   SET50   800   20.50    25.25    0.00
# 19     B   SAPPE  -65      XXX     SET   300   70.00    86.25    2.25
# 21     B  SINGER  -48  RD70pct  SET100  3000    8.30    11.50   -0.10
#
#     %change  active       xdate   amount
# 10    -3.24       0  2022-12-22 20000.00
# 12     0.81       0  2023-11-17 23000.00
# 13     0.00       1  2023-08-24 16400.00
# 19     2.68       0  2022-12-22 21000.00
# 21    -0.86       0  2023-08-03 24900.00

# %%
df.query('trade == "B" & spd > 0')
# Out:
# Empty DataFrame
# Columns: [trade, name, spd, reason, market, qty, target, current, change, %change, active, xdate, amount]
# Index: []

# %%
df.query('trade == "S" & spd < 0')
# Out:
#    trade name  spd   reason market  qty  target  current  change  %change  \
# 32     S  IVL -608  RD45pct  SET50  800    0.00    27.00    0.00     0.00
#
#     active       xdate  amount
# 32       0  2023-11-29    0.00

# %%
colx = ['trade', 'name', 'spd', 'reason', 'market', 'qty', 'target', 'current', 'change', '%change',
        'active', 'xdate']

file_name = "orders-log.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

df[colx].to_csv(output_file, header=True, index=False)
df[colx].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Convert column name to make it valid for df.query

# %%
df['percent'] = df['%change']

# %%
df.query('percent < -2')
# Out:
#    trade  name  spd reason  market  qty  target  current  change  %change  \
# 10     B  HANA  -49    XXX  SET100  500   40.00    52.25   -1.75    -3.24
#
#     active       xdate   amount  percent
# 10       0  2022-12-22 20000.00    -3.24

# %%
df.query('percent >= 2.00')
# Out:
#    trade   name  spd   reason  market   qty  target  current  change  %change  \
# 19     B  SAPPE  -65      XXX     SET   300   70.00    86.25    2.25     2.68
# 27     B  WHART  -26  RD30pct     SET  5000    8.80    10.30    0.35     3.52
# 36     S    RCL   27      COS  SET100  3000   30.50    24.50    1.10     4.70
#
#     active       xdate   amount  percent
# 19       0  2022-12-22 21000.00     2.68
# 27       0  2023-11-24 44000.00     3.52
# 36       0  2023-08-24 91500.00     4.70

# %%
df.loc[df.trade == 'B'].sort_values('spd',ascending=False)
# Out:
#    trade     name  spd   reason  market    qty  target  current  change  \
# 14     B      KTB   -1      XXX   SET50   1000   18.00    18.10   -0.10
# 3      B      BEM   -4      XXX   SET50   2500    7.70     7.90   -0.05
# 20     B     SENA   -5  RD50pct     SET   7000    2.24     2.34    0.00
# 23     B    TFFIF   -6  RD15pct     SET   2500    6.25     6.55    0.05
# 17     B      PTG   -8  RD30pct  SET100   3600    7.90     8.30    0.15
# 0      B       AH   -8  RD30pct     SET    600   25.75    27.75    0.50
# 4      B       BH  -10      XXX   SET50    100  210.00   220.00   -2.00
# 9      B   GVREIT  -10  RD35pct     SET   6000    5.15     5.65    0.00
# 24     B      TMT  -10  RD45pct     SET   3000    5.65     6.15    0.05
pd.set_option('display.max_rows', 40)
sql = """SELECT name, qty, price AS cost, date 
FROM buys B 
JOIN stocks S 
ON stock_id = S.id 
WHERE status = 'Active'
ORDER BY name, date"""
buys = pd.read_sql(sql, conpf)
buys.shape
# Out:
# (113, 4)

# %%
colu = 'name date_x qty cost price difa %change %profit'.split()
buys_price = pd.merge(buys, prices, on='name', how='inner')
buys_price['diff'] = buys_price['price'] - buys_price['cost']
buys_price['difa'] = buys_price['diff'] * buys_price['qty']
buys_price['%profit'] = round(buys_price['difa'] / (buys_price['qty'] * buys_price['cost']) * 100,2)

# %%
laggards = buys_price.loc[buys_price.cost > buys_price.price,colu]
laggards.shape
# Out:
# (111, 8)

# %%
watch_list = buys_price.loc[buys_price.cost <= buys_price.price,colu]
watch_list.sort_values('name',ascending='False')
# Out:
#       name      date_x   qty  cost  price    difa  %change  %profit
# 5      BCH  2021-09-07  6000 21.70  22.40 4200.00     1.82     3.23
# 100  TFFIF  2023-12-12  2500  6.35   6.55  500.00     0.77     3.15

# %% [markdown]
# ### Profit per Day

# %%
sql = '''
SELECT name, YEAR(sells.date) AS sell_year, MONTH(sells.date) AS sell_month, 
       sells.price AS sell_price, buys.price AS buy_price, (sells.price - buys.price) AS diff, 
       qty, (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt, 
       (sells.price - buys.price) * qty AS gross, 
       ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, days
FROM sells JOIN buys ON sells.buy_id = buys.id
JOIN stocks ON buys.stock_id = stocks.id
WHERE YEAR(sells.date) = %s AND MONTH(sells.date) = %s
ORDER BY sells.date DESC, name'''
sql = sql % (year, month)
sells_df = pd.read_sql(sql, conpf)
print(sql)
# Out:
# SELECT name, YEAR(sells.date) AS sell_year, MONTH(sells.date) AS sell_month,
#        sells.price AS sell_price, buys.price AS buy_price, (sells.price - buys.price) AS diff,
#        qty, (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
#        (sells.price - buys.price) * qty AS gross,
#        ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, days
# FROM sells JOIN buys ON sells.buy_id = buys.id
# JOIN stocks ON buys.stock_id = stocks.id
# WHERE YEAR(sells.date) = 2023 AND MONTH(sells.date) = 12
# ORDER BY sells.date DESC, name

# %%
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7734f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_year</th>
#       <th class="col_heading level0 col2" >sell_month</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7734f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7734f_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_7734f_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_7734f_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_7734f_row0_col3" class="data row0 col3" >22.40</td>
#       <td id="T_7734f_row0_col4" class="data row0 col4" >21.30</td>
#       <td id="T_7734f_row0_col5" class="data row0 col5" >1.10</td>
#       <td id="T_7734f_row0_col6" class="data row0 col6" >4,000</td>
#       <td id="T_7734f_row0_col7" class="data row0 col7" >89,600.00</td>
#       <td id="T_7734f_row0_col8" class="data row0 col8" >85,200.00</td>
#       <td id="T_7734f_row0_col9" class="data row0 col9" >4,400.00</td>
#       <td id="T_7734f_row0_col10" class="data row0 col10" >5.16</td>
#       <td id="T_7734f_row0_col11" class="data row0 col11" >818</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f"Monthly Profit Amount: {sells_df.gross.sum():,.2f}")
# Out:
# Monthly Profit Amount: 4,400.00

# %%
file_name = "monthly-sales.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

sells_df.to_csv(output_file, header=True, index=False)
sells_df.to_csv(osd_file, header=True, index=False)

# %%
sells_df['profit_per_day'] = (sells_df['gross'] / sells_df['buy_amt']) / sells_df['days'] * 100
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_37f16_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_year</th>
#       <th class="col_heading level0 col2" >sell_month</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >days</th>
#       <th class="col_heading level0 col12" >profit_per_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37f16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37f16_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_37f16_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_37f16_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_37f16_row0_col3" class="data row0 col3" >22.40</td>
#       <td id="T_37f16_row0_col4" class="data row0 col4" >21.30</td>
#       <td id="T_37f16_row0_col5" class="data row0 col5" >1.10</td>
#       <td id="T_37f16_row0_col6" class="data row0 col6" >4,000</td>
#       <td id="T_37f16_row0_col7" class="data row0 col7" >89,600.00</td>
#       <td id="T_37f16_row0_col8" class="data row0 col8" >85,200.00</td>
#       <td id="T_37f16_row0_col9" class="data row0 col9" >4,400.00</td>
#       <td id="T_37f16_row0_col10" class="data row0 col10" >5.16</td>
#       <td id="T_37f16_row0_col11" class="data row0 col11" >818</td>
#       <td id="T_37f16_row0_col12" class="data row0 col12" >0.006313</td>
#     </tr>
#   </tbody>
# </table>

# %%
average_profit_percent = sells_df['profit_per_day'].mean()
print(f"Average Profit Percent: {average_profit_percent:.2f}%")
# Out:
# Average Profit Percent: 0.01%

# %%
#dt = date(2023, 11, 8)
dt = today
dt.strftime("%B %d, %Y")
# Out:
# 'December 27, 2023'

# %%
print("Hello, {}! Today is {:%B %d, %Y}.".format("Alice", dt))
# Out:
# Hello, Alice! Today is December 27, 2023.
