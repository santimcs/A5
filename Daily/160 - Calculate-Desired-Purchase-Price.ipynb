# %%
import calendar
import pandas as pd
import numpy as np
from datetime import date, timedelta
from math import ceil, floor, trunc

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2025, 6, 18), datetime.date(2025, 6, 17))

# %%
def number_of_spread(x):
    # Unpack values from input list
    q0 = x[0]   # old quantity
    p0 = x[1]   # old unit price
    old_unit_cost = x[1]  # store old unit price for later use
    q1 = x[2]   # purchase quantity
    d1 = x[3]   # spread according to price range
    c0 = x[4]   # desired down percent to adjust purchase price

    # Calculate old cost amount
    a0 = q0 * p0

    # Initialize loop variables
    i = 1000
    pct = 0
    pt = 0
    dt = 0
    p2 = 0

    # Loop until i becomes 0
    while i > 0:
        # Calculate simulated purchase price
        p1 = p0 - d1

        # Update old unit price for next iteration
        p0 = p1

        # Calculate new purchase amount
        a1 = q1 * p1

        # Calculate new total quantity and cost amount
        q2 = q0 + q1
        a2 = a0 + a1

        # Calculate new unit cost
        p2 = a2 / q2

        # Round simulated purchase price and spread according to price range
        pt = round(p2 * 100, 2)
        dt = d1 * 100

        # Debugging output
        print('before if', i, 'p1=' + str(round(p1, 2)), 'a1=' + str(round(a1, 2)), 'a2=' + str(round(a2, 2)), 'p2=' + str(round(p2, 2)))

        # Check if simulated purchase price is divisible by spread
        if (pt % dt) == 0:
            # Calculate percentage change in unit cost
            pct = ((p1 - old_unit_cost) / old_unit_cost) * 100

            # Debugging output
            print('in loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

            # Check if absolute value of percentage change is less than desired down percent
            if abs(pct) < c0:
                # Continue to next iteration if condition is met
                continue

            # Break loop if condition is not met
            break

        # Debugging output
        print('out loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

        # Decrement loop counter
        i -= 1

    # Return simulated purchase price, new unit cost, and percentage change in unit cost
    return print('p1=' + str(round(p1, 2)), 'p2=' + str(round(p2, 2)), 'pct=' + str(round(pct, 2)))

# %%
my_array = [[27_000,7.45,5_000,.02,45]]
tmp = (np.apply_along_axis(number_of_spread, axis=1, arr=my_array))
tmp
# Out:
# before if 1000 p1=7.43 a1=37150.0 a2=238300.0 p2=7.45
# out loop 1000 p2=7.45 238300.0 p1=7.43 pct=0
# before if 999 p1=7.41 a1=37050.0 a2=238200.0 p2=7.44
# out loop 999 p2=7.44 238200.0 p1=7.41 pct=0
# before if 998 p1=7.39 a1=36950.0 a2=238100.0 p2=7.44
# out loop 998 p2=7.44 238100.0 p1=7.39 pct=0
# before if 997 p1=7.37 a1=36850.0 a2=238000.0 p2=7.44
# out loop 997 p2=7.44 238000.0 p1=7.37 pct=0
# before if 996 p1=7.35 a1=36750.0 a2=237900.0 p2=7.43
# out loop 996 p2=7.43 237900.0 p1=7.35 pct=0
# before if 995 p1=7.33 a1=36650.0 a2=237800.0 p2=7.43
# out loop 995 p2=7.43 237800.0 p1=7.33 pct=0
# before if 994 p1=7.31 a1=36550.0 a2=237700.0 p2=7.43
# out loop 994 p2=7.43 237700.0 p1=7.31 pct=0
# before if 993 p1=7.29 a1=36450.0 a2=237600.0 p2=7.42
# out loop 993 p2=7.42 237600.0 p1=7.29 pct=0
# before if 992 p1=7.27 a1=36350.0 a2=237500.0 p2=7.42
# out loop 992 p2=7.42 237500.00000000003 p1=7.27 pct=0
# before if 991 p1=7.25 a1=36250.0 a2=237400.0 p2=7.42
# out loop 991 p2=7.42 237400.00000000003 p1=7.25 pct=0
# before if 990 p1=7.23 a1=36150.0 a2=237300.0 p2=7.42
# out loop 990 p2=7.42 237300.00000000003 p1=7.23 pct=0
# before if 989 p1=7.21 a1=36050.0 a2=237200.0 p2=7.41
# out loop 989 p2=7.41 237200.00000000003 p1=7.21 pct=0
# before if 988 p1=7.19 a1=35950.0 a2=237100.0 p2=7.41
# out loop 988 p2=7.41 237100.00000000003 p1=7.19 pct=0
# before if 987 p1=7.17 a1=35850.0 a2=237000.0 p2=7.41
# out loop 987 p2=7.41 237000.00000000003 p1=7.17 pct=0
# before if 986 p1=7.15 a1=35750.0 a2=236900.0 p2=7.4
# out loop 986 p2=7.4 236900.00000000003 p1=7.15 pct=0
# before if 985 p1=7.13 a1=35650.0 a2=236800.0 p2=7.4
# in loop 985 p2=7.4 236800.00000000003 p1=7.13 pct=-4.3
# before if 985 p1=7.11 a1=35550.0 a2=236700.0 p2=7.4
# out loop 985 p2=7.4 236700.00000000003 p1=7.11 pct=-4.3
# before if 984 p1=7.09 a1=35450.0 a2=236600.0 p2=7.39
# out loop 984 p2=7.39 236600.00000000003 p1=7.09 pct=-4.3
# before if 983 p1=7.07 a1=35350.0 a2=236500.0 p2=7.39
# out loop 983 p2=7.39 236500.00000000006 p1=7.07 pct=-4.3
# before if 982 p1=7.05 a1=35250.0 a2=236400.0 p2=7.39
# out loop 982 p2=7.39 236400.00000000006 p1=7.05 pct=-4.3
# before if 981 p1=7.03 a1=35150.0 a2=236300.0 p2=7.38
# out loop 981 p2=7.38 236300.00000000006 p1=7.03 pct=-4.3
# before if 980 p1=7.01 a1=35050.0 a2=236200.0 p2=7.38
# out loop 980 p2=7.38 236200.00000000006 p1=7.01 pct=-4.3
# before if 979 p1=6.99 a1=34950.0 a2=236100.0 p2=7.38
# out loop 979 p2=7.38 236100.00000000006 p1=6.99 pct=-4.3
# before if 978 p1=6.97 a1=34850.0 a2=236000.0 p2=7.38
# out loop 978 p2=7.38 236000.00000000006 p1=6.97 pct=-4.3
# before if 977 p1=6.95 a1=34750.0 a2=235900.0 p2=7.37
# out loop 977 p2=7.37 235900.00000000006 p1=6.95 pct=-4.3
# before if 976 p1=6.93 a1=34650.0 a2=235800.0 p2=7.37
# out loop 976 p2=7.37 235800.00000000006 p1=6.93 pct=-4.3
# before if 975 p1=6.91 a1=34550.0 a2=235700.0 p2=7.37
# out loop 975 p2=7.37 235700.00000000006 p1=6.91 pct=-4.3
# before if 974 p1=6.89 a1=34450.0 a2=235600.0 p2=7.36
# out loop 974 p2=7.36 235600.00000000006 p1=6.89 pct=-4.3
# before if 973 p1=6.87 a1=34350.0 a2=235500.0 p2=7.36
# out loop 973 p2=7.36 235500.00000000006 p1=6.87 pct=-4.3
# before if 972 p1=6.85 a1=34250.0 a2=235400.0 p2=7.36
# out loop 972 p2=7.36 235400.00000000006 p1=6.85 pct=-4.3
# before if 971 p1=6.83 a1=34150.0 a2=235300.0 p2=7.35
# out loop 971 p2=7.35 235300.00000000006 p1=6.83 pct=-4.3
# before if 970 p1=6.81 a1=34050.0 a2=235200.0 p2=7.35
# out loop 970 p2=7.35 235200.00000000006 p1=6.81 pct=-4.3
# before if 969 p1=6.79 a1=33950.0 a2=235100.0 p2=7.35
# out loop 969 p2=7.35 235100.00000000006 p1=6.79 pct=-4.3
# before if 968 p1=6.77 a1=33850.0 a2=235000.0 p2=7.34
# out loop 968 p2=7.34 235000.00000000006 p1=6.77 pct=-4.3
# before if 967 p1=6.75 a1=33750.0 a2=234900.0 p2=7.34
# out loop 967 p2=7.34 234900.00000000006 p1=6.75 pct=-4.3
# before if 966 p1=6.73 a1=33650.0 a2=234800.0 p2=7.34
# out loop 966 p2=7.34 234800.0000000001 p1=6.73 pct=-4.3
# before if 965 p1=6.71 a1=33550.0 a2=234700.0 p2=7.33
# out loop 965 p2=7.33 234700.0000000001 p1=6.71 pct=-4.3
# before if 964 p1=6.69 a1=33450.0 a2=234600.0 p2=7.33
# out loop 964 p2=7.33 234600.0000000001 p1=6.69 pct=-4.3
# before if 963 p1=6.67 a1=33350.0 a2=234500.0 p2=7.33
# out loop 963 p2=7.33 234500.0000000001 p1=6.67 pct=-4.3
# before if 962 p1=6.65 a1=33250.0 a2=234400.0 p2=7.33
# out loop 962 p2=7.33 234400.0000000001 p1=6.65 pct=-4.3
# before if 961 p1=6.63 a1=33150.0 a2=234300.0 p2=7.32
# out loop 961 p2=7.32 234300.0000000001 p1=6.63 pct=-4.3
# before if 960 p1=6.61 a1=33050.0 a2=234200.0 p2=7.32
# out loop 960 p2=7.32 234200.0000000001 p1=6.61 pct=-4.3
# before if 959 p1=6.59 a1=32950.0 a2=234100.0 p2=7.32
# out loop 959 p2=7.32 234100.0000000001 p1=6.59 pct=-4.3
# before if 958 p1=6.57 a1=32850.0 a2=234000.0 p2=7.31
# out loop 958 p2=7.31 234000.0000000001 p1=6.57 pct=-4.3
# before if 957 p1=6.55 a1=32750.0 a2=233900.0 p2=7.31
# out loop 957 p2=7.31 233900.0000000001 p1=6.55 pct=-4.3
# before if 956 p1=6.53 a1=32650.0 a2=233800.0 p2=7.31
# out loop 956 p2=7.31 233800.0000000001 p1=6.53 pct=-4.3
# before if 955 p1=6.51 a1=32550.0 a2=233700.0 p2=7.3
# out loop 955 p2=7.3 233700.00000000012 p1=6.51 pct=-4.3
# before if 954 p1=6.49 a1=32450.0 a2=233600.0 p2=7.3
# in loop 954 p2=7.3 233600.00000000012 p1=6.49 pct=-12.89
# before if 954 p1=6.47 a1=32350.0 a2=233500.0 p2=7.3
# out loop 954 p2=7.3 233500.00000000012 p1=6.47 pct=-12.89
# before if 953 p1=6.45 a1=32250.0 a2=233400.0 p2=7.29
# out loop 953 p2=7.29 233400.00000000012 p1=6.45 pct=-12.89
# before if 952 p1=6.43 a1=32150.0 a2=233300.0 p2=7.29
# out loop 952 p2=7.29 233300.00000000012 p1=6.43 pct=-12.89
# before if 951 p1=6.41 a1=32050.0 a2=233200.0 p2=7.29
# out loop 951 p2=7.29 233200.00000000012 p1=6.41 pct=-12.89
# before if 950 p1=6.39 a1=31950.0 a2=233100.0 p2=7.28
# out loop 950 p2=7.28 233100.00000000012 p1=6.39 pct=-12.89
# before if 949 p1=6.37 a1=31850.0 a2=233000.0 p2=7.28
# out loop 949 p2=7.28 233000.00000000012 p1=6.37 pct=-12.89
# before if 948 p1=6.35 a1=31750.0 a2=232900.0 p2=7.28
# out loop 948 p2=7.28 232900.00000000012 p1=6.35 pct=-12.89
# before if 947 p1=6.33 a1=31650.0 a2=232800.0 p2=7.28
# out loop 947 p2=7.28 232800.00000000012 p1=6.33 pct=-12.89
# before if 946 p1=6.31 a1=31550.0 a2=232700.0 p2=7.27
# out loop 946 p2=7.27 232700.00000000012 p1=6.31 pct=-12.89
# before if 945 p1=6.29 a1=31450.0 a2=232600.0 p2=7.27
# out loop 945 p2=7.27 232600.00000000012 p1=6.29 pct=-12.89
# before if 944 p1=6.27 a1=31350.0 a2=232500.0 p2=7.27
# out loop 944 p2=7.27 232500.00000000012 p1=6.27 pct=-12.89
# before if 943 p1=6.25 a1=31250.0 a2=232400.0 p2=7.26
# out loop 943 p2=7.26 232400.00000000012 p1=6.25 pct=-12.89
# before if 942 p1=6.23 a1=31150.0 a2=232300.0 p2=7.26
# out loop 942 p2=7.26 232300.00000000012 p1=6.23 pct=-12.89
# before if 941 p1=6.21 a1=31050.0 a2=232200.0 p2=7.26
# out loop 941 p2=7.26 232200.00000000015 p1=6.21 pct=-12.89
# before if 940 p1=6.19 a1=30950.0 a2=232100.0 p2=7.25
# out loop 940 p2=7.25 232100.00000000015 p1=6.19 pct=-12.89
# before if 939 p1=6.17 a1=30850.0 a2=232000.0 p2=7.25
# out loop 939 p2=7.25 232000.00000000015 p1=6.17 pct=-12.89
# before if 938 p1=6.15 a1=30750.0 a2=231900.0 p2=7.25
# out loop 938 p2=7.25 231900.00000000015 p1=6.15 pct=-12.89
# before if 937 p1=6.13 a1=30650.0 a2=231800.0 p2=7.24
# out loop 937 p2=7.24 231800.00000000015 p1=6.13 pct=-12.89
# before if 936 p1=6.11 a1=30550.0 a2=231700.0 p2=7.24
# out loop 936 p2=7.24 231700.00000000015 p1=6.11 pct=-12.89
# before if 935 p1=6.09 a1=30450.0 a2=231600.0 p2=7.24
# out loop 935 p2=7.24 231600.00000000015 p1=6.09 pct=-12.89
# before if 934 p1=6.07 a1=30350.0 a2=231500.0 p2=7.23
# out loop 934 p2=7.23 231500.00000000015 p1=6.07 pct=-12.89
# before if 933 p1=6.05 a1=30250.0 a2=231400.0 p2=7.23
# out loop 933 p2=7.23 231400.00000000015 p1=6.05 pct=-12.89
# before if 932 p1=6.03 a1=30150.0 a2=231300.0 p2=7.23
# out loop 932 p2=7.23 231300.00000000015 p1=6.03 pct=-12.89
# before if 931 p1=6.01 a1=30050.0 a2=231200.0 p2=7.23
# out loop 931 p2=7.23 231200.00000000015 p1=6.01 pct=-12.89
# before if 930 p1=5.99 a1=29950.0 a2=231100.0 p2=7.22
# out loop 930 p2=7.22 231100.00000000015 p1=5.99 pct=-12.89
# before if 929 p1=5.97 a1=29850.0 a2=231000.0 p2=7.22
# out loop 929 p2=7.22 231000.00000000017 p1=5.97 pct=-12.89
# before if 928 p1=5.95 a1=29750.0 a2=230900.0 p2=7.22
# out loop 928 p2=7.22 230900.00000000017 p1=5.95 pct=-12.89
# before if 927 p1=5.93 a1=29650.0 a2=230800.0 p2=7.21
# out loop 927 p2=7.21 230800.00000000017 p1=5.93 pct=-12.89
# before if 926 p1=5.91 a1=29550.0 a2=230700.0 p2=7.21
# out loop 926 p2=7.21 230700.00000000017 p1=5.91 pct=-12.89
# before if 925 p1=5.89 a1=29450.0 a2=230600.0 p2=7.21
# out loop 925 p2=7.21 230600.00000000017 p1=5.89 pct=-12.89
# before if 924 p1=5.87 a1=29350.0 a2=230500.0 p2=7.2
# out loop 924 p2=7.2 230500.00000000017 p1=5.87 pct=-12.89
# before if 923 p1=5.85 a1=29250.0 a2=230400.0 p2=7.2
# in loop 923 p2=7.2 230400.00000000017 p1=5.85 pct=-21.48
# before if 923 p1=5.83 a1=29150.0 a2=230300.0 p2=7.2
# out loop 923 p2=7.2 230300.00000000017 p1=5.83 pct=-21.48
# before if 922 p1=5.81 a1=29050.0 a2=230200.0 p2=7.19
# out loop 922 p2=7.19 230200.00000000017 p1=5.81 pct=-21.48
# before if 921 p1=5.79 a1=28950.0 a2=230100.0 p2=7.19
# out loop 921 p2=7.19 230100.00000000017 p1=5.79 pct=-21.48
# before if 920 p1=5.77 a1=28850.0 a2=230000.0 p2=7.19
# out loop 920 p2=7.19 230000.00000000017 p1=5.77 pct=-21.48
# before if 919 p1=5.75 a1=28750.0 a2=229900.0 p2=7.18
# out loop 919 p2=7.18 229900.00000000017 p1=5.75 pct=-21.48
# before if 918 p1=5.73 a1=28650.0 a2=229800.0 p2=7.18
# out loop 918 p2=7.18 229800.00000000017 p1=5.73 pct=-21.48
# before if 917 p1=5.71 a1=28550.0 a2=229700.0 p2=7.18
# out loop 917 p2=7.18 229700.00000000017 p1=5.71 pct=-21.48
# before if 916 p1=5.69 a1=28450.0 a2=229600.0 p2=7.18
# out loop 916 p2=7.18 229600.00000000017 p1=5.69 pct=-21.48
# before if 915 p1=5.67 a1=28350.0 a2=229500.0 p2=7.17
# out loop 915 p2=7.17 229500.00000000017 p1=5.67 pct=-21.48
# before if 914 p1=5.65 a1=28250.0 a2=229400.0 p2=7.17
# out loop 914 p2=7.17 229400.0000000002 p1=5.65 pct=-21.48
# before if 913 p1=5.63 a1=28150.0 a2=229300.0 p2=7.17
# out loop 913 p2=7.17 229300.0000000002 p1=5.63 pct=-21.48
# before if 912 p1=5.61 a1=28050.0 a2=229200.0 p2=7.16
# out loop 912 p2=7.16 229200.0000000002 p1=5.61 pct=-21.48
# before if 911 p1=5.59 a1=27950.0 a2=229100.0 p2=7.16
# out loop 911 p2=7.16 229100.0000000002 p1=5.59 pct=-21.48
# before if 910 p1=5.57 a1=27850.0 a2=229000.0 p2=7.16
# out loop 910 p2=7.16 229000.0000000002 p1=5.57 pct=-21.48
# before if 909 p1=5.55 a1=27750.0 a2=228900.0 p2=7.15
# out loop 909 p2=7.15 228900.0000000002 p1=5.55 pct=-21.48
# before if 908 p1=5.53 a1=27650.0 a2=228800.0 p2=7.15
# out loop 908 p2=7.15 228800.0000000002 p1=5.53 pct=-21.48
# before if 907 p1=5.51 a1=27550.0 a2=228700.0 p2=7.15
# out loop 907 p2=7.15 228700.0000000002 p1=5.51 pct=-21.48
# before if 906 p1=5.49 a1=27450.0 a2=228600.0 p2=7.14
# out loop 906 p2=7.14 228600.0000000002 p1=5.49 pct=-21.48
# before if 905 p1=5.47 a1=27350.0 a2=228500.0 p2=7.14
# out loop 905 p2=7.14 228500.0000000002 p1=5.47 pct=-21.48
# before if 904 p1=5.45 a1=27250.0 a2=228400.0 p2=7.14
# out loop 904 p2=7.14 228400.0000000002 p1=5.45 pct=-21.48
# before if 903 p1=5.43 a1=27150.0 a2=228300.0 p2=7.13
# out loop 903 p2=7.13 228300.0000000002 p1=5.43 pct=-21.48
# before if 902 p1=5.41 a1=27050.0 a2=228200.0 p2=7.13
# out loop 902 p2=7.13 228200.00000000023 p1=5.41 pct=-21.48
# before if 901 p1=5.39 a1=26950.0 a2=228100.0 p2=7.13
# out loop 901 p2=7.13 228100.00000000023 p1=5.39 pct=-21.48
# before if 900 p1=5.37 a1=26850.0 a2=228000.0 p2=7.13
# out loop 900 p2=7.13 228000.00000000023 p1=5.37 pct=-21.48
# before if 899 p1=5.35 a1=26750.0 a2=227900.0 p2=7.12
# out loop 899 p2=7.12 227900.00000000023 p1=5.35 pct=-21.48
# before if 898 p1=5.33 a1=26650.0 a2=227800.0 p2=7.12
# out loop 898 p2=7.12 227800.00000000023 p1=5.33 pct=-21.48
# before if 897 p1=5.31 a1=26550.0 a2=227700.0 p2=7.12
# out loop 897 p2=7.12 227700.00000000023 p1=5.31 pct=-21.48
# before if 896 p1=5.29 a1=26450.0 a2=227600.0 p2=7.11
# out loop 896 p2=7.11 227600.00000000023 p1=5.29 pct=-21.48
# before if 895 p1=5.27 a1=26350.0 a2=227500.0 p2=7.11
# out loop 895 p2=7.11 227500.00000000023 p1=5.27 pct=-21.48
# before if 894 p1=5.25 a1=26250.0 a2=227400.0 p2=7.11
# out loop 894 p2=7.11 227400.00000000023 p1=5.25 pct=-21.48
# before if 893 p1=5.23 a1=26150.0 a2=227300.0 p2=7.1
# out loop 893 p2=7.1 227300.00000000023 p1=5.23 pct=-21.48
# before if 892 p1=5.21 a1=26050.0 a2=227200.0 p2=7.1
# in loop 892 p2=7.1 227200.00000000023 p1=5.21 pct=-30.07
# before if 892 p1=5.19 a1=25950.0 a2=227100.0 p2=7.1
# out loop 892 p2=7.1 227100.00000000023 p1=5.19 pct=-30.07
# before if 891 p1=5.17 a1=25850.0 a2=227000.0 p2=7.09
# out loop 891 p2=7.09 227000.00000000023 p1=5.17 pct=-30.07
# before if 890 p1=5.15 a1=25750.0 a2=226900.0 p2=7.09
# out loop 890 p2=7.09 226900.00000000023 p1=5.15 pct=-30.07
# before if 889 p1=5.13 a1=25650.0 a2=226800.0 p2=7.09
# out loop 889 p2=7.09 226800.00000000023 p1=5.13 pct=-30.07
# before if 888 p1=5.11 a1=25550.0 a2=226700.0 p2=7.08
# out loop 888 p2=7.08 226700.00000000026 p1=5.11 pct=-30.07
# before if 887 p1=5.09 a1=25450.0 a2=226600.0 p2=7.08
# out loop 887 p2=7.08 226600.00000000026 p1=5.09 pct=-30.07
# before if 886 p1=5.07 a1=25350.0 a2=226500.0 p2=7.08
# out loop 886 p2=7.08 226500.00000000026 p1=5.07 pct=-30.07
# before if 885 p1=5.05 a1=25250.0 a2=226400.0 p2=7.08
# out loop 885 p2=7.08 226400.00000000026 p1=5.05 pct=-30.07
# before if 884 p1=5.03 a1=25150.0 a2=226300.0 p2=7.07
# out loop 884 p2=7.07 226300.00000000026 p1=5.03 pct=-30.07
# before if 883 p1=5.01 a1=25050.0 a2=226200.0 p2=7.07
# out loop 883 p2=7.07 226200.00000000026 p1=5.01 pct=-30.07
# before if 882 p1=4.99 a1=24950.0 a2=226100.0 p2=7.07
# out loop 882 p2=7.07 226100.00000000026 p1=4.99 pct=-30.07
# before if 881 p1=4.97 a1=24850.0 a2=226000.0 p2=7.06
# out loop 881 p2=7.06 226000.00000000026 p1=4.97 pct=-30.07
# before if 880 p1=4.95 a1=24750.0 a2=225900.0 p2=7.06
# out loop 880 p2=7.06 225900.00000000026 p1=4.95 pct=-30.07
# before if 879 p1=4.93 a1=24650.0 a2=225800.0 p2=7.06
# out loop 879 p2=7.06 225800.00000000026 p1=4.93 pct=-30.07
# before if 878 p1=4.91 a1=24550.0 a2=225700.0 p2=7.05
# out loop 878 p2=7.05 225700.00000000026 p1=4.91 pct=-30.07
# before if 877 p1=4.89 a1=24450.0 a2=225600.0 p2=7.05
# out loop 877 p2=7.05 225600.00000000026 p1=4.89 pct=-30.07
# before if 876 p1=4.87 a1=24350.0 a2=225500.0 p2=7.05
# out loop 876 p2=7.05 225500.0000000003 p1=4.87 pct=-30.07
# before if 875 p1=4.85 a1=24250.0 a2=225400.0 p2=7.04
# out loop 875 p2=7.04 225400.0000000003 p1=4.85 pct=-30.07
# before if 874 p1=4.83 a1=24150.0 a2=225300.0 p2=7.04
# out loop 874 p2=7.04 225300.0000000003 p1=4.83 pct=-30.07
# before if 873 p1=4.81 a1=24050.0 a2=225200.0 p2=7.04
# out loop 873 p2=7.04 225200.0000000003 p1=4.81 pct=-30.07
# before if 872 p1=4.79 a1=23950.0 a2=225100.0 p2=7.03
# out loop 872 p2=7.03 225100.0000000003 p1=4.79 pct=-30.07
# before if 871 p1=4.77 a1=23850.0 a2=225000.0 p2=7.03
# out loop 871 p2=7.03 225000.0000000003 p1=4.77 pct=-30.07
# before if 870 p1=4.75 a1=23750.0 a2=224900.0 p2=7.03
# out loop 870 p2=7.03 224900.0000000003 p1=4.75 pct=-30.07
# before if 869 p1=4.73 a1=23650.0 a2=224800.0 p2=7.03
# out loop 869 p2=7.03 224800.0000000003 p1=4.73 pct=-30.07
# before if 868 p1=4.71 a1=23550.0 a2=224700.0 p2=7.02
# out loop 868 p2=7.02 224700.0000000003 p1=4.71 pct=-30.07
# before if 867 p1=4.69 a1=23450.0 a2=224600.0 p2=7.02
# out loop 867 p2=7.02 224600.0000000003 p1=4.69 pct=-30.07
# before if 866 p1=4.67 a1=23350.0 a2=224500.0 p2=7.02
# out loop 866 p2=7.02 224500.0000000003 p1=4.67 pct=-30.07
# before if 865 p1=4.65 a1=23250.0 a2=224400.0 p2=7.01
# out loop 865 p2=7.01 224400.0000000003 p1=4.65 pct=-30.07
# before if 864 p1=4.63 a1=23150.0 a2=224300.0 p2=7.01
# out loop 864 p2=7.01 224300.0000000003 p1=4.63 pct=-30.07
# before if 863 p1=4.61 a1=23050.0 a2=224200.0 p2=7.01
# out loop 863 p2=7.01 224200.0000000003 p1=4.61 pct=-30.07
# before if 862 p1=4.59 a1=22950.0 a2=224100.0 p2=7.0
# out loop 862 p2=7.0 224100.0000000003 p1=4.59 pct=-30.07
# before if 861 p1=4.57 a1=22850.0 a2=224000.0 p2=7.0
# in loop 861 p2=7.0 224000.00000000032 p1=4.57 pct=-38.66
# before if 861 p1=4.55 a1=22750.0 a2=223900.0 p2=7.0
# out loop 861 p2=7.0 223900.00000000032 p1=4.55 pct=-38.66
# before if 860 p1=4.53 a1=22650.0 a2=223800.0 p2=6.99
# out loop 860 p2=6.99 223800.00000000032 p1=4.53 pct=-38.66
# before if 859 p1=4.51 a1=22550.0 a2=223700.0 p2=6.99
# out loop 859 p2=6.99 223700.00000000032 p1=4.51 pct=-38.66
# before if 858 p1=4.49 a1=22450.0 a2=223600.0 p2=6.99
# out loop 858 p2=6.99 223600.00000000032 p1=4.49 pct=-38.66
# before if 857 p1=4.47 a1=22350.0 a2=223500.0 p2=6.98
# out loop 857 p2=6.98 223500.00000000032 p1=4.47 pct=-38.66
# before if 856 p1=4.45 a1=22250.0 a2=223400.0 p2=6.98
# out loop 856 p2=6.98 223400.00000000032 p1=4.45 pct=-38.66
# before if 855 p1=4.43 a1=22150.0 a2=223300.0 p2=6.98
# out loop 855 p2=6.98 223300.00000000032 p1=4.43 pct=-38.66
# before if 854 p1=4.41 a1=22050.0 a2=223200.0 p2=6.98
# out loop 854 p2=6.98 223200.00000000032 p1=4.41 pct=-38.66
# before if 853 p1=4.39 a1=21950.0 a2=223100.0 p2=6.97
# out loop 853 p2=6.97 223100.00000000032 p1=4.39 pct=-38.66
# before if 852 p1=4.37 a1=21850.0 a2=223000.0 p2=6.97
# out loop 852 p2=6.97 223000.00000000032 p1=4.37 pct=-38.66
# before if 851 p1=4.35 a1=21750.0 a2=222900.0 p2=6.97
# out loop 851 p2=6.97 222900.00000000032 p1=4.35 pct=-38.66
# before if 850 p1=4.33 a1=21650.0 a2=222800.0 p2=6.96
# out loop 850 p2=6.96 222800.00000000035 p1=4.33 pct=-38.66
# before if 849 p1=4.31 a1=21550.0 a2=222700.0 p2=6.96
# out loop 849 p2=6.96 222700.00000000035 p1=4.31 pct=-38.66
# before if 848 p1=4.29 a1=21450.0 a2=222600.0 p2=6.96
# out loop 848 p2=6.96 222600.00000000035 p1=4.29 pct=-38.66
# before if 847 p1=4.27 a1=21350.0 a2=222500.0 p2=6.95
# out loop 847 p2=6.95 222500.00000000035 p1=4.27 pct=-38.66
# before if 846 p1=4.25 a1=21250.0 a2=222400.0 p2=6.95
# out loop 846 p2=6.95 222400.00000000035 p1=4.25 pct=-38.66
# before if 845 p1=4.23 a1=21150.0 a2=222300.0 p2=6.95
# out loop 845 p2=6.95 222300.00000000035 p1=4.23 pct=-38.66
# before if 844 p1=4.21 a1=21050.0 a2=222200.0 p2=6.94
# out loop 844 p2=6.94 222200.00000000035 p1=4.21 pct=-38.66
# before if 843 p1=4.19 a1=20950.0 a2=222100.0 p2=6.94
# out loop 843 p2=6.94 222100.00000000035 p1=4.19 pct=-38.66
# before if 842 p1=4.17 a1=20850.0 a2=222000.0 p2=6.94
# out loop 842 p2=6.94 222000.00000000035 p1=4.17 pct=-38.66
# before if 841 p1=4.15 a1=20750.0 a2=221900.0 p2=6.93
# out loop 841 p2=6.93 221900.00000000035 p1=4.15 pct=-38.66
# before if 840 p1=4.13 a1=20650.0 a2=221800.0 p2=6.93
# out loop 840 p2=6.93 221800.00000000035 p1=4.13 pct=-38.66
# before if 839 p1=4.11 a1=20550.0 a2=221700.0 p2=6.93
# out loop 839 p2=6.93 221700.00000000035 p1=4.11 pct=-38.66
# before if 838 p1=4.09 a1=20450.0 a2=221600.0 p2=6.93
# out loop 838 p2=6.93 221600.00000000035 p1=4.09 pct=-38.66
# before if 837 p1=4.07 a1=20350.0 a2=221500.0 p2=6.92
# out loop 837 p2=6.92 221500.00000000035 p1=4.07 pct=-38.66
# before if 836 p1=4.05 a1=20250.0 a2=221400.0 p2=6.92
# out loop 836 p2=6.92 221400.00000000035 p1=4.05 pct=-38.66
# before if 835 p1=4.03 a1=20150.0 a2=221300.0 p2=6.92
# out loop 835 p2=6.92 221300.00000000035 p1=4.03 pct=-38.66
# before if 834 p1=4.01 a1=20050.0 a2=221200.0 p2=6.91
# out loop 834 p2=6.91 221200.00000000038 p1=4.01 pct=-38.66
# before if 833 p1=3.99 a1=19950.0 a2=221100.0 p2=6.91
# out loop 833 p2=6.91 221100.00000000038 p1=3.99 pct=-38.66
# before if 832 p1=3.97 a1=19850.0 a2=221000.0 p2=6.91
# out loop 832 p2=6.91 221000.00000000038 p1=3.97 pct=-38.66
# before if 831 p1=3.95 a1=19750.0 a2=220900.0 p2=6.9
# out loop 831 p2=6.9 220900.00000000038 p1=3.95 pct=-38.66
# before if 830 p1=3.93 a1=19650.0 a2=220800.0 p2=6.9
# in loop 830 p2=6.9 220800.00000000038 p1=3.93 pct=-47.25
# p1=3.93 p2=6.9 pct=-47.25
# array([None], dtype=object)

# %% [markdown]
# #####
