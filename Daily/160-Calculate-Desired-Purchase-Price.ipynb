# %%
import calendar
import pandas as pd
import numpy as np
from datetime import date, timedelta
from math import ceil, floor, trunc

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2025, 2, 21), datetime.date(2025, 2, 20))

# %%
def number_of_spread(x):
    # Unpack values from input list
    q0 = x[0]   # old quantity
    p0 = x[1]   # old unit price
    old_unit_cost = x[1]  # store old unit price for later use
    q1 = x[2]   # purchase quantity
    d1 = x[3]   # spread according to price range
    c0 = x[4]   # desired down percent to adjust purchase price

    # Calculate old cost amount
    a0 = q0 * p0

    # Initialize loop variables
    i = 1000
    pct = 0
    pt = 0
    dt = 0
    p2 = 0

    # Loop until i becomes 0
    while i > 0:
        # Calculate simulated purchase price
        p1 = p0 - d1

        # Update old unit price for next iteration
        p0 = p1

        # Calculate new purchase amount
        a1 = q1 * p1

        # Calculate new total quantity and cost amount
        q2 = q0 + q1
        a2 = a0 + a1

        # Calculate new unit cost
        p2 = a2 / q2

        # Round simulated purchase price and spread according to price range
        pt = round(p2 * 100, 2)
        dt = d1 * 100

        # Debugging output
        print('before if', i, 'p1=' + str(round(p1, 2)), 'a1=' + str(round(a1, 2)), 'a2=' + str(round(a2, 2)), 'p2=' + str(round(p2, 2)))

        # Check if simulated purchase price is divisible by spread
        if (pt % dt) == 0:
            # Calculate percentage change in unit cost
            pct = ((p1 - old_unit_cost) / old_unit_cost) * 100

            # Debugging output
            print('in loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

            # Check if absolute value of percentage change is less than desired down percent
            if abs(pct) < c0:
                # Continue to next iteration if condition is met
                continue

            # Break loop if condition is not met
            break

        # Debugging output
        print('out loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

        # Decrement loop counter
        i -= 1

    # Return simulated purchase price, new unit cost, and percentage change in unit cost
    return print('p1=' + str(round(p1, 2)), 'p2=' + str(round(p2, 2)), 'pct=' + str(round(pct, 2)))

# %%
my_array = [[75_000,15.40,5000,.10,55]]
tmp = (np.apply_along_axis(number_of_spread, axis=1, arr=my_array))
tmp
# Out:
# before if 1000 p1=15.3 a1=76500.0 a2=1231500.0 p2=15.39
# out loop 1000 p2=15.39 1231500.0 p1=15.3 pct=0
# before if 999 p1=15.2 a1=76000.0 a2=1231000.0 p2=15.39
# out loop 999 p2=15.39 1231000.0 p1=15.2 pct=0
# before if 998 p1=15.1 a1=75500.0 a2=1230500.0 p2=15.38
# out loop 998 p2=15.38 1230500.0 p1=15.1 pct=0
# before if 997 p1=15.0 a1=75000.0 a2=1230000.0 p2=15.38
# out loop 997 p2=15.38 1230000.0 p1=15.0 pct=0
# before if 996 p1=14.9 a1=74500.0 a2=1229500.0 p2=15.37
# out loop 996 p2=15.37 1229500.0 p1=14.9 pct=0
# before if 995 p1=14.8 a1=74000.0 a2=1229000.0 p2=15.36
# out loop 995 p2=15.36 1229000.0 p1=14.8 pct=0
# before if 994 p1=14.7 a1=73500.0 a2=1228500.0 p2=15.36
# out loop 994 p2=15.36 1228500.0 p1=14.7 pct=0
# before if 993 p1=14.6 a1=73000.0 a2=1228000.0 p2=15.35
# out loop 993 p2=15.35 1228000.0 p1=14.6 pct=0
# before if 992 p1=14.5 a1=72500.0 a2=1227500.0 p2=15.34
# out loop 992 p2=15.34 1227500.0 p1=14.5 pct=0
# before if 991 p1=14.4 a1=72000.0 a2=1227000.0 p2=15.34
# out loop 991 p2=15.34 1227000.0 p1=14.4 pct=0
# before if 990 p1=14.3 a1=71500.0 a2=1226500.0 p2=15.33
# out loop 990 p2=15.33 1226500.0 p1=14.3 pct=0
# before if 989 p1=14.2 a1=71000.0 a2=1226000.0 p2=15.32
# out loop 989 p2=15.32 1226000.0 p1=14.2 pct=0
# before if 988 p1=14.1 a1=70500.0 a2=1225500.0 p2=15.32
# out loop 988 p2=15.32 1225500.0 p1=14.1 pct=0
# before if 987 p1=14.0 a1=70000.0 a2=1225000.0 p2=15.31
# out loop 987 p2=15.31 1225000.0 p1=14.0 pct=0
# before if 986 p1=13.9 a1=69500.0 a2=1224500.0 p2=15.31
# out loop 986 p2=15.31 1224500.0 p1=13.9 pct=0
# before if 985 p1=13.8 a1=69000.0 a2=1224000.0 p2=15.3
# in loop 985 p2=15.3 1224000.0 p1=13.8 pct=-10.39
# before if 985 p1=13.7 a1=68500.0 a2=1223500.0 p2=15.29
# out loop 985 p2=15.29 1223500.0 p1=13.7 pct=-10.39
# before if 984 p1=13.6 a1=68000.0 a2=1223000.0 p2=15.29
# out loop 984 p2=15.29 1223000.0 p1=13.6 pct=-10.39
# before if 983 p1=13.5 a1=67500.0 a2=1222500.0 p2=15.28
# out loop 983 p2=15.28 1222500.0 p1=13.5 pct=-10.39
# before if 982 p1=13.4 a1=67000.0 a2=1222000.0 p2=15.28
# out loop 982 p2=15.28 1222000.0 p1=13.4 pct=-10.39
# before if 981 p1=13.3 a1=66500.0 a2=1221500.0 p2=15.27
# out loop 981 p2=15.27 1221500.0 p1=13.3 pct=-10.39
# before if 980 p1=13.2 a1=66000.0 a2=1221000.0 p2=15.26
# out loop 980 p2=15.26 1221000.0 p1=13.2 pct=-10.39
# before if 979 p1=13.1 a1=65500.0 a2=1220500.0 p2=15.26
# out loop 979 p2=15.26 1220500.0 p1=13.1 pct=-10.39
# before if 978 p1=13.0 a1=65000.0 a2=1220000.0 p2=15.25
# out loop 978 p2=15.25 1220000.0 p1=13.0 pct=-10.39
# before if 977 p1=12.9 a1=64500.0 a2=1219500.0 p2=15.24
# out loop 977 p2=15.24 1219500.0 p1=12.9 pct=-10.39
# before if 976 p1=12.8 a1=64000.0 a2=1219000.0 p2=15.24
# out loop 976 p2=15.24 1219000.0 p1=12.8 pct=-10.39
# before if 975 p1=12.7 a1=63500.0 a2=1218500.0 p2=15.23
# out loop 975 p2=15.23 1218500.0 p1=12.7 pct=-10.39
# before if 974 p1=12.6 a1=63000.0 a2=1218000.0 p2=15.22
# out loop 974 p2=15.22 1218000.0 p1=12.6 pct=-10.39
# before if 973 p1=12.5 a1=62500.0 a2=1217500.0 p2=15.22
# out loop 973 p2=15.22 1217500.0 p1=12.5 pct=-10.39
# before if 972 p1=12.4 a1=62000.0 a2=1217000.0 p2=15.21
# out loop 972 p2=15.21 1217000.0 p1=12.4 pct=-10.39
# before if 971 p1=12.3 a1=61500.0 a2=1216500.0 p2=15.21
# out loop 971 p2=15.21 1216500.0 p1=12.3 pct=-10.39
# before if 970 p1=12.2 a1=61000.0 a2=1216000.0 p2=15.2
# in loop 970 p2=15.2 1216000.0 p1=12.2 pct=-20.78
# before if 970 p1=12.1 a1=60500.0 a2=1215500.0 p2=15.19
# out loop 970 p2=15.19 1215500.0 p1=12.1 pct=-20.78
# before if 969 p1=12.0 a1=60000.0 a2=1215000.0 p2=15.19
# out loop 969 p2=15.19 1215000.0 p1=12.0 pct=-20.78
# before if 968 p1=11.9 a1=59500.0 a2=1214500.0 p2=15.18
# out loop 968 p2=15.18 1214500.0 p1=11.9 pct=-20.78
# before if 967 p1=11.8 a1=59000.0 a2=1214000.0 p2=15.18
# out loop 967 p2=15.18 1214000.0 p1=11.8 pct=-20.78
# before if 966 p1=11.7 a1=58500.0 a2=1213500.0 p2=15.17
# out loop 966 p2=15.17 1213500.0 p1=11.7 pct=-20.78
# before if 965 p1=11.6 a1=58000.0 a2=1213000.0 p2=15.16
# out loop 965 p2=15.16 1213000.0 p1=11.6 pct=-20.78
# before if 964 p1=11.5 a1=57500.0 a2=1212500.0 p2=15.16
# out loop 964 p2=15.16 1212500.0 p1=11.5 pct=-20.78
# before if 963 p1=11.4 a1=57000.0 a2=1212000.0 p2=15.15
# out loop 963 p2=15.15 1212000.0 p1=11.4 pct=-20.78
# before if 962 p1=11.3 a1=56500.0 a2=1211500.0 p2=15.14
# out loop 962 p2=15.14 1211500.0 p1=11.3 pct=-20.78
# before if 961 p1=11.2 a1=56000.0 a2=1211000.0 p2=15.14
# out loop 961 p2=15.14 1211000.0 p1=11.2 pct=-20.78
# before if 960 p1=11.1 a1=55500.0 a2=1210500.0 p2=15.13
# out loop 960 p2=15.13 1210500.0 p1=11.1 pct=-20.78
# before if 959 p1=11.0 a1=55000.0 a2=1210000.0 p2=15.12
# out loop 959 p2=15.12 1210000.0 p1=11.0 pct=-20.78
# before if 958 p1=10.9 a1=54500.0 a2=1209500.0 p2=15.12
# out loop 958 p2=15.12 1209500.0 p1=10.9 pct=-20.78
# before if 957 p1=10.8 a1=54000.0 a2=1209000.0 p2=15.11
# out loop 957 p2=15.11 1209000.0 p1=10.8 pct=-20.78
# before if 956 p1=10.7 a1=53500.0 a2=1208500.0 p2=15.11
# out loop 956 p2=15.11 1208500.0 p1=10.7 pct=-20.78
# before if 955 p1=10.6 a1=53000.0 a2=1208000.0 p2=15.1
# in loop 955 p2=15.1 1208000.0 p1=10.6 pct=-31.17
# before if 955 p1=10.5 a1=52500.0 a2=1207500.0 p2=15.09
# out loop 955 p2=15.09 1207500.0 p1=10.5 pct=-31.17
# before if 954 p1=10.4 a1=52000.0 a2=1207000.0 p2=15.09
# out loop 954 p2=15.09 1207000.0 p1=10.4 pct=-31.17
# before if 953 p1=10.3 a1=51500.0 a2=1206500.0 p2=15.08
# out loop 953 p2=15.08 1206500.0 p1=10.3 pct=-31.17
# before if 952 p1=10.2 a1=51000.0 a2=1206000.0 p2=15.08
# out loop 952 p2=15.08 1206000.0 p1=10.2 pct=-31.17
# before if 951 p1=10.1 a1=50500.0 a2=1205500.0 p2=15.07
# out loop 951 p2=15.07 1205500.0 p1=10.1 pct=-31.17
# before if 950 p1=10.0 a1=50000.0 a2=1205000.0 p2=15.06
# out loop 950 p2=15.06 1205000.0 p1=10.0 pct=-31.17
# before if 949 p1=9.9 a1=49500.0 a2=1204500.0 p2=15.06
# out loop 949 p2=15.06 1204500.0 p1=9.9 pct=-31.17
# before if 948 p1=9.8 a1=49000.0 a2=1204000.0 p2=15.05
# out loop 948 p2=15.05 1204000.0 p1=9.8 pct=-31.17
# before if 947 p1=9.7 a1=48500.0 a2=1203500.0 p2=15.04
# out loop 947 p2=15.04 1203500.0 p1=9.7 pct=-31.17
# before if 946 p1=9.6 a1=48000.0 a2=1203000.0 p2=15.04
# out loop 946 p2=15.04 1203000.0 p1=9.6 pct=-31.17
# before if 945 p1=9.5 a1=47500.0 a2=1202500.0 p2=15.03
# out loop 945 p2=15.03 1202500.0 p1=9.5 pct=-31.17
# before if 944 p1=9.4 a1=47000.0 a2=1202000.0 p2=15.02
# out loop 944 p2=15.02 1202000.0 p1=9.4 pct=-31.17
# before if 943 p1=9.3 a1=46500.0 a2=1201500.0 p2=15.02
# out loop 943 p2=15.02 1201500.0 p1=9.3 pct=-31.17
# before if 942 p1=9.2 a1=46000.0 a2=1201000.0 p2=15.01
# out loop 942 p2=15.01 1201000.0 p1=9.2 pct=-31.17
# before if 941 p1=9.1 a1=45500.0 a2=1200500.0 p2=15.01
# out loop 941 p2=15.01 1200500.0 p1=9.1 pct=-31.17
# before if 940 p1=9.0 a1=45000.0 a2=1200000.0 p2=15.0
# in loop 940 p2=15.0 1200000.0 p1=9.0 pct=-41.56
# before if 940 p1=8.9 a1=44500.0 a2=1199500.0 p2=14.99
# out loop 940 p2=14.99 1199500.0 p1=8.9 pct=-41.56
# before if 939 p1=8.8 a1=44000.0 a2=1199000.0 p2=14.99
# out loop 939 p2=14.99 1199000.0 p1=8.8 pct=-41.56
# before if 938 p1=8.7 a1=43500.0 a2=1198500.0 p2=14.98
# out loop 938 p2=14.98 1198500.0000000002 p1=8.7 pct=-41.56
# before if 937 p1=8.6 a1=43000.0 a2=1198000.0 p2=14.98
# out loop 937 p2=14.98 1198000.0000000002 p1=8.6 pct=-41.56
# before if 936 p1=8.5 a1=42500.0 a2=1197500.0 p2=14.97
# out loop 936 p2=14.97 1197500.0000000002 p1=8.5 pct=-41.56
# before if 935 p1=8.4 a1=42000.0 a2=1197000.0 p2=14.96
# out loop 935 p2=14.96 1197000.0000000002 p1=8.4 pct=-41.56
# before if 934 p1=8.3 a1=41500.0 a2=1196500.0 p2=14.96
# out loop 934 p2=14.96 1196500.0000000002 p1=8.3 pct=-41.56
# before if 933 p1=8.2 a1=41000.0 a2=1196000.0 p2=14.95
# out loop 933 p2=14.95 1196000.0000000002 p1=8.2 pct=-41.56
# before if 932 p1=8.1 a1=40500.0 a2=1195500.0 p2=14.94
# out loop 932 p2=14.94 1195500.0000000002 p1=8.1 pct=-41.56
# before if 931 p1=8.0 a1=40000.0 a2=1195000.0 p2=14.94
# out loop 931 p2=14.94 1195000.0000000002 p1=8.0 pct=-41.56
# before if 930 p1=7.9 a1=39500.0 a2=1194500.0 p2=14.93
# out loop 930 p2=14.93 1194500.0000000002 p1=7.9 pct=-41.56
# before if 929 p1=7.8 a1=39000.0 a2=1194000.0 p2=14.93
# out loop 929 p2=14.93 1194000.0000000002 p1=7.8 pct=-41.56
# before if 928 p1=7.7 a1=38500.0 a2=1193500.0 p2=14.92
# out loop 928 p2=14.92 1193500.0000000002 p1=7.7 pct=-41.56
# before if 927 p1=7.6 a1=38000.0 a2=1193000.0 p2=14.91
# out loop 927 p2=14.91 1193000.0000000002 p1=7.6 pct=-41.56
# before if 926 p1=7.5 a1=37500.0 a2=1192500.0 p2=14.91
# out loop 926 p2=14.91 1192500.0000000002 p1=7.5 pct=-41.56
# before if 925 p1=7.4 a1=37000.0 a2=1192000.0 p2=14.9
# in loop 925 p2=14.9 1192000.0000000002 p1=7.4 pct=-51.95
# before if 925 p1=7.3 a1=36500.0 a2=1191500.0 p2=14.89
# out loop 925 p2=14.89 1191500.0000000002 p1=7.3 pct=-51.95
# before if 924 p1=7.2 a1=36000.0 a2=1191000.0 p2=14.89
# out loop 924 p2=14.89 1191000.0000000002 p1=7.2 pct=-51.95
# before if 923 p1=7.1 a1=35500.0 a2=1190500.0 p2=14.88
# out loop 923 p2=14.88 1190500.0000000002 p1=7.1 pct=-51.95
# before if 922 p1=7.0 a1=35000.0 a2=1190000.0 p2=14.88
# out loop 922 p2=14.88 1190000.0000000002 p1=7.0 pct=-51.95
# before if 921 p1=6.9 a1=34500.0 a2=1189500.0 p2=14.87
# out loop 921 p2=14.87 1189500.0000000002 p1=6.9 pct=-51.95
# before if 920 p1=6.8 a1=34000.0 a2=1189000.0 p2=14.86
# out loop 920 p2=14.86 1189000.0000000002 p1=6.8 pct=-51.95
# before if 919 p1=6.7 a1=33500.0 a2=1188500.0 p2=14.86
# out loop 919 p2=14.86 1188500.0000000002 p1=6.7 pct=-51.95
# before if 918 p1=6.6 a1=33000.0 a2=1188000.0 p2=14.85
# out loop 918 p2=14.85 1188000.0000000002 p1=6.6 pct=-51.95
# before if 917 p1=6.5 a1=32500.0 a2=1187500.0 p2=14.84
# out loop 917 p2=14.84 1187500.0000000002 p1=6.5 pct=-51.95
# before if 916 p1=6.4 a1=32000.0 a2=1187000.0 p2=14.84
# out loop 916 p2=14.84 1187000.0000000002 p1=6.4 pct=-51.95
# before if 915 p1=6.3 a1=31500.0 a2=1186500.0 p2=14.83
# out loop 915 p2=14.83 1186500.0000000002 p1=6.3 pct=-51.95
# before if 914 p1=6.2 a1=31000.0 a2=1186000.0 p2=14.83
# out loop 914 p2=14.83 1186000.0000000002 p1=6.2 pct=-51.95
# before if 913 p1=6.1 a1=30500.0 a2=1185500.0 p2=14.82
# out loop 913 p2=14.82 1185500.0000000002 p1=6.1 pct=-51.95
# before if 912 p1=6.0 a1=30000.0 a2=1185000.0 p2=14.81
# out loop 912 p2=14.81 1185000.0000000002 p1=6.0 pct=-51.95
# before if 911 p1=5.9 a1=29500.0 a2=1184500.0 p2=14.81
# out loop 911 p2=14.81 1184500.0000000002 p1=5.9 pct=-51.95
# before if 910 p1=5.8 a1=29000.0 a2=1184000.0 p2=14.8
# in loop 910 p2=14.8 1184000.0000000002 p1=5.8 pct=-62.34
# p1=5.8 p2=14.8 pct=-62.34
# array([None], dtype=object)

# %% [markdown]
# #####
