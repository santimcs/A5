# %%
import calendar
import pandas as pd
import numpy as np
from datetime import date, timedelta
from math import ceil, floor, trunc

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2024, 11, 18), datetime.date(2024, 11, 17))

# %%
def number_of_spread(x):
    # Unpack values from input list
    q0 = x[0]   # old quantity
    p0 = x[1]   # old unit price
    old_unit_cost = x[1]  # store old unit price for later use
    q1 = x[2]   # purchase quantity
    d1 = x[3]   # spread according to price range
    c0 = x[4]   # desired down percent to adjust purchase price

    # Calculate old cost amount
    a0 = q0 * p0

    # Initialize loop variables
    i = 1000
    pct = 0
    pt = 0
    dt = 0
    p2 = 0

    # Loop until i becomes 0
    while i > 0:
        # Calculate simulated purchase price
        p1 = p0 - d1

        # Update old unit price for next iteration
        p0 = p1

        # Calculate new purchase amount
        a1 = q1 * p1

        # Calculate new total quantity and cost amount
        q2 = q0 + q1
        a2 = a0 + a1

        # Calculate new unit cost
        p2 = a2 / q2

        # Round simulated purchase price and spread according to price range
        pt = round(p2 * 100, 2)
        dt = d1 * 100

        # Debugging output
        print('before if', i, 'p1=' + str(round(p1, 2)), 'a1=' + str(round(a1, 2)), 'a2=' + str(round(a2, 2)), 'p2=' + str(round(p2, 2)))

        # Check if simulated purchase price is divisible by spread
        if (pt % dt) == 0:
            # Calculate percentage change in unit cost
            pct = ((p1 - old_unit_cost) / old_unit_cost) * 100

            # Debugging output
            print('in loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

            # Check if absolute value of percentage change is less than desired down percent
            if abs(pct) < c0:
                # Continue to next iteration if condition is met
                continue

            # Break loop if condition is not met
            break

        # Debugging output
        print('out loop', i, 'p2=' + str(round(p2, 2)), a2, 'p1=' + str(round(p1, 2)), 'pct=' + str(round(pct, 2)))

        # Decrement loop counter
        i -= 1

    # Return simulated purchase price, new unit cost, and percentage change in unit cost
    return print('p1=' + str(round(p1, 2)), 'p2=' + str(round(p2, 2)), 'pct=' + str(round(pct, 2)))

# %%
my_array = [[120_000,10.40,5000,.02,60]]
tmp = (np.apply_along_axis(number_of_spread, axis=1, arr=my_array))
tmp
# Out:
# before if 1000 p1=10.38 a1=51900.0 a2=571900.0 p2=10.4
# out loop 1000 p2=10.4 571900.0 p1=10.38 pct=0
# before if 999 p1=10.36 a1=51800.0 a2=571800.0 p2=10.4
# out loop 999 p2=10.4 571800.0 p1=10.36 pct=0
# before if 998 p1=10.34 a1=51700.0 a2=571700.0 p2=10.39
# out loop 998 p2=10.39 571700.0 p1=10.34 pct=0
# before if 997 p1=10.32 a1=51600.0 a2=571600.0 p2=10.39
# out loop 997 p2=10.39 571600.0 p1=10.32 pct=0
# before if 996 p1=10.3 a1=51500.0 a2=571500.0 p2=10.39
# out loop 996 p2=10.39 571500.0 p1=10.3 pct=0
# before if 995 p1=10.28 a1=51400.0 a2=571400.0 p2=10.39
# out loop 995 p2=10.39 571400.0 p1=10.28 pct=0
# before if 994 p1=10.26 a1=51300.0 a2=571300.0 p2=10.39
# out loop 994 p2=10.39 571300.0 p1=10.26 pct=0
# before if 993 p1=10.24 a1=51200.0 a2=571200.0 p2=10.39
# out loop 993 p2=10.39 571200.0 p1=10.24 pct=0
# before if 992 p1=10.22 a1=51100.0 a2=571100.0 p2=10.38
# out loop 992 p2=10.38 571100.0 p1=10.22 pct=0
# before if 991 p1=10.2 a1=51000.0 a2=571000.0 p2=10.38
# out loop 991 p2=10.38 571000.0 p1=10.2 pct=0
# before if 990 p1=10.18 a1=50900.0 a2=570900.0 p2=10.38
# in loop 990 p2=10.38 570900.0 p1=10.18 pct=-2.12
# before if 990 p1=10.16 a1=50800.0 a2=570800.0 p2=10.38
# out loop 990 p2=10.38 570800.0 p1=10.16 pct=-2.12
# before if 989 p1=10.14 a1=50700.0 a2=570700.0 p2=10.38
# out loop 989 p2=10.38 570700.0 p1=10.14 pct=-2.12
# before if 988 p1=10.12 a1=50600.0 a2=570600.0 p2=10.37
# out loop 988 p2=10.37 570600.0 p1=10.12 pct=-2.12
# before if 987 p1=10.1 a1=50500.0 a2=570500.0 p2=10.37
# out loop 987 p2=10.37 570500.0 p1=10.1 pct=-2.12
# before if 986 p1=10.08 a1=50400.0 a2=570400.0 p2=10.37
# out loop 986 p2=10.37 570400.0 p1=10.08 pct=-2.12
# before if 985 p1=10.06 a1=50300.0 a2=570300.0 p2=10.37
# out loop 985 p2=10.37 570300.0 p1=10.06 pct=-2.12
# before if 984 p1=10.04 a1=50200.0 a2=570200.0 p2=10.37
# out loop 984 p2=10.37 570200.0 p1=10.04 pct=-2.12
# before if 983 p1=10.02 a1=50100.0 a2=570100.0 p2=10.37
# out loop 983 p2=10.37 570100.0 p1=10.02 pct=-2.12
# before if 982 p1=10.0 a1=50000.0 a2=570000.0 p2=10.36
# out loop 982 p2=10.36 570000.0 p1=10.0 pct=-2.12
# before if 981 p1=9.98 a1=49900.0 a2=569900.0 p2=10.36
# out loop 981 p2=10.36 569900.0 p1=9.98 pct=-2.12
# before if 980 p1=9.96 a1=49800.0 a2=569800.0 p2=10.36
# in loop 980 p2=10.36 569800.0 p1=9.96 pct=-4.23
# before if 980 p1=9.94 a1=49700.0 a2=569700.0 p2=10.36
# out loop 980 p2=10.36 569700.0 p1=9.94 pct=-4.23
# before if 979 p1=9.92 a1=49600.0 a2=569600.0 p2=10.36
# out loop 979 p2=10.36 569600.0 p1=9.92 pct=-4.23
# before if 978 p1=9.9 a1=49500.0 a2=569500.0 p2=10.35
# out loop 978 p2=10.35 569500.0 p1=9.9 pct=-4.23
# before if 977 p1=9.88 a1=49400.0 a2=569400.0 p2=10.35
# out loop 977 p2=10.35 569400.0 p1=9.88 pct=-4.23
# before if 976 p1=9.86 a1=49300.0 a2=569300.0 p2=10.35
# out loop 976 p2=10.35 569300.0 p1=9.86 pct=-4.23
# before if 975 p1=9.84 a1=49200.0 a2=569200.0 p2=10.35
# out loop 975 p2=10.35 569200.0 p1=9.84 pct=-4.23
# before if 974 p1=9.82 a1=49100.0 a2=569100.0 p2=10.35
# out loop 974 p2=10.35 569100.0000000001 p1=9.82 pct=-4.23
# before if 973 p1=9.8 a1=49000.0 a2=569000.0 p2=10.35
# out loop 973 p2=10.35 569000.0000000001 p1=9.8 pct=-4.23
# before if 972 p1=9.78 a1=48900.0 a2=568900.0 p2=10.34
# out loop 972 p2=10.34 568900.0000000001 p1=9.78 pct=-4.23
# before if 971 p1=9.76 a1=48800.0 a2=568800.0 p2=10.34
# out loop 971 p2=10.34 568800.0000000001 p1=9.76 pct=-4.23
# before if 970 p1=9.74 a1=48700.0 a2=568700.0 p2=10.34
# in loop 970 p2=10.34 568700.0000000001 p1=9.74 pct=-6.35
# before if 970 p1=9.72 a1=48600.0 a2=568600.0 p2=10.34
# out loop 970 p2=10.34 568600.0000000001 p1=9.72 pct=-6.35
# before if 969 p1=9.7 a1=48500.0 a2=568500.0 p2=10.34
# out loop 969 p2=10.34 568500.0000000001 p1=9.7 pct=-6.35
# before if 968 p1=9.68 a1=48400.0 a2=568400.0 p2=10.33
# out loop 968 p2=10.33 568400.0000000001 p1=9.68 pct=-6.35
# before if 967 p1=9.66 a1=48300.0 a2=568300.0 p2=10.33
# out loop 967 p2=10.33 568300.0000000001 p1=9.66 pct=-6.35
# before if 966 p1=9.64 a1=48200.0 a2=568200.0 p2=10.33
# out loop 966 p2=10.33 568200.0000000001 p1=9.64 pct=-6.35
# before if 965 p1=9.62 a1=48100.0 a2=568100.0 p2=10.33
# out loop 965 p2=10.33 568100.0000000001 p1=9.62 pct=-6.35
# before if 964 p1=9.6 a1=48000.0 a2=568000.0 p2=10.33
# out loop 964 p2=10.33 568000.0000000001 p1=9.6 pct=-6.35
# before if 963 p1=9.58 a1=47900.0 a2=567900.0 p2=10.33
# out loop 963 p2=10.33 567900.0000000001 p1=9.58 pct=-6.35
# before if 962 p1=9.56 a1=47800.0 a2=567800.0 p2=10.32
# out loop 962 p2=10.32 567800.0000000001 p1=9.56 pct=-6.35
# before if 961 p1=9.54 a1=47700.0 a2=567700.0 p2=10.32
# out loop 961 p2=10.32 567700.0000000001 p1=9.54 pct=-6.35
# before if 960 p1=9.52 a1=47600.0 a2=567600.0 p2=10.32
# in loop 960 p2=10.32 567600.0000000001 p1=9.52 pct=-8.46
# before if 960 p1=9.5 a1=47500.0 a2=567500.0 p2=10.32
# out loop 960 p2=10.32 567500.0000000001 p1=9.5 pct=-8.46
# before if 959 p1=9.48 a1=47400.0 a2=567400.0 p2=10.32
# out loop 959 p2=10.32 567400.0000000001 p1=9.48 pct=-8.46
# before if 958 p1=9.46 a1=47300.0 a2=567300.0 p2=10.31
# out loop 958 p2=10.31 567300.0000000001 p1=9.46 pct=-8.46
# before if 957 p1=9.44 a1=47200.0 a2=567200.0 p2=10.31
# out loop 957 p2=10.31 567200.0000000001 p1=9.44 pct=-8.46
# before if 956 p1=9.42 a1=47100.0 a2=567100.0 p2=10.31
# out loop 956 p2=10.31 567100.0000000001 p1=9.42 pct=-8.46
# before if 955 p1=9.4 a1=47000.0 a2=567000.0 p2=10.31
# out loop 955 p2=10.31 567000.0000000001 p1=9.4 pct=-8.46
# before if 954 p1=9.38 a1=46900.0 a2=566900.0 p2=10.31
# out loop 954 p2=10.31 566900.0000000001 p1=9.38 pct=-8.46
# before if 953 p1=9.36 a1=46800.0 a2=566800.0 p2=10.31
# out loop 953 p2=10.31 566800.0000000001 p1=9.36 pct=-8.46
# before if 952 p1=9.34 a1=46700.0 a2=566700.0 p2=10.3
# out loop 952 p2=10.3 566700.0000000001 p1=9.34 pct=-8.46
# before if 951 p1=9.32 a1=46600.0 a2=566600.0 p2=10.3
# out loop 951 p2=10.3 566600.0000000001 p1=9.32 pct=-8.46
# before if 950 p1=9.3 a1=46500.0 a2=566500.0 p2=10.3
# in loop 950 p2=10.3 566500.0000000001 p1=9.3 pct=-10.58
# before if 950 p1=9.28 a1=46400.0 a2=566400.0 p2=10.3
# out loop 950 p2=10.3 566400.0000000001 p1=9.28 pct=-10.58
# before if 949 p1=9.26 a1=46300.0 a2=566300.0 p2=10.3
# out loop 949 p2=10.3 566300.0000000001 p1=9.26 pct=-10.58
# before if 948 p1=9.24 a1=46200.0 a2=566200.0 p2=10.29
# out loop 948 p2=10.29 566200.0000000001 p1=9.24 pct=-10.58
# before if 947 p1=9.22 a1=46100.0 a2=566100.0 p2=10.29
# out loop 947 p2=10.29 566100.0000000001 p1=9.22 pct=-10.58
# before if 946 p1=9.2 a1=46000.0 a2=566000.0 p2=10.29
# out loop 946 p2=10.29 566000.0000000001 p1=9.2 pct=-10.58
# before if 945 p1=9.18 a1=45900.0 a2=565900.0 p2=10.29
# out loop 945 p2=10.29 565900.0000000001 p1=9.18 pct=-10.58
# before if 944 p1=9.16 a1=45800.0 a2=565800.0 p2=10.29
# out loop 944 p2=10.29 565800.0000000001 p1=9.16 pct=-10.58
# before if 943 p1=9.14 a1=45700.0 a2=565700.0 p2=10.29
# out loop 943 p2=10.29 565700.0000000001 p1=9.14 pct=-10.58
# before if 942 p1=9.12 a1=45600.0 a2=565600.0 p2=10.28
# out loop 942 p2=10.28 565600.0000000001 p1=9.12 pct=-10.58
# before if 941 p1=9.1 a1=45500.0 a2=565500.0 p2=10.28
# out loop 941 p2=10.28 565500.0000000001 p1=9.1 pct=-10.58
# before if 940 p1=9.08 a1=45400.0 a2=565400.0 p2=10.28
# in loop 940 p2=10.28 565400.0000000001 p1=9.08 pct=-12.69
# before if 940 p1=9.06 a1=45300.0 a2=565300.0 p2=10.28
# out loop 940 p2=10.28 565300.0000000001 p1=9.06 pct=-12.69
# before if 939 p1=9.04 a1=45200.0 a2=565200.0 p2=10.28
# out loop 939 p2=10.28 565200.0000000001 p1=9.04 pct=-12.69
# before if 938 p1=9.02 a1=45100.0 a2=565100.0 p2=10.27
# out loop 938 p2=10.27 565100.0000000001 p1=9.02 pct=-12.69
# before if 937 p1=9.0 a1=45000.0 a2=565000.0 p2=10.27
# out loop 937 p2=10.27 565000.0000000001 p1=9.0 pct=-12.69
# before if 936 p1=8.98 a1=44900.0 a2=564900.0 p2=10.27
# out loop 936 p2=10.27 564900.0000000001 p1=8.98 pct=-12.69
# before if 935 p1=8.96 a1=44800.0 a2=564800.0 p2=10.27
# out loop 935 p2=10.27 564800.0000000001 p1=8.96 pct=-12.69
# before if 934 p1=8.94 a1=44700.0 a2=564700.0 p2=10.27
# out loop 934 p2=10.27 564700.0000000001 p1=8.94 pct=-12.69
# before if 933 p1=8.92 a1=44600.0 a2=564600.0 p2=10.27
# out loop 933 p2=10.27 564600.0000000001 p1=8.92 pct=-12.69
# before if 932 p1=8.9 a1=44500.0 a2=564500.0 p2=10.26
# out loop 932 p2=10.26 564500.0000000001 p1=8.9 pct=-12.69
# before if 931 p1=8.88 a1=44400.0 a2=564400.0 p2=10.26
# out loop 931 p2=10.26 564400.0000000001 p1=8.88 pct=-12.69
# before if 930 p1=8.86 a1=44300.0 a2=564300.0 p2=10.26
# in loop 930 p2=10.26 564300.0000000001 p1=8.86 pct=-14.81
# before if 930 p1=8.84 a1=44200.0 a2=564200.0 p2=10.26
# out loop 930 p2=10.26 564200.0000000001 p1=8.84 pct=-14.81
# before if 929 p1=8.82 a1=44100.0 a2=564100.0 p2=10.26
# out loop 929 p2=10.26 564100.0000000001 p1=8.82 pct=-14.81
# before if 928 p1=8.8 a1=44000.0 a2=564000.0 p2=10.25
# out loop 928 p2=10.25 564000.0000000002 p1=8.8 pct=-14.81
# before if 927 p1=8.78 a1=43900.0 a2=563900.0 p2=10.25
# out loop 927 p2=10.25 563900.0000000002 p1=8.78 pct=-14.81
# before if 926 p1=8.76 a1=43800.0 a2=563800.0 p2=10.25
# out loop 926 p2=10.25 563800.0000000002 p1=8.76 pct=-14.81
# before if 925 p1=8.74 a1=43700.0 a2=563700.0 p2=10.25
# out loop 925 p2=10.25 563700.0000000002 p1=8.74 pct=-14.81
# before if 924 p1=8.72 a1=43600.0 a2=563600.0 p2=10.25
# out loop 924 p2=10.25 563600.0000000002 p1=8.72 pct=-14.81
# before if 923 p1=8.7 a1=43500.0 a2=563500.0 p2=10.25
# out loop 923 p2=10.25 563500.0000000002 p1=8.7 pct=-14.81
# before if 922 p1=8.68 a1=43400.0 a2=563400.0 p2=10.24
# out loop 922 p2=10.24 563400.0000000002 p1=8.68 pct=-14.81
# before if 921 p1=8.66 a1=43300.0 a2=563300.0 p2=10.24
# out loop 921 p2=10.24 563300.0000000002 p1=8.66 pct=-14.81
# before if 920 p1=8.64 a1=43200.0 a2=563200.0 p2=10.24
# in loop 920 p2=10.24 563200.0000000002 p1=8.64 pct=-16.92
# before if 920 p1=8.62 a1=43100.0 a2=563100.0 p2=10.24
# out loop 920 p2=10.24 563100.0000000002 p1=8.62 pct=-16.92
# before if 919 p1=8.6 a1=43000.0 a2=563000.0 p2=10.24
# out loop 919 p2=10.24 563000.0000000002 p1=8.6 pct=-16.92
# before if 918 p1=8.58 a1=42900.0 a2=562900.0 p2=10.23
# out loop 918 p2=10.23 562900.0000000002 p1=8.58 pct=-16.92
# before if 917 p1=8.56 a1=42800.0 a2=562800.0 p2=10.23
# out loop 917 p2=10.23 562800.0000000002 p1=8.56 pct=-16.92
# before if 916 p1=8.54 a1=42700.0 a2=562700.0 p2=10.23
# out loop 916 p2=10.23 562700.0000000002 p1=8.54 pct=-16.92
# before if 915 p1=8.52 a1=42600.0 a2=562600.0 p2=10.23
# out loop 915 p2=10.23 562600.0000000002 p1=8.52 pct=-16.92
# before if 914 p1=8.5 a1=42500.0 a2=562500.0 p2=10.23
# out loop 914 p2=10.23 562500.0000000002 p1=8.5 pct=-16.92
# before if 913 p1=8.48 a1=42400.0 a2=562400.0 p2=10.23
# out loop 913 p2=10.23 562400.0000000002 p1=8.48 pct=-16.92
# before if 912 p1=8.46 a1=42300.0 a2=562300.0 p2=10.22
# out loop 912 p2=10.22 562300.0000000002 p1=8.46 pct=-16.92
# before if 911 p1=8.44 a1=42200.0 a2=562200.0 p2=10.22
# out loop 911 p2=10.22 562200.0000000002 p1=8.44 pct=-16.92
# before if 910 p1=8.42 a1=42100.0 a2=562100.0 p2=10.22
# in loop 910 p2=10.22 562100.0000000002 p1=8.42 pct=-19.04
# before if 910 p1=8.4 a1=42000.0 a2=562000.0 p2=10.22
# out loop 910 p2=10.22 562000.0000000002 p1=8.4 pct=-19.04
# before if 909 p1=8.38 a1=41900.0 a2=561900.0 p2=10.22
# out loop 909 p2=10.22 561900.0000000002 p1=8.38 pct=-19.04
# before if 908 p1=8.36 a1=41800.0 a2=561800.0 p2=10.21
# out loop 908 p2=10.21 561800.0000000002 p1=8.36 pct=-19.04
# before if 907 p1=8.34 a1=41700.0 a2=561700.0 p2=10.21
# out loop 907 p2=10.21 561700.0000000002 p1=8.34 pct=-19.04
# before if 906 p1=8.32 a1=41600.0 a2=561600.0 p2=10.21
# out loop 906 p2=10.21 561600.0000000002 p1=8.32 pct=-19.04
# before if 905 p1=8.3 a1=41500.0 a2=561500.0 p2=10.21
# out loop 905 p2=10.21 561500.0000000002 p1=8.3 pct=-19.04
# before if 904 p1=8.28 a1=41400.0 a2=561400.0 p2=10.21
# out loop 904 p2=10.21 561400.0000000002 p1=8.28 pct=-19.04
# before if 903 p1=8.26 a1=41300.0 a2=561300.0 p2=10.21
# out loop 903 p2=10.21 561300.0000000002 p1=8.26 pct=-19.04
# before if 902 p1=8.24 a1=41200.0 a2=561200.0 p2=10.2
# out loop 902 p2=10.2 561200.0000000002 p1=8.24 pct=-19.04
# before if 901 p1=8.22 a1=41100.0 a2=561100.0 p2=10.2
# out loop 901 p2=10.2 561100.0000000002 p1=8.22 pct=-19.04
# before if 900 p1=8.2 a1=41000.0 a2=561000.0 p2=10.2
# in loop 900 p2=10.2 561000.0000000002 p1=8.2 pct=-21.15
# before if 900 p1=8.18 a1=40900.0 a2=560900.0 p2=10.2
# out loop 900 p2=10.2 560900.0000000002 p1=8.18 pct=-21.15
# before if 899 p1=8.16 a1=40800.0 a2=560800.0 p2=10.2
# out loop 899 p2=10.2 560800.0000000002 p1=8.16 pct=-21.15
# before if 898 p1=8.14 a1=40700.0 a2=560700.0 p2=10.19
# out loop 898 p2=10.19 560700.0000000002 p1=8.14 pct=-21.15
# before if 897 p1=8.12 a1=40600.0 a2=560600.0 p2=10.19
# out loop 897 p2=10.19 560600.0000000002 p1=8.12 pct=-21.15
# before if 896 p1=8.1 a1=40500.0 a2=560500.0 p2=10.19
# out loop 896 p2=10.19 560500.0000000002 p1=8.1 pct=-21.15
# before if 895 p1=8.08 a1=40400.0 a2=560400.0 p2=10.19
# out loop 895 p2=10.19 560400.0000000002 p1=8.08 pct=-21.15
# before if 894 p1=8.06 a1=40300.0 a2=560300.0 p2=10.19
# out loop 894 p2=10.19 560300.0000000002 p1=8.06 pct=-21.15
# before if 893 p1=8.04 a1=40200.0 a2=560200.0 p2=10.19
# out loop 893 p2=10.19 560200.0000000002 p1=8.04 pct=-21.15
# before if 892 p1=8.02 a1=40100.0 a2=560100.0 p2=10.18
# out loop 892 p2=10.18 560100.0000000002 p1=8.02 pct=-21.15
# before if 891 p1=8.0 a1=40000.0 a2=560000.0 p2=10.18
# out loop 891 p2=10.18 560000.0000000002 p1=8.0 pct=-21.15
# before if 890 p1=7.98 a1=39900.0 a2=559900.0 p2=10.18
# in loop 890 p2=10.18 559900.0000000002 p1=7.98 pct=-23.27
# before if 890 p1=7.96 a1=39800.0 a2=559800.0 p2=10.18
# out loop 890 p2=10.18 559800.0000000002 p1=7.96 pct=-23.27
# before if 889 p1=7.94 a1=39700.0 a2=559700.0 p2=10.18
# out loop 889 p2=10.18 559700.0000000002 p1=7.94 pct=-23.27
# before if 888 p1=7.92 a1=39600.0 a2=559600.0 p2=10.17
# out loop 888 p2=10.17 559600.0000000002 p1=7.92 pct=-23.27
# before if 887 p1=7.9 a1=39500.0 a2=559500.0 p2=10.17
# out loop 887 p2=10.17 559500.0000000002 p1=7.9 pct=-23.27
# before if 886 p1=7.88 a1=39400.0 a2=559400.0 p2=10.17
# out loop 886 p2=10.17 559400.0000000002 p1=7.88 pct=-23.27
# before if 885 p1=7.86 a1=39300.0 a2=559300.0 p2=10.17
# out loop 885 p2=10.17 559300.0000000002 p1=7.86 pct=-23.27
# before if 884 p1=7.84 a1=39200.0 a2=559200.0 p2=10.17
# out loop 884 p2=10.17 559200.0000000002 p1=7.84 pct=-23.27
# before if 883 p1=7.82 a1=39100.0 a2=559100.0 p2=10.17
# out loop 883 p2=10.17 559100.0000000002 p1=7.82 pct=-23.27
# before if 882 p1=7.8 a1=39000.0 a2=559000.0 p2=10.16
# out loop 882 p2=10.16 559000.0000000002 p1=7.8 pct=-23.27
# before if 881 p1=7.78 a1=38900.0 a2=558900.0 p2=10.16
# out loop 881 p2=10.16 558900.0000000002 p1=7.78 pct=-23.27
# before if 880 p1=7.76 a1=38800.0 a2=558800.0 p2=10.16
# in loop 880 p2=10.16 558800.0000000002 p1=7.76 pct=-25.38
# before if 880 p1=7.74 a1=38700.0 a2=558700.0 p2=10.16
# out loop 880 p2=10.16 558700.0000000002 p1=7.74 pct=-25.38
# before if 879 p1=7.72 a1=38600.0 a2=558600.0 p2=10.16
# out loop 879 p2=10.16 558600.0000000002 p1=7.72 pct=-25.38
# before if 878 p1=7.7 a1=38500.0 a2=558500.0 p2=10.15
# out loop 878 p2=10.15 558500.0000000002 p1=7.7 pct=-25.38
# before if 877 p1=7.68 a1=38400.0 a2=558400.0 p2=10.15
# out loop 877 p2=10.15 558400.0000000002 p1=7.68 pct=-25.38
# before if 876 p1=7.66 a1=38300.0 a2=558300.0 p2=10.15
# out loop 876 p2=10.15 558300.0000000002 p1=7.66 pct=-25.38
# before if 875 p1=7.64 a1=38200.0 a2=558200.0 p2=10.15
# out loop 875 p2=10.15 558200.0000000003 p1=7.64 pct=-25.38
# before if 874 p1=7.62 a1=38100.0 a2=558100.0 p2=10.15
# out loop 874 p2=10.15 558100.0000000003 p1=7.62 pct=-25.38
# before if 873 p1=7.6 a1=38000.0 a2=558000.0 p2=10.15
# out loop 873 p2=10.15 558000.0000000003 p1=7.6 pct=-25.38
# before if 872 p1=7.58 a1=37900.0 a2=557900.0 p2=10.14
# out loop 872 p2=10.14 557900.0000000003 p1=7.58 pct=-25.38
# before if 871 p1=7.56 a1=37800.0 a2=557800.0 p2=10.14
# out loop 871 p2=10.14 557800.0000000003 p1=7.56 pct=-25.38
# before if 870 p1=7.54 a1=37700.0 a2=557700.0 p2=10.14
# in loop 870 p2=10.14 557700.0000000003 p1=7.54 pct=-27.5
# before if 870 p1=7.52 a1=37600.0 a2=557600.0 p2=10.14
# out loop 870 p2=10.14 557600.0000000003 p1=7.52 pct=-27.5
# before if 869 p1=7.5 a1=37500.0 a2=557500.0 p2=10.14
# out loop 869 p2=10.14 557500.0000000003 p1=7.5 pct=-27.5
# before if 868 p1=7.48 a1=37400.0 a2=557400.0 p2=10.13
# out loop 868 p2=10.13 557400.0000000003 p1=7.48 pct=-27.5
# before if 867 p1=7.46 a1=37300.0 a2=557300.0 p2=10.13
# out loop 867 p2=10.13 557300.0000000003 p1=7.46 pct=-27.5
# before if 866 p1=7.44 a1=37200.0 a2=557200.0 p2=10.13
# out loop 866 p2=10.13 557200.0000000003 p1=7.44 pct=-27.5
# before if 865 p1=7.42 a1=37100.0 a2=557100.0 p2=10.13
# out loop 865 p2=10.13 557100.0000000003 p1=7.42 pct=-27.5
# before if 864 p1=7.4 a1=37000.0 a2=557000.0 p2=10.13
# out loop 864 p2=10.13 557000.0000000003 p1=7.4 pct=-27.5
# before if 863 p1=7.38 a1=36900.0 a2=556900.0 p2=10.13
# out loop 863 p2=10.13 556900.0000000003 p1=7.38 pct=-27.5
# before if 862 p1=7.36 a1=36800.0 a2=556800.0 p2=10.12
# out loop 862 p2=10.12 556800.0000000003 p1=7.36 pct=-27.5
# before if 861 p1=7.34 a1=36700.0 a2=556700.0 p2=10.12
# out loop 861 p2=10.12 556700.0000000003 p1=7.34 pct=-27.5
# before if 860 p1=7.32 a1=36600.0 a2=556600.0 p2=10.12
# in loop 860 p2=10.12 556600.0000000003 p1=7.32 pct=-29.62
# before if 860 p1=7.3 a1=36500.0 a2=556500.0 p2=10.12
# out loop 860 p2=10.12 556500.0000000003 p1=7.3 pct=-29.62
# before if 859 p1=7.28 a1=36400.0 a2=556400.0 p2=10.12
# out loop 859 p2=10.12 556400.0000000003 p1=7.28 pct=-29.62
# before if 858 p1=7.26 a1=36300.0 a2=556300.0 p2=10.11
# out loop 858 p2=10.11 556300.0000000003 p1=7.26 pct=-29.62
# before if 857 p1=7.24 a1=36200.0 a2=556200.0 p2=10.11
# out loop 857 p2=10.11 556200.0000000003 p1=7.24 pct=-29.62
# before if 856 p1=7.22 a1=36100.0 a2=556100.0 p2=10.11
# out loop 856 p2=10.11 556100.0000000003 p1=7.22 pct=-29.62
# before if 855 p1=7.2 a1=36000.0 a2=556000.0 p2=10.11
# out loop 855 p2=10.11 556000.0000000003 p1=7.2 pct=-29.62
# before if 854 p1=7.18 a1=35900.0 a2=555900.0 p2=10.11
# out loop 854 p2=10.11 555900.0000000003 p1=7.18 pct=-29.62
# before if 853 p1=7.16 a1=35800.0 a2=555800.0 p2=10.11
# out loop 853 p2=10.11 555800.0000000003 p1=7.16 pct=-29.62
# before if 852 p1=7.14 a1=35700.0 a2=555700.0 p2=10.1
# out loop 852 p2=10.1 555700.0000000003 p1=7.14 pct=-29.62
# before if 851 p1=7.12 a1=35600.0 a2=555600.0 p2=10.1
# out loop 851 p2=10.1 555600.0000000003 p1=7.12 pct=-29.62
# before if 850 p1=7.1 a1=35500.0 a2=555500.0 p2=10.1
# in loop 850 p2=10.1 555500.0000000003 p1=7.1 pct=-31.73
# before if 850 p1=7.08 a1=35400.0 a2=555400.0 p2=10.1
# out loop 850 p2=10.1 555400.0000000003 p1=7.08 pct=-31.73
# before if 849 p1=7.06 a1=35300.0 a2=555300.0 p2=10.1
# out loop 849 p2=10.1 555300.0000000003 p1=7.06 pct=-31.73
# before if 848 p1=7.04 a1=35200.0 a2=555200.0 p2=10.09
# out loop 848 p2=10.09 555200.0000000003 p1=7.04 pct=-31.73
# before if 847 p1=7.02 a1=35100.0 a2=555100.0 p2=10.09
# out loop 847 p2=10.09 555100.0000000003 p1=7.02 pct=-31.73
# before if 846 p1=7.0 a1=35000.0 a2=555000.0 p2=10.09
# out loop 846 p2=10.09 555000.0000000003 p1=7.0 pct=-31.73
# before if 845 p1=6.98 a1=34900.0 a2=554900.0 p2=10.09
# out loop 845 p2=10.09 554900.0000000003 p1=6.98 pct=-31.73
# before if 844 p1=6.96 a1=34800.0 a2=554800.0 p2=10.09
# out loop 844 p2=10.09 554800.0000000003 p1=6.96 pct=-31.73
# before if 843 p1=6.94 a1=34700.0 a2=554700.0 p2=10.09
# out loop 843 p2=10.09 554700.0000000003 p1=6.94 pct=-31.73
# before if 842 p1=6.92 a1=34600.0 a2=554600.0 p2=10.08
# out loop 842 p2=10.08 554600.0000000003 p1=6.92 pct=-31.73
# before if 841 p1=6.9 a1=34500.0 a2=554500.0 p2=10.08
# out loop 841 p2=10.08 554500.0000000003 p1=6.9 pct=-31.73
# before if 840 p1=6.88 a1=34400.0 a2=554400.0 p2=10.08
# in loop 840 p2=10.08 554400.0000000003 p1=6.88 pct=-33.85
# before if 840 p1=6.86 a1=34300.0 a2=554300.0 p2=10.08
# out loop 840 p2=10.08 554300.0000000003 p1=6.86 pct=-33.85
# before if 839 p1=6.84 a1=34200.0 a2=554200.0 p2=10.08
# out loop 839 p2=10.08 554200.0000000003 p1=6.84 pct=-33.85
# before if 838 p1=6.82 a1=34100.0 a2=554100.0 p2=10.07
# out loop 838 p2=10.07 554100.0000000003 p1=6.82 pct=-33.85
# before if 837 p1=6.8 a1=34000.0 a2=554000.0 p2=10.07
# out loop 837 p2=10.07 554000.0000000003 p1=6.8 pct=-33.85
# before if 836 p1=6.78 a1=33900.0 a2=553900.0 p2=10.07
# out loop 836 p2=10.07 553900.0000000003 p1=6.78 pct=-33.85
# before if 835 p1=6.76 a1=33800.0 a2=553800.0 p2=10.07
# out loop 835 p2=10.07 553800.0000000003 p1=6.76 pct=-33.85
# before if 834 p1=6.74 a1=33700.0 a2=553700.0 p2=10.07
# out loop 834 p2=10.07 553700.0000000003 p1=6.74 pct=-33.85
# before if 833 p1=6.72 a1=33600.0 a2=553600.0 p2=10.07
# out loop 833 p2=10.07 553600.0000000003 p1=6.72 pct=-33.85
# before if 832 p1=6.7 a1=33500.0 a2=553500.0 p2=10.06
# out loop 832 p2=10.06 553500.0000000003 p1=6.7 pct=-33.85
# before if 831 p1=6.68 a1=33400.0 a2=553400.0 p2=10.06
# out loop 831 p2=10.06 553400.0000000003 p1=6.68 pct=-33.85
# before if 830 p1=6.66 a1=33300.0 a2=553300.0 p2=10.06
# in loop 830 p2=10.06 553300.0000000003 p1=6.66 pct=-35.96
# before if 830 p1=6.64 a1=33200.0 a2=553200.0 p2=10.06
# out loop 830 p2=10.06 553200.0000000003 p1=6.64 pct=-35.96
# before if 829 p1=6.62 a1=33100.0 a2=553100.0 p2=10.06
# out loop 829 p2=10.06 553100.0000000005 p1=6.62 pct=-35.96
# before if 828 p1=6.6 a1=33000.0 a2=553000.0 p2=10.05
# out loop 828 p2=10.05 553000.0000000005 p1=6.6 pct=-35.96
# before if 827 p1=6.58 a1=32900.0 a2=552900.0 p2=10.05
# out loop 827 p2=10.05 552900.0000000005 p1=6.58 pct=-35.96
# before if 826 p1=6.56 a1=32800.0 a2=552800.0 p2=10.05
# out loop 826 p2=10.05 552800.0000000005 p1=6.56 pct=-35.96
# before if 825 p1=6.54 a1=32700.0 a2=552700.0 p2=10.05
# out loop 825 p2=10.05 552700.0000000005 p1=6.54 pct=-35.96
# before if 824 p1=6.52 a1=32600.0 a2=552600.0 p2=10.05
# out loop 824 p2=10.05 552600.0000000005 p1=6.52 pct=-35.96
# before if 823 p1=6.5 a1=32500.0 a2=552500.0 p2=10.05
# out loop 823 p2=10.05 552500.0000000005 p1=6.5 pct=-35.96
# before if 822 p1=6.48 a1=32400.0 a2=552400.0 p2=10.04
# out loop 822 p2=10.04 552400.0000000005 p1=6.48 pct=-35.96
# before if 821 p1=6.46 a1=32300.0 a2=552300.0 p2=10.04
# out loop 821 p2=10.04 552300.0000000005 p1=6.46 pct=-35.96
# before if 820 p1=6.44 a1=32200.0 a2=552200.0 p2=10.04
# in loop 820 p2=10.04 552200.0000000005 p1=6.44 pct=-38.08
# before if 820 p1=6.42 a1=32100.0 a2=552100.0 p2=10.04
# out loop 820 p2=10.04 552100.0000000005 p1=6.42 pct=-38.08
# before if 819 p1=6.4 a1=32000.0 a2=552000.0 p2=10.04
# out loop 819 p2=10.04 552000.0000000005 p1=6.4 pct=-38.08
# before if 818 p1=6.38 a1=31900.0 a2=551900.0 p2=10.03
# out loop 818 p2=10.03 551900.0000000005 p1=6.38 pct=-38.08
# before if 817 p1=6.36 a1=31800.0 a2=551800.0 p2=10.03
# out loop 817 p2=10.03 551800.0000000005 p1=6.36 pct=-38.08
# before if 816 p1=6.34 a1=31700.0 a2=551700.0 p2=10.03
# out loop 816 p2=10.03 551700.0000000005 p1=6.34 pct=-38.08
# before if 815 p1=6.32 a1=31600.0 a2=551600.0 p2=10.03
# out loop 815 p2=10.03 551600.0000000005 p1=6.32 pct=-38.08
# before if 814 p1=6.3 a1=31500.0 a2=551500.0 p2=10.03
# out loop 814 p2=10.03 551500.0000000005 p1=6.3 pct=-38.08
# before if 813 p1=6.28 a1=31400.0 a2=551400.0 p2=10.03
# out loop 813 p2=10.03 551400.0000000005 p1=6.28 pct=-38.08
# before if 812 p1=6.26 a1=31300.0 a2=551300.0 p2=10.02
# out loop 812 p2=10.02 551300.0000000005 p1=6.26 pct=-38.08
# before if 811 p1=6.24 a1=31200.0 a2=551200.0 p2=10.02
# out loop 811 p2=10.02 551200.0000000005 p1=6.24 pct=-38.08
# before if 810 p1=6.22 a1=31100.0 a2=551100.0 p2=10.02
# in loop 810 p2=10.02 551100.0000000005 p1=6.22 pct=-40.19
# before if 810 p1=6.2 a1=31000.0 a2=551000.0 p2=10.02
# out loop 810 p2=10.02 551000.0000000005 p1=6.2 pct=-40.19
# before if 809 p1=6.18 a1=30900.0 a2=550900.0 p2=10.02
# out loop 809 p2=10.02 550900.0000000005 p1=6.18 pct=-40.19
# before if 808 p1=6.16 a1=30800.0 a2=550800.0 p2=10.01
# out loop 808 p2=10.01 550800.0000000005 p1=6.16 pct=-40.19
# before if 807 p1=6.14 a1=30700.0 a2=550700.0 p2=10.01
# out loop 807 p2=10.01 550700.0000000005 p1=6.14 pct=-40.19
# before if 806 p1=6.12 a1=30600.0 a2=550600.0 p2=10.01
# out loop 806 p2=10.01 550600.0000000005 p1=6.12 pct=-40.19
# before if 805 p1=6.1 a1=30500.0 a2=550500.0 p2=10.01
# out loop 805 p2=10.01 550500.0000000005 p1=6.1 pct=-40.19
# before if 804 p1=6.08 a1=30400.0 a2=550400.0 p2=10.01
# out loop 804 p2=10.01 550400.0000000005 p1=6.08 pct=-40.19
# before if 803 p1=6.06 a1=30300.0 a2=550300.0 p2=10.01
# out loop 803 p2=10.01 550300.0000000005 p1=6.06 pct=-40.19
# before if 802 p1=6.04 a1=30200.0 a2=550200.0 p2=10.0
# out loop 802 p2=10.0 550200.0000000005 p1=6.04 pct=-40.19
# before if 801 p1=6.02 a1=30100.0 a2=550100.0 p2=10.0
# out loop 801 p2=10.0 550100.0000000005 p1=6.02 pct=-40.19
# before if 800 p1=6.0 a1=30000.0 a2=550000.0 p2=10.0
# in loop 800 p2=10.0 550000.0000000005 p1=6.0 pct=-42.31
# before if 800 p1=5.98 a1=29900.0 a2=549900.0 p2=10.0
# out loop 800 p2=10.0 549900.0000000005 p1=5.98 pct=-42.31
# before if 799 p1=5.96 a1=29800.0 a2=549800.0 p2=10.0
# out loop 799 p2=10.0 549800.0000000005 p1=5.96 pct=-42.31
# before if 798 p1=5.94 a1=29700.0 a2=549700.0 p2=9.99
# out loop 798 p2=9.99 549700.0000000005 p1=5.94 pct=-42.31
# before if 797 p1=5.92 a1=29600.0 a2=549600.0 p2=9.99
# out loop 797 p2=9.99 549600.0000000005 p1=5.92 pct=-42.31
# before if 796 p1=5.9 a1=29500.0 a2=549500.0 p2=9.99
# out loop 796 p2=9.99 549500.0000000005 p1=5.9 pct=-42.31
# before if 795 p1=5.88 a1=29400.0 a2=549400.0 p2=9.99
# out loop 795 p2=9.99 549400.0000000005 p1=5.88 pct=-42.31
# before if 794 p1=5.86 a1=29300.0 a2=549300.0 p2=9.99
# out loop 794 p2=9.99 549300.0000000005 p1=5.86 pct=-42.31
# before if 793 p1=5.84 a1=29200.0 a2=549200.0 p2=9.99
# out loop 793 p2=9.99 549200.0000000005 p1=5.84 pct=-42.31
# before if 792 p1=5.82 a1=29100.0 a2=549100.0 p2=9.98
# out loop 792 p2=9.98 549100.0000000005 p1=5.82 pct=-42.31
# before if 791 p1=5.8 a1=29000.0 a2=549000.0 p2=9.98
# out loop 791 p2=9.98 549000.0000000005 p1=5.8 pct=-42.31
# before if 790 p1=5.78 a1=28900.0 a2=548900.0 p2=9.98
# in loop 790 p2=9.98 548900.0000000005 p1=5.78 pct=-44.42
# before if 790 p1=5.76 a1=28800.0 a2=548800.0 p2=9.98
# out loop 790 p2=9.98 548800.0000000005 p1=5.76 pct=-44.42
# before if 789 p1=5.74 a1=28700.0 a2=548700.0 p2=9.98
# out loop 789 p2=9.98 548700.0000000005 p1=5.74 pct=-44.42
# before if 788 p1=5.72 a1=28600.0 a2=548600.0 p2=9.97
# out loop 788 p2=9.97 548600.0000000005 p1=5.72 pct=-44.42
# before if 787 p1=5.7 a1=28500.0 a2=548500.0 p2=9.97
# out loop 787 p2=9.97 548500.0000000005 p1=5.7 pct=-44.42
# before if 786 p1=5.68 a1=28400.0 a2=548400.0 p2=9.97
# out loop 786 p2=9.97 548400.0000000005 p1=5.68 pct=-44.42
# before if 785 p1=5.66 a1=28300.0 a2=548300.0 p2=9.97
# out loop 785 p2=9.97 548300.0000000005 p1=5.66 pct=-44.42
# before if 784 p1=5.64 a1=28200.0 a2=548200.0 p2=9.97
# out loop 784 p2=9.97 548200.0000000005 p1=5.64 pct=-44.42
# before if 783 p1=5.62 a1=28100.0 a2=548100.0 p2=9.97
# out loop 783 p2=9.97 548100.0000000005 p1=5.62 pct=-44.42
# before if 782 p1=5.6 a1=28000.0 a2=548000.0 p2=9.96
# out loop 782 p2=9.96 548000.0000000005 p1=5.6 pct=-44.42
# before if 781 p1=5.58 a1=27900.0 a2=547900.0 p2=9.96
# out loop 781 p2=9.96 547900.0000000005 p1=5.58 pct=-44.42
# before if 780 p1=5.56 a1=27800.0 a2=547800.0 p2=9.96
# in loop 780 p2=9.96 547800.0000000005 p1=5.56 pct=-46.54
# before if 780 p1=5.54 a1=27700.0 a2=547700.0 p2=9.96
# out loop 780 p2=9.96 547700.0000000005 p1=5.54 pct=-46.54
# before if 779 p1=5.52 a1=27600.0 a2=547600.0 p2=9.96
# out loop 779 p2=9.96 547600.0000000005 p1=5.52 pct=-46.54
# before if 778 p1=5.5 a1=27500.0 a2=547500.0 p2=9.95
# out loop 778 p2=9.95 547500.0000000005 p1=5.5 pct=-46.54
# before if 777 p1=5.48 a1=27400.0 a2=547400.0 p2=9.95
# out loop 777 p2=9.95 547400.0000000006 p1=5.48 pct=-46.54
# before if 776 p1=5.46 a1=27300.0 a2=547300.0 p2=9.95
# out loop 776 p2=9.95 547300.0000000006 p1=5.46 pct=-46.54
# before if 775 p1=5.44 a1=27200.0 a2=547200.0 p2=9.95
# out loop 775 p2=9.95 547200.0000000006 p1=5.44 pct=-46.54
# before if 774 p1=5.42 a1=27100.0 a2=547100.0 p2=9.95
# out loop 774 p2=9.95 547100.0000000006 p1=5.42 pct=-46.54
# before if 773 p1=5.4 a1=27000.0 a2=547000.0 p2=9.95
# out loop 773 p2=9.95 547000.0000000006 p1=5.4 pct=-46.54
# before if 772 p1=5.38 a1=26900.0 a2=546900.0 p2=9.94
# out loop 772 p2=9.94 546900.0000000006 p1=5.38 pct=-46.54
# before if 771 p1=5.36 a1=26800.0 a2=546800.0 p2=9.94
# out loop 771 p2=9.94 546800.0000000006 p1=5.36 pct=-46.54
# before if 770 p1=5.34 a1=26700.0 a2=546700.0 p2=9.94
# in loop 770 p2=9.94 546700.0000000006 p1=5.34 pct=-48.65
# before if 770 p1=5.32 a1=26600.0 a2=546600.0 p2=9.94
# out loop 770 p2=9.94 546600.0000000006 p1=5.32 pct=-48.65
# before if 769 p1=5.3 a1=26500.0 a2=546500.0 p2=9.94
# out loop 769 p2=9.94 546500.0000000006 p1=5.3 pct=-48.65
# before if 768 p1=5.28 a1=26400.0 a2=546400.0 p2=9.93
# out loop 768 p2=9.93 546400.0000000006 p1=5.28 pct=-48.65
# before if 767 p1=5.26 a1=26300.0 a2=546300.0 p2=9.93
# out loop 767 p2=9.93 546300.0000000006 p1=5.26 pct=-48.65
# before if 766 p1=5.24 a1=26200.0 a2=546200.0 p2=9.93
# out loop 766 p2=9.93 546200.0000000006 p1=5.24 pct=-48.65
# before if 765 p1=5.22 a1=26100.0 a2=546100.0 p2=9.93
# out loop 765 p2=9.93 546100.0000000006 p1=5.22 pct=-48.65
# before if 764 p1=5.2 a1=26000.0 a2=546000.0 p2=9.93
# out loop 764 p2=9.93 546000.0000000006 p1=5.2 pct=-48.65
# before if 763 p1=5.18 a1=25900.0 a2=545900.0 p2=9.93
# out loop 763 p2=9.93 545900.0000000006 p1=5.18 pct=-48.65
# before if 762 p1=5.16 a1=25800.0 a2=545800.0 p2=9.92
# out loop 762 p2=9.92 545800.0000000006 p1=5.16 pct=-48.65
# before if 761 p1=5.14 a1=25700.0 a2=545700.0 p2=9.92
# out loop 761 p2=9.92 545700.0000000006 p1=5.14 pct=-48.65
# before if 760 p1=5.12 a1=25600.0 a2=545600.0 p2=9.92
# in loop 760 p2=9.92 545600.0000000006 p1=5.12 pct=-50.77
# before if 760 p1=5.1 a1=25500.0 a2=545500.0 p2=9.92
# out loop 760 p2=9.92 545500.0000000006 p1=5.1 pct=-50.77
# before if 759 p1=5.08 a1=25400.0 a2=545400.0 p2=9.92
# out loop 759 p2=9.92 545400.0000000006 p1=5.08 pct=-50.77
# before if 758 p1=5.06 a1=25300.0 a2=545300.0 p2=9.91
# out loop 758 p2=9.91 545300.0000000006 p1=5.06 pct=-50.77
# before if 757 p1=5.04 a1=25200.0 a2=545200.0 p2=9.91
# out loop 757 p2=9.91 545200.0000000006 p1=5.04 pct=-50.77
# before if 756 p1=5.02 a1=25100.0 a2=545100.0 p2=9.91
# out loop 756 p2=9.91 545100.0000000006 p1=5.02 pct=-50.77
# before if 755 p1=5.0 a1=25000.0 a2=545000.0 p2=9.91
# out loop 755 p2=9.91 545000.0000000006 p1=5.0 pct=-50.77
# before if 754 p1=4.98 a1=24900.0 a2=544900.0 p2=9.91
# out loop 754 p2=9.91 544900.0000000006 p1=4.98 pct=-50.77
# before if 753 p1=4.96 a1=24800.0 a2=544800.0 p2=9.91
# out loop 753 p2=9.91 544800.0000000006 p1=4.96 pct=-50.77
# before if 752 p1=4.94 a1=24700.0 a2=544700.0 p2=9.9
# out loop 752 p2=9.9 544700.0000000006 p1=4.94 pct=-50.77
# before if 751 p1=4.92 a1=24600.0 a2=544600.0 p2=9.9
# out loop 751 p2=9.9 544600.0000000006 p1=4.92 pct=-50.77
# before if 750 p1=4.9 a1=24500.0 a2=544500.0 p2=9.9
# in loop 750 p2=9.9 544500.0000000006 p1=4.9 pct=-52.88
# before if 750 p1=4.88 a1=24400.0 a2=544400.0 p2=9.9
# out loop 750 p2=9.9 544400.0000000006 p1=4.88 pct=-52.88
# before if 749 p1=4.86 a1=24300.0 a2=544300.0 p2=9.9
# out loop 749 p2=9.9 544300.0000000006 p1=4.86 pct=-52.88
# before if 748 p1=4.84 a1=24200.0 a2=544200.0 p2=9.89
# out loop 748 p2=9.89 544200.0000000006 p1=4.84 pct=-52.88
# before if 747 p1=4.82 a1=24100.0 a2=544100.0 p2=9.89
# out loop 747 p2=9.89 544100.0000000006 p1=4.82 pct=-52.88
# before if 746 p1=4.8 a1=24000.0 a2=544000.0 p2=9.89
# out loop 746 p2=9.89 544000.0000000006 p1=4.8 pct=-52.88
# before if 745 p1=4.78 a1=23900.0 a2=543900.0 p2=9.89
# out loop 745 p2=9.89 543900.0000000006 p1=4.78 pct=-52.88
# before if 744 p1=4.76 a1=23800.0 a2=543800.0 p2=9.89
# out loop 744 p2=9.89 543800.0000000006 p1=4.76 pct=-52.88
# before if 743 p1=4.74 a1=23700.0 a2=543700.0 p2=9.89
# out loop 743 p2=9.89 543700.0000000006 p1=4.74 pct=-52.88
# before if 742 p1=4.72 a1=23600.0 a2=543600.0 p2=9.88
# out loop 742 p2=9.88 543600.0000000006 p1=4.72 pct=-52.88
# before if 741 p1=4.7 a1=23500.0 a2=543500.0 p2=9.88
# out loop 741 p2=9.88 543500.0000000006 p1=4.7 pct=-52.88
# before if 740 p1=4.68 a1=23400.0 a2=543400.0 p2=9.88
# in loop 740 p2=9.88 543400.0000000006 p1=4.68 pct=-55.0
# before if 740 p1=4.66 a1=23300.0 a2=543300.0 p2=9.88
# out loop 740 p2=9.88 543300.0000000006 p1=4.66 pct=-55.0
# before if 739 p1=4.64 a1=23200.0 a2=543200.0 p2=9.88
# out loop 739 p2=9.88 543200.0000000006 p1=4.64 pct=-55.0
# before if 738 p1=4.62 a1=23100.0 a2=543100.0 p2=9.87
# out loop 738 p2=9.87 543100.0000000006 p1=4.62 pct=-55.0
# before if 737 p1=4.6 a1=23000.0 a2=543000.0 p2=9.87
# out loop 737 p2=9.87 543000.0000000006 p1=4.6 pct=-55.0
# before if 736 p1=4.58 a1=22900.0 a2=542900.0 p2=9.87
# out loop 736 p2=9.87 542900.0000000006 p1=4.58 pct=-55.0
# before if 735 p1=4.56 a1=22800.0 a2=542800.0 p2=9.87
# out loop 735 p2=9.87 542800.0000000006 p1=4.56 pct=-55.0
# before if 734 p1=4.54 a1=22700.0 a2=542700.0 p2=9.87
# out loop 734 p2=9.87 542700.0000000006 p1=4.54 pct=-55.0
# before if 733 p1=4.52 a1=22600.0 a2=542600.0 p2=9.87
# out loop 733 p2=9.87 542600.0000000006 p1=4.52 pct=-55.0
# before if 732 p1=4.5 a1=22500.0 a2=542500.0 p2=9.86
# out loop 732 p2=9.86 542500.0000000006 p1=4.5 pct=-55.0
# before if 731 p1=4.48 a1=22400.0 a2=542400.0 p2=9.86
# out loop 731 p2=9.86 542400.0000000006 p1=4.48 pct=-55.0
# before if 730 p1=4.46 a1=22300.0 a2=542300.0 p2=9.86
# in loop 730 p2=9.86 542300.0000000006 p1=4.46 pct=-57.12
# before if 730 p1=4.44 a1=22200.0 a2=542200.0 p2=9.86
# out loop 730 p2=9.86 542200.0000000006 p1=4.44 pct=-57.12
# before if 729 p1=4.42 a1=22100.0 a2=542100.0 p2=9.86
# out loop 729 p2=9.86 542100.0000000007 p1=4.42 pct=-57.12
# before if 728 p1=4.4 a1=22000.0 a2=542000.0 p2=9.85
# out loop 728 p2=9.85 542000.0000000007 p1=4.4 pct=-57.12
# before if 727 p1=4.38 a1=21900.0 a2=541900.0 p2=9.85
# out loop 727 p2=9.85 541900.0000000007 p1=4.38 pct=-57.12
# before if 726 p1=4.36 a1=21800.0 a2=541800.0 p2=9.85
# out loop 726 p2=9.85 541800.0000000007 p1=4.36 pct=-57.12
# before if 725 p1=4.34 a1=21700.0 a2=541700.0 p2=9.85
# out loop 725 p2=9.85 541700.0000000007 p1=4.34 pct=-57.12
# before if 724 p1=4.32 a1=21600.0 a2=541600.0 p2=9.85
# out loop 724 p2=9.85 541600.0000000007 p1=4.32 pct=-57.12
# before if 723 p1=4.3 a1=21500.0 a2=541500.0 p2=9.85
# out loop 723 p2=9.85 541500.0000000007 p1=4.3 pct=-57.12
# before if 722 p1=4.28 a1=21400.0 a2=541400.0 p2=9.84
# out loop 722 p2=9.84 541400.0000000007 p1=4.28 pct=-57.12
# before if 721 p1=4.26 a1=21300.0 a2=541300.0 p2=9.84
# out loop 721 p2=9.84 541300.0000000007 p1=4.26 pct=-57.12
# before if 720 p1=4.24 a1=21200.0 a2=541200.0 p2=9.84
# in loop 720 p2=9.84 541200.0000000007 p1=4.24 pct=-59.23
# before if 720 p1=4.22 a1=21100.0 a2=541100.0 p2=9.84
# out loop 720 p2=9.84 541100.0000000007 p1=4.22 pct=-59.23
# before if 719 p1=4.2 a1=21000.0 a2=541000.0 p2=9.84
# out loop 719 p2=9.84 541000.0000000007 p1=4.2 pct=-59.23
# before if 718 p1=4.18 a1=20900.0 a2=540900.0 p2=9.83
# out loop 718 p2=9.83 540900.0000000007 p1=4.18 pct=-59.23
# before if 717 p1=4.16 a1=20800.0 a2=540800.0 p2=9.83
# out loop 717 p2=9.83 540800.0000000007 p1=4.16 pct=-59.23
# before if 716 p1=4.14 a1=20700.0 a2=540700.0 p2=9.83
# out loop 716 p2=9.83 540700.0000000007 p1=4.14 pct=-59.23
# before if 715 p1=4.12 a1=20600.0 a2=540600.0 p2=9.83
# out loop 715 p2=9.83 540600.0000000007 p1=4.12 pct=-59.23
# before if 714 p1=4.1 a1=20500.0 a2=540500.0 p2=9.83
# out loop 714 p2=9.83 540500.0000000007 p1=4.1 pct=-59.23
# before if 713 p1=4.08 a1=20400.0 a2=540400.0 p2=9.83
# out loop 713 p2=9.83 540400.0000000007 p1=4.08 pct=-59.23
# before if 712 p1=4.06 a1=20300.0 a2=540300.0 p2=9.82
# out loop 712 p2=9.82 540300.0000000007 p1=4.06 pct=-59.23
# before if 711 p1=4.04 a1=20200.0 a2=540200.0 p2=9.82
# out loop 711 p2=9.82 540200.0000000007 p1=4.04 pct=-59.23
# before if 710 p1=4.02 a1=20100.0 a2=540100.0 p2=9.82
# in loop 710 p2=9.82 540100.0000000007 p1=4.02 pct=-61.35
# p1=4.02 p2=9.82 pct=-61.35
# array([None], dtype=object)

# %% [markdown]
# #####
