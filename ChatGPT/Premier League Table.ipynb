# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

# %%
url = 'https://www.bbc.com/sport/football/tables'
r = requests.get(url)
html = r.text
#html

# %%
soup = BeautifulSoup(html, 'html.parser')
#soup

# %%
table = soup.find('table')
df = pd.read_html(str(table))[0]
df
# Out:
#     Position                     Team  Played  Won  Drawn  Lost  Goals For  \
# 0          1          Manchester City      38   28      7     3         96
# 1          2                  Arsenal      38   28      5     5         91
# 2          3                Liverpool      38   24     10     4         86
# 3          4              Aston Villa      38   20      8    10         76
# 4          5        Tottenham Hotspur      38   20      6    12         74
# 5          6                  Chelsea      38   18      9    11         77
# 6          7         Newcastle United      38   18      6    14         85
# 7          8        Manchester United      38   18      6    14         57
# 8          9          West Ham United      38   14     10    14         60
# 9         10           Crystal Palace      38   13     10    15         57
# 10        11   Brighton & Hove Albion      38   12     12    14         55
# ...

# %%
#print(df.head())

# %%
df.columns
# Out:
# Index(['Position', 'Team', 'Played', 'Won', 'Drawn', 'Lost', 'Goals For',
#        'Goals Against', 'Goal Difference', 'Points',
#        'Form, Last 6 games, Oldest first'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 1','Form'],inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.drop(columns=['Unnamed: 0','Unnamed: 1','Form'],inplace=True)
#       2 df
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
# ...

# %%
df.drop([20],inplace=True)
df

# %%
file_name = 'Premier-League.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
osd_file = osd_path + file_name
one_file = one_path + file_name

df.sort_values(['Pts'],ascending=[False]).to_csv(output_file, index=False)
df.sort_values(['Pts'],ascending=[False]).to_csv(data_file, index=False)
df.sort_values(['Pts'],ascending=[False]).to_csv(osd_file, index=False)
df.sort_values(['Pts'],ascending=[False]).to_csv(one_file, index=False)
